# %%
import arcpy
from arcpy import env
import pandas as pd
import numpy as np
import os

# %%
# 数组整形
def resize_arrays(A, B, fill_value=0):
    """调整数组形状一致"""
    new_shape = (max(A.shape[0], B.shape[0]), max(A.shape[1], B.shape[1]))

    if A.shape != new_shape:
        if A.shape[0] < new_shape[0]:
            padding_rows = new_shape[0] - A.shape[0]
            padding = np.full((padding_rows, A.shape[1]), fill_value)
            A = np.vstack((A, padding))
        elif A.shape[0] > new_shape[0]:
            A = A[:new_shape[0], :]

        if A.shape[1] < new_shape[1]:
            pad_width = ((0, 0), (0, new_shape[1] - A.shape[1]))
            A = np.pad(A, pad_width, mode='constant', constant_values=fill_value)
        elif A.shape[1] > new_shape[1]:
            A = A[:, :new_shape[1]]
    
    if B.shape != new_shape:
        if B.shape[0] < new_shape[0]:
            padding_rows = new_shape[0] - B.shape[0]
            padding = np.full((padding_rows, B.shape[1]), fill_value)
            B = np.vstack((B, padding))
        elif B.shape[0] > new_shape[0]:
            B = B[:new_shape[0], :]

        if B.shape[1] < new_shape[1]:
            pad_width = ((0, 0), (0, new_shape[1] - B.shape[1]))
            B = np.pad(B, pad_width, mode='constant', constant_values=fill_value)
        elif B.shape[1] > new_shape[1]:
            B = B[:, :new_shape[1]]
    
    return A, B

# %%
# 设置工作环境
env.workspace = r"D:\ArcGISProjects\workspace\shbyq\feature_raster_file\features_data_ky.gdb"
arcpy.ListRasters()
# Out:
# ['PRE',
#  'SRA',
#  'TMP',
#  'VAP',
#  'WIND',
#  'BIO',
#  'Contrast',
#  'Correlation',
#  'Dissimilarity',
#  'Entropy',
#  'Homogeneity',
#  'Mean',
#  'ndvi',
#  'PCA_0',
#  'PCA_1',
#  'SecondMoment',
#  'Variance',
#  'LON',
#  'LAT',
#  'Aspect',
#  'ChannelNetworkBaseLevel',
#  'ChannelNetworkDistance',
#  'ClosedDepressions',
#  'ConvergenceIndex',
#  'LSFactor',
#  'PlanCurvature',
#  'ProfileCurvature',
#  'RelativeSlopePosition',
#  'Slope',
#  'TopographicPositionIndex',
#  'TopographicWetnessIndex',
#  'TotalCatchmentArea',
#  'ValleyDepth',
#  'DEM',
#  'AnalyticalHillshading',
#  'DL',
#  'ASP_a',
#  'TWI3_a',
#  'TWI5_a',
#  'TPI3_a',
#  'TPI5_a',
#  'DZ']

# %%
feature_numpyarray_dict = {}
# feature_list = ['BIO', 'PRE', 'SRA', 'TMP', 'VAP', 'WIN', 'NDVI', 'TDQS', 'LIGHT', 'AnalyticalHillshading', 'Aspect', 'ChannelNetworkBaseLevel', 'ChannelNetworkDistance', 'ClosedDepressions', 'ConvergenceIndex', 'LSFactor', 'PlanCurvature', 'ProfileCurvature', 'RelativeSlopePosition', 'Slope', 'TopographicWetnessIndex', 'TotalCatchmentArea', 'ValleyDepth', 'DEM', 'LON', 'LAT']
# feature_list = ['DEM', 'AnalyticalHillshading', 'ChannelNetworkDistance', 'PlanCurvature', 'ProfileCurvature', 'RelativeSlopePosition', 'Slope', 'ValleyDepth', 'PCA_0', 'PCA_1', 'PRE', 'SRA', 'BIO', 'LON', 'LAT']
feature_list = arcpy.ListRasters()
for one_raster in feature_list:
    feature_numpyarray_dict[one_raster] = arcpy.RasterToNumPyArray(one_raster)

# %%
# 检查形状是否一致
print(len(set([feature_numpyarray_dict[_].shape for _ in feature_numpyarray_dict.keys()])))
# Out:
# 1

# %%
# 集成特征表
features_table = np.column_stack(tuple([feature_numpyarray_dict[_].flatten() for _ in feature_numpyarray_dict.keys()]))

# %%
features_table.size
# Out:
# 2578067745

# %%
features_table.shape
# Out:
# (171871183, 15)

# %%
# 添加列名
data = pd.DataFrame(features_table,columns = feature_list)

# %%
# 保存为csv文件
import os
out_path = r"D:\ArcGISProjects\workspace\pred_feature_table\dy"
chunk_size = 500000
total_rows = data.shape[0]
for i in range(0, total_rows, chunk_size):
    start = i
    end = min(i + chunk_size, total_rows)
    filename =  os.path.join(out_path,f'data_chunk_{i}.csv') # 文件名格式可以根据您的需要进行修改
    df_chunk = data.iloc[start:end]
    df_chunk.to_csv(filename, index=False)
    print(i)
# Out:
# 0
# 500000
# 1000000
# 1500000
# 2000000
# 2500000
# 3000000
# 3500000
# 4000000
# 4500000
# 5000000
# 5500000
# 6000000
# 6500000
# 7000000
# 7500000
# 8000000
# 8500000
# 9000000
# 9500000
# 10000000
# 10500000
# 11000000
# 11500000
# 12000000
# 12500000
# 13000000
# 13500000
# 14000000
# 14500000
# 15000000
# 15500000
# 16000000
# 16500000
# 17000000
# 17500000
# 18000000
# 18500000
# 19000000
# 19500000
# 20000000
# 20500000
# 21000000
# 21500000
# 22000000
# 22500000
# 23000000
# 23500000
# 24000000
# 24500000
# 25000000
# 25500000
# 26000000
# 26500000
# 27000000
# 27500000
# 28000000
# 28500000
# 29000000
# 29500000
# 30000000
# 30500000
# 31000000
# 31500000
# 32000000
# 32500000
# 33000000
# 33500000
# 34000000
# 34500000
# 35000000
# 35500000
# 36000000
# 36500000
# 37000000
# 37500000
# 38000000
# 38500000
# 39000000
# 39500000
# 40000000
# 40500000
# 41000000
# 41500000
# 42000000
# 42500000
# 43000000
# 43500000
# 44000000
# 44500000
# 45000000
# 45500000
# 46000000
# 46500000
# 47000000
# 47500000
# 48000000
# 48500000
# 49000000
# 49500000
# 50000000
# 50500000
# 51000000
# 51500000
# 52000000
# 52500000
# 53000000
# 53500000
# 54000000
# 54500000
# 55000000
# 55500000
# 56000000
# 56500000
# 57000000
# 57500000
# 58000000
# 58500000
# 59000000
# 59500000
# 60000000
# 60500000
# 61000000
# 61500000
# 62000000
# 62500000
# 63000000
# 63500000
# 64000000
# 64500000
# 65000000
# 65500000
# 66000000
# 66500000
# 67000000
# 67500000
# 68000000
# 68500000
# 69000000
# 69500000
# 70000000
# 70500000
# 71000000
# 71500000
# 72000000
# 72500000
# 73000000
# 73500000
# 74000000
# 74500000
# 75000000
# 75500000
# 76000000
# 76500000
# 77000000
# 77500000
# 78000000
# 78500000
# 79000000
# 79500000
# 80000000
# 80500000
# 81000000
# 81500000
# 82000000
# 82500000
# 83000000
# 83500000
# 84000000
# 84500000
# 85000000
# 85500000
# 86000000
# 86500000
# 87000000
# 87500000
# 88000000
# 88500000
# 89000000
# 89500000
# 90000000
# 90500000
# 91000000
# 91500000
# 92000000
# 92500000
# 93000000
# 93500000
# 94000000
# 94500000
# 95000000
# 95500000
# 96000000
# 96500000
# 97000000
# 97500000
# 98000000
# 98500000
# 99000000
# 99500000
# 100000000
# 100500000
# 101000000
# 101500000
# 102000000
# 102500000
# 103000000
# 103500000
# 104000000
# 104500000
# 105000000
# 105500000
# 106000000
# 106500000
# 107000000
# 107500000
# 108000000
# 108500000
# 109000000
# 109500000
# 110000000
# 110500000
# 111000000
# 111500000
# 112000000
# 112500000
# 113000000
# 113500000
# 114000000
# 114500000
# 115000000
# 115500000
# 116000000
# 116500000
# 117000000
# 117500000
# 118000000
# 118500000
# 119000000
# 119500000
# 120000000
# 120500000
# 121000000
# 121500000
# 122000000
# 122500000
# 123000000
# 123500000
# 124000000
# 124500000
# 125000000
# 125500000
# 126000000
# 126500000
# 127000000
# 127500000
# 128000000
# 128500000
# 129000000
# 129500000
# 130000000
# 130500000
# 131000000
# 131500000
# 132000000
# 132500000
# 133000000
# 133500000
# 134000000
# 134500000
# 135000000
# 135500000
# 136000000
# 136500000
# 137000000
# 137500000
# 138000000
# 138500000
# 139000000
# 139500000
# 140000000
# 140500000
# 141000000
# 141500000
# 142000000
# 142500000
# 143000000
# 143500000
# 144000000
# 144500000
# 145000000
# 145500000
# 146000000
# 146500000
# 147000000
# 147500000
# 148000000
# 148500000
# 149000000
# 149500000
# 150000000
# 150500000
# 151000000
# 151500000
# 152000000
# 152500000
# 153000000
# 153500000
# 154000000
# 154500000
# 155000000
# 155500000
# 156000000
# 156500000
# 157000000
# 157500000
# 158000000
# 158500000
# 159000000
# 159500000
# 160000000
# 160500000
# 161000000
# 161500000
# 162000000
# 162500000
# 163000000
# 163500000
# 164000000
# 164500000
# 165000000
# 165500000
# 166000000
# 166500000
# 167000000
# 167500000
# 168000000
# 168500000
# 169000000
# 169500000
# 170000000
# 170500000
# 171000000
# 171500000

# %%
# 创建输出路径
out_path = r"F:\cache_data\pred_feature_table\ky\feature_table\all"

# %%
flatten_list = [feature_numpyarray_dict[_].flatten() for _ in feature_numpyarray_dict.keys()]

# %%
# 定义每个小块的大小
chunk_size = 500000

# 获取特征数量
num_features = len(feature_numpyarray_dict)

# 获取行数（假设所有栅格数据的行数相同，以第一个为准）
num_rows = len(list(feature_numpyarray_dict.values())[0].flatten())

# 计算需要切割成多少块
num_chunks = num_rows // chunk_size + (num_rows % chunk_size > 0)
print(num_chunks)
# 逐块处理或导出
for i in range(num_chunks):
    # 判断文件是否存在，如果存在则跳过
    if os.path.exists(os.path.join(out_path,f'data_chunk_{str(i).zfill(3)}.csv')):
        print(f'data_chunk_{str(i).zfill(3)}.csv exists, skip')
        continue
    start_idx = i * chunk_size
    end_idx = min((i + 1) * chunk_size, num_rows)
    
    # 获取当前块的数据
    # chunk_data = np.column_stack([feature_numpyarray_dict[feature].flatten()[start_idx:end_idx] for feature in feature_list])
    chunk_data = np.column_stack([_[start_idx:end_idx] for _ in flatten_list])
    # 转为pandas datafram
    data = pd.DataFrame(chunk_data,columns = feature_list)
    data.to_csv(os.path.join(out_path,f'data_chunk_{str(i).zfill(3)}.csv'))
    print(i)
# Out:
# 335
# data_chunk_000.csv exists, skip
# data_chunk_001.csv exists, skip
# data_chunk_002.csv exists, skip
# data_chunk_003.csv exists, skip
# data_chunk_004.csv exists, skip
# data_chunk_005.csv exists, skip
# data_chunk_006.csv exists, skip
# data_chunk_007.csv exists, skip
# data_chunk_008.csv exists, skip
# data_chunk_009.csv exists, skip
# data_chunk_010.csv exists, skip
# data_chunk_011.csv exists, skip
# data_chunk_012.csv exists, skip
# data_chunk_013.csv exists, skip
# data_chunk_014.csv exists, skip
# data_chunk_015.csv exists, skip
# data_chunk_016.csv exists, skip
# data_chunk_017.csv exists, skip
# data_chunk_018.csv exists, skip
# data_chunk_019.csv exists, skip
# data_chunk_020.csv exists, skip
# data_chunk_021.csv exists, skip
# data_chunk_022.csv exists, skip
# data_chunk_023.csv exists, skip
# data_chunk_024.csv exists, skip
# data_chunk_025.csv exists, skip
# data_chunk_026.csv exists, skip
# data_chunk_027.csv exists, skip
# data_chunk_028.csv exists, skip
# data_chunk_029.csv exists, skip
# data_chunk_030.csv exists, skip
# data_chunk_031.csv exists, skip
# data_chunk_032.csv exists, skip
# data_chunk_033.csv exists, skip
# data_chunk_034.csv exists, skip
# data_chunk_035.csv exists, skip
# data_chunk_036.csv exists, skip
# data_chunk_037.csv exists, skip
# data_chunk_038.csv exists, skip
# data_chunk_039.csv exists, skip
# data_chunk_040.csv exists, skip
# data_chunk_041.csv exists, skip
# data_chunk_042.csv exists, skip
# data_chunk_043.csv exists, skip
# data_chunk_044.csv exists, skip
# data_chunk_045.csv exists, skip
# data_chunk_046.csv exists, skip
# data_chunk_047.csv exists, skip
# data_chunk_048.csv exists, skip
# data_chunk_049.csv exists, skip
# data_chunk_050.csv exists, skip
# data_chunk_051.csv exists, skip
# data_chunk_052.csv exists, skip
# data_chunk_053.csv exists, skip
# data_chunk_054.csv exists, skip
# data_chunk_055.csv exists, skip
# data_chunk_056.csv exists, skip
# data_chunk_057.csv exists, skip
# data_chunk_058.csv exists, skip
# data_chunk_059.csv exists, skip
# data_chunk_060.csv exists, skip
# data_chunk_061.csv exists, skip
# data_chunk_062.csv exists, skip
# data_chunk_063.csv exists, skip
# data_chunk_064.csv exists, skip
# data_chunk_065.csv exists, skip
# data_chunk_066.csv exists, skip
# data_chunk_067.csv exists, skip
# data_chunk_068.csv exists, skip
# data_chunk_069.csv exists, skip
# data_chunk_070.csv exists, skip
# data_chunk_071.csv exists, skip
# data_chunk_072.csv exists, skip
# data_chunk_073.csv exists, skip
# data_chunk_074.csv exists, skip
# data_chunk_075.csv exists, skip
# data_chunk_076.csv exists, skip
# data_chunk_077.csv exists, skip
# data_chunk_078.csv exists, skip
# data_chunk_079.csv exists, skip
# data_chunk_080.csv exists, skip
# data_chunk_081.csv exists, skip
# data_chunk_082.csv exists, skip
# data_chunk_083.csv exists, skip
# data_chunk_084.csv exists, skip
# data_chunk_085.csv exists, skip
# data_chunk_086.csv exists, skip
# data_chunk_087.csv exists, skip
# data_chunk_088.csv exists, skip
# data_chunk_089.csv exists, skip
# data_chunk_090.csv exists, skip
# data_chunk_091.csv exists, skip
# data_chunk_092.csv exists, skip
# data_chunk_093.csv exists, skip
# data_chunk_094.csv exists, skip
# data_chunk_095.csv exists, skip
# data_chunk_096.csv exists, skip
# data_chunk_097.csv exists, skip
# data_chunk_098.csv exists, skip
# data_chunk_099.csv exists, skip
# data_chunk_100.csv exists, skip
# data_chunk_101.csv exists, skip
# data_chunk_102.csv exists, skip
# data_chunk_103.csv exists, skip
# data_chunk_104.csv exists, skip
# data_chunk_105.csv exists, skip
# data_chunk_106.csv exists, skip
# data_chunk_107.csv exists, skip
# data_chunk_108.csv exists, skip
# data_chunk_109.csv exists, skip
# data_chunk_110.csv exists, skip
# data_chunk_111.csv exists, skip
# data_chunk_112.csv exists, skip
# data_chunk_113.csv exists, skip
# data_chunk_114.csv exists, skip
# data_chunk_115.csv exists, skip
# data_chunk_116.csv exists, skip
# data_chunk_117.csv exists, skip
# data_chunk_118.csv exists, skip
# data_chunk_119.csv exists, skip
# data_chunk_120.csv exists, skip
# data_chunk_121.csv exists, skip
# data_chunk_122.csv exists, skip
# data_chunk_123.csv exists, skip
# data_chunk_124.csv exists, skip
# data_chunk_125.csv exists, skip
# data_chunk_126.csv exists, skip
# data_chunk_127.csv exists, skip
# data_chunk_128.csv exists, skip
# data_chunk_129.csv exists, skip
# data_chunk_130.csv exists, skip
# data_chunk_131.csv exists, skip
# data_chunk_132.csv exists, skip
# data_chunk_133.csv exists, skip
# data_chunk_134.csv exists, skip
# data_chunk_135.csv exists, skip
# data_chunk_136.csv exists, skip
# data_chunk_137.csv exists, skip
# data_chunk_138.csv exists, skip
# data_chunk_139.csv exists, skip
# data_chunk_140.csv exists, skip
# data_chunk_141.csv exists, skip
# data_chunk_142.csv exists, skip
# data_chunk_143.csv exists, skip
# data_chunk_144.csv exists, skip
# data_chunk_145.csv exists, skip
# data_chunk_146.csv exists, skip
# data_chunk_147.csv exists, skip
# data_chunk_148.csv exists, skip
# data_chunk_149.csv exists, skip
# data_chunk_150.csv exists, skip
# data_chunk_151.csv exists, skip
# data_chunk_152.csv exists, skip
# data_chunk_153.csv exists, skip
# data_chunk_154.csv exists, skip
# data_chunk_155.csv exists, skip
# data_chunk_156.csv exists, skip
# data_chunk_157.csv exists, skip
# data_chunk_158.csv exists, skip
# data_chunk_159.csv exists, skip
# data_chunk_160.csv exists, skip
# data_chunk_161.csv exists, skip
# data_chunk_162.csv exists, skip
# data_chunk_163.csv exists, skip
# data_chunk_164.csv exists, skip
# data_chunk_165.csv exists, skip
# data_chunk_166.csv exists, skip
# data_chunk_167.csv exists, skip
# data_chunk_168.csv exists, skip
# data_chunk_169.csv exists, skip
# data_chunk_170.csv exists, skip
# data_chunk_171.csv exists, skip
# data_chunk_172.csv exists, skip
# data_chunk_173.csv exists, skip
# data_chunk_174.csv exists, skip
# data_chunk_175.csv exists, skip
# data_chunk_176.csv exists, skip
# data_chunk_177.csv exists, skip
# data_chunk_178.csv exists, skip
# data_chunk_179.csv exists, skip
# data_chunk_180.csv exists, skip
# data_chunk_181.csv exists, skip
# data_chunk_182.csv exists, skip
# data_chunk_183.csv exists, skip
# data_chunk_184.csv exists, skip
# data_chunk_185.csv exists, skip
# data_chunk_186.csv exists, skip
# data_chunk_187.csv exists, skip
# data_chunk_188.csv exists, skip
# data_chunk_189.csv exists, skip
# data_chunk_190.csv exists, skip
# data_chunk_191.csv exists, skip
# data_chunk_192.csv exists, skip
# data_chunk_193.csv exists, skip
# data_chunk_194.csv exists, skip
# data_chunk_195.csv exists, skip
# data_chunk_196.csv exists, skip
# data_chunk_197.csv exists, skip
# data_chunk_198.csv exists, skip
# data_chunk_199.csv exists, skip
# data_chunk_200.csv exists, skip
# data_chunk_201.csv exists, skip
# data_chunk_202.csv exists, skip
# data_chunk_203.csv exists, skip
# data_chunk_204.csv exists, skip
# data_chunk_205.csv exists, skip
# data_chunk_206.csv exists, skip
# data_chunk_207.csv exists, skip
# data_chunk_208.csv exists, skip
# data_chunk_209.csv exists, skip
# data_chunk_210.csv exists, skip
# data_chunk_211.csv exists, skip
# data_chunk_212.csv exists, skip
# data_chunk_213.csv exists, skip
# data_chunk_214.csv exists, skip
# data_chunk_215.csv exists, skip
# data_chunk_216.csv exists, skip
# data_chunk_217.csv exists, skip
# data_chunk_218.csv exists, skip
# data_chunk_219.csv exists, skip
# data_chunk_220.csv exists, skip
# data_chunk_221.csv exists, skip
# data_chunk_222.csv exists, skip
# data_chunk_223.csv exists, skip
# data_chunk_224.csv exists, skip
# data_chunk_225.csv exists, skip
# data_chunk_226.csv exists, skip
# data_chunk_227.csv exists, skip
# data_chunk_228.csv exists, skip
# data_chunk_229.csv exists, skip
# 230
# 231
# 232
# 233
# 234
# 235
# 236
# 237
# 238
# 239
# 240
# 241
# 242
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 297
# 298
# 299
# 300
# 301
# 302
# 303
# 304
# 305
# 306
# 307
# 308
# 309
# 310
# 311
# 312
# 313
# 314
# 315
# 316
# 317
# 318
# 319
# 320
# 321
# 322
# 323
# 324
# 325
# 326
# 327
# 328
# 329
# 330
# 331
# 332
# 333
# 334
