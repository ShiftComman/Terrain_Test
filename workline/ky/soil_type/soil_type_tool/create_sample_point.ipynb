# %%
import os
import pandas as pd
import arcpy
from arcpy import env
from arcpy.management import *
from arcpy.sa import *
from arcpy.da import *
from arcpy.conversion import *
from arcpy.analysis import *
import numpy as np

# %%
# tool function
# 创建渔网
def create_net(output_file,extent_file,cell_size):
    """参数说明：
        output_file: 输出文件
        extent_file: 输入范围文件
        cell_size: 生成的cell大小
    """
    proj = arcpy.Describe(extent_file).spatialReference
    extent_x_min = arcpy.Describe(extent_file).extent.XMin
    extent_y_min = arcpy.Describe(extent_file).extent.YMin
    extent_x_max = arcpy.Describe(extent_file).extent.XMax
    extent_y_max = arcpy.Describe(extent_file).extent.YMax
    with arcpy.EnvManager(outputCoordinateSystem = proj):
        arcpy.management.CreateFishnet(out_feature_class=output_file,origin_coord=f"{extent_x_min} {extent_y_min}",y_axis_coord=f"{extent_x_min} {extent_y_min+10}",cell_width=cell_size,cell_height=cell_size,number_rows=None,number_columns=None,corner_coord=f"{extent_x_max} {extent_y_max}",labels="NO_LABELS",template="#",geometry_type="POLYGON")
# 面转点
def polygon_point(in_feature, out_feature):
    """参数说明：
        in_feature: 输入面
        out_feature: 输出点
    """
    proj = arcpy.Describe(in_feature).spatialReference
    with arcpy.EnvManager(outputCoordinateSystem=proj):
        arcpy.management.FeatureToPoint(in_features=in_feature,out_feature_class=out_feature,point_location="INSIDE")

# 筛选点

def select_point(input_polygon,input_point,output_point):
    """参数说明：
        input_polygon: 选择面
        input_point: 待选择点
        output_point: 选择点
    """
    polygon_layer = "polygonLayer"
    point_layer = "pointLayer"
    arcpy.MakeFeatureLayer_management(input_polygon, polygon_layer)
    arcpy.MakeFeatureLayer_management(input_point, point_layer)
    arcpy.SelectLayerByLocation_management(in_layer=point_layer, overlap_type="INTERSECT", select_features=polygon_layer,search_distance=0,selection_type='NEW_SELECTION',invert_spatial_relationship="NOT_INVERT")
    # 导出选择的要素
    arcpy.CopyFeatures_management(point_layer, output_point)

# 添加字段
def add_field(input_table,field_name,field_type='TEXT'):
    """参数说明：
        input_table: 输入数据表
        field_name: 字段名
        field_type: 字段类型"""
    arcpy.AddField_management(input_table,field_name,field_type)
# 删除要素
def delete_feature(input_feature):
    arcpy.Delete_management(input_feature)
# 空间连接
def perform_spatial_join(target_layer_path, join_layer_path, output_layer_path, field_mapping_dict):
    """参数说明：
        target_layer_path: 目标图层路径 (点图层)
        join_layer_path: 连接图层路径 (包含属性的面图层)
        output_layer_path: 输出图层路径
        field_mapping_dict: 字段映射字典 {目标字段:源字段}
    """
    # 创建空的 FieldMappings 对象
    field_mappings = arcpy.FieldMappings()

    # 只添加需要的字段映射
    for target_field, source_field in field_mapping_dict.items():
        # 创建字段映射对象
        field_map = arcpy.FieldMap()
        
        # 添加源字段（从连接图层）
        field_map.addInputField(join_layer_path, source_field)
        
        # 设置输出字段属性
        output_field = field_map.outputField
        output_field.name = target_field
        output_field.aliasName = target_field
        field_map.outputField = output_field
        
        # 添加到field_mappings
        field_mappings.addFieldMap(field_map)

    # 执行空间连接操作
    arcpy.analysis.SpatialJoin(
        target_layer_path, 
        join_layer_path, 
        output_layer_path,
        "JOIN_ONE_TO_ONE", 
        "KEEP_ALL", 
        field_mappings,
        match_option="INTERSECT"
    )

def perform_multiple_spatial_joins(target_layer_path, join_layers_info, final_output):
    """
    对一个目标图层执行多个空间连接操作,并清理中间文件
    
    参数说明：
        target_layer_path: 目标图层路径 (点图层)
        join_layers_info: 连接图层信息列表，每个元素为字典，包含：
            {
                'join_layer': 连接图层路径,
                'field_mapping': 字段映射字典 {目标字段:源字段}
            }
        final_output: 最终输出图层路径
    """
    current_input = target_layer_path
    temp_outputs = []  # 存储中间输出文件路径
    
    # 获取工作空间路径
    workspace = os.path.dirname(target_layer_path)
    
    for idx, join_info in enumerate(join_layers_info):
        # 获取当前连接操作的参数
        join_layer = join_info['join_layer']
        # 生成临时输出文件完整路径
        temp_output = os.path.join(workspace, f"temp_join_{idx}.shp")
        temp_outputs.append(temp_output)
        
        # 最后一次连接时使用最终输出路径
        output_layer = final_output if idx == len(join_layers_info) - 1 else temp_output
        field_mapping_dict = join_info['field_mapping']
        
        # 创建空的 FieldMappings 对象
        field_mappings = arcpy.FieldMappings()
        
        # 保留目标图层的所有字段
        field_mappings.addTable(current_input)
        field_mappings.addTable(join_layer)
        
        # 获取需要保留的字段列表
        keep_fields = [f.name for f in arcpy.ListFields(current_input)]  # 保留目标图层的所有字段
        keep_fields.extend(list(field_mapping_dict.keys()))  # 添加新的映射字段
        
        # 移除所有不需要的字段
        field_indices_to_remove = []
        for i in range(field_mappings.fieldCount):
            field = field_mappings.getFieldMap(i)
            if field.getInputFieldName(0) not in keep_fields and \
               field.outputField.name not in keep_fields:
                field_indices_to_remove.append(i)
        
        # 从后向前移除字段，避免索引变化
        for i in reversed(field_indices_to_remove):
            field_mappings.removeFieldMap(i)
        
        # 添加或更新需要的连接字段映射
        for target_field, source_field in field_mapping_dict.items():
            # 创建字段映射对象
            field_map = arcpy.FieldMap()
            
            # 添加源字段（从连接图层）
            field_map.addInputField(join_layer, source_field)
            
            # 设置输出字段属性
            output_field = field_map.outputField
            output_field.name = target_field
            output_field.aliasName = target_field
            field_map.outputField = output_field
            
            # 找到并替换现有的字段映射（如果存在）
            field_index = field_mappings.findFieldMapIndex(target_field)
            if field_index != -1:
                field_mappings.replaceFieldMap(field_index, field_map)
            else:
                field_mappings.addFieldMap(field_map)
        
        # 执行空间连接操作
        arcpy.analysis.SpatialJoin(
            current_input, 
            join_layer, 
            output_layer,
            "JOIN_ONE_TO_ONE", 
            "KEEP_ALL", 
            field_mappings,
            match_option="INTERSECT"
        )
        
        # 更新当前输入图层为最新的输出图层
        current_input = output_layer  # 这是关键修改

    # 清理中间文件
    for temp_file in temp_outputs[:-1]:  # 不删除最后一个输出文件
        if arcpy.Exists(temp_file):
            arcpy.Delete_management(temp_file)
# 点采样
def sample_point(point_,raster_,out_name):
    """根据栅格采样点,输出为表格"""
    Sample(raster_,point_,out_name,"NEAREST", "OBJECTID", "CURRENT_SLICE", None, '', None, None, "ROW_WISE", "TABLE")
    return None

# 导出CSV
def export_csv(table_,out_path,out_name):
    """参数说明：
        table_: 输入数据表
        out_path: 输出路径
        out_name: 输出表名"""
    TableToTable(table_,out_path,out_name)
    return None

# 要素转点
def feature_to_point(input_layer,output_layer):
    """参数说明："""
    proj = arcpy.Describe(input_layer).spatialReference
    with arcpy.EnvManager(outputCoordinateSystem=proj):
        arcpy.management.FeatureToPoint(input_layer, output_layer, "INSIDE")

# 删除多余字段
def delete_extra_fields(input_feature_class, fields_list):
    """参数说明："""
    fields = arcpy.ListFields(input_feature_class)
    for field in fields:
        name = field.name
        type = field.type.upper()
        # 如果字段名不在删选列表中且类型不为OID和Geometry便删除这个字段
        if name not in fields_list and type not in ['OID','GEOMETRY']:
            arcpy.DeleteField_management(input_feature_class, [name])

# %%
# 设置工作空间
env.workspace = r'F:\cache_data\shp_file\ky'
env.overwriteOutput=True

# %%
def create_point(input_layer):
    """生成虚拟点"""
    # 定义文件名称
    fish_net_name = "ky_grid"
    net_to_point_name = "ky_inside_point"
    select_point_name = "select_point"
    result_point_name = "join_point"
    # 渔网构建
    create_net(fish_net_name,input_layer,300)
    # 要素转点
    polygon_point(fish_net_name,net_to_point_name)
    # 按位置选择
    select_point(input_layer,net_to_point_name,select_point_name)
    # 添加字段
    field_list = ['TL','YL','TS','TZ']
    for one_field in field_list:
        # 添加字段
        add_field(input_table=select_point_name,field_name=one_field,field_type='TEXT')
    # 空间连接赋予地类属性
    # 定义目标要素图层和连接要素图层的路径 
    fields_mapping = {
        "TL": "TL",
        "YL": "YL",
        "TS": "TS",
        "TZ": "TZ"
    }
    # 空间连接
    perform_spatial_join(select_point_name,input_layer,result_point_name,fields_mapping)
    # 删除多余数据
    for one_feature in [fish_net_name,net_to_point_name,select_point_name]:
        delete_feature(one_feature)

# %%
# 生成渔网点
create_point(input_layer="ky_ep_polygon")

# %%
# 生成面内部点
feature_to_point(input_layer="ky_ep_polygon",output_layer="ky_tl_dh_point")

# %%
# 内部点字段整理
input_feature = r"F:\cache_data\shp_file\ky\ky_tl_dh_point.shp"
# 定义字段映射关系：新字段名:原字段名
field_mapping = {
    'TL': 'TL',
    'YL': 'YL',
    'TS': 'TS',
    'TZ': 'TZ'
}

# 添加字段并复制值
for new_field, source_field in field_mapping.items():
    # 添加新字段
    add_field(input_table=input_feature, field_name=new_field, field_type='TEXT')
    # 从原有字段复制值到新字段
    arcpy.CalculateField_management(input_feature, new_field, f"!{source_field}!", "PYTHON3")

# 只保留新添加的字段
delete_extra_fields(input_feature, list(field_mapping.keys()))

# %%
# 渔网点字段整理
# 添加字段
# input_feature = r"F:\cache_data\shp_file\ky\join_point.shp"
input_feature = r"F:\cache_data\shp_file\ky\ky_tl_dh_point.shp"
field_list = ['TL','YL','TS','TZ']
# 删除多余字段
delete_extra_fields(input_feature, field_list)

# %%
# 为两个点位数据增加label
feature_1 = r"F:\cache_data\shp_file\ky\join_point.shp"
feature_2 = r"F:\cache_data\shp_file\ky\ky_tl_dh_point.shp"
for one_feature in [[feature_1,'fish_net'],[feature_2,'inner']]:
    features = one_feature[0]
    labels = one_feature[1]
    field_name = "label"
    # 添加字段
    add_field(input_table=features,field_name="label",field_type='TEXT')
    # 注意：这里使用了Python表达式
    arcpy.CalculateField_management(features, field_name, f"'{labels}'", "PYTHON3")

# %%
# 合并点位数据
feature_1 = "join_point"
feature_2 = "ky_tl_dh_point"
output_feature = "filter_result_point"
# 合并
arcpy.management.Merge([feature_1,feature_2],output_feature)
# 删除过渡文件
for one_feature in [feature_1,feature_2]:
    delete_feature(one_feature)

# %%
# 添加经纬度字段并计算经纬度

# 输入和输出文件
input_feature_class = "filter_result_point"  # 请替换为您的点文件的名称

# 添加字段
arcpy.AddField_management(input_feature_class, "LON", "DOUBLE")
arcpy.AddField_management(input_feature_class, "LAT", "DOUBLE")

# 使用CalculateField_management计算经纬度
# 假设您的点文件有一个名为"SHAPE"的字段，它包含了点的几何信息
# arcpy.CalculateField_management(input_feature_class, "LON", "!SHAPE.firstPoint.X!", "PYTHON3")
# arcpy.CalculateField_management(input_feature_class, "LAT", "!SHAPE.firstPoint.Y!", "PYTHON3")
arcpy.management.CalculateGeometryAttributes(input_feature_class, [['LON','POINT_X'], ['LAT','POINT_Y']],coordinate_format='DD')
# print("字段添加和计算完成！")
# Out:
# <Result 'F:\\cache_data\\shp_file\\ky\\filter_result_point'>

# %% [markdown]
# # 名称完善

# %%
excel_path = r"D:\worker\工作\work\三普\数据\开阳\开阳县土种明细表20240905.xlsx"

# %%
df_excel = pd.read_excel(excel_path)
# 向前填充
df_excel = df_excel.ffill()

# %%
# 查看所有土种
table_list = list(set(df_excel['开阳土种'].unique()))
table_list
# Out:
# ['中层紫色沙土',
#  '砾质紫色土',
#  '薄层硅质黄壤性土',
#  '中层硅铁质黄壤性土',
#  '羊肝石土',
#  '中白善泥',
#  '厚层次生黄色石灰土',
#  '中层紫色土',
#  '紫砂泥',
#  '紫油泥',
#  '中层硅铝质黄棕壤',
#  '中层淋溶黄色石灰土',
#  '紫油砂土',
#  '潮砂泥',
#  '潮泥',
#  '大泥土',
#  '黄泥',
#  '龙凤大眼泥',
#  '中层硅铁质黄壤',
#  '轻白胶泥',
#  '火石砂土',
#  '中层硅铁质黄棕壤',
#  '黄大泥',
#  '石喳子土',
#  '潮砂土',
#  '黄砂泥',
#  '厚层硅铝质黄棕壤',
#  '砾石紫泥土',
#  '黄砂土',
#  '厚层酸性紫色土',
#  '薄层硅铁质黄壤性土',
#  '黄油砂土',
#  '薄层淋溶黄色石灰土',
#  '厚层铁铝质黄壤',
#  '大泥',
#  '中层酸性紫色土',
#  '苦鸭屎泥',
#  '死黄泥',
#  '煤锈田',
#  '中层硅质黄壤',
#  '干鸭屎泥',
#  '冷砂土',
#  '冷砂田',
#  '薄层酸性紫色土',
#  '厚层硅铝质黄壤性土',
#  '黄胶泥土',
#  '白胶泥土',
#  '重白胶泥',
#  '黄胶泥',
#  '薄层黑色石灰土',
#  '白砂土',
#  '浅血泥田',
#  '灰泡黄泥土',
#  '中层硅铝质黄壤性土',
#  '寡黄泥',
#  '黑色灰泡土',
#  '厚层铁质黄壤',
#  '白云砂土',
#  '扁砂土',
#  '羊肝泥',
#  '熟白胶泥',
#  '熟白善泥',
#  '湿鸭屎泥',
#  '锈水田',
#  '岩灰泥',
#  '薄层硅铝质黄壤性土',
#  '白大泥',
#  '小黄泥土',
#  '薄层铁铝质黄壤',
#  '中层硅铝质黄壤',
#  '中层铁质黄壤',
#  '中层铁铝质黄壤',
#  '大眼泥',
#  '豆办泥土',
#  '中层酸性紫色砂土',
#  '厚层酸性紫色砂土',
#  '灰泡土',
#  '薄层硅铝质黄壤',
#  '厚层黄色石灰土',
#  '薄层黄色石灰土',
#  '烂锈田',
#  '黄泥土',
#  '中层黑色石灰土',
#  '薄层硅质黄壤',
#  '岩泥',
#  '热鸭屎泥',
#  '厚层硅铝质黄壤',
#  '薄层次生黄色石灰土',
#  '黄灰泡土',
#  '黑潮泥',
#  '薄层硅铁质黄壤',
#  '黄油砂泥',
#  '小土泥',
#  '豆办砂泥',
#  '豆面泥土',
#  '深脚烂泥田',
#  '冷水田',
#  '血砂泥土',
#  '黄石砂田',
#  '苦大泥',
#  '大土泥',
#  '紫砂土',
#  '小黄泥',
#  '厚层硅铁质黄棕壤',
#  '厚层硅质黄壤',
#  '紫色土',
#  '浅脚烂泥田',
#  '紫色大土',
#  '中白胶泥',
#  '中层次生黄色石灰土',
#  '中层黄色石灰土',
#  '厚层硅铁质黄壤',
#  '厚层黑色石灰土',
#  '轻白善泥',
#  '重白善泥',
#  '扁砂泥',
#  '死黄泥土',
#  '黑色油砂石',
#  '厚层淋溶黄色石灰土',
#  '冷浸田',
#  '厚层硅铁质黄壤性土',
#  '紫泥']

# %%
shp_list = list(set(pd.DataFrame(arcpy.da.FeatureClassToNumPyArray(r'F:\cache_data\shp_file\ky\filter_result_point.shp', ['TZ'])).TZ.unique()))
shp_list
# Out:
# ['中层紫色沙土',
#  '薄层硅质黄壤性土',
#  '中层硅铁质黄壤性土',
#  '羊肝石土',
#  '中白善泥',
#  '厚层次生黄色石灰土',
#  '中层紫色土',
#  '紫砂泥',
#  '紫油泥',
#  '中层淋溶黄色石灰土',
#  '潮砂泥',
#  '中层硅铝质黄棕壤',
#  '潮泥',
#  '紫油砂土',
#  '大泥土',
#  '黄泥',
#  '龙凤大眼泥',
#  '中层硅铁质黄壤',
#  '轻白胶泥',
#  '火石砂土',
#  '中层硅铁质黄棕壤',
#  '黄大泥',
#  '石喳子土',
#  '潮砂土',
#  '黄砂泥',
#  '厚层硅铝质黄棕壤',
#  '砾石紫泥土',
#  '黄砂土',
#  '厚层酸性紫色土',
#  '薄层硅铁质黄壤性土',
#  '黄油砂土',
#  '薄层淋溶黄色石灰土',
#  '厚层铁铝质黄壤',
#  '大泥',
#  '中层酸性紫色土',
#  '苦鸭屎泥',
#  '死黄泥',
#  '煤锈田',
#  '中层硅质黄壤',
#  '干鸭屎泥',
#  '冷砂土',
#  '冷砂田',
#  '薄层酸性紫色土',
#  '厚层硅铝质黄壤性土',
#  '黄胶泥土',
#  '白胶泥土',
#  '重白胶泥',
#  '黄胶泥',
#  '薄层黑色石灰土',
#  '白砂土',
#  '浅血泥田',
#  '灰泡黄泥土',
#  '中层硅铝质黄壤性土',
#  '寡黄泥',
#  '厚层铁质黄壤',
#  '白云砂土',
#  '扁砂土',
#  '羊肝泥',
#  '熟白胶泥',
#  '熟白善泥',
#  '锈水田',
#  '湿鸭屎泥',
#  '岩灰泥',
#  '薄层硅铝质黄壤性土',
#  '白大泥',
#  '小黄泥土',
#  '薄层铁铝质黄壤',
#  '中层硅铝质黄壤',
#  '中层铁质黄壤',
#  '中层铁铝质黄壤',
#  '大眼泥',
#  '豆办泥土',
#  '中层酸性紫色砂土',
#  '厚层酸性紫色砂土',
#  '灰泡土',
#  '薄层硅铝质黄壤',
#  '薄层黄色石灰土',
#  '厚层黄色石灰土',
#  '烂锈田',
#  '黄泥土',
#  '中层黑色石灰土',
#  '薄层硅质黄壤',
#  '岩泥',
#  '热鸭屎泥',
#  '厚层硅铝质黄壤',
#  '薄层次生黄色石灰土',
#  '黄灰泡土',
#  '黑潮泥',
#  '薄层硅铁质黄壤',
#  '黄油砂泥',
#  '小土泥',
#  '豆办砂泥',
#  '深脚烂泥田',
#  '豆面泥土',
#  '冷水田',
#  '血砂泥土',
#  '苦大泥',
#  '黄石砂田',
#  '大土泥',
#  '紫砂土',
#  '小黄泥',
#  '厚层硅铁质黄棕壤',
#  '厚层硅质黄壤',
#  '紫色土',
#  '浅脚烂泥田',
#  '中白胶泥',
#  '紫色大土',
#  '中层次生黄色石灰土',
#  '中层黄色石灰土',
#  '厚层硅铁质黄壤',
#  '厚层黑色石灰土',
#  '轻白善泥',
#  '重白善泥',
#  '扁砂泥',
#  '死黄泥土',
#  '黑色油砂石',
#  '厚层淋溶黄色石灰土',
#  '冷浸田',
#  '厚层硅铁质黄壤性土',
#  '紫泥']

# %%
# 比较两个列表
# 表中有的，shp中没有的
set(table_list) - set(shp_list)
# Out:
# {'砾质紫色土', '黑色灰泡土'}

# %%
# shp中有的，表中没有的
set(shp_list) - set(table_list)
# Out:
# set()

# %%
# 使用groupby按照`土种编号`聚合，并应用自定义函数
# 定义聚合函数
def aggregate_rows(group):
    records = group[['三普土类', '三普亚类', '三普土属', '三普土种']].to_dict('records')
    return records[0] if records else {}

# 使用groupby按照`开阳土种`聚合
result_dict = df_excel.groupby('开阳土种').apply(aggregate_rows).to_dict()

# %%
result_dict,len(result_dict),len(df_excel['开阳土种'].unique())
# Out:
# ({'中层次生黄色石灰土': {'三普土类': '石灰（岩）土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '中层黏质黄色石灰土'},
#   '中层淋溶黄色石灰土': {'三普土类': '石灰（岩）土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '腐中层壤质黄色石灰土'},
#   '中层硅质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤（自然土）',
#    '三普土属': '硅质黄壤',
#    '三普土种': '腐中层硅质黄壤'},
#   '中层硅铁质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤（自然土）',
#    '三普土属': '红泥质黄壤',
#    '三普土种': '腐中层红泥质黄壤'},
#   '中层硅铁质黄壤性土': {'三普土类': '黄壤',
#    '三普亚类': '黄壤性土',
#    '三普土属': '泥质黄壤性土',
#    '三普土种': '腐中层泥质黄壤性土'},
#   '中层硅铁质黄棕壤': {'三普土类': '黄棕壤',
#    '三普亚类': '暗黄棕壤',
#    '三普土属': '红泥质黄棕壤',
#    '三普土种': '腐中层红泥质黄棕壤'},
#   '中层硅铝质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤（自然土）',
#    '三普土属': '砂泥质黄壤',
#    '三普土种': '腐中层砂泥质黄壤'},
#   '中层硅铝质黄壤性土': {'三普土类': '黄壤',
#    '三普亚类': '黄壤性土',
#    '三普土属': '砂泥质黄壤性土',
#    '三普土种': '腐中层砂泥质黄壤性土'},
#   '中层硅铝质黄棕壤': {'三普土类': '黄棕壤',
#    '三普亚类': '暗黄棕壤',
#    '三普土属': '砂泥质黄棕壤',
#    '三普土种': '腐中层砂泥质黄棕壤'},
#   '中层紫色土': {'三普土类': '紫色土',
#    '三普亚类': '中性紫色土',
#    '三普土属': '壤质中性紫色土',
#    '三普土种': '腐中层壤质中性紫色土'},
#   '中层紫色沙土': {'三普土类': '紫色土',
#    '三普亚类': '中性紫色土',
#    '三普土属': '砂质中性紫色土',
#    '三普土种': '腐中层砂质中性紫色土'},
#   '中层酸性紫色土': {'三普土类': '紫色土',
#    '三普亚类': '酸性紫色土',
#    '三普土属': '壤质酸性紫色土',
#    '三普土种': '腐中层酸性紫色土'},
#   '中层酸性紫色砂土': {'三普土类': '紫色土',
#    '三普亚类': '酸性紫色土',
#    '三普土属': '砂质酸性紫色土',
#    '三普土种': '腐中层砂质酸性紫色土'},
#   '中层铁质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤（自然土）',
#    '三普土属': '暗泥质黄壤',
#    '三普土种': '中层暗泥质黄壤'},
#   '中层铁铝质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤（自然土）',
#    '三普土属': '砂泥质黄壤',
#    '三普土种': '腐中层砂泥质黄壤'},
#   '中层黄色石灰土': {'三普土类': '石灰（岩）土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '腐中层壤质黄色石灰土'},
#   '中层黑色石灰土': {'三普土类': '石灰（岩）土',
#    '三普亚类': '黑色石灰土',
#    '三普土属': '壤质黑色石灰土',
#    '三普土种': '中层壤质黑色石灰土'},
#   '中白善泥': {'三普土类': '水稻土', '三普亚类': '漂洗型水稻土', '三普土属': '漂砂泥田', '三普土种': '重漂砂泥田'},
#   '中白胶泥': {'三普土类': '水稻土', '三普亚类': '漂洗型水稻土', '三普土属': '漂红泥田', '三普土种': '轻漂红泥田'},
#   '冷水田': {'三普土类': '水稻土',
#    '三普亚类': '潴育型  水稻土',
#    '三普土属': '砂泥田或灰泥田等',
#    '三普土种': '砂泥田或灰泥田等'},
#   '冷浸田': {'三普土类': '水稻土',
#    '三普亚类': '潜育型     水稻土',
#    '三普土属': '青红泥田',
#    '三普土种': '黄青红泥田'},
#   '冷砂土': {'三普土类': '黄壤', '三普亚类': '黄壤性土', '三普土属': '砾质黄壤性土', '三普土种': '薄层砾质黄壤性土'},
#   '冷砂田': {'三普土类': '水稻土',
#    '三普亚类': '潜育型     水稻土',
#    '三普土属': '青砂泥田',
#    '三普土种': '黄青砂泥田'},
#   '厚层次生黄色石灰土': {'三普土类': '石灰（岩）土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '腐厚层壤质黄色石灰土'},
#   '厚层淋溶黄色石灰土': {'三普土类': '石灰（岩）土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '腐厚层壤质黄色石灰土'},
#   '厚层硅质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤（自然土）',
#    '三普土属': '暗泥质黄壤',
#    '三普土种': '腐厚层硅质黄壤'},
#   '厚层硅铁质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤（自然土）',
#    '三普土属': '红泥质黄壤',
#    '三普土种': '腐厚层红泥质黄壤'},
#   '厚层硅铁质黄壤性土': {'三普土类': '黄壤',
#    '三普亚类': '黄壤性土',
#    '三普土属': '泥质黄壤性土',
#    '三普土种': '腐厚层泥质黄壤性土'},
#   '厚层硅铁质黄棕壤': {'三普土类': '黄棕壤',
#    '三普亚类': '暗黄棕壤',
#    '三普土属': '红泥质黄棕壤',
#    '三普土种': '腐厚层红泥质黄棕壤'},
#   '厚层硅铝质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤（自然土）',
#    '三普土属': '砂泥质黄壤',
#    '三普土种': '腐厚层砂泥质黄壤'},
#   '厚层硅铝质黄壤性土': {'三普土类': '黄壤',
#    '三普亚类': '黄壤性土',
#    '三普土属': '砂泥质黄壤性土',
#    '三普土种': '腐厚层砂泥质黄壤性土'},
#   '厚层硅铝质黄棕壤': {'三普土类': '黄棕壤',
#    '三普亚类': '暗黄棕壤',
#    '三普土属': '砂泥质黄棕壤',
#    '三普土种': '腐厚层砂泥质黄棕壤'},
#   '厚层酸性紫色土': {'三普土类': '紫色土',
#    '三普亚类': '酸性紫色土',
#    '三普土属': '壤质酸性紫色土',
#    '三普土种': '腐厚层酸性紫色土'},
#   '厚层酸性紫色砂土': {'三普土类': '紫色土',
#    '三普亚类': '酸性紫色土',
#    '三普土属': '砂质酸性紫色土',
#    '三普土种': '腐厚层砂质酸性紫色土'},
#   '厚层铁质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤（自然土）',
#    '三普土属': '暗泥质黄壤',
#    '三普土种': '厚层暗泥质黄壤'},
#   '厚层铁铝质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤（自然土）',
#    '三普土属': '砂泥质黄壤',
#    '三普土种': '腐厚层砂泥质黄壤'},
#   '厚层黄色石灰土': {'三普土类': '石灰（岩）土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '腐厚层壤质黄色石灰土'},
#   '厚层黑色石灰土': {'三普土类': '黄壤',
#    '三普亚类': '黑色石灰土',
#    '三普土属': '壤质黑色石灰土',
#    '三普土种': '厚层壤质黑色石灰土'},
#   '大土泥': {'三普土类': '石灰（岩）土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '薄层壤质黄色石灰土'},
#   '大泥': {'三普土类': '水稻土', '三普亚类': '淹育型  水稻土', '三普土属': '浅灰泥田', '三普土种': '黄浅灰泥田'},
#   '大泥土': {'三普土类': '石灰（岩）土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '中层壤质黄色石灰土'},
#   '大眼泥': {'三普土类': '水稻土', '三普亚类': '潴育型  水稻土', '三普土属': '灰泥田', '三普土种': '黄石灰泥田'},
#   '寡黄泥': {'三普土类': '水稻土', '三普亚类': '淹育型  水稻土', '三普土属': '浅砂泥田', '三普土种': '黄浅砂泥田'},
#   '小土泥': {'三普土类': '石灰（岩）土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '薄层壤质黄色石灰土'},
#   '小黄泥': {'三普土类': '水稻土', '三普亚类': '潴育型  水稻土', '三普土属': '砂泥田', '三普土种': '黄砂泥田'},
#   '小黄泥土': {'三普土类': '黄壤',
#    '三普亚类': '典型黄 壤（耕作土）',
#    '三普土属': '红泥质黄壤',
#    '三普土种': '中层红泥质黄壤'},
#   '岩泥': {'三普土类': '石灰（岩）土',
#    '三普亚类': '黑色石灰土',
#    '三普土属': '壤质黑色石灰土',
#    '三普土种': '薄层壤质黑色石灰土'},
#   '岩灰泥': {'三普土类': '石灰（岩）土',
#    '三普亚类': '黑色石灰土',
#    '三普土属': '壤质黑色石灰土',
#    '三普土种': '薄层壤质黑色石灰土'},
#   '干鸭屎泥': {'三普土类': '水稻土', '三普亚类': '脱潜型水稻土', '三普土属': '黄灰泥田', '三普土种': '黄石灰泥田'},
#   '扁砂土': {'三普土类': '黄壤', '三普亚类': '黄壤性土', '三普土属': '砾质黄壤性土', '三普土种': '薄层砾质黄壤性土'},
#   '扁砂泥': {'三普土类': '水稻土', '三普亚类': '淹育型  水稻土', '三普土属': '浅鳝泥田', '三普土种': '黄浅鳝泥田'},
#   '死黄泥': {'三普土类': '水稻土', '三普亚类': '淹育型  水稻土', '三普土属': '浅红泥田', '三普土种': '黄浅红泥田'},
#   '死黄泥土': {'三普土类': '黄壤',
#    '三普亚类': '典型黄 壤（耕作土）',
#    '三普土属': '红泥质黄壤',
#    '三普土种': '厚层红泥质黄壤'},
#   '浅脚烂泥田': {'三普土类': '水稻土',
#    '三普亚类': '潜育型     水稻土',
#    '三普土属': '青砂泥田',
#    '三普土种': '黄青砂泥田'},
#   '浅血泥田': {'三普土类': '水稻土', '三普亚类': '潴育型  水稻土', '三普土属': '紫泥田', '三普土种': '酸性紫泥土'},
#   '深脚烂泥田': {'三普土类': '水稻土',
#    '三普亚类': '潜育型     水稻土',
#    '三普土属': '示例：青灰泥田',
#    '三普土种': '示例：黄青灰泥田'},
#   '湿鸭屎泥': {'三普土类': '水稻土',
#    '三普亚类': '潜育型     水稻土',
#    '三普土属': '青灰泥田',
#    '三普土种': '青石灰泥田'},
#   '潮泥': {'三普土类': '水稻土', '三普亚类': '潴育型  水稻土', '三普土属': '潮泥田', '三普土种': '潮泥田'},
#   '潮砂土': {'三普土类': '潮土', '三普亚类': '灰潮土', '三普土属': '砂质灰潮土', '三普土种': '中层砂质灰潮土'},
#   '潮砂泥': {'三普土类': '水稻土', '三普亚类': '潴育型  水稻土', '三普土属': '潮砂泥田', '三普土种': '潮砂泥田'},
#   '火石砂土': {'三普土类': '黄壤',
#    '三普亚类': '典型黄 壤（耕作土）',
#    '三普土属': '砂（砾）质黄壤',
#    '三普土种': '薄层砂砾质黄壤'},
#   '灰泡土': {'三普土类': '黄棕壤', '三普亚类': '暗黄棕壤', '三普土属': '泥质暗黄棕壤', '三普土种': '厚层泥质暗黄棕壤'},
#   '灰泡黄泥土': {'三普土类': '黄壤',
#    '三普亚类': '典型黄 壤（耕作土）',
#    '三普土属': '灰泥质黄壤',
#    '三普土种': '薄层灰泥质黄壤'},
#   '烂锈田': {'三普土类': '水稻土',
#    '三普亚类': '潜育型     水稻土',
#    '三普土属': '示例：青红泥田',
#    '三普土种': '示例：黄青红泥田'},
#   '热鸭屎泥': {'三普土类': '水稻土', '三普亚类': '脱潜型水稻土', '三普土属': '黄灰泥田', '三普土种': '黄石灰泥田'},
#   '煤锈田': {'三普土类': '水稻土',
#    '三普亚类': '潜育型     水稻土',
#    '三普土属': '示例：青砂泥田',
#    '三普土种': '示例：黄青砂泥田'},
#   '熟白善泥': {'三普土类': '水稻土', '三普亚类': '漂洗型水稻土', '三普土属': '漂砂泥田', '三普土种': '轻漂砂泥田'},
#   '熟白胶泥': {'三普土类': '水稻土', '三普亚类': '漂洗型水稻土', '三普土属': '漂灰泥田', '三普土种': '重漂灰泥田'},
#   '白云砂土': {'三普土类': '石灰（岩）土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '中层壤质黄色石灰土'},
#   '白大泥': {'三普土类': '水稻土', '三普亚类': '淹育型  水稻土', '三普土属': '浅灰泥田', '三普土种': '浅石灰泥田'},
#   '白砂土': {'三普土类': '黄壤',
#    '三普亚类': '典型黄 壤（耕作土）',
#    '三普土属': '砂（砾）质黄壤',
#    '三普土种': '薄层砂砾质黄壤'},
#   '白胶泥土': {'三普土类': '黄壤',
#    '三普亚类': '漂洗黄壤',
#    '三普土属': '红泥质漂洗黄壤',
#    '三普土种': '厚层红泥质漂洗黄壤'},
#   '石喳子土': {'三普土类': '黄壤', '三普亚类': '黄壤性土', '三普土属': '砾质黄壤性土', '三普土种': '薄层砾质黄壤性土'},
#   '砾石紫泥土': {'三普土类': '紫色土',
#    '三普亚类': '酸性紫色土',
#    '三普土属': '砂质酸性紫色土',
#    '三普土种': '中层砂质酸性紫色土'},
#   '砾质紫色土': {'三普土类': '紫色土',
#    '三普亚类': '酸性紫色土',
#    '三普土属': '砂质酸性紫色土',
#    '三普土种': '中层砂质酸性紫色土'},
#   '紫油泥': {'三普土类': '水稻土', '三普亚类': '潴育型  水稻土', '三普土属': '紫泥田', '三普土种': '紫泥田'},
#   '紫油砂土': {'三普土类': '紫色土',
#    '三普亚类': '中性紫色土',
#    '三普土属': '砂质中性紫色土',
#    '三普土种': '中层砂质中性紫色土'},
#   '紫泥': {'三普土类': '水稻土', '三普亚类': '潴育型  水稻土', '三普土属': '紫泥田', '三普土种': '紫泥田'},
#   '紫砂土': {'三普土类': '紫色土',
#    '三普亚类': '中性紫色土',
#    '三普土属': '砂质中性紫色土',
#    '三普土种': '中层砂质中性紫色土'},
#   '紫砂泥': {'三普土类': '水稻土', '三普亚类': '潴育型  水稻土', '三普土属': '紫泥田', '三普土种': '紫泥田'},
#   '紫色土': {'三普土类': '紫色土',
#    '三普亚类': '中性紫色土',
#    '三普土属': '壤质中性紫色土',
#    '三普土种': '中层壤质中性紫色土'},
#   '紫色大土': {'三普土类': '紫色土',
#    '三普亚类': '中性紫色土',
#    '三普土属': '壤质中性紫色土',
#    '三普土种': '中层壤质中性紫色土'},
#   '羊肝泥': {'三普土类': '水稻土', '三普亚类': '淹育型  水稻土', '三普土属': '浅血泥田', '三普土种': '红浅血泥田'},
#   '羊肝石土': {'三普土类': '紫色土',
#    '三普亚类': '中性紫色土',
#    '三普土属': '壤质中性紫色土',
#    '三普土种': '中层壤质中性紫色土'},
#   '苦大泥': {'三普土类': '水稻土', '三普亚类': '淹育型  水稻土', '三普土属': '浅灰泥田', '三普土种': '浅石灰泥田'},
#   '苦鸭屎泥': {'三普土类': '水稻土',
#    '三普亚类': '潜育型     水稻土',
#    '三普土属': '青灰泥田',
#    '三普土种': '青石灰泥田'},
#   '薄层次生黄色石灰土': {'三普土类': '石灰（岩）土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '腐薄层黏质黄色石灰土'},
#   '薄层淋溶黄色石灰土': {'三普土类': '石灰（岩）土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '腐薄层壤质黄色石灰土'},
#   '薄层硅质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤（自然土）',
#    '三普土属': '硅质黄壤',
#    '三普土种': '腐薄层硅质黄壤'},
#   '薄层硅质黄壤性土': {'三普土类': '黄壤',
#    '三普亚类': '黄壤性土',
#    '三普土属': '硅质黄壤性土',
#    '三普土种': '腐薄层硅质黄壤性土'},
#   '薄层硅铁质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤（自然土）',
#    '三普土属': '红泥质黄壤',
#    '三普土种': '腐薄层红泥质黄壤'},
#   '薄层硅铁质黄壤性土': {'三普土类': '黄壤',
#    '三普亚类': '黄壤性土',
#    '三普土属': '泥质黄壤性土',
#    '三普土种': '腐薄层泥质黄壤性土'},
#   '薄层硅铝质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤（自然土）',
#    '三普土属': '砂泥质黄壤',
#    '三普土种': '腐薄层砂泥质黄壤'},
#   '薄层硅铝质黄壤性土': {'三普土类': '黄壤',
#    '三普亚类': '黄壤性土',
#    '三普土属': '砂泥质黄壤性土',
#    '三普土种': '腐薄层砂泥质黄壤性土'},
#   '薄层酸性紫色土': {'三普土类': '紫色土',
#    '三普亚类': '酸性紫色土',
#    '三普土属': '壤质酸性紫色土',
#    '三普土种': '腐薄层酸性紫色土'},
#   '薄层铁铝质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤（自然土）',
#    '三普土属': '砂泥质黄壤',
#    '三普土种': '腐薄层砂泥质黄壤'},
#   '薄层黄色石灰土': {'三普土类': '石灰（岩）土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '腐薄层壤质黄色石灰土'},
#   '薄层黑色石灰土': {'三普土类': '石灰（岩）土',
#    '三普亚类': '黑色石灰土',
#    '三普土属': '壤质黑色石灰土',
#    '三普土种': '薄层壤质黑色石灰土'},
#   '血砂泥土': {'三普土类': '紫色土',
#    '三普亚类': '酸性紫色土',
#    '三普土属': '壤质酸性紫色土',
#    '三普土种': '中层壤质酸性紫色土'},
#   '豆办泥土': {'三普土类': '黄壤',
#    '三普亚类': '典型黄 壤（耕作土）',
#    '三普土属': '泥质黄壤',
#    '三普土种': '厚层泥质黄壤'},
#   '豆办砂泥': {'三普土类': '水稻土', '三普亚类': '淹育型  水稻土', '三普土属': '浅砂泥田', '三普土种': '黄浅砂泥田'},
#   '豆面泥土': {'三普土类': '黄壤',
#    '三普亚类': '典型黄 壤（耕作土）',
#    '三普土属': '砂泥质黄壤',
#    '三普土种': '薄层砂泥质黄壤'},
#   '轻白善泥': {'三普土类': '水稻土', '三普亚类': '漂洗型水稻土', '三普土属': '漂砂泥田', '三普土种': '轻漂砂泥田'},
#   '轻白胶泥': {'三普土类': '水稻土', '三普亚类': '漂洗型水稻土', '三普土属': '漂灰泥田', '三普土种': '轻漂灰泥田'},
#   '重白善泥': {'三普土类': '水稻土', '三普亚类': '漂洗型水稻土', '三普土属': '漂砂泥田', '三普土种': '重漂砂泥田'},
#   '重白胶泥': {'三普土类': '水稻土', '三普亚类': '漂洗型水稻土', '三普土属': '漂红泥田', '三普土种': '重漂红泥田'},
#   '锈水田': {'三普土类': '水稻土',
#    '三普亚类': '潜育型     水稻土',
#    '三普土属': '示例：青灰泥田',
#    '三普土种': '示例：黄青灰泥田'},
#   '黄大泥': {'三普土类': '水稻土', '三普亚类': '淹育型  水稻土', '三普土属': '浅灰泥田', '三普土种': '黄浅灰泥田'},
#   '黄油砂土': {'三普土类': '黄壤',
#    '三普亚类': '典型黄 壤（耕作土）',
#    '三普土属': '砂泥质黄壤',
#    '三普土种': '厚层砂泥质黄壤'},
#   '黄油砂泥': {'三普土类': '水稻土', '三普亚类': '潴育型  水稻土', '三普土属': '砂泥田', '三普土种': '黄砂泥田'},
#   '黄泥': {'三普土类': '水稻土', '三普亚类': '潴育型  水稻土', '三普土属': '砂泥田', '三普土种': '黄砂泥田'},
#   '黄泥土': {'三普土类': '黄壤',
#    '三普亚类': '典型黄 壤（耕作土）',
#    '三普土属': '红泥质黄壤',
#    '三普土种': '中层红泥质黄壤'},
#   '黄灰泡土': {'三普土类': '黄棕壤',
#    '三普亚类': '暗黄棕壤',
#    '三普土属': '泥质暗黄棕壤',
#    '三普土种': '厚层泥质暗黄棕壤'},
#   '黄石砂田': {'三普土类': '水稻土', '三普亚类': '淹育型  水稻土', '三普土属': '浅砂泥田', '三普土种': '黄浅砂泥田'},
#   '黄砂土': {'三普土类': '黄壤',
#    '三普亚类': '典型黄 壤（耕作土）',
#    '三普土属': '砂泥质黄壤',
#    '三普土种': '中层砂泥质黄壤'},
#   '黄砂泥': {'三普土类': '水稻土', '三普亚类': '淹育型  水稻土', '三普土属': '浅砂泥田', '三普土种': '黄浅砂泥田'},
#   '黄胶泥': {'三普土类': '水稻土', '三普亚类': '潴育型  水稻土', '三普土属': '红泥田', '三普土种': '黄红泥田'},
#   '黄胶泥土': {'三普土类': '黄壤', '三普亚类': '典型黄壤', '三普土属': '泥质黄壤', '三普土种': '厚层泥质黄壤'},
#   '黑潮泥': {'三普土类': '水稻土', '三普亚类': '潴育型  水稻土', '三普土属': '潮泥田', '三普土种': '潮泥田'},
#   '黑色油砂石': {'三普土类': '石灰（岩）土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '厚层壤质黄色石灰土'},
#   '黑色灰泡土': {'三普土类': '黄棕壤',
#    '三普亚类': '暗黄棕壤',
#    '三普土属': '泥质暗黄棕壤',
#    '三普土种': '厚层泥质暗黄棕壤'},
#   '龙凤大眼泥': {'三普土类': '水稻土',
#    '三普亚类': '潴育型  水稻土',
#    '三普土属': '灰泥田',
#    '三普土种': '黄石灰泥田'}},
#  122,
#  122)

# %%
# 去除字典中值和键的空格，并将中文括号替换为英文括号
result_dict = {str(k).strip(): {str(key).strip().replace('（', '(').replace('）', ')'): str(value).strip().replace('（', '(').replace('）', ')') for key, value in v.items()} for k, v in result_dict.items() if v}
result_dict, len(result_dict)
# Out:
# ({'中层次生黄色石灰土': {'三普土类': '石灰(岩)土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '中层黏质黄色石灰土'},
#   '中层淋溶黄色石灰土': {'三普土类': '石灰(岩)土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '腐中层壤质黄色石灰土'},
#   '中层硅质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤(自然土)',
#    '三普土属': '硅质黄壤',
#    '三普土种': '腐中层硅质黄壤'},
#   '中层硅铁质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤(自然土)',
#    '三普土属': '红泥质黄壤',
#    '三普土种': '腐中层红泥质黄壤'},
#   '中层硅铁质黄壤性土': {'三普土类': '黄壤',
#    '三普亚类': '黄壤性土',
#    '三普土属': '泥质黄壤性土',
#    '三普土种': '腐中层泥质黄壤性土'},
#   '中层硅铁质黄棕壤': {'三普土类': '黄棕壤',
#    '三普亚类': '暗黄棕壤',
#    '三普土属': '红泥质黄棕壤',
#    '三普土种': '腐中层红泥质黄棕壤'},
#   '中层硅铝质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤(自然土)',
#    '三普土属': '砂泥质黄壤',
#    '三普土种': '腐中层砂泥质黄壤'},
#   '中层硅铝质黄壤性土': {'三普土类': '黄壤',
#    '三普亚类': '黄壤性土',
#    '三普土属': '砂泥质黄壤性土',
#    '三普土种': '腐中层砂泥质黄壤性土'},
#   '中层硅铝质黄棕壤': {'三普土类': '黄棕壤',
#    '三普亚类': '暗黄棕壤',
#    '三普土属': '砂泥质黄棕壤',
#    '三普土种': '腐中层砂泥质黄棕壤'},
#   '中层紫色土': {'三普土类': '紫色土',
#    '三普亚类': '中性紫色土',
#    '三普土属': '壤质中性紫色土',
#    '三普土种': '腐中层壤质中性紫色土'},
#   '中层紫色沙土': {'三普土类': '紫色土',
#    '三普亚类': '中性紫色土',
#    '三普土属': '砂质中性紫色土',
#    '三普土种': '腐中层砂质中性紫色土'},
#   '中层酸性紫色土': {'三普土类': '紫色土',
#    '三普亚类': '酸性紫色土',
#    '三普土属': '壤质酸性紫色土',
#    '三普土种': '腐中层酸性紫色土'},
#   '中层酸性紫色砂土': {'三普土类': '紫色土',
#    '三普亚类': '酸性紫色土',
#    '三普土属': '砂质酸性紫色土',
#    '三普土种': '腐中层砂质酸性紫色土'},
#   '中层铁质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤(自然土)',
#    '三普土属': '暗泥质黄壤',
#    '三普土种': '中层暗泥质黄壤'},
#   '中层铁铝质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤(自然土)',
#    '三普土属': '砂泥质黄壤',
#    '三普土种': '腐中层砂泥质黄壤'},
#   '中层黄色石灰土': {'三普土类': '石灰(岩)土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '腐中层壤质黄色石灰土'},
#   '中层黑色石灰土': {'三普土类': '石灰(岩)土',
#    '三普亚类': '黑色石灰土',
#    '三普土属': '壤质黑色石灰土',
#    '三普土种': '中层壤质黑色石灰土'},
#   '中白善泥': {'三普土类': '水稻土', '三普亚类': '漂洗型水稻土', '三普土属': '漂砂泥田', '三普土种': '重漂砂泥田'},
#   '中白胶泥': {'三普土类': '水稻土', '三普亚类': '漂洗型水稻土', '三普土属': '漂红泥田', '三普土种': '轻漂红泥田'},
#   '冷水田': {'三普土类': '水稻土',
#    '三普亚类': '潴育型  水稻土',
#    '三普土属': '砂泥田或灰泥田等',
#    '三普土种': '砂泥田或灰泥田等'},
#   '冷浸田': {'三普土类': '水稻土',
#    '三普亚类': '潜育型     水稻土',
#    '三普土属': '青红泥田',
#    '三普土种': '黄青红泥田'},
#   '冷砂土': {'三普土类': '黄壤', '三普亚类': '黄壤性土', '三普土属': '砾质黄壤性土', '三普土种': '薄层砾质黄壤性土'},
#   '冷砂田': {'三普土类': '水稻土',
#    '三普亚类': '潜育型     水稻土',
#    '三普土属': '青砂泥田',
#    '三普土种': '黄青砂泥田'},
#   '厚层次生黄色石灰土': {'三普土类': '石灰(岩)土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '腐厚层壤质黄色石灰土'},
#   '厚层淋溶黄色石灰土': {'三普土类': '石灰(岩)土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '腐厚层壤质黄色石灰土'},
#   '厚层硅质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤(自然土)',
#    '三普土属': '暗泥质黄壤',
#    '三普土种': '腐厚层硅质黄壤'},
#   '厚层硅铁质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤(自然土)',
#    '三普土属': '红泥质黄壤',
#    '三普土种': '腐厚层红泥质黄壤'},
#   '厚层硅铁质黄壤性土': {'三普土类': '黄壤',
#    '三普亚类': '黄壤性土',
#    '三普土属': '泥质黄壤性土',
#    '三普土种': '腐厚层泥质黄壤性土'},
#   '厚层硅铁质黄棕壤': {'三普土类': '黄棕壤',
#    '三普亚类': '暗黄棕壤',
#    '三普土属': '红泥质黄棕壤',
#    '三普土种': '腐厚层红泥质黄棕壤'},
#   '厚层硅铝质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤(自然土)',
#    '三普土属': '砂泥质黄壤',
#    '三普土种': '腐厚层砂泥质黄壤'},
#   '厚层硅铝质黄壤性土': {'三普土类': '黄壤',
#    '三普亚类': '黄壤性土',
#    '三普土属': '砂泥质黄壤性土',
#    '三普土种': '腐厚层砂泥质黄壤性土'},
#   '厚层硅铝质黄棕壤': {'三普土类': '黄棕壤',
#    '三普亚类': '暗黄棕壤',
#    '三普土属': '砂泥质黄棕壤',
#    '三普土种': '腐厚层砂泥质黄棕壤'},
#   '厚层酸性紫色土': {'三普土类': '紫色土',
#    '三普亚类': '酸性紫色土',
#    '三普土属': '壤质酸性紫色土',
#    '三普土种': '腐厚层酸性紫色土'},
#   '厚层酸性紫色砂土': {'三普土类': '紫色土',
#    '三普亚类': '酸性紫色土',
#    '三普土属': '砂质酸性紫色土',
#    '三普土种': '腐厚层砂质酸性紫色土'},
#   '厚层铁质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤(自然土)',
#    '三普土属': '暗泥质黄壤',
#    '三普土种': '厚层暗泥质黄壤'},
#   '厚层铁铝质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤(自然土)',
#    '三普土属': '砂泥质黄壤',
#    '三普土种': '腐厚层砂泥质黄壤'},
#   '厚层黄色石灰土': {'三普土类': '石灰(岩)土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '腐厚层壤质黄色石灰土'},
#   '厚层黑色石灰土': {'三普土类': '黄壤',
#    '三普亚类': '黑色石灰土',
#    '三普土属': '壤质黑色石灰土',
#    '三普土种': '厚层壤质黑色石灰土'},
#   '大土泥': {'三普土类': '石灰(岩)土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '薄层壤质黄色石灰土'},
#   '大泥': {'三普土类': '水稻土', '三普亚类': '淹育型  水稻土', '三普土属': '浅灰泥田', '三普土种': '黄浅灰泥田'},
#   '大泥土': {'三普土类': '石灰(岩)土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '中层壤质黄色石灰土'},
#   '大眼泥': {'三普土类': '水稻土', '三普亚类': '潴育型  水稻土', '三普土属': '灰泥田', '三普土种': '黄石灰泥田'},
#   '寡黄泥': {'三普土类': '水稻土', '三普亚类': '淹育型  水稻土', '三普土属': '浅砂泥田', '三普土种': '黄浅砂泥田'},
#   '小土泥': {'三普土类': '石灰(岩)土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '薄层壤质黄色石灰土'},
#   '小黄泥': {'三普土类': '水稻土', '三普亚类': '潴育型  水稻土', '三普土属': '砂泥田', '三普土种': '黄砂泥田'},
#   '小黄泥土': {'三普土类': '黄壤',
#    '三普亚类': '典型黄 壤(耕作土)',
#    '三普土属': '红泥质黄壤',
#    '三普土种': '中层红泥质黄壤'},
#   '岩泥': {'三普土类': '石灰(岩)土',
#    '三普亚类': '黑色石灰土',
#    '三普土属': '壤质黑色石灰土',
#    '三普土种': '薄层壤质黑色石灰土'},
#   '岩灰泥': {'三普土类': '石灰(岩)土',
#    '三普亚类': '黑色石灰土',
#    '三普土属': '壤质黑色石灰土',
#    '三普土种': '薄层壤质黑色石灰土'},
#   '干鸭屎泥': {'三普土类': '水稻土', '三普亚类': '脱潜型水稻土', '三普土属': '黄灰泥田', '三普土种': '黄石灰泥田'},
#   '扁砂土': {'三普土类': '黄壤', '三普亚类': '黄壤性土', '三普土属': '砾质黄壤性土', '三普土种': '薄层砾质黄壤性土'},
#   '扁砂泥': {'三普土类': '水稻土', '三普亚类': '淹育型  水稻土', '三普土属': '浅鳝泥田', '三普土种': '黄浅鳝泥田'},
#   '死黄泥': {'三普土类': '水稻土', '三普亚类': '淹育型  水稻土', '三普土属': '浅红泥田', '三普土种': '黄浅红泥田'},
#   '死黄泥土': {'三普土类': '黄壤',
#    '三普亚类': '典型黄 壤(耕作土)',
#    '三普土属': '红泥质黄壤',
#    '三普土种': '厚层红泥质黄壤'},
#   '浅脚烂泥田': {'三普土类': '水稻土',
#    '三普亚类': '潜育型     水稻土',
#    '三普土属': '青砂泥田',
#    '三普土种': '黄青砂泥田'},
#   '浅血泥田': {'三普土类': '水稻土', '三普亚类': '潴育型  水稻土', '三普土属': '紫泥田', '三普土种': '酸性紫泥土'},
#   '深脚烂泥田': {'三普土类': '水稻土',
#    '三普亚类': '潜育型     水稻土',
#    '三普土属': '示例：青灰泥田',
#    '三普土种': '示例：黄青灰泥田'},
#   '湿鸭屎泥': {'三普土类': '水稻土',
#    '三普亚类': '潜育型     水稻土',
#    '三普土属': '青灰泥田',
#    '三普土种': '青石灰泥田'},
#   '潮泥': {'三普土类': '水稻土', '三普亚类': '潴育型  水稻土', '三普土属': '潮泥田', '三普土种': '潮泥田'},
#   '潮砂土': {'三普土类': '潮土', '三普亚类': '灰潮土', '三普土属': '砂质灰潮土', '三普土种': '中层砂质灰潮土'},
#   '潮砂泥': {'三普土类': '水稻土', '三普亚类': '潴育型  水稻土', '三普土属': '潮砂泥田', '三普土种': '潮砂泥田'},
#   '火石砂土': {'三普土类': '黄壤',
#    '三普亚类': '典型黄 壤(耕作土)',
#    '三普土属': '砂(砾)质黄壤',
#    '三普土种': '薄层砂砾质黄壤'},
#   '灰泡土': {'三普土类': '黄棕壤', '三普亚类': '暗黄棕壤', '三普土属': '泥质暗黄棕壤', '三普土种': '厚层泥质暗黄棕壤'},
#   '灰泡黄泥土': {'三普土类': '黄壤',
#    '三普亚类': '典型黄 壤(耕作土)',
#    '三普土属': '灰泥质黄壤',
#    '三普土种': '薄层灰泥质黄壤'},
#   '烂锈田': {'三普土类': '水稻土',
#    '三普亚类': '潜育型     水稻土',
#    '三普土属': '示例：青红泥田',
#    '三普土种': '示例：黄青红泥田'},
#   '热鸭屎泥': {'三普土类': '水稻土', '三普亚类': '脱潜型水稻土', '三普土属': '黄灰泥田', '三普土种': '黄石灰泥田'},
#   '煤锈田': {'三普土类': '水稻土',
#    '三普亚类': '潜育型     水稻土',
#    '三普土属': '示例：青砂泥田',
#    '三普土种': '示例：黄青砂泥田'},
#   '熟白善泥': {'三普土类': '水稻土', '三普亚类': '漂洗型水稻土', '三普土属': '漂砂泥田', '三普土种': '轻漂砂泥田'},
#   '熟白胶泥': {'三普土类': '水稻土', '三普亚类': '漂洗型水稻土', '三普土属': '漂灰泥田', '三普土种': '重漂灰泥田'},
#   '白云砂土': {'三普土类': '石灰(岩)土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '中层壤质黄色石灰土'},
#   '白大泥': {'三普土类': '水稻土', '三普亚类': '淹育型  水稻土', '三普土属': '浅灰泥田', '三普土种': '浅石灰泥田'},
#   '白砂土': {'三普土类': '黄壤',
#    '三普亚类': '典型黄 壤(耕作土)',
#    '三普土属': '砂(砾)质黄壤',
#    '三普土种': '薄层砂砾质黄壤'},
#   '白胶泥土': {'三普土类': '黄壤',
#    '三普亚类': '漂洗黄壤',
#    '三普土属': '红泥质漂洗黄壤',
#    '三普土种': '厚层红泥质漂洗黄壤'},
#   '石喳子土': {'三普土类': '黄壤', '三普亚类': '黄壤性土', '三普土属': '砾质黄壤性土', '三普土种': '薄层砾质黄壤性土'},
#   '砾石紫泥土': {'三普土类': '紫色土',
#    '三普亚类': '酸性紫色土',
#    '三普土属': '砂质酸性紫色土',
#    '三普土种': '中层砂质酸性紫色土'},
#   '砾质紫色土': {'三普土类': '紫色土',
#    '三普亚类': '酸性紫色土',
#    '三普土属': '砂质酸性紫色土',
#    '三普土种': '中层砂质酸性紫色土'},
#   '紫油泥': {'三普土类': '水稻土', '三普亚类': '潴育型  水稻土', '三普土属': '紫泥田', '三普土种': '紫泥田'},
#   '紫油砂土': {'三普土类': '紫色土',
#    '三普亚类': '中性紫色土',
#    '三普土属': '砂质中性紫色土',
#    '三普土种': '中层砂质中性紫色土'},
#   '紫泥': {'三普土类': '水稻土', '三普亚类': '潴育型  水稻土', '三普土属': '紫泥田', '三普土种': '紫泥田'},
#   '紫砂土': {'三普土类': '紫色土',
#    '三普亚类': '中性紫色土',
#    '三普土属': '砂质中性紫色土',
#    '三普土种': '中层砂质中性紫色土'},
#   '紫砂泥': {'三普土类': '水稻土', '三普亚类': '潴育型  水稻土', '三普土属': '紫泥田', '三普土种': '紫泥田'},
#   '紫色土': {'三普土类': '紫色土',
#    '三普亚类': '中性紫色土',
#    '三普土属': '壤质中性紫色土',
#    '三普土种': '中层壤质中性紫色土'},
#   '紫色大土': {'三普土类': '紫色土',
#    '三普亚类': '中性紫色土',
#    '三普土属': '壤质中性紫色土',
#    '三普土种': '中层壤质中性紫色土'},
#   '羊肝泥': {'三普土类': '水稻土', '三普亚类': '淹育型  水稻土', '三普土属': '浅血泥田', '三普土种': '红浅血泥田'},
#   '羊肝石土': {'三普土类': '紫色土',
#    '三普亚类': '中性紫色土',
#    '三普土属': '壤质中性紫色土',
#    '三普土种': '中层壤质中性紫色土'},
#   '苦大泥': {'三普土类': '水稻土', '三普亚类': '淹育型  水稻土', '三普土属': '浅灰泥田', '三普土种': '浅石灰泥田'},
#   '苦鸭屎泥': {'三普土类': '水稻土',
#    '三普亚类': '潜育型     水稻土',
#    '三普土属': '青灰泥田',
#    '三普土种': '青石灰泥田'},
#   '薄层次生黄色石灰土': {'三普土类': '石灰(岩)土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '腐薄层黏质黄色石灰土'},
#   '薄层淋溶黄色石灰土': {'三普土类': '石灰(岩)土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '腐薄层壤质黄色石灰土'},
#   '薄层硅质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤(自然土)',
#    '三普土属': '硅质黄壤',
#    '三普土种': '腐薄层硅质黄壤'},
#   '薄层硅质黄壤性土': {'三普土类': '黄壤',
#    '三普亚类': '黄壤性土',
#    '三普土属': '硅质黄壤性土',
#    '三普土种': '腐薄层硅质黄壤性土'},
#   '薄层硅铁质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤(自然土)',
#    '三普土属': '红泥质黄壤',
#    '三普土种': '腐薄层红泥质黄壤'},
#   '薄层硅铁质黄壤性土': {'三普土类': '黄壤',
#    '三普亚类': '黄壤性土',
#    '三普土属': '泥质黄壤性土',
#    '三普土种': '腐薄层泥质黄壤性土'},
#   '薄层硅铝质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤(自然土)',
#    '三普土属': '砂泥质黄壤',
#    '三普土种': '腐薄层砂泥质黄壤'},
#   '薄层硅铝质黄壤性土': {'三普土类': '黄壤',
#    '三普亚类': '黄壤性土',
#    '三普土属': '砂泥质黄壤性土',
#    '三普土种': '腐薄层砂泥质黄壤性土'},
#   '薄层酸性紫色土': {'三普土类': '紫色土',
#    '三普亚类': '酸性紫色土',
#    '三普土属': '壤质酸性紫色土',
#    '三普土种': '腐薄层酸性紫色土'},
#   '薄层铁铝质黄壤': {'三普土类': '黄壤',
#    '三普亚类': '典型黄壤(自然土)',
#    '三普土属': '砂泥质黄壤',
#    '三普土种': '腐薄层砂泥质黄壤'},
#   '薄层黄色石灰土': {'三普土类': '石灰(岩)土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '腐薄层壤质黄色石灰土'},
#   '薄层黑色石灰土': {'三普土类': '石灰(岩)土',
#    '三普亚类': '黑色石灰土',
#    '三普土属': '壤质黑色石灰土',
#    '三普土种': '薄层壤质黑色石灰土'},
#   '血砂泥土': {'三普土类': '紫色土',
#    '三普亚类': '酸性紫色土',
#    '三普土属': '壤质酸性紫色土',
#    '三普土种': '中层壤质酸性紫色土'},
#   '豆办泥土': {'三普土类': '黄壤',
#    '三普亚类': '典型黄 壤(耕作土)',
#    '三普土属': '泥质黄壤',
#    '三普土种': '厚层泥质黄壤'},
#   '豆办砂泥': {'三普土类': '水稻土', '三普亚类': '淹育型  水稻土', '三普土属': '浅砂泥田', '三普土种': '黄浅砂泥田'},
#   '豆面泥土': {'三普土类': '黄壤',
#    '三普亚类': '典型黄 壤(耕作土)',
#    '三普土属': '砂泥质黄壤',
#    '三普土种': '薄层砂泥质黄壤'},
#   '轻白善泥': {'三普土类': '水稻土', '三普亚类': '漂洗型水稻土', '三普土属': '漂砂泥田', '三普土种': '轻漂砂泥田'},
#   '轻白胶泥': {'三普土类': '水稻土', '三普亚类': '漂洗型水稻土', '三普土属': '漂灰泥田', '三普土种': '轻漂灰泥田'},
#   '重白善泥': {'三普土类': '水稻土', '三普亚类': '漂洗型水稻土', '三普土属': '漂砂泥田', '三普土种': '重漂砂泥田'},
#   '重白胶泥': {'三普土类': '水稻土', '三普亚类': '漂洗型水稻土', '三普土属': '漂红泥田', '三普土种': '重漂红泥田'},
#   '锈水田': {'三普土类': '水稻土',
#    '三普亚类': '潜育型     水稻土',
#    '三普土属': '示例：青灰泥田',
#    '三普土种': '示例：黄青灰泥田'},
#   '黄大泥': {'三普土类': '水稻土', '三普亚类': '淹育型  水稻土', '三普土属': '浅灰泥田', '三普土种': '黄浅灰泥田'},
#   '黄油砂土': {'三普土类': '黄壤',
#    '三普亚类': '典型黄 壤(耕作土)',
#    '三普土属': '砂泥质黄壤',
#    '三普土种': '厚层砂泥质黄壤'},
#   '黄油砂泥': {'三普土类': '水稻土', '三普亚类': '潴育型  水稻土', '三普土属': '砂泥田', '三普土种': '黄砂泥田'},
#   '黄泥': {'三普土类': '水稻土', '三普亚类': '潴育型  水稻土', '三普土属': '砂泥田', '三普土种': '黄砂泥田'},
#   '黄泥土': {'三普土类': '黄壤',
#    '三普亚类': '典型黄 壤(耕作土)',
#    '三普土属': '红泥质黄壤',
#    '三普土种': '中层红泥质黄壤'},
#   '黄灰泡土': {'三普土类': '黄棕壤',
#    '三普亚类': '暗黄棕壤',
#    '三普土属': '泥质暗黄棕壤',
#    '三普土种': '厚层泥质暗黄棕壤'},
#   '黄石砂田': {'三普土类': '水稻土', '三普亚类': '淹育型  水稻土', '三普土属': '浅砂泥田', '三普土种': '黄浅砂泥田'},
#   '黄砂土': {'三普土类': '黄壤',
#    '三普亚类': '典型黄 壤(耕作土)',
#    '三普土属': '砂泥质黄壤',
#    '三普土种': '中层砂泥质黄壤'},
#   '黄砂泥': {'三普土类': '水稻土', '三普亚类': '淹育型  水稻土', '三普土属': '浅砂泥田', '三普土种': '黄浅砂泥田'},
#   '黄胶泥': {'三普土类': '水稻土', '三普亚类': '潴育型  水稻土', '三普土属': '红泥田', '三普土种': '黄红泥田'},
#   '黄胶泥土': {'三普土类': '黄壤', '三普亚类': '典型黄壤', '三普土属': '泥质黄壤', '三普土种': '厚层泥质黄壤'},
#   '黑潮泥': {'三普土类': '水稻土', '三普亚类': '潴育型  水稻土', '三普土属': '潮泥田', '三普土种': '潮泥田'},
#   '黑色油砂石': {'三普土类': '石灰(岩)土',
#    '三普亚类': '黄色石  灰土',
#    '三普土属': '壤质黄色石灰土',
#    '三普土种': '厚层壤质黄色石灰土'},
#   '黑色灰泡土': {'三普土类': '黄棕壤',
#    '三普亚类': '暗黄棕壤',
#    '三普土属': '泥质暗黄棕壤',
#    '三普土种': '厚层泥质暗黄棕壤'},
#   '龙凤大眼泥': {'三普土类': '水稻土',
#    '三普亚类': '潴育型  水稻土',
#    '三普土属': '灰泥田',
#    '三普土种': '黄石灰泥田'}},
#  122)

# %%
file_path2 = r'F:\cache_data\shp_file\ky\filter_result_point.shp'

# %%
for one_name in arcpy.ListFields(file_path2):
    print(one_name.name)
# Out:
# FID
# Shape
# TL
# YL
# TS
# TZ
# label
# LON
# LAT
# DH

# %%
code_block =f"""
def get_soil_class(soil_code):
    
    soil_dict = {result_dict}
    if soil_code in soil_dict:
        return soil_dict[soil_code]['三普土种']
    else:
        return "NONE"
"""
field_name = "NEW_TZ"
expression = "get_soil_class(!TZ!)"

# %%
arcpy.CalculateField_management(in_table=file_path2, field=field_name, expression=expression, expression_type="PYTHON3", code_block=code_block)
# Out:
# <Result 'F:\\cache_data\\shp_file\\ky\\filter_result_point.shp'>

# %%
# 使用空间连接获取点位数据的地类名称、地质类别、坡位
point_layer = r"F:\cache_data\shp_file\ky\filter_result_point.shp"
dl_layer = r"F:\cache_data\shp_file\ky\ky_sd_polygon.shp"
dz_layer = r"F:\cache_data\shp_file\ky\ky_dzhaveriver_polygon.shp"
pw_layer = r"C:\Users\Runker\Desktop\slope_temp\ky_slope_postion_101_smooth_smooth.shp"

# %%
# 添加字段
add_field(input_table=point_layer,field_name="DL",field_type="TEXT")
add_field(input_table=point_layer,field_name="DLLB",field_type="TEXT")
add_field(input_table=point_layer,field_name="DZ",field_type="TEXT")
add_field(input_table=point_layer,field_name="PW",field_type="TEXT")

# %%
# 空间连接
output_layer = r"F:\cache_data\shp_file\ky\filter_result_point_join.shp"
perform_multiple_spatial_joins(point_layer,[
    {'join_layer':dl_layer,'output_layer':'filter_result_point_dl','field_mapping':{'DL':'DLMC'}},
    {'join_layer':dl_layer,'output_layer':'filter_result_point_dllb','field_mapping':{'LB':'DLLB'}},
    {'join_layer':dz_layer,'output_layer':'filter_result_point_dz','field_mapping':{'DZ':'MZMC'}},
    {'join_layer':pw_layer,'output_layer':'filter_result_point_pw','field_mapping':{'PW':'gridcode'}}
],final_output=output_layer)

# %% [markdown]
# # 获取地类类别

# %%
# 计算地类类别
def calc_soil_class(soil_code):
    dldm = str(soil_code)[:2]
    if dldm in ['01','02','12']:
        return '非自然土'
    elif dldm in ['03','04']:
        return '自然土'
    else:
        return '其他'
# Out:
# '非自然土'

# %%
import os
import shutil

# %%
in_dir = r'G:\data\第三次全国土壤普查\贵州省地理国情普查框架数据更新DEM（5米格网_2000坐标系）\G48'
# in_dir = r'G:\data\第三次全国土壤普查\贵州省地理国情普查框架数据更新DEM（5米格网_2000坐标系）\H48'
# in_dir = r'G:\data\第三次全国土壤普查\贵州省地理国情普查框架数据更新DEM（5米格网_2000坐标系）\H49'
out_dir = r'F:\ArcgisData\m5\qz'

# %%
# 复制指定范围的文件夹到指定路径
mid_min = 25   # 23
min_max = 39   # 06

tail_min = 65  # 66  001
tail_max = 75  # 47  008

def get_file_name(file_name):
    mid = file_name[4:7]
    tail = file_name[7:]
    # 判断mid 和tail是否可以转换位数字
    if mid.isdigit() and tail.isdigit():
        if int(mid) >= mid_min and int(mid) <= min_max and int(tail) >= tail_min and int(tail) <= tail_max:
            return True
    else:
        print(file_name)
        return False

# %%
for one_dir in os.listdir(in_dir):
    if get_file_name(one_dir):
        if not os.path.exists(os.path.join(out_dir,one_dir)):
            shutil.copytree(os.path.join(in_dir,one_dir),os.path.join(out_dir,one_dir))
    else:
        continue
# Out:
# _desktop.ini
