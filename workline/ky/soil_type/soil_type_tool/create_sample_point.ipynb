# %%
import os
import pandas as pd
import arcpy
from arcpy import env
from arcpy.management import *
from arcpy.sa import *
from arcpy.da import *
from arcpy.conversion import *
from arcpy.analysis import *
import numpy as np

# %%
# tool function
# 创建渔网
def create_net(output_file,extent_file,cell_size):
    """参数说明：
        output_file: 输出文件
        extent_file: 输入范围文件
        cell_size: 生成的cell大小
    """
    proj = arcpy.Describe(extent_file).spatialReference
    extent_x_min = arcpy.Describe(extent_file).extent.XMin
    extent_y_min = arcpy.Describe(extent_file).extent.YMin
    extent_x_max = arcpy.Describe(extent_file).extent.XMax
    extent_y_max = arcpy.Describe(extent_file).extent.YMax
    with arcpy.EnvManager(outputCoordinateSystem = proj):
        arcpy.management.CreateFishnet(out_feature_class=output_file,origin_coord=f"{extent_x_min} {extent_y_min}",y_axis_coord=f"{extent_x_min} {extent_y_min+10}",cell_width=cell_size,cell_height=cell_size,number_rows=None,number_columns=None,corner_coord=f"{extent_x_max} {extent_y_max}",labels="NO_LABELS",template="#",geometry_type="POLYGON")
# 面转点
def polygon_point(in_feature, out_feature):
    """参数说明：
        in_feature: 输入面
        out_feature: 输出点
    """
    proj = arcpy.Describe(in_feature).spatialReference
    with arcpy.EnvManager(outputCoordinateSystem=proj):
        arcpy.management.FeatureToPoint(in_features=in_feature,out_feature_class=out_feature,point_location="INSIDE")

# 筛选点

def select_point(input_polygon,input_point,output_point):
    """参数说明：
        input_polygon: 选择面
        input_point: 待选择点
        output_point: 选择点
    """
    polygon_layer = "polygonLayer"
    point_layer = "pointLayer"
    arcpy.MakeFeatureLayer_management(input_polygon, polygon_layer)
    arcpy.MakeFeatureLayer_management(input_point, point_layer)
    arcpy.SelectLayerByLocation_management(in_layer=point_layer, overlap_type="INTERSECT", select_features=polygon_layer,search_distance=0,selection_type='NEW_SELECTION',invert_spatial_relationship="NOT_INVERT")
    # 导出选择的要素
    arcpy.CopyFeatures_management(point_layer, output_point)

# 添加字段
def add_field(input_table,field_name,field_type='TEXT'):
    """参数说明：
        input_table: 输入数据表
        field_name: 字段名
        field_type: 字段类型"""
    arcpy.AddField_management(input_table,field_name,field_type)
# 删除要素
def delete_feature(input_feature):
    arcpy.Delete_management(input_feature)
# 空间连接
def perform_spatial_join(target_layer_path, join_layer_path, output_layer_path, field_mapping_dict):
    """参数说明：
        target_layer_path: 目标图层路径
        join_layer_path: 连接图层路径
        output_layer_path: 输出图层路径
        field_mapping_dict: 字段映射字典
    """
    # 创建 FieldMappings 对象
    field_mappings = arcpy.FieldMappings()

    # 为每个字段对创建 FieldMap 并添加到 FieldMappings
    for target_field, join_field in field_mapping_dict.items():
        field_map = arcpy.FieldMap()
        
        # 添加目标字段和连接字段到FieldMap
        field_map.addInputField(target_layer_path, target_field)
        field_map.addInputField(join_layer_path, join_field)
        
        # 设置输出字段属性
        output_field = field_map.outputField
        output_field.name = target_field
        output_field.aliasName = target_field
        field_map.outputField = output_field

        # 将 FieldMap 添加到 FieldMappings
        field_mappings.addFieldMap(field_map)

    # 执行空间连接操作
    arcpy.analysis.SpatialJoin(target_layer_path, join_layer_path, output_layer_path,"JOIN_ONE_TO_ONE", "KEEP_ALL", field_mappings)


# 点采样
def sample_point(point_,raster_,out_name):
    """根据栅格采样点,输出为表格"""
    Sample(raster_,point_,out_name,"NEAREST", "OBJECTID", "CURRENT_SLICE", None, '', None, None, "ROW_WISE", "TABLE")
    return None

# 导出CSV
def export_csv(table_,out_path,out_name):
    """参数说明：
        table_: 输入数据表
        out_path: 输出路径
        out_name: 输出表名"""
    TableToTable(table_,out_path,out_name)
    return None

# 要素转点
def feature_to_point(input_layer,output_layer):
    """参数说明："""
    proj = arcpy.Describe(input_layer).spatialReference
    with arcpy.EnvManager(outputCoordinateSystem=proj):
        arcpy.management.FeatureToPoint(input_layer, output_layer, "INSIDE")

# 删除多余字段
def delete_extra_fields(input_feature_class, fields_list):
    """参数说明："""
    fields = arcpy.ListFields(input_feature_class)
    for field in fields:
        name = field.name
        type = field.type.upper()
        # 如果字段名不在删选列表中且类型不为OID和Geometry便删除这个字段
        if name not in fields_list and type not in ['OID','GEOMETRY']:
            arcpy.DeleteField_management(input_feature_class, [name])

# %%
# 设置工作空间
env.workspace = r'D:\ArcGISProjects\workspace\shbyq\features_data_vector.gdb\features_ky'
env.overwriteOutput=True

# %%
def create_point(input_layer):
    """生成虚拟点"""
    # 定义文件名称
    fish_net_name = "temp_grid"
    net_to_point_name = "temp_inside_point"
    select_point_name = "select_point"
    result_point_name = "join_point"
    # 渔网构建
    create_net(fish_net_name,input_layer,300)
    # 要素转点
    polygon_point(fish_net_name,net_to_point_name)
    # 按位置选择
    select_point(input_layer,net_to_point_name,select_point_name)
    # 添加字段
    field_list = ['TL','YL','TS','TZ']
    for one_field in field_list:
        # 添加字段
        add_field(input_table=select_point_name,field_name=one_field,field_type='TEXT')
    # 空间连接赋予地类属性
    # 定义目标要素图层和连接要素图层的路径 检查面文件中的字段
    fields_mapping = {
        "TL": "TL",
        "YL": "YL",
        "TS": "TS",
        "TZ": "TZ"
    }
    # 空间连接
    perform_spatial_join(select_point_name,input_layer,result_point_name,fields_mapping)
    # 删除多余数据
    for one_feature in [fish_net_name,net_to_point_name,select_point_name]:
        delete_feature(one_feature)

# %%
# 生成渔网点
create_point(input_layer="ky_tl")

# %%
# 生成面内部点
feature_to_point(input_layer="ky_tl",output_layer="ky_tl_inner_point")

# %%
# 内部点字段整理
# 添加字段
input_feature = "ky_tl_inner_point"
field_list = ['TL','YL','TS','TZ']
# calc_field = "修改代号"
for one_field in field_list:
    # 添加字段
    add_field(input_table=input_feature,field_name=one_field,field_type='TEXT')
    # 注意：这里使用了Python表达式
    # arcpy.CalculateField_management(input_feature, one_field, f"!{calc_field}!", "PYTHON3")
# 删除多余字段
delete_extra_fields(input_feature, field_list)

# %%
# 渔网点字段整理
# 添加字段
input_feature = "join_point"
field_list = ['TL','YL','TS','TZ']
# 删除多余字段
delete_extra_fields(input_feature, field_list)

# %%
# 为两个点位数据增加label
feature_1 = "join_point"
feature_2 = "ky_tl_inner_point"
for one_feature in [[feature_1,'fish_net'],[feature_2,'inner']]:
    features = one_feature[0]
    labels = one_feature[1]
    field_name = "label"
    # 添加字段
    add_field(input_table=features,field_name="label",field_type='TEXT')
    # 注意：这里使用了Python表达式
    arcpy.CalculateField_management(features, field_name, f"'{labels}'", "PYTHON3")

# %%
# 合并点位数据
feature_1 = "join_point"
feature_2 = "ky_tl_inner_point"
output_feature = "filter_result_point_ky"
# 合并
arcpy.management.Merge([feature_1,feature_2],output_feature)
# 删除过渡文件
for one_feature in [feature_1,feature_2]:
    delete_feature(one_feature)

# %% [markdown]
# # 采样环节

# %%
# 对特征因子采样
# result table name
sample_csv_name = 'ky_frequency_filter_less_feature_TL.csv'
# 选择用于采样的特征因子数据库
stander_raster_gdb = r"D:\ArcGISProjects\workspace\shbyq\feature_raster_file\features_data_ky.gdb"
env.workspace = stander_raster_gdb # 切换工作空间用于采样
# 用于采样的特征因子列表
feature_list = arcpy.ListRasters()
len(feature_list)
# Out:
# 43

# %%
# 选择用于采样的要素类
point_data = r"D:\ArcGISProjects\workspace\shbyq\features_data_vector.gdb\features_ky\filter_result_point_ky"

# 用于存放采样表的数据库路径
sample_gdb_path = r"F:\cache_data\frequency_filter\ky"

# %%
# 采样点数据名称
sample_name =os.path.basename(point_data)
filed_list = [_.name for _ in arcpy.ListFields(point_data)]
print(filed_list)
# 需要保留的字段
# elements_yes = ['OBJECTID', 'TL','YL','TS','TZ']
elements_yes = ['OBJECTID', 'TL','YL','TS','TZ']
filter_list = [_ for _ in filed_list if _ in elements_yes]
print(filter_list)
# Out:
# ['OBJECTID', 'Shape', 'TL', 'YL', 'TS', 'TZ', 'label']
# ['OBJECTID', 'TL', 'YL', 'TS', 'TZ']

# %%
# 使用Delete_management函数删除数据库中的所有内容
try:
    arcpy.Delete_management(os.path.join(sample_gdb_path,'tabledata.gdb'))
except:
    pass
# 再创建一个新的数据库
arcpy.management.CreateFileGDB(sample_gdb_path, "tabledata", "CURRENT")
# Out:
# <Result 'F:\\cache_data\\frequency_filter\\ky\\tabledata.gdb'>

# %%
# 逐个采样并保存到csv文件
gdb_path = os.path.join(sample_gdb_path,"tabledata.gdb")
for one_feature in feature_list:
    print(one_feature)
    sample_point(point_data,one_feature,os.path.join(gdb_path,one_feature))
# Out:
# PRE
# SRA
# TMP
# VAP
# WIND
# BIO
# Contrast
# Correlation
# Dissimilarity
# Entropy
# Homogeneity
# Mean
# ndvi
# PCA_0
# PCA_1
# SecondMoment
# Variance
# LON
# LAT
# Aspect
# ChannelNetworkBaseLevel
# ChannelNetworkDistance
# ClosedDepressions
# ConvergenceIndex
# LSFactor
# PlanCurvature
# ProfileCurvature
# RelativeSlopePosition
# Slope
# TopographicPositionIndex
# TopographicWetnessIndex
# TotalCatchmentArea
# ValleyDepth
# DEM
# AnalyticalHillshading
# DL
# ASP_a
# TWI3_a
# TWI5_a
# TPI3_a
# TPI5_a
# DZ
# MRVBF_60

# %%
# 导出CSV表用于分析
env.workspace = gdb_path # 切换工作空间用于导出csv文件

# %%
# 读取数据表并保存到csv文件
result_df = pd.DataFrame(arcpy.da.FeatureClassToNumPyArray(point_data,filter_list+['label']))
result_df.rename(columns={"OBJECTID":sample_name},inplace=True)

# %%
#  读取每个表的最后一个字段的数据,存储每个表的最后一个字段的数据
for table in feature_list:
    print(table)
    # 将表转换为pandas数据帧
    # df = pd.DataFrame(arcpy.da.TableToNumPyArray(table, "*"))  # 确保数据表中无空值
    # df = pd.DataFrame(arcpy.da.TableToNumPyArray(table, "*",skip_nulls=False,null_value=99))  # 确保数据表中无空值
    df = pd.DataFrame(arcpy.da.TableToNumPyArray(table, "*",null_value=0))  # 确保数据表中无空值
    # 提取最后一个字段的数据
    merged_df = df[[sample_name, df.columns[-1]]]
    # 合并
    result_df = pd.merge(result_df, merged_df, on=[sample_name])
# 保存到csv文件
result_df.rename(columns=dict(zip(result_df.columns[-len(feature_list):], feature_list)),inplace=True)
result_df.drop(result_df.columns[0],axis=1,inplace=True)
# result_df.rename(columns={"PH":"PH_T"},inplace=True)
result_df.to_csv(os.path.join(sample_gdb_path,sample_csv_name),index=False,encoding='utf-8')
# Out:
# PRE
# SRA
# TMP
# VAP
# WIND
# BIO
# Contrast
# Correlation
# Dissimilarity
# Entropy
# Homogeneity
# Mean
# ndvi
# PCA_0
# PCA_1
# SecondMoment
# Variance
# LON
# LAT
# Aspect
# ChannelNetworkBaseLevel
# ChannelNetworkDistance
# ClosedDepressions
# ConvergenceIndex
# LSFactor
# PlanCurvature
# ProfileCurvature
# RelativeSlopePosition
# Slope
# TopographicPositionIndex
# TopographicWetnessIndex
# TotalCatchmentArea
# ValleyDepth
# DEM
# AnalyticalHillshading
# DL
# ASP_a
# TWI3_a
# TWI5_a
# TPI3_a
# TPI5_a
# DZ
# MRVBF_60

# %%
df = pd.read_csv(os.path.join(sample_gdb_path,sample_csv_name))
df
# Out:
#         TL     YL     TS       TZ     label        PRE        SRA        TMP  \
# 0       黄壤     黄壤  硅铁质黄壤  中层硅铁质黄壤  fish_net  92.416664  12677.500  15.166667
# 1       黄壤     黄壤  硅铁质黄壤  中层硅铁质黄壤  fish_net  92.416664  12677.500  15.166667
# 2       黄壤    黄泥土    黄泥土     死黄泥土  fish_net  92.416664  12677.500  15.166667
# 3       黄壤    黄泥土    黄泥土     死黄泥土  fish_net  92.416664  12677.500  15.166667
# 4      水稻土    潴育型     黄泥       黄泥  fish_net  92.666664  12655.333  14.883333
# ...    ...    ...    ...      ...       ...        ...        ...        ...
# 32431  水稻土    淹育型   坡塝黄泥      黄砂泥     inner  92.083336  12574.500  14.600000
# 32432  水稻土    淹育型   坡塝黄泥      黄砂泥     inner  95.083336  12565.667  13.566667
# 32433  水稻土    潴育型     黄泥       黄泥     inner  90.000000  12560.917  14.841667
# 32434  石灰土  黄色石灰土  黄色石灰土  薄层黄色石灰土     inner  90.166664  12640.083  15.783334
# 32435   黄壤    黄泥土    黄泥土      黄泥土     inner  92.250000  12630.250  14.866667
#
#             VAP      WIND  ...         DEM  AnalyticalHillshading  DL  \
# 0      1.469167  1.700000  ...   920.99240               1.253124   3
# 1      1.469167  1.700000  ...   999.21160               1.423982   3
# 2      1.469167  1.700000  ...   934.41064               1.022579   2
# 3      1.469167  1.700000  ...   879.38776               1.048102   3
# 4      1.444167  1.733333  ...  1105.48200               0.996057   7
# ...         ...       ...  ...         ...                    ...  ..
# 32431  1.403333  1.808333  ...  1184.11300               0.849817   7
# 32432  1.338333  1.916667  ...  1337.10000               0.785191   9
# 32433  1.432500  1.741667  ...   914.23083               0.893939   1
# 32434  1.510000  1.608333  ...   901.90564               0.497453   7
# 32435  1.432500  1.733333  ...  1041.44930               0.555250   9
#
#            ASP_a    TWI3_a    TWI5_a      TPI3_a      TPI5_a  DZ  MRVBF_60
# 0      112.93275  4.501821  5.012647  100.021430  100.051380   5  0.326753
# 1      146.01454  3.568255  4.079081  100.019540  100.039780   5  0.010064
# 2      167.66680  5.704602  6.215428  100.000490   99.998900   5  0.574630
# 3      156.46916  4.435872  4.946697  100.067880  100.172700   5  0.528471
# 4      149.77339  3.380327  3.891153   99.998405   99.991974   5  0.524177
# ...          ...       ...       ...         ...         ...  ..       ...
# 32431  233.49763  4.815844  5.326669  100.008800  100.010216   6  0.078464
# 32432   -1.00000  8.006368  8.517193  100.000000  100.000000   5  4.988244
# 32433  163.19098  3.937913  4.448739  100.004810  100.013260  20  2.978450
# 32434  336.46426  3.151996  3.662821  100.109500  100.226616   5  0.935338
# 32435  317.40292  5.621511  6.132337  100.005710  100.021576   5  1.476034
#
# [32436 rows x 48 columns]

# %%
file_path = r"D:\ArcGISProjects\workspace\shbyq\features_data_vector.gdb\features\dy_tl"

# %%
field_list = arcpy.ListFields(file_path)

# %%
for one_field in field_list:
    print(one_field.name)
# Out:
# OBJECTID
# Shape
# 土种代
# Shape_Leng
# 土类
# 亚类
# 土属
# 土种
# 土种编号
# Shape_Length
# Shape_Area

# %%
df2 = pd.DataFrame(arcpy.da.TableToNumPyArray(r"D:\ArcGISProjects\workspace\shbyq\features_data_vector.gdb\features\dy_tl", ["土类","亚类","土属","土种","土种编号"]))  # 确保数据表中无空值

# %%
# 对每个唯一的土种编号生成一个字典
def aggregate_rows(group):
    records = group[['土类', '亚类', '土属', '土种']].to_dict('records')
    # 假设每个土种编号下的记录是相同的，这里我们取第一个记录
    return records[0] if records else {}

# 使用groupby按照`土种编号`聚合，并应用自定义函数
soil_dict = df2.groupby('土种编号').apply(aggregate_rows).to_dict()

# %%
soil_dict,len(soil_dict)
# Out:
# ({'101': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型潮沙田', '土种': '潮板沙田'},
#   '102': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型黄泥田APWC或APBC', '土种': '黄泥田'},
#   '103': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型黄泥田APWC或APBC', '土种': '黄胶泥田'},
#   '104': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型黄泥田APWC或APBC', '土种': '小黄泥田'},
#   '105': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型黄泥田APWC或APBC', '土种': '黄油沙泥田'},
#   '106': {'土类': '水稻土',
#    '亚类': '潴育型水稻土',
#    '土属': '潴育型石灰性大眼泥田ARWC或APBC',
#    '土种': '大眼泥田'},
#   '107': {'土类': '水稻土',
#    '亚类': '潴育型水稻土',
#    '土属': '潴育型石灰性大眼泥田ARWC或APBC',
#    '土种': '龙凤大眼泥田'},
#   '108': {'土类': '水稻土',
#    '亚类': '潴育型水稻土',
#    '土属': '潴育型石灰性大眼泥田ARWC或APBC',
#    '土种': '大眼黄泥田'},
#   '112': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型潮泥田APWC或APWG', '土种': '潮沙田'},
#   '113': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型潮泥田APWC或APWG', '土种': '潮沙泥田'},
#   '114': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型潮泥田APWC或APWG', '土种': '潮泥田'},
#   '115': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型潮泥田APWC或APWG', '土种': '潮油沙泥田'},
#   '116': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型潮泥田APWC或APWG', '土种': '黑潮泥田'},
#   '117': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '冷水田', '土种': '冷水田'},
#   '118': {'土类': '水稻土',
#    '亚类': '潜育型水稻土',
#    '土属': '鸭屎泥潜育型石灰性草甸沼泽水稻土APGC或APG',
#    '土种': '湿鸭屎泥田'},
#   '119': {'土类': '水稻土',
#    '亚类': '潜育型水稻土',
#    '土属': '鸭屎泥潜育型石灰性草甸沼泽水稻土APGC或APG',
#    '土种': '干鸭屎泥田'},
#   '11f': {'土类': '黄壤', '亚类': '黄壤', '土属': '铁质黄壤', '土种': '薄腐殖层薄土层铁质黄壤'},
#   '120': {'土类': '水稻土',
#    '亚类': '潜育型水稻土',
#    '土属': '鸭屎泥潜育型石灰性草甸沼泽水稻土APGC或APG',
#    '土种': '熟鸭屎泥田'},
#   '125': {'土类': '水稻土', '亚类': '潜育型水稻土', '土属': '冷浸田APG或APWC', '土种': '冷浸田'},
#   '126': {'土类': '水稻土', '亚类': '潜育型水稻土', '土属': '冷浸田APG或APWC', '土种': '冷沙田'},
#   '129': {'土类': '水稻土', '亚类': '沼泽型水稻土', '土属': '烂泥田AG或AG-G', '土种': '深足烂泥田'},
#   '12b': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅质黄壤', '土种': '厚腐殖层中土层硅质黄壤'},
#   '12d': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅质黄壤', '土种': '薄腐殖层厚土层硅质黄壤'},
#   '12e': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅质黄壤', '土种': '厚腐殖层薄土层硅质黄壤'},
#   '12f': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅质黄壤', '土种': '薄腐殖层薄土层硅质黄壤'},
#   '130': {'土类': '水稻土', '亚类': '沼泽型水稻土', '土属': '烂泥田AG或AG-G', '土种': '浅足烂泥田'},
#   '131': {'土类': '水稻土', '亚类': '侧渗型水稻土', '土属': '白胶泥田A—P E—E(C)', '土种': '重白胶泥田'},
#   '135': {'土类': '水稻土',
#    '亚类': '侧渗型水稻土',
#    '土属': '白泥田A—P E—E(C)或A—P—E(C)',
#    '土种': '重白鳝泥田'},
#   '136': {'土类': '水稻土',
#    '亚类': '侧渗型水稻土',
#    '土属': '白泥田A—P E—E(C)或A—P—E(C)',
#    '土种': '中白鳝泥田'},
#   '139': {'土类': '水稻土', '亚类': '矿毒田', '土属': '锈毒田MA—MG  MA—P—C', '土种': '锈水田'},
#   '13d': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅铁质黄壤', '土种': '薄腐殖层厚土层硅铁质黄壤'},
#   '13e': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅铁质黄壤', '土种': '薄腐殖层中土层硅铁质黄壤'},
#   '13f': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅铁质黄壤', '土种': '薄腐殖层薄土层硅铁质黄壤'},
#   '141': {'土类': '水稻土', '亚类': '矿毒田', '土属': '锈毒田MA—MG  MA—P—C', '土种': '烂锈田'},
#   '143': {'土类': '水稻土', '亚类': '矿毒田', '土属': '其他矿毒田MA—MG  MA—P—C', '土种': '铅毒田'},
#   '14d': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅铝质黄壤', '土种': '薄腐殖层厚土层硅铝质黄壤'},
#   '14e': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅铝质黄壤', '土种': '薄腐殖层中土层硅铝质黄壤'},
#   '14f': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅铝质黄壤', '土种': '薄腐殖层薄土层硅铝质黄壤'},
#   '15d': {'土类': '黄壤', '亚类': '黄壤', '土属': '铁铝质黄壤', '土种': '薄腐殖层厚土层铁铝质黄壤'},
#   '15e': {'土类': '黄壤', '亚类': '黄壤', '土属': '铁铝质黄壤', '土种': '薄腐殖层中土层铁铝质黄壤'},
#   '15f': {'土类': '黄壤', '亚类': '黄壤', '土属': '铁铝质黄壤', '土种': '薄腐殖层薄土层铁铝质黄壤'},
#   '18e': {'土类': '黄壤', '亚类': '黄壤', '土属': '黄壤性土', '土种': '薄腐殖层中土层黄壤性土'},
#   '1e': {'土类': '山地灌丛草甸土',
#    '亚类': '山地灌丛草甸土',
#    '土属': '山地灌丛草甸土',
#    '土种': '薄腐殖层中土层山地灌丛草甸土'},
#   '1f': {'土类': '山地灌丛草甸土',
#    '亚类': '山地灌丛草甸土',
#    '土属': '山地灌丛草甸土',
#    '土种': '薄腐殖薄土层山地灌丛草甸土'},
#   '21': {'土类': '黄壤', '亚类': '黄泥土', '土属': '黄泥土', '土种': '死黄泥土'},
#   '22': {'土类': '黄壤', '亚类': '黄泥土', '土属': '黄泥土', '土种': '黄泥土'},
#   '23': {'土类': '黄壤', '亚类': '黄泥土', '土属': '黄泥土', '土种': '小黄泥土'},
#   '26': {'土类': '黄壤', '亚类': '黄泥土', '土属': '黄沙泥土', '土种': '黄沙泥土'},
#   '29': {'土类': '黄壤', '亚类': '黄泥土', '土属': '石砂土', '土种': '白沙土'},
#   '30': {'土类': '黄壤', '亚类': '黄泥土', '土属': '石砂土', '土种': '火石沙土'},
#   '31': {'土类': '黄壤', '亚类': '黄泥土', '土属': '石砂土', '土种': '偏沙土'},
#   '32': {'土类': '黄壤', '亚类': '黄泥土', '土属': '石砂土', '土种': '冷沙土'},
#   '33': {'土类': '黄壤', '亚类': '黄泥土', '土属': '石砂土', '土种': '石碴子土'},
#   '34': {'土类': '黄壤', '亚类': '黄泥土', '土属': '胶泥土', '土种': '黄胶泥土'},
#   '61e': {'土类': '石灰土', '亚类': '黑色石灰土', '土属': '黑色石灰土', '土种': '薄腐殖层中土层黑色石灰土'},
#   '61f': {'土类': '石灰土', '亚类': '黑色石灰土', '土属': '黑色石灰土', '土种': '薄腐殖层薄土层黑色石灰土'},
#   '63b': {'土类': '石灰土', '亚类': '黄色石灰土', '土属': '黄色石灰土', '土种': '厚腐殖层中土层黄色石灰土'},
#   '63d': {'土类': '石灰土', '亚类': '黄色石灰土', '土属': '黄色石灰土', '土种': '薄腐殖层厚土层黄色石灰土'},
#   '63e': {'土类': '石灰土', '亚类': '黄色石灰土', '土属': '黄色石灰土', '土种': '薄腐殖层中土层黄色石灰土'},
#   '63f': {'土类': '石灰土', '亚类': '黄色石灰土', '土属': '黄色石灰土', '土种': '薄腐殖层薄土层黄色石灰土'},
#   '64d': {'土类': '石灰土', '亚类': '黄色石灰土', '土属': '淋溶黄色石灰土', '土种': '薄腐殖层厚土层淋溶黄色石灰土'},
#   '65d': {'土类': '石灰土', '亚类': '黄色石灰土', '土属': '次生黄色石灰土', '土种': '薄腐殖层厚土层次生黄色石灰土'},
#   '65e': {'土类': '石灰土', '亚类': '黄色石灰土', '土属': '次生黄色石灰土', '土种': '薄腐殖层中土层次生黄色石灰土'},
#   '68': {'土类': '石灰土', '亚类': '大土泥', '土属': '大土泥', '土种': '大泥土'},
#   '69': {'土类': '石灰土', '亚类': '大土泥', '土属': '大土泥', '土种': '岩泥'},
#   '70': {'土类': '石灰土', '亚类': '大土泥', '土属': '小泥土', '土种': '小泥土'},
#   '72': {'土类': '石灰土', '亚类': '大土泥', '土属': '白沙土', '土种': '白云沙土'},
#   '76e': {'土类': '紫色土', '亚类': '酸性紫色土', '土属': '酸性紫色土', '土种': '薄腐殖层中土层酸性紫色土'},
#   '77.5': {'土类': '紫色土', '亚类': '酸性紫色土', '土属': '酸性紫色土', '土种': '薄腐殖层中土层紫色土'},
#   '79': {'土类': '紫色土', '亚类': '紫泥土', '土属': '紫泥土', '土种': '紫色土'},
#   '82': {'土类': '紫色土', '亚类': '紫泥土', '土属': '紫沙土', '土种': '紫沙土'},
#   '86': {'土类': '紫色土', '亚类': '紫泥土', '土属': '砾质紫沙土', '土种': '砾质紫沙土'},
#   '90': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型黄泥田AC或APC', '土种': '死黄泥田'},
#   '91': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型黄泥田AC或APC', '土种': '雾黄泥田'},
#   '92': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型黄泥田AC或APC', '土种': '黄沙泥田'},
#   '93': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型黄泥田AC或APC', '土种': '扁沙泥田'},
#   '94': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型黄泥田AC或APC', '土种': '黄石砂田'},
#   '95': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型石灰性大泥田APC', '土种': '黄大泥田'},
#   '96': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型石灰性大泥田APC', '土种': '大泥田'},
#   '97': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型石灰性大泥田APC', '土种': '苦大泥田'},
#   '98': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型石灰性大泥田APC', '土种': '马血泥田'},
#   'None': {'土类': 'None', '亚类': 'None', '土属': 'None', '土种': 'None'}},
#  82)

# %%
excel_path = r"C:\Users\Runker\Desktop\土壤属性表.xls"

# %%
df_excel = pd.read_excel(excel_path)
# 将土种编号一列设置为字符串类型
df_excel['土种编号'] = df_excel['土种编号'].astype(str)
df_excel
# Out:
#          土类       亚类                      土属              土种 土种编号
# 0   山地灌丛草甸土  山地灌丛草甸土                 山地灌丛草甸土  薄腐殖层中土层山地灌丛草甸土   1e
# 1   山地灌丛草甸土  山地灌丛草甸土                 山地灌丛草甸土   薄腐殖薄土层山地灌丛草甸土   1f
# 2        黄壤       黄壤                    铁质黄壤     薄腐殖层薄土层铁质黄壤  11f
# 3        黄壤       黄壤                    硅质黄壤     厚腐殖层中土层硅质黄壤  12b
# 4        黄壤       黄壤                    硅质黄壤     厚腐殖层薄土层硅质黄壤  12e
# ..      ...      ...                     ...             ...  ...
# 85      水稻土   侧渗型水稻土  白泥田A—P E—E(C)或A—P—E(C)            白沙泥田  137
# 86      水稻土      矿毒田        锈毒田MA—MG  MA—P—C             锈水田  139
# 87      水稻土      矿毒田        锈毒田MA—MG  MA—P—C             煤锈田  140
# 88      水稻土      矿毒田        锈毒田MA—MG  MA—P—C             烂锈田  141
# 89      水稻土      矿毒田      其他矿毒田MA—MG  MA—P—C             铅毒田  143
#
# [90 rows x 5 columns]

# %%
# 使用groupby按照`土种编号`聚合，并应用自定义函数
soil_excel = df_excel.groupby('土种编号').apply(aggregate_rows).to_dict()

# %%
soil_excel,len(soil_excel)
# Out:
# ({'101': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型潮沙田', '土种': '潮板沙田'},
#   '102': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型黄泥田APWC或APBC', '土种': '黄泥田'},
#   '103': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型黄泥田APWC或APBC', '土种': '黄胶泥田'},
#   '104': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型黄泥田APWC或APBC', '土种': '小黄泥田'},
#   '105': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型黄泥田APWC或APBC', '土种': '黄油沙泥田'},
#   '106': {'土类': '水稻土',
#    '亚类': '潴育型水稻土',
#    '土属': '潴育型石灰性大眼泥田ARWC或APBC',
#    '土种': '大眼泥田'},
#   '107': {'土类': '水稻土',
#    '亚类': '潴育型水稻土',
#    '土属': '潴育型石灰性大眼泥田ARWC或APBC',
#    '土种': '龙凤大眼泥田'},
#   '108': {'土类': '水稻土',
#    '亚类': '潴育型水稻土',
#    '土属': '潴育型石灰性大眼泥田ARWC或APBC',
#    '土种': '大眼黄泥田'},
#   '109': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型紫泥田', '土种': '浅紫泥田'},
#   '112': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型潮泥田APWC或APWG', '土种': '潮沙田'},
#   '113': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型潮泥田APWC或APWG', '土种': '潮沙泥田'},
#   '114': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型潮泥田APWC或APWG', '土种': '潮泥田'},
#   '115': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型潮泥田APWC或APWG', '土种': '潮油沙泥田'},
#   '116': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型潮泥田APWC或APWG', '土种': '黑潮泥田'},
#   '117': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '冷水田', '土种': '冷水田'},
#   '118': {'土类': '水稻土',
#    '亚类': '潜育型水稻土',
#    '土属': '鸭屎泥潜育型石灰性草甸沼泽水稻土APGC或APG',
#    '土种': '湿鸭屎泥田'},
#   '119': {'土类': '水稻土',
#    '亚类': '潜育型水稻土',
#    '土属': '鸭屎泥潜育型石灰性草甸沼泽水稻土APGC或APG',
#    '土种': '干鸭屎泥田'},
#   '11f': {'土类': '黄壤', '亚类': '黄壤', '土属': '铁质黄壤', '土种': '薄腐殖层薄土层铁质黄壤'},
#   '120': {'土类': '水稻土',
#    '亚类': '潜育型水稻土',
#    '土属': '鸭屎泥潜育型石灰性草甸沼泽水稻土APGC或APG',
#    '土种': '熟鸭屎泥田'},
#   '125': {'土类': '水稻土', '亚类': '潜育型水稻土', '土属': '冷浸田APG或APWC', '土种': '冷浸田'},
#   '126': {'土类': '水稻土', '亚类': '潜育型水稻土', '土属': '冷浸田APG或APWC', '土种': '冷沙田'},
#   '129': {'土类': '水稻土', '亚类': '沼泽型水稻土', '土属': '烂泥田AG或AG-G', '土种': '深足烂泥田'},
#   '12b': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅质黄壤', '土种': '厚腐殖层中土层硅质黄壤'},
#   '12d': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅质黄壤', '土种': '薄腐殖层厚土层硅质黄壤'},
#   '12e': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅质黄壤', '土种': '厚腐殖层薄土层硅质黄壤'},
#   '12f': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅质黄壤', '土种': '薄腐殖层薄土层硅质黄壤'},
#   '130': {'土类': '水稻土', '亚类': '沼泽型水稻土', '土属': '烂泥田AG或AG-G', '土种': '浅足烂泥田'},
#   '131': {'土类': '水稻土', '亚类': '侧渗型水稻土', '土属': '白胶泥田A—P E—E(C)', '土种': '重白胶泥田'},
#   '135': {'土类': '水稻土',
#    '亚类': '侧渗型水稻土',
#    '土属': '白泥田A—P E—E(C)或A—P—E(C)',
#    '土种': '重白鳝泥田'},
#   '136': {'土类': '水稻土',
#    '亚类': '侧渗型水稻土',
#    '土属': '白泥田A—P E—E(C)或A—P—E(C)',
#    '土种': '中白鳝泥田'},
#   '137': {'土类': '水稻土',
#    '亚类': '侧渗型水稻土',
#    '土属': '白泥田A—P E—E(C)或A—P—E(C)',
#    '土种': '白沙泥田'},
#   '139': {'土类': '水稻土', '亚类': '矿毒田', '土属': '锈毒田MA—MG  MA—P—C', '土种': '锈水田'},
#   '13d': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅铁质黄壤', '土种': '薄腐殖层厚土层硅铁质黄壤'},
#   '13e': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅铁质黄壤', '土种': '薄腐殖层中土层硅铁质黄壤'},
#   '13f': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅铁质黄壤', '土种': '薄腐殖层薄土层硅铁质黄壤'},
#   '140': {'土类': '水稻土', '亚类': '矿毒田', '土属': '锈毒田MA—MG  MA—P—C', '土种': '煤锈田'},
#   '141': {'土类': '水稻土', '亚类': '矿毒田', '土属': '锈毒田MA—MG  MA—P—C', '土种': '烂锈田'},
#   '143': {'土类': '水稻土', '亚类': '矿毒田', '土属': '其他矿毒田MA—MG  MA—P—C', '土种': '铅毒田'},
#   '14d': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅铝质黄壤', '土种': '薄腐殖层厚土层硅铝质黄壤'},
#   '14e': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅铝质黄壤', '土种': '薄腐殖层中土层硅铝质黄壤'},
#   '14f': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅铝质黄壤', '土种': '薄腐殖层薄土层硅铝质黄壤'},
#   '15d': {'土类': '黄壤', '亚类': '黄壤', '土属': '铁铝质黄壤', '土种': '薄腐殖层厚土层铁铝质黄壤'},
#   '15e': {'土类': '黄壤', '亚类': '黄壤', '土属': '铁铝质黄壤', '土种': '薄腐殖层中土层铁铝质黄壤'},
#   '15f': {'土类': '黄壤', '亚类': '黄壤', '土属': '铁铝质黄壤', '土种': '薄腐殖层薄土层铁铝质黄壤'},
#   '18e': {'土类': '黄壤', '亚类': '黄壤性土', '土属': '硅铝质黄壤性土', '土种': '薄腐殖层中土层黄壤性土'},
#   '1e': {'土类': '山地灌丛草甸土',
#    '亚类': '山地灌丛草甸土',
#    '土属': '山地灌丛草甸土',
#    '土种': '薄腐殖层中土层山地灌丛草甸土'},
#   '1f': {'土类': '山地灌丛草甸土',
#    '亚类': '山地灌丛草甸土',
#    '土属': '山地灌丛草甸土',
#    '土种': '薄腐殖薄土层山地灌丛草甸土'},
#   '21': {'土类': '黄壤', '亚类': '黄泥土', '土属': '黄泥土', '土种': '死黄泥土'},
#   '22': {'土类': '黄壤', '亚类': '黄泥土', '土属': '黄泥土', '土种': '黄泥土'},
#   '23': {'土类': '黄壤', '亚类': '黄泥土', '土属': '黄泥土', '土种': '小黄泥土'},
#   '26': {'土类': '黄壤', '亚类': '黄泥土', '土属': '黄沙泥土', '土种': '黄沙泥土'},
#   '29': {'土类': '黄壤', '亚类': '黄泥土', '土属': '石砂土', '土种': '白沙土'},
#   '30': {'土类': '黄壤', '亚类': '黄泥土', '土属': '石砂土', '土种': '火石沙土'},
#   '31': {'土类': '黄壤', '亚类': '黄泥土', '土属': '石砂土', '土种': '偏沙土'},
#   '32': {'土类': '黄壤', '亚类': '黄泥土', '土属': '石砂土', '土种': '冷沙土'},
#   '33': {'土类': '黄壤', '亚类': '黄泥土', '土属': '石砂土', '土种': '石碴子土'},
#   '34': {'土类': '黄壤', '亚类': '黄泥土', '土属': '胶泥土', '土种': '黄胶泥土'},
#   '36': {'土类': '黄壤', '亚类': '黄泥土', '土属': '胶泥土', '土种': '白胶泥土'},
#   '61d': {'土类': '石灰土', '亚类': '黑色石灰土', '土属': '黑色石灰土', '土种': '薄腐殖层厚土层黑色石灰土'},
#   '61e': {'土类': '石灰土', '亚类': '黑色石灰土', '土属': '黑色石灰土', '土种': '薄腐殖层中土层黑色石灰土'},
#   '61f': {'土类': '石灰土', '亚类': '黑色石灰土', '土属': '黑色石灰土', '土种': '薄腐殖层薄土层黑色石灰土'},
#   '63b': {'土类': '石灰土', '亚类': '黄色石灰土', '土属': '黄色石灰土', '土种': '厚腐殖层中土层黄色石灰土'},
#   '63d': {'土类': '石灰土', '亚类': '黄色石灰土', '土属': '黄色石灰土', '土种': '薄腐殖层厚土层黄色石灰土'},
#   '63e': {'土类': '石灰土', '亚类': '黄色石灰土', '土属': '黄色石灰土', '土种': '薄腐殖层中土层黄色石灰土'},
#   '63f': {'土类': '石灰土', '亚类': '黄色石灰土', '土属': '黄色石灰土', '土种': '薄腐殖层薄土层黄色石灰土'},
#   '64d': {'土类': '石灰土', '亚类': '黄色石灰土', '土属': '淋溶黄色石灰土', '土种': '薄腐殖层厚土层淋溶黄色石灰土'},
#   '65d': {'土类': '石灰土', '亚类': '黄色石灰土', '土属': '次生黄色石灰土', '土种': '薄腐殖层厚土层次生黄色石灰土'},
#   '65e': {'土类': '石灰土', '亚类': '黄色石灰土', '土属': '次生黄色石灰土', '土种': '薄腐殖层中土层次生黄色石灰土'},
#   '68': {'土类': '石灰土', '亚类': '大土泥', '土属': '大土泥', '土种': '大泥土'},
#   '69': {'土类': '石灰土', '亚类': '大土泥', '土属': '大土泥', '土种': '岩泥'},
#   '70': {'土类': '石灰土', '亚类': '大土泥', '土属': '小泥土', '土种': '小泥土'},
#   '72': {'土类': '石灰土', '亚类': '大土泥', '土属': '白沙土', '土种': '白云沙土'},
#   '72.5': {'土类': '石灰土', '亚类': '大土泥', '土属': '白沙土', '土种': '钙石子土'},
#   '74d': {'土类': '紫色土', '亚类': '钙质性宁性紫色土', '土属': '紫色土', '土种': '薄腐殖层厚土层紫色土'},
#   '74e': {'土类': '紫色土', '亚类': '钙质性宁性紫色土', '土属': '紫色土', '土种': '薄腐殖层中土层紫色土'},
#   '76e': {'土类': '紫色土', '亚类': '酸性紫色土', '土属': '酸性紫色土', '土种': '薄腐殖层中土层酸性紫色土'},
#   '77.5': {'土类': '紫色土', '亚类': '酸性紫色土', '土属': '酸性紫色土', '土种': '薄腐殖层中土层紫色土'},
#   '79': {'土类': '紫色土', '亚类': '紫泥土', '土属': '紫泥土', '土种': '紫色土'},
#   '82': {'土类': '紫色土', '亚类': '紫泥土', '土属': '紫沙土', '土种': '紫沙土'},
#   '86': {'土类': '紫色土', '亚类': '紫泥土', '土属': '砾质紫沙土', '土种': '砾质紫沙土'},
#   '90': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型黄泥田AC或APC', '土种': '死黄泥田'},
#   '91': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型黄泥田AC或APC', '土种': '雾黄泥田'},
#   '92': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型黄泥田AC或APC', '土种': '黄沙泥田'},
#   '93': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型黄泥田AC或APC', '土种': '扁沙泥田'},
#   '94': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型黄泥田AC或APC', '土种': '黄石砂田'},
#   '95': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型石灰性大泥田APC', '土种': '黄大泥田'},
#   '96': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型石灰性大泥田APC', '土种': '大泥田'},
#   '97': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型石灰性大泥田APC', '土种': '苦大泥田'},
#   '98': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型石灰性大泥田APC', '土种': '马血泥田'}},
#  89)

# %%
# 合并两个字典
result_dict = {**soil_dict, **soil_excel}
result_dict,len(result_dict)
# Out:
# ({'101': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型潮沙田', '土种': '潮板沙田'},
#   '102': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型黄泥田APWC或APBC', '土种': '黄泥田'},
#   '103': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型黄泥田APWC或APBC', '土种': '黄胶泥田'},
#   '104': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型黄泥田APWC或APBC', '土种': '小黄泥田'},
#   '105': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型黄泥田APWC或APBC', '土种': '黄油沙泥田'},
#   '106': {'土类': '水稻土',
#    '亚类': '潴育型水稻土',
#    '土属': '潴育型石灰性大眼泥田ARWC或APBC',
#    '土种': '大眼泥田'},
#   '107': {'土类': '水稻土',
#    '亚类': '潴育型水稻土',
#    '土属': '潴育型石灰性大眼泥田ARWC或APBC',
#    '土种': '龙凤大眼泥田'},
#   '108': {'土类': '水稻土',
#    '亚类': '潴育型水稻土',
#    '土属': '潴育型石灰性大眼泥田ARWC或APBC',
#    '土种': '大眼黄泥田'},
#   '112': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型潮泥田APWC或APWG', '土种': '潮沙田'},
#   '113': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型潮泥田APWC或APWG', '土种': '潮沙泥田'},
#   '114': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型潮泥田APWC或APWG', '土种': '潮泥田'},
#   '115': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型潮泥田APWC或APWG', '土种': '潮油沙泥田'},
#   '116': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型潮泥田APWC或APWG', '土种': '黑潮泥田'},
#   '117': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '冷水田', '土种': '冷水田'},
#   '118': {'土类': '水稻土',
#    '亚类': '潜育型水稻土',
#    '土属': '鸭屎泥潜育型石灰性草甸沼泽水稻土APGC或APG',
#    '土种': '湿鸭屎泥田'},
#   '119': {'土类': '水稻土',
#    '亚类': '潜育型水稻土',
#    '土属': '鸭屎泥潜育型石灰性草甸沼泽水稻土APGC或APG',
#    '土种': '干鸭屎泥田'},
#   '11f': {'土类': '黄壤', '亚类': '黄壤', '土属': '铁质黄壤', '土种': '薄腐殖层薄土层铁质黄壤'},
#   '120': {'土类': '水稻土',
#    '亚类': '潜育型水稻土',
#    '土属': '鸭屎泥潜育型石灰性草甸沼泽水稻土APGC或APG',
#    '土种': '熟鸭屎泥田'},
#   '125': {'土类': '水稻土', '亚类': '潜育型水稻土', '土属': '冷浸田APG或APWC', '土种': '冷浸田'},
#   '126': {'土类': '水稻土', '亚类': '潜育型水稻土', '土属': '冷浸田APG或APWC', '土种': '冷沙田'},
#   '129': {'土类': '水稻土', '亚类': '沼泽型水稻土', '土属': '烂泥田AG或AG-G', '土种': '深足烂泥田'},
#   '12b': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅质黄壤', '土种': '厚腐殖层中土层硅质黄壤'},
#   '12d': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅质黄壤', '土种': '薄腐殖层厚土层硅质黄壤'},
#   '12e': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅质黄壤', '土种': '厚腐殖层薄土层硅质黄壤'},
#   '12f': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅质黄壤', '土种': '薄腐殖层薄土层硅质黄壤'},
#   '130': {'土类': '水稻土', '亚类': '沼泽型水稻土', '土属': '烂泥田AG或AG-G', '土种': '浅足烂泥田'},
#   '131': {'土类': '水稻土', '亚类': '侧渗型水稻土', '土属': '白胶泥田A—P E—E(C)', '土种': '重白胶泥田'},
#   '135': {'土类': '水稻土',
#    '亚类': '侧渗型水稻土',
#    '土属': '白泥田A—P E—E(C)或A—P—E(C)',
#    '土种': '重白鳝泥田'},
#   '136': {'土类': '水稻土',
#    '亚类': '侧渗型水稻土',
#    '土属': '白泥田A—P E—E(C)或A—P—E(C)',
#    '土种': '中白鳝泥田'},
#   '139': {'土类': '水稻土', '亚类': '矿毒田', '土属': '锈毒田MA—MG  MA—P—C', '土种': '锈水田'},
#   '13d': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅铁质黄壤', '土种': '薄腐殖层厚土层硅铁质黄壤'},
#   '13e': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅铁质黄壤', '土种': '薄腐殖层中土层硅铁质黄壤'},
#   '13f': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅铁质黄壤', '土种': '薄腐殖层薄土层硅铁质黄壤'},
#   '141': {'土类': '水稻土', '亚类': '矿毒田', '土属': '锈毒田MA—MG  MA—P—C', '土种': '烂锈田'},
#   '143': {'土类': '水稻土', '亚类': '矿毒田', '土属': '其他矿毒田MA—MG  MA—P—C', '土种': '铅毒田'},
#   '14d': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅铝质黄壤', '土种': '薄腐殖层厚土层硅铝质黄壤'},
#   '14e': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅铝质黄壤', '土种': '薄腐殖层中土层硅铝质黄壤'},
#   '14f': {'土类': '黄壤', '亚类': '黄壤', '土属': '硅铝质黄壤', '土种': '薄腐殖层薄土层硅铝质黄壤'},
#   '15d': {'土类': '黄壤', '亚类': '黄壤', '土属': '铁铝质黄壤', '土种': '薄腐殖层厚土层铁铝质黄壤'},
#   '15e': {'土类': '黄壤', '亚类': '黄壤', '土属': '铁铝质黄壤', '土种': '薄腐殖层中土层铁铝质黄壤'},
#   '15f': {'土类': '黄壤', '亚类': '黄壤', '土属': '铁铝质黄壤', '土种': '薄腐殖层薄土层铁铝质黄壤'},
#   '18e': {'土类': '黄壤', '亚类': '黄壤性土', '土属': '硅铝质黄壤性土', '土种': '薄腐殖层中土层黄壤性土'},
#   '1e': {'土类': '山地灌丛草甸土',
#    '亚类': '山地灌丛草甸土',
#    '土属': '山地灌丛草甸土',
#    '土种': '薄腐殖层中土层山地灌丛草甸土'},
#   '1f': {'土类': '山地灌丛草甸土',
#    '亚类': '山地灌丛草甸土',
#    '土属': '山地灌丛草甸土',
#    '土种': '薄腐殖薄土层山地灌丛草甸土'},
#   '21': {'土类': '黄壤', '亚类': '黄泥土', '土属': '黄泥土', '土种': '死黄泥土'},
#   '22': {'土类': '黄壤', '亚类': '黄泥土', '土属': '黄泥土', '土种': '黄泥土'},
#   '23': {'土类': '黄壤', '亚类': '黄泥土', '土属': '黄泥土', '土种': '小黄泥土'},
#   '26': {'土类': '黄壤', '亚类': '黄泥土', '土属': '黄沙泥土', '土种': '黄沙泥土'},
#   '29': {'土类': '黄壤', '亚类': '黄泥土', '土属': '石砂土', '土种': '白沙土'},
#   '30': {'土类': '黄壤', '亚类': '黄泥土', '土属': '石砂土', '土种': '火石沙土'},
#   '31': {'土类': '黄壤', '亚类': '黄泥土', '土属': '石砂土', '土种': '偏沙土'},
#   '32': {'土类': '黄壤', '亚类': '黄泥土', '土属': '石砂土', '土种': '冷沙土'},
#   '33': {'土类': '黄壤', '亚类': '黄泥土', '土属': '石砂土', '土种': '石碴子土'},
#   '34': {'土类': '黄壤', '亚类': '黄泥土', '土属': '胶泥土', '土种': '黄胶泥土'},
#   '61e': {'土类': '石灰土', '亚类': '黑色石灰土', '土属': '黑色石灰土', '土种': '薄腐殖层中土层黑色石灰土'},
#   '61f': {'土类': '石灰土', '亚类': '黑色石灰土', '土属': '黑色石灰土', '土种': '薄腐殖层薄土层黑色石灰土'},
#   '63b': {'土类': '石灰土', '亚类': '黄色石灰土', '土属': '黄色石灰土', '土种': '厚腐殖层中土层黄色石灰土'},
#   '63d': {'土类': '石灰土', '亚类': '黄色石灰土', '土属': '黄色石灰土', '土种': '薄腐殖层厚土层黄色石灰土'},
#   '63e': {'土类': '石灰土', '亚类': '黄色石灰土', '土属': '黄色石灰土', '土种': '薄腐殖层中土层黄色石灰土'},
#   '63f': {'土类': '石灰土', '亚类': '黄色石灰土', '土属': '黄色石灰土', '土种': '薄腐殖层薄土层黄色石灰土'},
#   '64d': {'土类': '石灰土', '亚类': '黄色石灰土', '土属': '淋溶黄色石灰土', '土种': '薄腐殖层厚土层淋溶黄色石灰土'},
#   '65d': {'土类': '石灰土', '亚类': '黄色石灰土', '土属': '次生黄色石灰土', '土种': '薄腐殖层厚土层次生黄色石灰土'},
#   '65e': {'土类': '石灰土', '亚类': '黄色石灰土', '土属': '次生黄色石灰土', '土种': '薄腐殖层中土层次生黄色石灰土'},
#   '68': {'土类': '石灰土', '亚类': '大土泥', '土属': '大土泥', '土种': '大泥土'},
#   '69': {'土类': '石灰土', '亚类': '大土泥', '土属': '大土泥', '土种': '岩泥'},
#   '70': {'土类': '石灰土', '亚类': '大土泥', '土属': '小泥土', '土种': '小泥土'},
#   '72': {'土类': '石灰土', '亚类': '大土泥', '土属': '白沙土', '土种': '白云沙土'},
#   '76e': {'土类': '紫色土', '亚类': '酸性紫色土', '土属': '酸性紫色土', '土种': '薄腐殖层中土层酸性紫色土'},
#   '77.5': {'土类': '紫色土', '亚类': '酸性紫色土', '土属': '酸性紫色土', '土种': '薄腐殖层中土层紫色土'},
#   '79': {'土类': '紫色土', '亚类': '紫泥土', '土属': '紫泥土', '土种': '紫色土'},
#   '82': {'土类': '紫色土', '亚类': '紫泥土', '土属': '紫沙土', '土种': '紫沙土'},
#   '86': {'土类': '紫色土', '亚类': '紫泥土', '土属': '砾质紫沙土', '土种': '砾质紫沙土'},
#   '90': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型黄泥田AC或APC', '土种': '死黄泥田'},
#   '91': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型黄泥田AC或APC', '土种': '雾黄泥田'},
#   '92': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型黄泥田AC或APC', '土种': '黄沙泥田'},
#   '93': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型黄泥田AC或APC', '土种': '扁沙泥田'},
#   '94': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型黄泥田AC或APC', '土种': '黄石砂田'},
#   '95': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型石灰性大泥田APC', '土种': '黄大泥田'},
#   '96': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型石灰性大泥田APC', '土种': '大泥田'},
#   '97': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型石灰性大泥田APC', '土种': '苦大泥田'},
#   '98': {'土类': '水稻土', '亚类': '淹育型水稻土', '土属': '淹育型石灰性大泥田APC', '土种': '马血泥田'},
#   'None': {'土类': 'None', '亚类': 'None', '土属': 'None', '土种': 'None'},
#   '109': {'土类': '水稻土', '亚类': '潴育型水稻土', '土属': '潴育型紫泥田', '土种': '浅紫泥田'},
#   '137': {'土类': '水稻土',
#    '亚类': '侧渗型水稻土',
#    '土属': '白泥田A—P E—E(C)或A—P—E(C)',
#    '土种': '白沙泥田'},
#   '140': {'土类': '水稻土', '亚类': '矿毒田', '土属': '锈毒田MA—MG  MA—P—C', '土种': '煤锈田'},
#   '36': {'土类': '黄壤', '亚类': '黄泥土', '土属': '胶泥土', '土种': '白胶泥土'},
#   '61d': {'土类': '石灰土', '亚类': '黑色石灰土', '土属': '黑色石灰土', '土种': '薄腐殖层厚土层黑色石灰土'},
#   '72.5': {'土类': '石灰土', '亚类': '大土泥', '土属': '白沙土', '土种': '钙石子土'},
#   '74d': {'土类': '紫色土', '亚类': '钙质性宁性紫色土', '土属': '紫色土', '土种': '薄腐殖层厚土层紫色土'},
#   '74e': {'土类': '紫色土', '亚类': '钙质性宁性紫色土', '土属': '紫色土', '土种': '薄腐殖层中土层紫色土'}},
#  90)

# %%
file_path2 = r'D:\ArcGISProjects\workspace\shbyq\features_data_vector.gdb\features\dy_tl_dh'

# %%
for one_name in arcpy.ListFields(file_path2):
    print(one_name.name)
# Out:
# OBJECTID
# Shape
# 土种代
# 修改代号
# 修改过
# Shape_Length
# Shape_Area
# TL
# YL
# TS
# TZ

# %%
code_block =f"""
def get_soil_class(soil_code):
    
    soil_dict = {result_dict}
    if soil_code in soil_dict:
        return soil_dict[soil_code]['土类']
    else:
        return "NONE"
"""

# %%
expression = "get_soil_class(!修改代号!)"

# %%
field_name = "TL"

# %%
# 使用CalculateField_management执行更新
add_field(file_path2, field_name)

# %%
arcpy.CalculateField_management(in_table=file_path2, field=field_name, expression=expression, expression_type="PYTHON3", code_block=code_block)
# Out:
# <Result 'D:\\ArcGISProjects\\workspace\\shbyq\\features_data_vector.gdb\\features\\dy_tl_dh'>

# %%
df3 = pd.DataFrame(arcpy.da.TableToNumPyArray(file_path2, ["TL","YL","TS","TZ","修改代号"]))

# %%
df3['TL'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       水稻土
# 1       水稻土
# 2        黄壤
# 3       水稻土
# 4        黄壤
#        ...
# 1613     黄壤
# 1614    石灰土
# 1615    石灰土
# 1616    石灰土
# 1617    水稻土
# Name: TL, Length: 1618, dtype: object>

# %%
df_none = df3[df3['TZ'] == 'NONE']
df_none
# Out:
#         TL    YL    TS    TZ  修改代号
# 140   NONE  NONE  NONE  NONE   137
# 149   NONE  NONE  NONE  NONE    65
# 249   NONE  NONE  NONE  NONE    60
# 254   NONE  NONE  NONE  NONE   137
# 304   NONE  NONE  NONE  NONE   12c
# 359   NONE  NONE  NONE  NONE    63
# 451   NONE  NONE  NONE  NONE    65
# 481   NONE  NONE  NONE  NONE   138
# 510   NONE  NONE  NONE  NONE    65
# 545   NONE  NONE  NONE  NONE   18d
# 583   NONE  NONE  NONE  NONE   61d
# 649   NONE  NONE  NONE  NONE  72.5
# 669   NONE  NONE  NONE  NONE  72.5
# 693   NONE  NONE  NONE  NONE    65
# 824   NONE  NONE  NONE  NONE    15
# 832   NONE  NONE  NONE  NONE    2b
# 834   NONE  NONE  NONE  NONE   11e
# 887   NONE  NONE  NONE  NONE   137
# 1044  NONE  NONE  NONE  NONE   65f
# 1048  NONE  NONE  NONE  NONE   132
# 1172  NONE  NONE  NONE  NONE    63
# 1236  NONE  NONE  NONE  NONE   64f
# 1275  NONE  NONE  NONE  NONE   18d
# 1440  NONE  NONE  NONE  NONE   132
# 1466  NONE  NONE  NONE  NONE   12c
# 1507  NONE  NONE  NONE  NONE    20
# 1518  NONE  NONE  NONE  NONE   74d
# 1550  NONE  NONE  NONE  NONE    2f
# 1558  NONE  NONE  NONE  NONE    4d
# 1564  NONE  NONE  NONE  NONE    4f
# 1568  NONE  NONE  NONE  NONE    65
# 1569  NONE  NONE  NONE  NONE    67
# 1572  NONE  NONE  NONE  NONE    65
# 1575  NONE  NONE  NONE  NONE    4d
# 1577  NONE  NONE  NONE  NONE    4d
# 1578  NONE  NONE  NONE  NONE    2f
# 1581  NONE  NONE  NONE  NONE    24
# 1588  NONE  NONE  NONE  NONE    4e
# 1589  NONE  NONE  NONE  NONE    2f
# 1593  NONE  NONE  NONE  NONE   137
# 1594  NONE  NONE  NONE  NONE   137
# 1597  NONE  NONE  NONE  NONE    15

# %%
# 获取唯一值
a = df_none['修改代号'].unique().tolist()
print(a),print(len(a))
# Out:
# ['137', '65', '60', '12c', '63', '138', '18d', '61d', '72.5', '15', '2b', '11e', '65f', '132', '64f', '20', '74d', '2f', '4d', '4f', '67', '24', '4e']
# 23
# (None, None)

# %%
search_dict = {0: ['101'],
1: ['102'],
 2: ['103'],
 3: ['104'],
 4: ['105'],
 5: ['106'],
 6: ['107'],
 7: ['108'],
 8: ['112'],
 9: ['113'],
 10: ['114'],
 11: ['115'],
 12: ['116'],
 13: ['117'],
 14: ['118'],
 15: ['119'],
 16: ['11e'],
 17: ['120'],
 18: ['125'],
 19: ['126'],
 20: ['129'],
 21: ['12b'],
 22: ['12c'],
 23: ['12d'],
 24: ['12e'],
 25: ['12f'],
 26: ['130'],
 27: ['131'],
 28: ['132'],
 29: ['135'],
 30: ['136'],
 31: ['137'],
 32: ['138'],
 33: ['139'],
 34: ['13d'],
 35: ['13e'],
 36: ['13f'],
 37: ['141'],
 38: ['143'],
 39: ['14d'],
 40: ['14e'],
 41: ['14f'],
 42: ['15'],
 43: ['15d'],
 44: ['15e'],
 45: ['15f'],
 46: ['18d'],
 47: ['1e'],
 48: ['1f'],
 49: ['20'],
 50: ['21'],
 51: ['22'],
 52: ['23'],
 53: ['24'],
 54: ['26'],
 55: ['29'],
 56: ['2b'],
 57: ['2f'],
 58: ['30'],
 59: ['31'],
 60: ['32'],
 61: ['33'],
 62: ['34'],
 63: ['4d'],
 64: ['4e'],
 65: ['4f'],
 66: ['60'],
 67: ['61d'],
 68: ['61e'],
 69: ['61f'],
 70: ['63'],
 71: ['63b'],
 72: ['63d'],
 73: ['63e'],
 74: ['63f'],
 75: ['64d'],
 76: ['64f'],
 77: ['65'],
 78: ['65d'],
 79: ['65e'],
 80: ['65f'],
 81: ['67'],
 82: ['68'],
 83: ['69'],
 84: ['70'],
 85: ['72'],
 86: ['72.5'],
 87: ['74d'],
 88: ['76e'],
 89: ['77.5'],
 90: ['79'],
 91: ['82'],
 92: ['86'],
 93: ['90'],
 94: ['91'],
 95: ['92'],
 96: ['93'],
 97: ['94'],
 98: ['95'],
 99: ['96'],
 100: ['97'],
 101: ['98']}

# %%
result_path = r'D:\ArcGISProjects\workspace\shbyq\MyProject.gdb\RasterT_predict1'

# %%
for one_field in arcpy.ListFields(result_path):
    print(one_field.name)
# Out:
# OBJECTID
# Shape
# Id
# gridcode
# Shape_Length
# Shape_Area

# %%
# # 添加字段
# add_field(result_path, 'TL', 'TEXT')
# add_field(result_path, 'YL', 'TEXT')
# add_field(result_path, 'TS', 'TEXT')
# add_field(result_path, 'TZ', 'TEXT')

# %%
code_block =f"""
def get_soil_class(soil_code):
    search_dict = {search_dict}
    soil_dict = {result_dict}
    check_code = search_dict[soil_code][0]
    if check_code in soil_dict:
        return soil_dict[check_code]['土类']
    else:
        return "NONE"
"""
field_name = 'TL'

# %%
expression = "get_soil_class(!gridcode!)"

# %%
arcpy.CalculateField_management(in_table=result_path, field=field_name, expression=expression, expression_type="PYTHON3", code_block=code_block)
# Out:
# <Result 'D:\\ArcGISProjects\\workspace\\shbyq\\MyProject.gdb\\RasterT_predict1'>
