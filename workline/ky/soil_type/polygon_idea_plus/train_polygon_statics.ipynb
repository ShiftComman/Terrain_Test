# %%
import os
import arcpy
from arcpy import env
from arcpy.sa import *
from arcpy.da import *
import pandas as pd

# %%
def zonstatis(in_table, fields, value_raster,out_table):
    """统计分区矢量内的栅格信息
    :param in_table: 矢量分区
    :param fields: 矢量字段
    :param value_raster: 栅格数据
    :param out_table: 输出文件"""
    ZonalStatisticsAsTable(in_zone_data=in_table,zone_field=fields,in_value_raster=value_raster,out_table=out_table,ignore_nodata='#',statistics_type='ALL')

# %%
# 矢量数据路径
polygon_path = r"D:\ArcGISProjects\workspace\sp2024\MyProject.gdb\sb_polygon_tra_ExportFeature4"
# 栅格数据路径
raster_path = r'F:\tif_features\county_feature\sb'

# %%
# 统计结果表格存放路径
temp_table_gdb_path = r'F:\cache_data\zone_ana\sb\zone_temp.gdb'

# %%
# 使用Delete_management函数删除数据库中的所有内容
try:
    arcpy.Delete_management(temp_table_gdb_path)
except:
    pass
# 再创建一个新的数据库
arcpy.management.CreateFileGDB(os.path.dirname(temp_table_gdb_path), "zone_temp", "CURRENT")
# Out:
# <Result 'F:\\cache_data\\zone_ana\\sb\\zone_temp.gdb'>

# %%
# 切换工作空间
env.workspace = raster_path
env.overwriteOutput = True

# %%
# 获取需要处理的栅格列表
raster_list = arcpy.ListRasters()

# %%
raster_list
# Out:
# ['aligned_Analytical Hillshading.tif',
#  'aligned_Aspect.tif',
#  'aligned_Channel Network Base Level.tif',
#  'aligned_Channel Network Distance.tif',
#  'aligned_Closed Depressions.tif',
#  'aligned_Convergence Index.tif',
#  'aligned_dem.tif',
#  'aligned_ETP2022.tif',
#  'aligned_ETP2022_1.tif',
#  'aligned_ETP2022_10.tif',
#  'aligned_ETP2022_11.tif',
#  'aligned_ETP2022_12.tif',
#  'aligned_ETP2022_2.tif',
#  'aligned_ETP2022_3.tif',
#  'aligned_ETP2022_4.tif',
#  'aligned_ETP2022_5.tif',
#  'aligned_ETP2022_6.tif',
#  'aligned_ETP2022_7.tif',
#  'aligned_ETP2022_8.tif',
#  'aligned_ETP2022_9.tif',
#  'aligned_ETP2022_mean.tif',
#  'aligned_evi.tif',
#  'aligned_LS-Factor.tif',
#  'aligned_lswi.tif',
#  'aligned_mndwi.tif',
#  'aligned_ndmi.tif',
#  'aligned_ndvi.tif',
#  'aligned_ndwi.tif',
#  'aligned_NIGHT2022.tif',
#  'aligned_pca_1.tif',
#  'aligned_pca_2.tif',
#  'aligned_Plan Curvature.tif',
#  'aligned_PRE2022.tif',
#  'aligned_PRE2022_1.tif',
#  'aligned_PRE2022_10.tif',
#  'aligned_PRE2022_11.tif',
#  'aligned_PRE2022_12.tif',
#  'aligned_PRE2022_2.tif',
#  'aligned_PRE2022_3.tif',
#  'aligned_PRE2022_4.tif',
#  'aligned_PRE2022_5.tif',
#  'aligned_PRE2022_6.tif',
#  'aligned_PRE2022_7.tif',
#  'aligned_PRE2022_8.tif',
#  'aligned_PRE2022_9.tif',
#  'aligned_PRE2022_mean.tif',
#  'aligned_Profile Curvature.tif',
#  'aligned_Relative Slope Position.tif',
#  'aligned_savi.tif',
#  'aligned_Slope.tif',
#  'aligned_TMP2022.tif',
#  'aligned_TMP2022_1.tif',
#  'aligned_TMP2022_10.tif',
#  'aligned_TMP2022_11.tif',
#  'aligned_TMP2022_12.tif',
#  'aligned_TMP2022_2.tif',
#  'aligned_TMP2022_3.tif',
#  'aligned_TMP2022_4.tif',
#  'aligned_TMP2022_5.tif',
#  'aligned_TMP2022_6.tif',
#  'aligned_TMP2022_7.tif',
#  'aligned_TMP2022_8.tif',
#  'aligned_TMP2022_9.tif',
#  'aligned_TMP2022_mean.tif',
#  'aligned_Topographic Wetness Index.tif',
#  'aligned_Total Catchment Area.tif',
#  'aligned_Valley Depth.tif',
#  'aligned_vari.tif',
#  'clipped_dem.tif',
#  'DLMCN.tif',
#  'lat.tif',
#  'lon.tif',
#  'MRRTF.tif',
#  'MRVBF.tif',
#  'MZMC.tif',
#  'slope_postion_101.tif',
#  'slope_postion_101_smooth.tif']

# %%
[_.name for _ in arcpy.ListFields(polygon_path)]
# Out:
# ['OBJECTID',
#  'Shape',
#  'DLBM',
#  'DLMC',
#  'DLDM',
#  'MZMC',
#  'NEW_TL',
#  'NEW_YL',
#  'NEW_TS',
#  'NEW_TZ',
#  'Shape_Length',
#  'Shape_Area']

# %%
raster_list = ['aligned_Analytical Hillshading.tif',
 'aligned_Aspect.tif',
 'aligned_Channel Network Base Level.tif',
 'aligned_Channel Network Distance.tif',
 'aligned_Convergence Index.tif',
 'aligned_dem.tif',
 'aligned_ETP2022_3.tif',
 'aligned_ETP2022_8.tif',
 'aligned_ETP2022_mean.tif',
 'aligned_evi.tif',
 'aligned_LS-Factor.tif',
 'aligned_lswi.tif',
 'aligned_mndwi.tif',
 'aligned_ndmi.tif',
 'aligned_ndvi.tif',
 'aligned_ndwi.tif',
 'aligned_NIGHT2022.tif',
 'aligned_pca_1.tif',
 'aligned_pca_2.tif',
 'aligned_Plan Curvature.tif',
 'aligned_PRE2022_3.tif',
 'aligned_PRE2022_8.tif',
 'aligned_PRE2022_mean.tif',
 'aligned_Profile Curvature.tif',
 'aligned_Relative Slope Position.tif',
 'aligned_savi.tif',
 'aligned_Slope.tif',
 'aligned_TMP2022_3.tif',
 'aligned_TMP2022_8.tif',
 'aligned_TMP2022_mean.tif',
 'aligned_Topographic Wetness Index.tif',
 'aligned_Total Catchment Area.tif',
 'aligned_Valley Depth.tif',
 'aligned_vari.tif',
 'MRRTF.tif',
 'MRVBF.tif',
 'slope_postion_101_smooth.tif']

# %%
# 逐一统计分析
for one_raster in raster_list:
    raster_name = str(one_raster.split('.')[0]).replace(' ','_').replace('-','_')

    print(raster_name)
    print(one_raster)
    # 分区统计
    zonstatis(polygon_path,'OBJECTID',one_raster,os.path.join(temp_table_gdb_path,raster_name))
# Out:
# aligned_Analytical_Hillshading
# aligned_Analytical Hillshading.tif
# aligned_Aspect
# aligned_Aspect.tif
# aligned_Channel_Network_Base_Level
# aligned_Channel Network Base Level.tif
# aligned_Channel_Network_Distance
# aligned_Channel Network Distance.tif
# aligned_Convergence_Index
# aligned_Convergence Index.tif
# aligned_dem
# aligned_dem.tif
# aligned_ETP2022_3
# aligned_ETP2022_3.tif
# aligned_ETP2022_8
# aligned_ETP2022_8.tif
# aligned_ETP2022_mean
# aligned_ETP2022_mean.tif
# aligned_evi
# aligned_evi.tif
# aligned_LS_Factor
# aligned_LS-Factor.tif
# aligned_lswi
# aligned_lswi.tif
# aligned_mndwi
# aligned_mndwi.tif
# aligned_ndmi
# aligned_ndmi.tif
# aligned_ndvi
# aligned_ndvi.tif
# aligned_ndwi
# aligned_ndwi.tif
# aligned_NIGHT2022
# aligned_NIGHT2022.tif
# aligned_pca_1
# aligned_pca_1.tif
# aligned_pca_2
# aligned_pca_2.tif
# aligned_Plan_Curvature
# aligned_Plan Curvature.tif
# aligned_PRE2022_3
# aligned_PRE2022_3.tif
# aligned_PRE2022_8
# aligned_PRE2022_8.tif
# aligned_PRE2022_mean
# aligned_PRE2022_mean.tif
# aligned_Profile_Curvature
# aligned_Profile Curvature.tif
# aligned_Relative_Slope_Position
# aligned_Relative Slope Position.tif
# aligned_savi
# aligned_savi.tif
# aligned_Slope
# aligned_Slope.tif
# aligned_TMP2022_3
# aligned_TMP2022_3.tif
# aligned_TMP2022_8
# aligned_TMP2022_8.tif
# aligned_TMP2022_mean
# aligned_TMP2022_mean.tif
# aligned_Topographic_Wetness_Index
# aligned_Topographic Wetness Index.tif
# aligned_Total_Catchment_Area
# aligned_Total Catchment Area.tif
# aligned_Valley_Depth
# aligned_Valley Depth.tif
# aligned_vari
# aligned_vari.tif
# MRRTF
# MRRTF.tif
# MRVBF
# MRVBF.tif
# slope_postion_101_smooth
# slope_postion_101_smooth.tif

# %% [markdown]
# ### 构造训练表

# %%
# 切换工作空间
env.workspace = temp_table_gdb_path

# %%
# 获取表格列表
table_list = arcpy.ListTables()

# %%
# 指定需要的信息
line_fields = 'OBJECTID'
df_list = []
for one_table in table_list:
    # 将表转换为pandas数据帧
    df = pd.DataFrame(arcpy.da.TableToNumPyArray(one_table, "*"))  # 确保数据表中无空值
    # 提取统计字段的数据
    merged_df = df[[line_fields]+ list(df.columns[-10:])]
    # 在统计数据列名中添加表名
    merged_df.columns = [line_fields]+[one_table + '_' + col for col in merged_df.columns[-10:]]
    # 添加到列表
    df_list.append(merged_df)
# 初始合并数据帧
df_merged = df_list[0]
# 逐个合并其余的数据帧
for df in df_list[1:]:
    df_merged = pd.merge(df_merged, df, on=line_fields, how='outer')

# %%
df_merged
# Out:
#       OBJECTID  aligned_AnalyticalHillshading_COUNT  \
# 0            1                              10641.0
# 1            2                              13674.0
# 2            3                               4639.0
# 3            4                              28124.0
# 4            5                              12313.0
# ...        ...                                  ...
# 7046      7047                                237.0
# 7047      7048                                 96.0
# 7048      7049                                617.0
# 7049      7050                                453.0
# 7050      7051                                643.0
#
#       aligned_AnalyticalHillshading_AREA  aligned_AnalyticalHillshading_MIN  \
# 0                               266025.0                           0.217937
# 1                               341850.0                           0.474396
# 2                               115975.0                           0.527980
# 3                               703100.0                           0.005224
# 4                               307825.0                           0.171101
# ...                                  ...                                ...
# 7046                              5925.0                           0.229854
# 7047                              2400.0                           0.368239
# 7048                             15425.0                           0.298640
# 7049                             11325.0                           0.281637
# 7050                             16075.0                           0.545580
#
#       aligned_AnalyticalHillshading_MAX  aligned_AnalyticalHillshading_RANGE  \
# 0                              1.810760                             1.592823
# 1                              1.738472                             1.264076
# 2                              1.684530                             1.156551
# 3                              1.947900                             1.942676
# 4                              1.858746                             1.687645
# ...                                 ...                                  ...
# 7046                           0.912072                             0.682218
# 7047                           1.122485                             0.754246
# 7048                           1.108769                             0.810129
# 7049                           1.579640                             1.298003
# 7050                           1.249540                             0.703960
#
#       aligned_AnalyticalHillshading_MEAN  aligned_AnalyticalHillshading_STD  \
# 0                               1.089316                           0.216378
# 1                               1.078805                           0.175993
# 2                               1.210061                           0.176860
# 3                               0.908927                           0.402533
# 4                               1.187870                           0.259191
# ...                                  ...                                ...
# 7046                            0.738196                           0.072696
# 7047                            0.829170                           0.256710
# 7048                            0.641912                           0.102504
# 7049                            0.814878                           0.201756
# 7050                            0.876335                           0.105009
#
#       aligned_AnalyticalHillshading_SUM  aligned_AnalyticalHillshading_MEDIAN  \
# 0                          11591.407721                              1.105346
# 1                          14751.586378                              1.089436
# 2                           5613.474088                              1.231632
# 3                          25562.672947                              1.002194
# 4                          14626.239416                              1.233034
# ...                                 ...                                   ...
# 7046                         174.952354                              0.746210
# 7047                          79.600368                              0.969702
# 7048                         396.059828                              0.631680
# 7049                         369.139821                              0.799876
# 7050                         563.483520                              0.869092
#
#       ...  slope_postion_101_smooth_MAX  slope_postion_101_smooth_RANGE  \
# 0     ...                             4                               0
# 1     ...                             4                               0
# 2     ...                             5                               1
# 3     ...                             5                               3
# 4     ...                             5                               1
# ...   ...                           ...                             ...
# 7046  ...                             2                               1
# 7047  ...                             4                               0
# 7048  ...                             4                               2
# 7049  ...                             1                               0
# 7050  ...                             4                               0
#
#       slope_postion_101_smooth_MEAN  slope_postion_101_smooth_STD  \
# 0                          4.000000                      0.000000
# 1                          4.000000                      0.000000
# 2                          4.997844                      0.046379
# 3                          3.994702                      0.108357
# 4                          4.001949                      0.044106
# ...                             ...                           ...
# 7046                       1.004219                      0.064820
# 7047                       4.000000                      0.000000
# 7048                       2.009724                      0.139120
# 7049                       1.000000                      0.000000
# 7050                       4.000000                      0.000000
#
#       slope_postion_101_smooth_SUM  slope_postion_101_smooth_VARIETY  \
# 0                          42564.0                                 1
# 1                          54696.0                                 1
# 2                          23185.0                                 2
# 3                         112347.0                                 3
# 4                          49276.0                                 2
# ...                            ...                               ...
# 7046                         238.0                                 2
# 7047                         384.0                                 1
# 7048                        1240.0                                 2
# 7049                         453.0                                 1
# 7050                        2572.0                                 1
#
#       slope_postion_101_smooth_MAJORITY  slope_postion_101_smooth_MINORITY  \
# 0                                     4                                  4
# 1                                     4                                  4
# 2                                     5                                  4
# 3                                     4                                  5
# 4                                     4                                  5
# ...                                 ...                                ...
# 7046                                  1                                  2
# 7047                                  4                                  4
# 7048                                  2                                  4
# 7049                                  1                                  1
# 7050                                  4                                  4
#
#       slope_postion_101_smooth_MEDIAN  slope_postion_101_smooth_PCT90
# 0                                   4                               4
# 1                                   4                               4
# 2                                   5                               5
# 3                                   4                               4
# 4                                   4                               4
# ...                               ...                             ...
# 7046                                1                               1
# 7047                                4                               4
# 7048                                2                               2
# 7049                                1                               1
# 7050                                4                               4
#
# [7051 rows x 411 columns]

# %%
polygon_path = polygon_path

# %%
# 添加字段
def add_field(input_table,field_name,field_type='DOUBLE'):
    """参数说明：
        input_table: 输入数据表
        field_name: 字段名
        field_type: 字段类型"""
    arcpy.AddField_management(input_table,field_name,field_type)

# %%
# 新增面特征信息
# 添加新字段来存储四至坐标
for one_fields in ['XMin', 'YMin', 'XMax', 'YMax','Centroid_X','Centroid_Y']:
    add_field(polygon_path,one_fields)

# %%
# 更新字段值
with arcpy.da.UpdateCursor(polygon_path, ["SHAPE@", "XMin", "YMin", "XMax", "YMax", "Centroid_X", "Centroid_Y"]) as cursor:
    for row in cursor:
        centroid = row[0].centroid
        extent = row[0].extent
        row[1] = extent.XMin
        row[2] = extent.YMin
        row[3] = extent.XMax
        row[4] = extent.YMax
        row[5] = centroid.X
        row[6] = centroid.Y
        cursor.updateRow(row)

print("四至坐标计算完成并存储在新字段中。")
# Out:
# 四至坐标计算完成并存储在新字段中。

# %%
polygon_fields_list = [_.name for _ in arcpy.ListFields(polygon_path)]

# %%
print(polygon_fields_list)
# Out:
# ['OBJECTID', 'Shape', 'DLBM', 'DLMC', 'DLDM', 'MZMC', 'NEW_TL', 'NEW_YL', 'NEW_TS', 'NEW_TZ', 'Shape_Length', 'Shape_Area', 'XMin', 'YMin', 'XMax', 'YMax', 'Centroid_X', 'Centroid_Y']

# %%
polygon_df = pd.DataFrame(arcpy.da.FeatureClassToNumPyArray(polygon_path, ['OBJECTID', 'DLMC', 'DLDM', 'MZMC', 'NEW_TL', 'NEW_YL', 'NEW_TS', 'NEW_TZ','Centroid_X', 'Centroid_Y']))

# %%
polygon_df
# Out:
#       OBJECTID  DLMC DLDM      MZMC NEW_TL  NEW_YL  NEW_TS    NEW_TZ  \
# 0            1  乔木林地   03        板岩    黄棕壤    暗黄棕壤  泥质暗黄棕壤  腐薄层泥质黄棕壤
# 1            2  其他林地   03        板岩    黄棕壤    暗黄棕壤  泥质暗黄棕壤  腐薄层泥质黄棕壤
# 2            3  乔木林地   03        板岩    黄棕壤    暗黄棕壤  泥质暗黄棕壤  腐薄层泥质黄棕壤
# 3            4  乔木林地   03        板岩    黄棕壤    暗黄棕壤  泥质暗黄棕壤  腐薄层泥质黄棕壤
# 4            5  乔木林地   03        板岩    黄棕壤    暗黄棕壤  泥质暗黄棕壤  腐薄层泥质黄棕壤
# ...        ...   ...  ...       ...    ...     ...     ...       ...
# 7046      7048    水田   01  紫红色砂(页)岩    水稻土  潴育型水稻土     紫泥田       紫泥田
# 7047      7049    水田   01  紫红色砂(页)岩    水稻土  潴育型水稻土     紫泥田       紫泥田
# 7048      7050    水田   01  紫红色砂(页)岩    水稻土  潴育型水稻土     紫泥田       紫泥田
# 7049      7051    水田   01  紫红色砂(页)岩    水稻土  潴育型水稻土     紫泥田       紫泥田
# 7050      7052    水田   01  紫红色砂(页)岩    水稻土  潴育型水稻土     紫泥田       紫泥田
#
#          Centroid_X    Centroid_Y
# 0     508742.996211  3.024631e+06
# 1     508369.058003  3.024383e+06
# 2     507701.532800  3.024541e+06
# 3     508866.276700  3.023379e+06
# 4     506840.519135  3.023060e+06
# ...             ...           ...
# 7046  509780.328094  2.990161e+06
# 7047  518387.446600  2.987919e+06
# 7048  514359.824722  2.976365e+06
# 7049  533765.311671  2.976147e+06
# 7050  520663.498018  2.975175e+06
#
# [7051 rows x 10 columns]

# %%
# 连接表格
result_df = pd.merge(polygon_df, df_merged, on='OBJECTID',how='left')

# %%
result_df
# Out:
#       OBJECTID  DLMC DLDM      MZMC NEW_TL  NEW_YL  NEW_TS    NEW_TZ  \
# 0            1  乔木林地   03        板岩    黄棕壤    暗黄棕壤  泥质暗黄棕壤  腐薄层泥质黄棕壤
# 1            2  其他林地   03        板岩    黄棕壤    暗黄棕壤  泥质暗黄棕壤  腐薄层泥质黄棕壤
# 2            3  乔木林地   03        板岩    黄棕壤    暗黄棕壤  泥质暗黄棕壤  腐薄层泥质黄棕壤
# 3            4  乔木林地   03        板岩    黄棕壤    暗黄棕壤  泥质暗黄棕壤  腐薄层泥质黄棕壤
# 4            5  乔木林地   03        板岩    黄棕壤    暗黄棕壤  泥质暗黄棕壤  腐薄层泥质黄棕壤
# ...        ...   ...  ...       ...    ...     ...     ...       ...
# 7046      7048    水田   01  紫红色砂(页)岩    水稻土  潴育型水稻土     紫泥田       紫泥田
# 7047      7049    水田   01  紫红色砂(页)岩    水稻土  潴育型水稻土     紫泥田       紫泥田
# 7048      7050    水田   01  紫红色砂(页)岩    水稻土  潴育型水稻土     紫泥田       紫泥田
# 7049      7051    水田   01  紫红色砂(页)岩    水稻土  潴育型水稻土     紫泥田       紫泥田
# 7050      7052    水田   01  紫红色砂(页)岩    水稻土  潴育型水稻土     紫泥田       紫泥田
#
#          Centroid_X    Centroid_Y  ...  slope_postion_101_smooth_MAX  \
# 0     508742.996211  3.024631e+06  ...                           4.0
# 1     508369.058003  3.024383e+06  ...                           4.0
# 2     507701.532800  3.024541e+06  ...                           5.0
# 3     508866.276700  3.023379e+06  ...                           5.0
# 4     506840.519135  3.023060e+06  ...                           5.0
# ...             ...           ...  ...                           ...
# 7046  509780.328094  2.990161e+06  ...                           4.0
# 7047  518387.446600  2.987919e+06  ...                           4.0
# 7048  514359.824722  2.976365e+06  ...                           1.0
# 7049  533765.311671  2.976147e+06  ...                           4.0
# 7050  520663.498018  2.975175e+06  ...                           NaN
#
#       slope_postion_101_smooth_RANGE  slope_postion_101_smooth_MEAN  \
# 0                                0.0                       4.000000
# 1                                0.0                       4.000000
# 2                                1.0                       4.997844
# 3                                3.0                       3.994702
# 4                                1.0                       4.001949
# ...                              ...                            ...
# 7046                             0.0                       4.000000
# 7047                             2.0                       2.009724
# 7048                             0.0                       1.000000
# 7049                             0.0                       4.000000
# 7050                             NaN                            NaN
#
#       slope_postion_101_smooth_STD  slope_postion_101_smooth_SUM  \
# 0                         0.000000                       42564.0
# 1                         0.000000                       54696.0
# 2                         0.046379                       23185.0
# 3                         0.108357                      112347.0
# 4                         0.044106                       49276.0
# ...                            ...                           ...
# 7046                      0.000000                         384.0
# 7047                      0.139120                        1240.0
# 7048                      0.000000                         453.0
# 7049                      0.000000                        2572.0
# 7050                           NaN                           NaN
#
#       slope_postion_101_smooth_VARIETY  slope_postion_101_smooth_MAJORITY  \
# 0                                  1.0                                4.0
# 1                                  1.0                                4.0
# 2                                  2.0                                5.0
# 3                                  3.0                                4.0
# 4                                  2.0                                4.0
# ...                                ...                                ...
# 7046                               1.0                                4.0
# 7047                               2.0                                2.0
# 7048                               1.0                                1.0
# 7049                               1.0                                4.0
# 7050                               NaN                                NaN
#
#       slope_postion_101_smooth_MINORITY  slope_postion_101_smooth_MEDIAN  \
# 0                                   4.0                              4.0
# 1                                   4.0                              4.0
# 2                                   4.0                              5.0
# 3                                   5.0                              4.0
# 4                                   5.0                              4.0
# ...                                 ...                              ...
# 7046                                4.0                              4.0
# 7047                                4.0                              2.0
# 7048                                1.0                              1.0
# 7049                                4.0                              4.0
# 7050                                NaN                              NaN
#
#       slope_postion_101_smooth_PCT90
# 0                                4.0
# 1                                4.0
# 2                                5.0
# 3                                4.0
# 4                                4.0
# ...                              ...
# 7046                             4.0
# 7047                             2.0
# 7048                             1.0
# 7049                             4.0
# 7050                             NaN
#
# [7051 rows x 420 columns]

# %%
# 保存训练数据
train_data_path = r'F:\cache_data\zone_ana\sb\train_data'
result_df.to_csv(os.path.join(train_data_path, 'train_20240905.csv'), index=False)
