# %%
import geopandas as gpd
import pandas as pd
import numpy as np
from shapely.ops import unary_union
from shapely.validation import make_valid
from tqdm import tqdm
import time
import logging

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def find_neighbors(parcel, gdf):
    try:
        possible_matches_index = list(gdf.sindex.intersection(parcel.geometry.bounds))
        possible_matches = gdf.iloc[possible_matches_index]
        return possible_matches[possible_matches.geometry.touches(parcel.geometry)]
    except Exception as e:
        logging.error(f"在查找邻居时出错: {str(e)}")
        return gpd.GeoDataFrame()

def safe_union(geom1, geom2):
    try:
        union = unary_union([geom1, geom2])
        if not union.is_valid:
            union = make_valid(union)
        return union.buffer(0)  # 使用buffer(0)来修复可能的拓扑错误
    except Exception as e:
        logging.error(f"合并几何形状时出错: {str(e)}")
        return None

def calculate_total_area(gdf):
    return gdf.geometry.area.sum()

def compare_areas(area1, area2, tolerance=1e-6):
    diff = abs(area1 - area2)
    if diff > tolerance:
        logging.warning(f"面积不一致！差异: {diff}")
        return False
    else:
        logging.info("面积一致（在容忍范围内）")
        return True

def mark_small_parcels_for_merging(gdf, small_parcels, large_parcels, dldm_field, dlmc_field):
    merge_operations = []
    for index, small_parcel in tqdm(small_parcels.iterrows(), total=len(small_parcels), desc="标记小面积图斑"):
        neighbors = find_neighbors(small_parcel, large_parcels)
        if neighbors.empty:
            continue
        
        same_dlmc_neighbors = neighbors[neighbors[dlmc_field] == small_parcel[dlmc_field]]
        if not same_dlmc_neighbors.empty:
            target = same_dlmc_neighbors.loc[same_dlmc_neighbors['area'].idxmax()]
        else:
            target = neighbors.loc[neighbors['area'].idxmax()]
        
        merge_operations.append((index, target.name))
    
    return merge_operations

def execute_merges(gdf, merge_operations):
    merged_count = 0
    skipped_count = 0
    total_area_change = 0
    
    # 初始化 to_delete 列为 False
    gdf['to_delete'] = False
    
    for small_index, large_index in tqdm(merge_operations, desc="执行合并操作"):
        if small_index not in gdf.index or large_index not in gdf.index:
            skipped_count += 1
            continue
        
        small_geom = gdf.loc[small_index, 'geometry']
        large_geom = gdf.loc[large_index, 'geometry']
        
        original_area = small_geom.area + large_geom.area
        new_geometry = safe_union(small_geom, large_geom)
        
        if new_geometry is None:
            skipped_count += 1
            continue
        
        new_area = new_geometry.area
        area_change = new_area - original_area
        total_area_change += area_change
        
        if abs(area_change) > 1e-6:  # 允许1平方毫米的误差
            logging.warning(f"合并操作导致显著的面积变化。原面积: {original_area}, 新面积: {new_area}, 差异: {area_change}")
        
        # 更新大图斑
        gdf.loc[large_index, 'geometry'] = new_geometry
        gdf.loc[large_index, 'area'] = new_area
        
        # 标记小图斑为待删除
        gdf.loc[small_index, 'to_delete'] = True
        
        merged_count += 1
    
    # 删除已合并的小图斑
    gdf = gdf[~gdf['to_delete'].astype(bool)]
    gdf = gdf.drop(columns=['to_delete'])
    
    logging.info(f"合并了 {merged_count} 个图斑，跳过了 {skipped_count} 个图斑")
    logging.info(f"总面积变化: {total_area_change}")
    
    return gdf, merged_count


def merge_small_parcels(input_shp, output_base, dldm_field, dlmc_field, thresholds, default_threshold=50, max_iterations=10):
    start_time = time.time()
    logging.info(f"开始处理。输入Shapefile: {input_shp}")
    
    try:
        gdf = gpd.read_file(input_shp)
    except Exception as e:
        logging.error(f"读取shapefile时出错: {str(e)}")
        return
    
    original_count = len(gdf)
    original_area = calculate_total_area(gdf)
    logging.info(f"读取了 {original_count} 个图斑，总面积: {original_area}")
    
    logging.info("正在将多部件要素转换为单部件...")
    gdf = gdf.explode(index_parts=True).reset_index(drop=True)
    logging.info(f"转换后共有 {len(gdf)} 个图斑")
    
    iteration = 0
    total_merged = 0
    
    while iteration < max_iterations:
        iteration += 1
        logging.info(f"开始第 {iteration} 轮处理")
        
        gdf['area'] = gdf.geometry.area
        
        small_parcels = gdf[gdf.apply(lambda row: row['area'] < thresholds.get(row[dldm_field], default_threshold), axis=1)]
        large_parcels = gdf[gdf.apply(lambda row: row['area'] >= thresholds.get(row[dldm_field], default_threshold), axis=1)]
        
        logging.info(f"小面积图斑数量: {len(small_parcels)}, 大面积图斑数量: {len(large_parcels)}")
        
        merge_operations = mark_small_parcels_for_merging(gdf, small_parcels, large_parcels, dldm_field, dlmc_field)
        gdf, merged_count = execute_merges(gdf, merge_operations)
        
        total_merged += merged_count
        
        current_area = calculate_total_area(gdf)
        logging.info(f"第 {iteration} 轮处理完成。本轮合并 {merged_count} 个图斑。当前总面积: {current_area}")
        if not compare_areas(original_area, current_area):
            logging.error("面积不一致，处理终止。")
            return
        
        if merged_count == 0:
            logging.info("没有更多图斑可以合并，处理结束。")
            break
    
    logging.info(f"处理完成。总共合并 {total_merged} 个图斑。")
    
    final_area = calculate_total_area(gdf)
    logging.info(f"最终总面积: {final_area}")
    logging.info("比较原始面积和最终面积:")
    if not compare_areas(original_area, final_area):
        logging.error("最终面积与原始面积不一致，请检查处理过程。")
        return
    
    # 保存结果到SHP（截断字段名）
    output_shp = f"{output_base}.shp"
    result_truncated = gdf.rename(columns={col: col[:10] for col in gdf.columns if len(col) > 10})
    result_truncated.to_file(output_shp, encoding='utf-8')
    logging.info(f"结果保存为SHP（字段名已截断）: {output_shp}")
    
    end_time = time.time()
    logging.info(f"总处理时间: {(end_time - start_time) / 60:.2f} 分钟")
    logging.info(f"最终图斑数量: {len(gdf)}")
    logging.info(f"减少的图斑数量: {original_count - len(gdf)}")
# 使用示例
input_shp = r"C:\Users\Runker\Desktop\ele_sb\sb_merge_data_single.shp"
output_base = r"C:\Users\Runker\Desktop\ele_sb\sb_merge_data_single_moudle4"
dldm_field = "DLDM"
dlmc_field = "DLMC"
thresholds = {"01": 50, "02": 50, "03": 1000, "04": 1000}
default_threshold = 50  # 为未指定的DLDM类型设置默认阈值

merge_small_parcels(input_shp, output_base, dldm_field, dlmc_field, thresholds, default_threshold)
# Out:
# 2024-09-05 11:05:42,374 - INFO - 开始处理。输入Shapefile: C:\Users\Runker\Desktop\ele_test\sb_merge_data.shp
# 2024-09-05 11:06:32,904 - INFO - 读取了 165557 个图斑，总面积: 1463055810.020485
# 2024-09-05 11:06:32,904 - INFO - 正在将多部件要素转换为单部件...
# 2024-09-05 11:06:34,472 - INFO - 转换后共有 256241 个图斑
# 2024-09-05 11:06:34,472 - INFO - 开始第 1 轮处理
# 2024-09-05 11:06:37,188 - INFO - 小面积图斑数量: 77118, 大面积图斑数量: 179123
# 标记小面积图斑: 100%|██████████| 77118/77118 [02:55<00:00, 439.22it/s]
# 执行合并操作: 100%|██████████| 76052/76052 [01:01<00:00, 1235.44it/s]
# 2024-09-05 11:10:34,565 - INFO - 合并了 76052 个图斑，跳过了 0 个图斑
# 2024-09-05 11:10:34,566 - INFO - 总面积变化: 3.7359129123615276e-08
# 2024-09-05 11:10:34,697 - INFO - 第 1 轮处理完成。本轮合并 76052 个图斑。当前总面积: 1463055810.0204852
# 2024-09-05 11:10:34,698 - INFO - 面积一致（在容忍范围内）
# 2024-09-05 11:10:34,698 - INFO - 开始第 2 轮处理
# 2024-09-05 11:10:37,254 - INFO - 小面积图斑数量: 1066, 大面积图斑数量: 179123
# 标记小面积图斑: 100%|██████████| 1066/1066 [00:02<00:00, 372.70it/s]
# 执行合并操作: 100%|██████████| 672/672 [00:00<00:00, 1231.51it/s]
# 2024-09-05 11:10:40,839 - INFO - 合并了 672 个图斑，跳过了 0 个图斑
# 2024-09-05 11:10:40,839 - INFO - 总面积变化: 1.3432099876808934e-10
# 2024-09-05 11:10:40,959 - INFO - 第 2 轮处理完成。本轮合并 672 个图斑。当前总面积: 1463055810.0204852
# 2024-09-05 11:10:40,960 - INFO - 面积一致（在容忍范围内）
# 2024-09-05 11:10:40,960 - INFO - 开始第 3 轮处理
# 2024-09-05 11:10:43,681 - INFO - 小面积图斑数量: 394, 大面积图斑数量: 179123
# 标记小面积图斑: 100%|██████████| 394/394 [00:00<00:00, 477.95it/s]
# 执行合并操作: 100%|██████████| 46/46 [00:00<00:00, 1642.84it/s]
# 2024-09-05 11:10:44,701 - INFO - 合并了 46 个图斑，跳过了 0 个图斑
# 2024-09-05 11:10:44,701 - INFO - 总面积变化: 1.750777300912887e-11
# 2024-09-05 11:10:44,795 - INFO - 第 3 轮处理完成。本轮合并 46 个图斑。当前总面积: 1463055810.020485
# 2024-09-05 11:10:44,795 - INFO - 面积一致（在容忍范围内）
# 2024-09-05 11:10:44,796 - INFO - 开始第 4 轮处理
# 2024-09-05 11:10:47,117 - INFO - 小面积图斑数量: 348, 大面积图斑数量: 179123
# 标记小面积图斑: 100%|██████████| 348/348 [00:00<00:00, 492.22it/s]
# 执行合并操作: 100%|██████████| 5/5 [00:00<00:00, 1001.60it/s]
# 2024-09-05 11:10:48,012 - INFO - 合并了 5 个图斑，跳过了 0 个图斑
# 2024-09-05 11:10:48,013 - INFO - 总面积变化: 2.5011104298755527e-12
# 2024-09-05 11:10:48,138 - INFO - 第 4 轮处理完成。本轮合并 5 个图斑。当前总面积: 1463055810.0204852
# 2024-09-05 11:10:48,138 - INFO - 面积一致（在容忍范围内）
# 2024-09-05 11:10:48,138 - INFO - 开始第 5 轮处理
# 2024-09-05 11:10:50,573 - INFO - 小面积图斑数量: 343, 大面积图斑数量: 179123
# 标记小面积图斑: 100%|██████████| 343/343 [00:00<00:00, 531.99it/s]
# 执行合并操作: 100%|██████████| 2/2 [00:00<00:00, 665.18it/s]
# 2024-09-05 11:10:51,394 - INFO - 合并了 2 个图斑，跳过了 0 个图斑
# 2024-09-05 11:10:51,395 - INFO - 总面积变化: 5.4569682106375694e-12
# 2024-09-05 11:10:51,506 - INFO - 第 5 轮处理完成。本轮合并 2 个图斑。当前总面积: 1463055810.020485
# 2024-09-05 11:10:51,507 - INFO - 面积一致（在容忍范围内）
# 2024-09-05 11:10:51,507 - INFO - 开始第 6 轮处理
# 2024-09-05 11:10:54,073 - INFO - 小面积图斑数量: 341, 大面积图斑数量: 179123
# 标记小面积图斑: 100%|██████████| 341/341 [00:00<00:00, 485.06it/s]
# 执行合并操作: 100%|██████████| 3/3 [00:00<00:00, 748.67it/s]
# 2024-09-05 11:10:54,964 - INFO - 合并了 3 个图斑，跳过了 0 个图斑
# 2024-09-05 11:10:54,965 - INFO - 总面积变化: 9.094947017729282e-13
# 2024-09-05 11:10:55,087 - INFO - 第 6 轮处理完成。本轮合并 3 个图斑。当前总面积: 1463055810.0204847
# 2024-09-05 11:10:55,087 - INFO - 面积一致（在容忍范围内）
# 2024-09-05 11:10:55,088 - INFO - 开始第 7 轮处理
# 2024-09-05 11:10:57,474 - INFO - 小面积图斑数量: 338, 大面积图斑数量: 179123
# 标记小面积图斑: 100%|██████████| 338/338 [00:00<00:00, 475.32it/s]
# 执行合并操作: 100%|██████████| 1/1 [00:00<00:00, 332.78it/s]
# 2024-09-05 11:10:58,356 - INFO - 合并了 1 个图斑，跳过了 0 个图斑
# 2024-09-05 11:10:58,357 - INFO - 总面积变化: 0.0
# 2024-09-05 11:10:58,452 - INFO - 第 7 轮处理完成。本轮合并 1 个图斑。当前总面积: 1463055810.0204847
# 2024-09-05 11:10:58,453 - INFO - 面积一致（在容忍范围内）
# 2024-09-05 11:10:58,454 - INFO - 开始第 8 轮处理
# 2024-09-05 11:11:00,988 - INFO - 小面积图斑数量: 337, 大面积图斑数量: 179123
# 标记小面积图斑: 100%|██████████| 337/337 [00:00<00:00, 424.40it/s]
# 执行合并操作: 0it [00:00, ?it/s]
# 2024-09-05 11:11:01,945 - INFO - 合并了 0 个图斑，跳过了 0 个图斑
# 2024-09-05 11:11:01,945 - INFO - 总面积变化: 0
# 2024-09-05 11:11:02,054 - INFO - 第 8 轮处理完成。本轮合并 0 个图斑。当前总面积: 1463055810.0204847
# 2024-09-05 11:11:02,054 - INFO - 面积一致（在容忍范围内）
# 2024-09-05 11:11:02,055 - INFO - 没有更多图斑可以合并，处理结束。
# 2024-09-05 11:11:02,056 - INFO - 处理完成。总共合并 76781 个图斑。
# 2024-09-05 11:11:02,123 - INFO - 最终总面积: 1463055810.0204847
# 2024-09-05 11:11:02,123 - INFO - 比较原始面积和最终面积:
# 2024-09-05 11:11:02,123 - INFO - 面积一致（在容忍范围内）
# 2024-09-05 11:11:51,430 - INFO - 结果保存为SHP（字段名已截断）: C:\Users\Runker\Desktop\ele_test\sb_merge_data_result_3.shp
# 2024-09-05 11:11:51,431 - INFO - 总处理时间: 6.15 分钟
# 2024-09-05 11:11:51,431 - INFO - 最终图斑数量: 179460
# 2024-09-05 11:11:51,432 - INFO - 减少的图斑数量: -13903

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
from shapely.ops import unary_union
from shapely.validation import make_valid
from shapely.geometry import Polygon, MultiPolygon
from shapely.affinity import scale  # 添加这行来导入 scale 函数
from tqdm import tqdm
import time
import logging

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def safe_union(geom1, geom2):
    try:
        union = unary_union([geom1, geom2])
        if not union.is_valid:
            union = make_valid(union)
        return union.buffer(0)  # 使用buffer(0)来修复可能的拓扑错误
    except Exception as e:
        logging.error(f"合并几何形状时出错: {str(e)}")
        return None

def adjust_geometry(geometry, target_area):
    current_area = geometry.area
    scale_factor = np.sqrt(target_area / current_area)
    adjusted = scale(geometry, xfact=scale_factor, yfact=scale_factor, origin='centroid')
    return adjusted

def execute_merges(gdf, merge_operations, area_change_threshold=1.0):
    merged_count = 0
    skipped_count = 0
    total_area_change = 0
    area_changes = []
    
    gdf['to_delete'] = False
    
    for small_index, large_index in tqdm(merge_operations, desc="执行合并操作"):
        if small_index not in gdf.index or large_index not in gdf.index:
            skipped_count += 1
            continue
        
        small_geom = gdf.loc[small_index, 'geometry']
        large_geom = gdf.loc[large_index, 'geometry']
        
        original_area = small_geom.area + large_geom.area
        new_geometry = safe_union(small_geom, large_geom)
        
        if new_geometry is None:
            skipped_count += 1
            continue
        
        new_area = new_geometry.area
        area_change = new_area - original_area
        
        if abs(area_change) > area_change_threshold:
            adjusted_geometry = adjust_geometry(new_geometry, original_area)
            new_area = adjusted_geometry.area
            area_change = new_area - original_area
            logging.info(f"调整了合并后的几何形状。原面积: {original_area}, 调整后面积: {new_area}, 剩余差异: {area_change}")
            new_geometry = adjusted_geometry
        
        total_area_change += area_change
        area_changes.append(area_change)
        
        gdf.loc[large_index, 'geometry'] = new_geometry
        gdf.loc[large_index, 'area'] = new_area
        gdf.loc[small_index, 'to_delete'] = True
        
        merged_count += 1
    
    gdf = gdf[~gdf['to_delete']]
    gdf = gdf.drop(columns=['to_delete'])
    
    logging.info(f"合并了 {merged_count} 个图斑，跳过了 {skipped_count} 个图斑")
    logging.info(f"总面积变化: {total_area_change}")
    # logging.info(f"最大面积变化: {max(abs(change) for change in area_changes)}")
    # logging.info(f"平均面积变化: {sum(abs(change) for change in area_changes) / len(area_changes)}")
    
    return gdf, merged_count, total_area_change

def merge_small_parcels(input_shp, output_base, dldm_field, dlmc_field, thresholds, default_threshold=50, max_iterations=10, area_change_threshold=1.0):
    start_time = time.time()
    logging.info(f"开始处理。输入Shapefile: {input_shp}")
    
    try:
        gdf = gpd.read_file(input_shp)
    except Exception as e:
        logging.error(f"读取shapefile时出错: {str(e)}")
        return
    
    original_count = len(gdf)
    original_area = gdf.geometry.area.sum()
    logging.info(f"读取了 {original_count} 个图斑，总面积: {original_area}")
    
    logging.info("正在将多部件要素转换为单部件...")
    gdf = gdf.explode(index_parts=True).reset_index(drop=True)
    logging.info(f"转换后共有 {len(gdf)} 个图斑")
    
    iteration = 0
    total_merged = 0
    total_area_change = 0
    
    while iteration < max_iterations:
        iteration += 1
        logging.info(f"开始第 {iteration} 轮处理")
        
        gdf['area'] = gdf.geometry.area
        
        small_parcels = gdf[gdf.apply(lambda row: row['area'] < thresholds.get(row[dldm_field], default_threshold), axis=1)]
        large_parcels = gdf[gdf.apply(lambda row: row['area'] >= thresholds.get(row[dldm_field], default_threshold), axis=1)]
        
        logging.info(f"小面积图斑数量: {len(small_parcels)}, 大面积图斑数量: {len(large_parcels)}")
        
        merge_operations = mark_small_parcels_for_merging(gdf, small_parcels, large_parcels, dldm_field, dlmc_field)
        gdf, merged_count, area_change = execute_merges(gdf, merge_operations, area_change_threshold)
        
        total_merged += merged_count
        total_area_change += area_change
        
        current_area = gdf.geometry.area.sum()
        logging.info(f"第 {iteration} 轮处理完成。本轮合并 {merged_count} 个图斑。当前总面积: {current_area}")
        logging.info(f"累计面积变化: {total_area_change}")
        
        if merged_count == 0:
            logging.info("没有更多图斑可以合并，处理结束。")
            break
    
    logging.info(f"处理完成。总共合并 {total_merged} 个图斑。")
    
    final_area = gdf.geometry.area.sum()
    logging.info(f"最终总面积: {final_area}")
    logging.info(f"总面积变化: {final_area - original_area}")
    
    # 保存结果到SHP（截断字段名）
    output_shp = f"{output_base}.shp"
    result_truncated = gdf.rename(columns={col: col[:10] for col in gdf.columns if len(col) > 10})
    result_truncated.to_file(output_shp, encoding='utf-8')
    logging.info(f"结果保存为SHP（字段名已截断）: {output_shp}")
    
    end_time = time.time()
    logging.info(f"总处理时间: {(end_time - start_time) / 60:.2f} 分钟")
    logging.info(f"最终图斑数量: {len(gdf)}")
    logging.info(f"减少的图斑数量: {original_count - len(gdf)}")

# 使用示例
input_shp = r"C:\Users\Runker\Desktop\ele_sb\sb_merge_data_single.shp"
output_base = r"C:\Users\Runker\Desktop\ele_sb\sb_merge_data_single_moudle3"
dldm_field = "DLDM"
dlmc_field = "DLMC"
thresholds = {"01": 50, "02": 50, "03": 1000, "04": 1000}
default_threshold = 50  # 为未指定的DLDM类型设置默认阈值
area_change_threshold = 1.0  # 面积变化阈值（平方米）

merge_small_parcels(input_shp, output_base, dldm_field, dlmc_field, thresholds, default_threshold, area_change_threshold=area_change_threshold)
# Out:
# 2024-09-05 10:53:26,863 - INFO - 开始处理。输入Shapefile: C:\Users\Runker\Desktop\ele_test\sb_merge_data.shp
# 2024-09-05 10:54:37,563 - INFO - 读取了 165557 个图斑，总面积: 1463055810.020485
# 2024-09-05 10:54:37,564 - INFO - 正在将多部件要素转换为单部件...
# 2024-09-05 10:54:40,051 - INFO - 转换后共有 256241 个图斑
# 2024-09-05 10:54:40,052 - INFO - 开始第 1 轮处理
# 2024-09-05 10:54:43,755 - INFO - 小面积图斑数量: 77118, 大面积图斑数量: 179123
# 2024-09-05 10:54:43,992 - INFO - 图斑 42 没有找到邻居，跳过
# 2024-09-05 10:54:43,995 - INFO - 图斑 43 没有找到邻居，跳过
# 2024-09-05 10:54:43,998 - INFO - 图斑 44 没有找到邻居，跳过
# 2024-09-05 10:54:44,205 - INFO - 图斑 287 没有找到邻居，跳过
# 2024-09-05 10:54:44,284 - INFO - 图斑 397 没有找到邻居，跳过
# 2024-09-05 10:54:45,849 - INFO - 图斑 2209 没有找到邻居，跳过
# 2024-09-05 10:54:45,918 - INFO - 图斑 2296 没有找到邻居，跳过
# 2024-09-05 10:54:45,948 - INFO - 图斑 2312 没有找到邻居，跳过
# 2024-09-05 10:54:45,975 - INFO - 图斑 2340 没有找到邻居，跳过
# 2024-09-05 10:54:46,830 - INFO - 图斑 3272 没有找到邻居，跳过
# 2024-09-05 10:54:47,319 - INFO - 图斑 3804 没有找到邻居，跳过
# 2024-09-05 10:54:47,321 - INFO - 图斑 3805 没有找到邻居，跳过
# 2024-09-05 10:54:47,498 - INFO - 图斑 4024 没有找到邻居，跳过
# 2024-09-05 10:54:47,502 - INFO - 图斑 4026 没有找到邻居，跳过
# 2024-09-05 10:54:47,598 - INFO - 图斑 4120 没有找到邻居，跳过
# 2024-09-05 10:54:47,637 - INFO - 图斑 4166 没有找到邻居，跳过
# 2024-09-05 10:54:48,152 - INFO - 图斑 4757 没有找到邻居，跳过
# 2024-09-05 10:54:48,202 - INFO - 图斑 4880 没有找到邻居，跳过
# 2024-09-05 10:54:48,745 - INFO - 图斑 5515 没有找到邻居，跳过
# 2024-09-05 10:54:48,908 - INFO - 图斑 5658 没有找到邻居，跳过
# 2024-09-05 10:54:48,945 - INFO - 图斑 5699 没有找到邻居，跳过
# 2024-09-05 10:54:48,948 - INFO - 图斑 5700 没有找到邻居，跳过
# 2024-09-05 10:54:49,117 - INFO - 图斑 5861 没有找到邻居，跳过
# 2024-09-05 10:54:49,221 - INFO - 图斑 5984 没有找到邻居，跳过
# 2024-09-05 10:54:49,241 - INFO - 图斑 5997 没有找到邻居，跳过
# 2024-09-05 10:54:49,243 - INFO - 图斑 5998 没有找到邻居，跳过
# 2024-09-05 10:54:49,276 - INFO - 图斑 6013 没有找到邻居，跳过
# 2024-09-05 10:54:49,391 - INFO - 图斑 6164 没有找到邻居，跳过
# 2024-09-05 10:54:49,399 - INFO - 图斑 6169 没有找到邻居，跳过
# 2024-09-05 10:54:49,650 - INFO - 图斑 6510 没有找到邻居，跳过
# 2024-09-05 10:54:49,977 - INFO - 图斑 6839 没有找到邻居，跳过
# 2024-09-05 10:54:50,040 - INFO - 图斑 6912 没有找到邻居，跳过
# 2024-09-05 10:54:50,113 - INFO - 图斑 6994 没有找到邻居，跳过
# 2024-09-05 10:54:50,135 - INFO - 图斑 7006 没有找到邻居，跳过
# 2024-09-05 10:54:50,207 - INFO - 图斑 7085 没有找到邻居，跳过
# 2024-09-05 10:54:50,214 - INFO - 图斑 7088 没有找到邻居，跳过
# 2024-09-05 10:54:50,363 - INFO - 图斑 7202 没有找到邻居，跳过
# 2024-09-05 10:54:50,585 - INFO - 图斑 7495 没有找到邻居，跳过
# 2024-09-05 10:54:50,720 - INFO - 图斑 7665 没有找到邻居，跳过
# 2024-09-05 10:54:51,387 - INFO - 图斑 8313 没有找到邻居，跳过
# 2024-09-05 10:54:51,390 - INFO - 图斑 8314 没有找到邻居，跳过
# 2024-09-05 10:54:51,800 - INFO - 图斑 8746 没有找到邻居，跳过
# 2024-09-05 10:54:51,943 - INFO - 图斑 8936 没有找到邻居，跳过
# 2024-09-05 10:54:51,949 - INFO - 图斑 8938 没有找到邻居，跳过
# 2024-09-05 10:54:52,446 - INFO - 图斑 9357 没有找到邻居，跳过
# 2024-09-05 10:54:52,467 - INFO - 图斑 9375 没有找到邻居，跳过
# 2024-09-05 10:54:52,780 - INFO - 图斑 9682 没有找到邻居，跳过
# 2024-09-05 10:54:53,474 - INFO - 图斑 10198 没有找到邻居，跳过
# 2024-09-05 10:54:53,488 - INFO - 图斑 10208 没有找到邻居，跳过
# 2024-09-05 10:54:53,502 - INFO - 图斑 10212 没有找到邻居，跳过
# 2024-09-05 10:54:54,044 - INFO - 图斑 10685 没有找到邻居，跳过
# 2024-09-05 10:54:54,058 - INFO - 图斑 10689 没有找到邻居，跳过
# 2024-09-05 10:54:54,281 - INFO - 图斑 10858 没有找到邻居，跳过
# 2024-09-05 10:54:54,452 - INFO - 图斑 11022 没有找到邻居，跳过
# 2024-09-05 10:54:54,739 - INFO - 图斑 11344 没有找到邻居，跳过
# 2024-09-05 10:54:54,965 - INFO - 图斑 11608 没有找到邻居，跳过
# 2024-09-05 10:54:54,967 - INFO - 图斑 11609 没有找到邻居，跳过
# 2024-09-05 10:54:55,235 - INFO - 图斑 11951 没有找到邻居，跳过
# 2024-09-05 10:54:55,293 - INFO - 图斑 12041 没有找到邻居，跳过
# 2024-09-05 10:54:55,882 - INFO - 图斑 12757 没有找到邻居，跳过
# 2024-09-05 10:54:56,002 - INFO - 图斑 12893 没有找到邻居，跳过
# 2024-09-05 10:54:56,027 - INFO - 图斑 12934 没有找到邻居，跳过
# 2024-09-05 10:54:56,077 - INFO - 图斑 13020 没有找到邻居，跳过
# 2024-09-05 10:54:56,211 - INFO - 图斑 13327 没有找到邻居，跳过
# 2024-09-05 10:54:56,524 - INFO - 图斑 13726 没有找到邻居，跳过
# 2024-09-05 10:54:56,622 - INFO - 图斑 13818 没有找到邻居，跳过
# 2024-09-05 10:54:57,127 - INFO - 图斑 14539 没有找到邻居，跳过
# 2024-09-05 10:54:57,206 - INFO - 图斑 14619 没有找到邻居，跳过
# 2024-09-05 10:54:57,273 - INFO - 图斑 14709 没有找到邻居，跳过
# 2024-09-05 10:54:57,874 - INFO - 图斑 15290 没有找到邻居，跳过
# 2024-09-05 10:54:57,877 - INFO - 图斑 15291 没有找到邻居，跳过
# 2024-09-05 10:54:57,906 - INFO - 图斑 15318 没有找到邻居，跳过
# 2024-09-05 10:54:58,209 - INFO - 图斑 15714 没有找到邻居，跳过
# 2024-09-05 10:54:58,270 - INFO - 图斑 15791 没有找到邻居，跳过
# 2024-09-05 10:54:58,417 - INFO - 图斑 15947 没有找到邻居，跳过
# 2024-09-05 10:54:58,420 - INFO - 图斑 15948 没有找到邻居，跳过
# 2024-09-05 10:54:58,638 - INFO - 图斑 16246 没有找到邻居，跳过
# 2024-09-05 10:54:59,096 - INFO - 图斑 16620 没有找到邻居，跳过
# 2024-09-05 10:54:59,166 - INFO - 图斑 16693 没有找到邻居，跳过
# 2024-09-05 10:54:59,434 - INFO - 图斑 16777 没有找到邻居，跳过
# 2024-09-05 10:54:59,440 - INFO - 图斑 16778 没有找到邻居，跳过
# 2024-09-05 10:55:00,502 - INFO - 图斑 17457 没有找到邻居，跳过
# 2024-09-05 10:55:00,506 - INFO - 图斑 17458 没有找到邻居，跳过
# 2024-09-05 10:55:00,602 - INFO - 图斑 17536 没有找到邻居，跳过
# 2024-09-05 10:55:00,604 - INFO - 图斑 17537 没有找到邻居，跳过
# 2024-09-05 10:55:01,431 - INFO - 图斑 18468 没有找到邻居，跳过
# 2024-09-05 10:55:01,596 - INFO - 图斑 18685 没有找到邻居，跳过
# 2024-09-05 10:55:01,628 - INFO - 图斑 18728 没有找到邻居，跳过
# 2024-09-05 10:55:01,755 - INFO - 图斑 18828 没有找到邻居，跳过
# 2024-09-05 10:55:02,608 - INFO - 图斑 19698 没有找到邻居，跳过
# 2024-09-05 10:55:02,611 - INFO - 图斑 19699 没有找到邻居，跳过
# 2024-09-05 10:55:02,635 - INFO - 图斑 19728 没有找到邻居，跳过
# 2024-09-05 10:55:02,699 - INFO - 图斑 19770 没有找到邻居，跳过
# 2024-09-05 10:55:02,701 - INFO - 图斑 19771 没有找到邻居，跳过
# 2024-09-05 10:55:02,824 - INFO - 图斑 19903 没有找到邻居，跳过
# 2024-09-05 10:55:02,976 - INFO - 图斑 20051 没有找到邻居，跳过
# 2024-09-05 10:55:03,641 - INFO - 图斑 20910 没有找到邻居，跳过
# 2024-09-05 10:55:03,721 - INFO - 图斑 21027 没有找到邻居，跳过
# 2024-09-05 10:55:03,723 - INFO - 图斑 21028 没有找到邻居，跳过
# 2024-09-05 10:55:03,725 - INFO - 图斑 21029 没有找到邻居，跳过
# 2024-09-05 10:55:03,890 - INFO - 图斑 21212 没有找到邻居，跳过
# 2024-09-05 10:55:03,958 - INFO - 图斑 21306 没有找到邻居，跳过
# 2024-09-05 10:55:04,451 - INFO - 图斑 21889 没有找到邻居，跳过
# 2024-09-05 10:55:04,458 - INFO - 图斑 21892 没有找到邻居，跳过
# 2024-09-05 10:55:04,471 - INFO - 图斑 21905 没有找到邻居，跳过
# 2024-09-05 10:55:04,502 - INFO - 图斑 21934 没有找到邻居，跳过
# 2024-09-05 10:55:04,787 - INFO - 图斑 22244 没有找到邻居，跳过
# 2024-09-05 10:55:04,789 - INFO - 图斑 22245 没有找到邻居，跳过
# 2024-09-05 10:55:05,151 - INFO - 图斑 22662 没有找到邻居，跳过
# 2024-09-05 10:55:05,153 - INFO - 图斑 22663 没有找到邻居，跳过
# 2024-09-05 10:55:05,355 - INFO - 图斑 22894 没有找到邻居，跳过
# 2024-09-05 10:55:05,557 - INFO - 图斑 23118 没有找到邻居，跳过
# 2024-09-05 10:55:05,613 - INFO - 图斑 23221 没有找到邻居，跳过
# 2024-09-05 10:55:05,647 - INFO - 图斑 23284 没有找到邻居，跳过
# 2024-09-05 10:55:05,649 - INFO - 图斑 23285 没有找到邻居，跳过
# 2024-09-05 10:55:05,738 - INFO - 图斑 23421 没有找到邻居，跳过
# 2024-09-05 10:55:06,335 - INFO - 图斑 24247 没有找到邻居，跳过
# 2024-09-05 10:55:06,674 - INFO - 图斑 24637 没有找到邻居，跳过
# 2024-09-05 10:55:06,699 - INFO - 图斑 24680 没有找到邻居，跳过
# 2024-09-05 10:55:06,701 - INFO - 图斑 24681 没有找到邻居，跳过
# 2024-09-05 10:55:06,738 - INFO - 图斑 24717 没有找到邻居，跳过
# 2024-09-05 10:55:06,739 - INFO - 图斑 24718 没有找到邻居，跳过
# 2024-09-05 10:55:06,743 - INFO - 图斑 24719 没有找到邻居，跳过
# 2024-09-05 10:55:06,746 - INFO - 图斑 24720 没有找到邻居，跳过
# 2024-09-05 10:55:06,775 - INFO - 图斑 24739 没有找到邻居，跳过
# 2024-09-05 10:55:07,172 - INFO - 图斑 25056 没有找到邻居，跳过
# 2024-09-05 10:55:07,367 - INFO - 图斑 25371 没有找到邻居，跳过
# 2024-09-05 10:55:07,371 - INFO - 图斑 25372 没有找到邻居，跳过
# 2024-09-05 10:55:07,483 - INFO - 图斑 25463 没有找到邻居，跳过
# 2024-09-05 10:55:07,764 - INFO - 图斑 25787 没有找到邻居，跳过
# 2024-09-05 10:55:07,815 - INFO - 图斑 25859 没有找到邻居，跳过
# 2024-09-05 10:55:07,855 - INFO - 图斑 25924 没有找到邻居，跳过
# 2024-09-05 10:55:08,452 - INFO - 图斑 26635 没有找到邻居，跳过
# 2024-09-05 10:55:08,650 - INFO - 图斑 26788 没有找到邻居，跳过
# 2024-09-05 10:55:08,770 - INFO - 图斑 26901 没有找到邻居，跳过
# 2024-09-05 10:55:08,923 - INFO - 图斑 27082 没有找到邻居，跳过
# 2024-09-05 10:55:09,223 - INFO - 图斑 27254 没有找到邻居，跳过
# 2024-09-05 10:55:11,186 - INFO - 图斑 28798 没有找到邻居，跳过
# 2024-09-05 10:55:11,472 - INFO - 图斑 29059 没有找到邻居，跳过
# 2024-09-05 10:55:11,780 - INFO - 图斑 29325 没有找到邻居，跳过
# 2024-09-05 10:55:11,783 - INFO - 图斑 29326 没有找到邻居，跳过
# 2024-09-05 10:55:11,795 - INFO - 图斑 29344 没有找到邻居，跳过
# 2024-09-05 10:55:11,799 - INFO - 图斑 29345 没有找到邻居，跳过
# 2024-09-05 10:55:11,897 - INFO - 图斑 29431 没有找到邻居，跳过
# 2024-09-05 10:55:11,900 - INFO - 图斑 29432 没有找到邻居，跳过
# 2024-09-05 10:55:12,251 - INFO - 图斑 29803 没有找到邻居，跳过
# 2024-09-05 10:55:12,355 - INFO - 图斑 29919 没有找到邻居，跳过
# 2024-09-05 10:55:12,583 - INFO - 图斑 30117 没有找到邻居，跳过
# 2024-09-05 10:55:13,024 - INFO - 图斑 30614 没有找到邻居，跳过
# 2024-09-05 10:55:13,275 - INFO - 图斑 30832 没有找到邻居，跳过
# 2024-09-05 10:55:13,545 - INFO - 图斑 31075 没有找到邻居，跳过
# 2024-09-05 10:55:13,568 - INFO - 图斑 31087 没有找到邻居，跳过
# 2024-09-05 10:55:13,584 - INFO - 图斑 31106 没有找到邻居，跳过
# 2024-09-05 10:55:13,686 - INFO - 图斑 31264 没有找到邻居，跳过
# 2024-09-05 10:55:13,690 - INFO - 图斑 31266 没有找到邻居，跳过
# 2024-09-05 10:55:13,733 - INFO - 图斑 31308 没有找到邻居，跳过
# 2024-09-05 10:55:13,859 - INFO - 图斑 31498 没有找到邻居，跳过
# 2024-09-05 10:55:13,868 - INFO - 图斑 31499 没有找到邻居，跳过
# 2024-09-05 10:55:14,113 - INFO - 图斑 31680 没有找到邻居，跳过
# 2024-09-05 10:55:14,421 - INFO - 图斑 32149 没有找到邻居，跳过
# 2024-09-05 10:55:14,456 - INFO - 图斑 32179 没有找到邻居，跳过
# 2024-09-05 10:55:14,517 - INFO - 图斑 32259 没有找到邻居，跳过
# 2024-09-05 10:55:14,580 - INFO - 图斑 32321 没有找到邻居，跳过
# 2024-09-05 10:55:14,582 - INFO - 图斑 32322 没有找到邻居，跳过
# 2024-09-05 10:55:14,586 - INFO - 图斑 32324 没有找到邻居，跳过
# 2024-09-05 10:55:14,928 - INFO - 图斑 32646 没有找到邻居，跳过
# 2024-09-05 10:55:14,929 - INFO - 图斑 32647 没有找到邻居，跳过
# 2024-09-05 10:55:14,934 - INFO - 图斑 32649 没有找到邻居，跳过
# 2024-09-05 10:55:15,064 - INFO - 图斑 32844 没有找到邻居，跳过
# 2024-09-05 10:55:15,072 - INFO - 图斑 32848 没有找到邻居，跳过
# 2024-09-05 10:55:15,114 - INFO - 图斑 32914 没有找到邻居，跳过
# 2024-09-05 10:55:15,209 - INFO - 图斑 33034 没有找到邻居，跳过
# 2024-09-05 10:55:15,965 - INFO - 图斑 33874 没有找到邻居，跳过
# 2024-09-05 10:55:15,993 - INFO - 图斑 33904 没有找到邻居，跳过
# 2024-09-05 10:55:16,091 - INFO - 图斑 33992 没有找到邻居，跳过
# 2024-09-05 10:55:16,093 - INFO - 图斑 33993 没有找到邻居，跳过
# 2024-09-05 10:55:16,163 - INFO - 图斑 34066 没有找到邻居，跳过
# 2024-09-05 10:55:16,171 - INFO - 图斑 34076 没有找到邻居，跳过
# 2024-09-05 10:55:16,296 - INFO - 图斑 34186 没有找到邻居，跳过
# 2024-09-05 10:55:16,895 - INFO - 图斑 34817 没有找到邻居，跳过
# 2024-09-05 10:55:17,123 - INFO - 图斑 35077 没有找到邻居，跳过
# 2024-09-05 10:55:17,382 - INFO - 图斑 35391 没有找到邻居，跳过
# 2024-09-05 10:55:17,780 - INFO - 图斑 35799 没有找到邻居，跳过
# 2024-09-05 10:55:17,804 - INFO - 图斑 35825 没有找到邻居，跳过
# 2024-09-05 10:55:17,907 - INFO - 图斑 35923 没有找到邻居，跳过
# 2024-09-05 10:55:18,027 - INFO - 图斑 36073 没有找到邻居，跳过
# 2024-09-05 10:55:18,130 - INFO - 图斑 36236 没有找到邻居，跳过
# 2024-09-05 10:55:18,438 - INFO - 图斑 36622 没有找到邻居，跳过
# 2024-09-05 10:55:18,456 - INFO - 图斑 36635 没有找到邻居，跳过
# 2024-09-05 10:55:19,375 - INFO - 图斑 37538 没有找到邻居，跳过
# 2024-09-05 10:55:19,514 - INFO - 图斑 37736 没有找到邻居，跳过
# 2024-09-05 10:55:20,196 - INFO - 图斑 38341 没有找到邻居，跳过
# 2024-09-05 10:55:21,134 - INFO - 图斑 39309 没有找到邻居，跳过
# 2024-09-05 10:55:21,323 - INFO - 图斑 39532 没有找到邻居，跳过
# 2024-09-05 10:55:21,326 - INFO - 图斑 39533 没有找到邻居，跳过
# 2024-09-05 10:55:21,330 - INFO - 图斑 39534 没有找到邻居，跳过
# 2024-09-05 10:55:21,336 - INFO - 图斑 39548 没有找到邻居，跳过
# 2024-09-05 10:55:21,534 - INFO - 图斑 39728 没有找到邻居，跳过
# 2024-09-05 10:55:21,574 - INFO - 图斑 39797 没有找到邻居，跳过
# 2024-09-05 10:55:21,733 - INFO - 图斑 39923 没有找到邻居，跳过
# 2024-09-05 10:55:22,022 - INFO - 图斑 40268 没有找到邻居，跳过
# 2024-09-05 10:55:22,207 - INFO - 图斑 40482 没有找到邻居，跳过
# 2024-09-05 10:55:22,233 - INFO - 图斑 40528 没有找到邻居，跳过
# 2024-09-05 10:55:22,260 - INFO - 图斑 40564 没有找到邻居，跳过
# 2024-09-05 10:55:22,264 - INFO - 图斑 40565 没有找到邻居，跳过
# 2024-09-05 10:55:22,267 - INFO - 图斑 40569 没有找到邻居，跳过
# 2024-09-05 10:55:22,271 - INFO - 图斑 40570 没有找到邻居，跳过
# 2024-09-05 10:55:22,333 - INFO - 图斑 40629 没有找到邻居，跳过
# 2024-09-05 10:55:22,336 - INFO - 图斑 40630 没有找到邻居，跳过
# 2024-09-05 10:55:22,408 - INFO - 图斑 40735 没有找到邻居，跳过
# 2024-09-05 10:55:22,434 - INFO - 图斑 40753 没有找到邻居，跳过
# 2024-09-05 10:55:22,440 - INFO - 图斑 40756 没有找到邻居，跳过
# 2024-09-05 10:55:22,544 - INFO - 图斑 40858 没有找到邻居，跳过
# 2024-09-05 10:55:22,584 - INFO - 图斑 40897 没有找到邻居，跳过
# 2024-09-05 10:55:22,790 - INFO - 图斑 41100 没有找到邻居，跳过
# 2024-09-05 10:55:22,898 - INFO - 图斑 41219 没有找到邻居，跳过
# 2024-09-05 10:55:22,926 - INFO - 图斑 41238 没有找到邻居，跳过
# 2024-09-05 10:55:23,076 - INFO - 图斑 41378 没有找到邻居，跳过
# 2024-09-05 10:55:23,316 - INFO - 图斑 41603 没有找到邻居，跳过
# 2024-09-05 10:55:23,369 - INFO - 图斑 41645 没有找到邻居，跳过
# 2024-09-05 10:55:23,586 - INFO - 图斑 41837 没有找到邻居，跳过
# 2024-09-05 10:55:23,590 - INFO - 图斑 41838 没有找到邻居，跳过
# 2024-09-05 10:55:23,943 - INFO - 图斑 42176 没有找到邻居，跳过
# 2024-09-05 10:55:24,320 - INFO - 图斑 42585 没有找到邻居，跳过
# 2024-09-05 10:55:24,686 - INFO - 图斑 42882 没有找到邻居，跳过
# 2024-09-05 10:55:24,689 - INFO - 图斑 42883 没有找到邻居，跳过
# 2024-09-05 10:55:24,691 - INFO - 图斑 42884 没有找到邻居，跳过
# 2024-09-05 10:55:24,789 - INFO - 图斑 43016 没有找到邻居，跳过
# 2024-09-05 10:55:24,791 - INFO - 图斑 43017 没有找到邻居，跳过
# 2024-09-05 10:55:25,091 - INFO - 图斑 43302 没有找到邻居，跳过
# 2024-09-05 10:55:25,101 - INFO - 图斑 43305 没有找到邻居，跳过
# 2024-09-05 10:55:25,113 - INFO - 图斑 43312 没有找到邻居，跳过
# 2024-09-05 10:55:25,321 - INFO - 图斑 43495 没有找到邻居，跳过
# 2024-09-05 10:55:25,339 - INFO - 图斑 43506 没有找到邻居，跳过
# 2024-09-05 10:55:25,342 - INFO - 图斑 43507 没有找到邻居，跳过
# 2024-09-05 10:55:25,473 - INFO - 图斑 43647 没有找到邻居，跳过
# 2024-09-05 10:55:25,552 - INFO - 图斑 43725 没有找到邻居，跳过
# 2024-09-05 10:55:25,625 - INFO - 图斑 43768 没有找到邻居，跳过
# 2024-09-05 10:55:25,649 - INFO - 图斑 43792 没有找到邻居，跳过
# 2024-09-05 10:55:26,023 - INFO - 图斑 44058 没有找到邻居，跳过
# 2024-09-05 10:55:26,026 - INFO - 图斑 44059 没有找到邻居，跳过
# 2024-09-05 10:55:26,367 - INFO - 图斑 44389 没有找到邻居，跳过
# 2024-09-05 10:55:26,464 - INFO - 图斑 44467 没有找到邻居，跳过
# 2024-09-05 10:55:26,653 - INFO - 图斑 44592 没有找到邻居，跳过
# 2024-09-05 10:55:26,656 - INFO - 图斑 44593 没有找到邻居，跳过
# 2024-09-05 10:55:26,675 - INFO - 图斑 44632 没有找到邻居，跳过
# 2024-09-05 10:55:26,680 - INFO - 图斑 44634 没有找到邻居，跳过
# 2024-09-05 10:55:26,738 - INFO - 图斑 44661 没有找到邻居，跳过
# 2024-09-05 10:55:26,843 - INFO - 图斑 44738 没有找到邻居，跳过
# 2024-09-05 10:55:27,380 - INFO - 图斑 45164 没有找到邻居，跳过
# 2024-09-05 10:55:27,906 - INFO - 图斑 45495 没有找到邻居，跳过
# 2024-09-05 10:55:27,911 - INFO - 图斑 45496 没有找到邻居，跳过
# 2024-09-05 10:55:28,385 - INFO - 图斑 45869 没有找到邻居，跳过
# 2024-09-05 10:55:28,618 - INFO - 图斑 46055 没有找到邻居，跳过
# 2024-09-05 10:55:28,795 - INFO - 图斑 46229 没有找到邻居，跳过
# 2024-09-05 10:55:28,845 - INFO - 图斑 46270 没有找到邻居，跳过
# 2024-09-05 10:55:28,882 - INFO - 图斑 46309 没有找到邻居，跳过
# 2024-09-05 10:55:28,885 - INFO - 图斑 46310 没有找到邻居，跳过
# 2024-09-05 10:55:28,887 - INFO - 图斑 46311 没有找到邻居，跳过
# 2024-09-05 10:55:29,393 - INFO - 图斑 46905 没有找到邻居，跳过
# 2024-09-05 10:55:29,431 - INFO - 图斑 46944 没有找到邻居，跳过
# 2024-09-05 10:55:29,506 - INFO - 图斑 47036 没有找到邻居，跳过
# 2024-09-05 10:55:29,524 - INFO - 图斑 47044 没有找到邻居，跳过
# 2024-09-05 10:55:29,631 - INFO - 图斑 47178 没有找到邻居，跳过
# 2024-09-05 10:55:29,903 - INFO - 图斑 47468 没有找到邻居，跳过
# 2024-09-05 10:55:30,197 - INFO - 图斑 47706 没有找到邻居，跳过
# 2024-09-05 10:55:30,330 - INFO - 图斑 47839 没有找到邻居，跳过
# 2024-09-05 10:55:30,415 - INFO - 图斑 47913 没有找到邻居，跳过
# 2024-09-05 10:55:30,417 - INFO - 图斑 47914 没有找到邻居，跳过
# 2024-09-05 10:55:30,440 - INFO - 图斑 47921 没有找到邻居，跳过
# 2024-09-05 10:55:30,443 - INFO - 图斑 47922 没有找到邻居，跳过
# 2024-09-05 10:55:30,683 - INFO - 图斑 48132 没有找到邻居，跳过
# 2024-09-05 10:55:30,686 - INFO - 图斑 48133 没有找到邻居，跳过
# 2024-09-05 10:55:30,690 - INFO - 图斑 48134 没有找到邻居，跳过
# 2024-09-05 10:55:30,695 - INFO - 图斑 48135 没有找到邻居，跳过
# 2024-09-05 10:55:30,701 - INFO - 图斑 48136 没有找到邻居，跳过
# 2024-09-05 10:55:30,705 - INFO - 图斑 48137 没有找到邻居，跳过
# 2024-09-05 10:55:30,710 - INFO - 图斑 48138 没有找到邻居，跳过
# 2024-09-05 10:55:30,927 - INFO - 图斑 48303 没有找到邻居，跳过
# 2024-09-05 10:55:31,082 - INFO - 图斑 48385 没有找到邻居，跳过
# 2024-09-05 10:55:31,597 - INFO - 图斑 48748 没有找到邻居，跳过
# 2024-09-05 10:55:31,600 - INFO - 图斑 48749 没有找到邻居，跳过
# 2024-09-05 10:55:31,603 - INFO - 图斑 48751 没有找到邻居，跳过
# 2024-09-05 10:55:32,124 - INFO - 图斑 49118 没有找到邻居，跳过
# 2024-09-05 10:55:32,389 - INFO - 图斑 49288 没有找到邻居，跳过
# 2024-09-05 10:55:32,907 - INFO - 图斑 49785 没有找到邻居，跳过
# 2024-09-05 10:55:33,322 - INFO - 图斑 50111 没有找到邻居，跳过
# 2024-09-05 10:55:33,405 - INFO - 图斑 50174 没有找到邻居，跳过
# 2024-09-05 10:55:33,409 - INFO - 图斑 50175 没有找到邻居，跳过
# 2024-09-05 10:55:34,809 - INFO - 图斑 51470 没有找到邻居，跳过
# 2024-09-05 10:55:35,030 - INFO - 图斑 51679 没有找到邻居，跳过
# 2024-09-05 10:55:35,517 - INFO - 图斑 52190 没有找到邻居，跳过
# 2024-09-05 10:55:36,154 - INFO - 图斑 52886 没有找到邻居，跳过
# 2024-09-05 10:55:36,394 - INFO - 图斑 53095 没有找到邻居，跳过
# 2024-09-05 10:55:36,432 - INFO - 图斑 53139 没有找到邻居，跳过
# 2024-09-05 10:55:36,434 - INFO - 图斑 53140 没有找到邻居，跳过
# 2024-09-05 10:55:36,934 - INFO - 图斑 53742 没有找到邻居，跳过
# 2024-09-05 10:55:37,008 - INFO - 图斑 53801 没有找到邻居，跳过
# 2024-09-05 10:55:37,067 - INFO - 图斑 53846 没有找到邻居，跳过
# 2024-09-05 10:55:37,824 - INFO - 图斑 54479 没有找到邻居，跳过
# 2024-09-05 10:55:37,855 - INFO - 图斑 54495 没有找到邻居，跳过
# 2024-09-05 10:55:37,913 - INFO - 图斑 54520 没有找到邻居，跳过
# 2024-09-05 10:55:38,380 - INFO - 图斑 54917 没有找到邻居，跳过
# 2024-09-05 10:55:39,161 - INFO - 图斑 55745 没有找到邻居，跳过
# 2024-09-05 10:55:39,177 - INFO - 图斑 55767 没有找到邻居，跳过
# 2024-09-05 10:55:39,523 - INFO - 图斑 56242 没有找到邻居，跳过
# 2024-09-05 10:55:39,525 - INFO - 图斑 56243 没有找到邻居，跳过
# 2024-09-05 10:55:39,527 - INFO - 图斑 56244 没有找到邻居，跳过
# 2024-09-05 10:55:39,888 - INFO - 图斑 56613 没有找到邻居，跳过
# 2024-09-05 10:55:39,890 - INFO - 图斑 56614 没有找到邻居，跳过
# 2024-09-05 10:55:40,064 - INFO - 图斑 56764 没有找到邻居，跳过
# 2024-09-05 10:55:40,116 - INFO - 图斑 56806 没有找到邻居，跳过
# 2024-09-05 10:55:40,148 - INFO - 图斑 56830 没有找到邻居，跳过
# 2024-09-05 10:55:40,152 - INFO - 图斑 56832 没有找到邻居，跳过
# 2024-09-05 10:55:40,154 - INFO - 图斑 56833 没有找到邻居，跳过
# 2024-09-05 10:55:40,166 - INFO - 图斑 56839 没有找到邻居，跳过
# 2024-09-05 10:55:40,171 - INFO - 图斑 56847 没有找到邻居，跳过
# 2024-09-05 10:55:40,231 - INFO - 图斑 56944 没有找到邻居，跳过
# 2024-09-05 10:55:40,354 - INFO - 图斑 57102 没有找到邻居，跳过
# 2024-09-05 10:55:40,577 - INFO - 图斑 57392 没有找到邻居，跳过
# 2024-09-05 10:55:40,579 - INFO - 图斑 57393 没有找到邻居，跳过
# 2024-09-05 10:55:40,581 - INFO - 图斑 57394 没有找到邻居，跳过
# 2024-09-05 10:55:40,658 - INFO - 图斑 57476 没有找到邻居，跳过
# 2024-09-05 10:55:41,320 - INFO - 图斑 57990 没有找到邻居，跳过
# 2024-09-05 10:55:42,225 - INFO - 图斑 58747 没有找到邻居，跳过
# 2024-09-05 10:55:42,261 - INFO - 图斑 58766 没有找到邻居，跳过
# 2024-09-05 10:55:42,263 - INFO - 图斑 58767 没有找到邻居，跳过
# 2024-09-05 10:55:42,552 - INFO - 图斑 59100 没有找到邻居，跳过
# 2024-09-05 10:55:42,554 - INFO - 图斑 59101 没有找到邻居，跳过
# 2024-09-05 10:55:42,560 - INFO - 图斑 59104 没有找到邻居，跳过
# 2024-09-05 10:55:42,900 - INFO - 图斑 59506 没有找到邻居，跳过
# 2024-09-05 10:55:43,184 - INFO - 图斑 59832 没有找到邻居，跳过
# 2024-09-05 10:55:43,463 - INFO - 图斑 60082 没有找到邻居，跳过
# 2024-09-05 10:55:43,638 - INFO - 图斑 60248 没有找到邻居，跳过
# 2024-09-05 10:55:43,647 - INFO - 图斑 60252 没有找到邻居，跳过
# 2024-09-05 10:55:43,667 - INFO - 图斑 60262 没有找到邻居，跳过
# 2024-09-05 10:55:43,732 - INFO - 图斑 60351 没有找到邻居，跳过
# 2024-09-05 10:55:43,736 - INFO - 图斑 60356 没有找到邻居，跳过
# 2024-09-05 10:55:43,738 - INFO - 图斑 60357 没有找到邻居，跳过
# 2024-09-05 10:55:44,218 - INFO - 图斑 60863 没有找到邻居，跳过
# 2024-09-05 10:55:44,220 - INFO - 图斑 60864 没有找到邻居，跳过
# 2024-09-05 10:55:44,221 - INFO - 图斑 60865 没有找到邻居，跳过
# 2024-09-05 10:55:44,223 - INFO - 图斑 60866 没有找到邻居，跳过
# 2024-09-05 10:55:44,227 - INFO - 图斑 60868 没有找到邻居，跳过
# 2024-09-05 10:55:44,228 - INFO - 图斑 60869 没有找到邻居，跳过
# 2024-09-05 10:55:45,370 - INFO - 图斑 61790 没有找到邻居，跳过
# 2024-09-05 10:55:45,378 - INFO - 图斑 61794 没有找到邻居，跳过
# 2024-09-05 10:55:45,383 - INFO - 图斑 61798 没有找到邻居，跳过
# 2024-09-05 10:55:45,389 - INFO - 图斑 61809 没有找到邻居，跳过
# 2024-09-05 10:55:45,420 - INFO - 图斑 61838 没有找到邻居，跳过
# 2024-09-05 10:55:45,422 - INFO - 图斑 61839 没有找到邻居，跳过
# 2024-09-05 10:55:45,690 - INFO - 图斑 62088 没有找到邻居，跳过
# 2024-09-05 10:55:45,921 - INFO - 图斑 62363 没有找到邻居，跳过
# 2024-09-05 10:55:46,152 - INFO - 图斑 62594 没有找到邻居，跳过
# 2024-09-05 10:55:46,469 - INFO - 图斑 62902 没有找到邻居，跳过
# 2024-09-05 10:55:46,672 - INFO - 图斑 63102 没有找到邻居，跳过
# 2024-09-05 10:55:46,853 - INFO - 图斑 63358 没有找到邻居，跳过
# 2024-09-05 10:55:47,252 - INFO - 图斑 63790 没有找到邻居，跳过
# 2024-09-05 10:55:47,763 - INFO - 图斑 64285 没有找到邻居，跳过
# 2024-09-05 10:55:47,896 - INFO - 图斑 64389 没有找到邻居，跳过
# 2024-09-05 10:55:47,901 - INFO - 图斑 64391 没有找到邻居，跳过
# 2024-09-05 10:55:48,018 - INFO - 图斑 64494 没有找到邻居，跳过
# 2024-09-05 10:55:48,130 - INFO - 图斑 64631 没有找到邻居，跳过
# 2024-09-05 10:55:48,592 - INFO - 图斑 65124 没有找到邻居，跳过
# 2024-09-05 10:55:48,595 - INFO - 图斑 65125 没有找到邻居，跳过
# 2024-09-05 10:55:48,849 - INFO - 图斑 65382 没有找到邻居，跳过
# 2024-09-05 10:55:50,332 - INFO - 图斑 66882 没有找到邻居，跳过
# 2024-09-05 10:55:50,433 - INFO - 图斑 67031 没有找到邻居，跳过
# 2024-09-05 10:55:50,436 - INFO - 图斑 67034 没有找到邻居，跳过
# 2024-09-05 10:55:50,568 - INFO - 图斑 67273 没有找到邻居，跳过
# 2024-09-05 10:55:51,304 - INFO - 图斑 68004 没有找到邻居，跳过
# 2024-09-05 10:55:51,315 - INFO - 图斑 68008 没有找到邻居，跳过
# 2024-09-05 10:55:51,695 - INFO - 图斑 68290 没有找到邻居，跳过
# 2024-09-05 10:55:52,181 - INFO - 图斑 68759 没有找到邻居，跳过
# 2024-09-05 10:55:52,434 - INFO - 图斑 69018 没有找到邻居，跳过
# 2024-09-05 10:55:52,691 - INFO - 图斑 69290 没有找到邻居，跳过
# 2024-09-05 10:55:52,695 - INFO - 图斑 69293 没有找到邻居，跳过
# 2024-09-05 10:55:52,698 - INFO - 图斑 69294 没有找到邻居，跳过
# 2024-09-05 10:55:52,700 - INFO - 图斑 69297 没有找到邻居，跳过
# 2024-09-05 10:55:52,708 - INFO - 图斑 69305 没有找到邻居，跳过
# 2024-09-05 10:55:52,711 - INFO - 图斑 69307 没有找到邻居，跳过
# 2024-09-05 10:55:53,336 - INFO - 图斑 70004 没有找到邻居，跳过
# 2024-09-05 10:55:54,322 - INFO - 图斑 71109 没有找到邻居，跳过
# 2024-09-05 10:55:54,703 - INFO - 图斑 71434 没有找到邻居，跳过
# 2024-09-05 10:55:54,723 - INFO - 图斑 71456 没有找到邻居，跳过
# 2024-09-05 10:55:55,391 - INFO - 图斑 72162 没有找到邻居，跳过
# 2024-09-05 10:55:55,431 - INFO - 图斑 72183 没有找到邻居，跳过
# 2024-09-05 10:55:55,707 - INFO - 图斑 72412 没有找到邻居，跳过
# 2024-09-05 10:55:55,987 - INFO - 图斑 72738 没有找到邻居，跳过
# 2024-09-05 10:55:56,013 - INFO - 图斑 72758 没有找到邻居，跳过
# 2024-09-05 10:55:56,267 - INFO - 图斑 73010 没有找到邻居，跳过
# 2024-09-05 10:55:56,310 - INFO - 图斑 73025 没有找到邻居，跳过
# 2024-09-05 10:55:56,322 - INFO - 图斑 73028 没有找到邻居，跳过
# 2024-09-05 10:55:56,584 - INFO - 图斑 73226 没有找到邻居，跳过
# 2024-09-05 10:55:56,872 - INFO - 图斑 73398 没有找到邻居，跳过
# 2024-09-05 10:55:56,875 - INFO - 图斑 73399 没有找到邻居，跳过
# 2024-09-05 10:55:56,961 - INFO - 图斑 73475 没有找到邻居，跳过
# 2024-09-05 10:55:57,554 - INFO - 图斑 73989 没有找到邻居，跳过
# 2024-09-05 10:55:57,562 - INFO - 图斑 73991 没有找到邻居，跳过
# 2024-09-05 10:55:57,566 - INFO - 图斑 73992 没有找到邻居，跳过
# 2024-09-05 10:55:57,569 - INFO - 图斑 73993 没有找到邻居，跳过
# 2024-09-05 10:55:58,145 - INFO - 图斑 74565 没有找到邻居，跳过
# 2024-09-05 10:55:58,598 - INFO - 图斑 74994 没有找到邻居，跳过
# 2024-09-05 10:55:58,959 - INFO - 图斑 75440 没有找到邻居，跳过
# 2024-09-05 10:55:59,144 - INFO - 图斑 75609 没有找到邻居，跳过
# 2024-09-05 10:55:59,782 - INFO - 图斑 76306 没有找到邻居，跳过
# 2024-09-05 10:55:59,784 - INFO - 图斑 76307 没有找到邻居，跳过
# 2024-09-05 10:55:59,785 - INFO - 图斑 76308 没有找到邻居，跳过
# 2024-09-05 10:56:00,301 - INFO - 图斑 76945 没有找到邻居，跳过
# 2024-09-05 10:56:00,305 - INFO - 图斑 76947 没有找到邻居，跳过
# 2024-09-05 10:56:01,431 - INFO - 图斑 78222 没有找到邻居，跳过
# 2024-09-05 10:56:01,871 - INFO - 图斑 78999 没有找到邻居，跳过
# 2024-09-05 10:56:02,513 - INFO - 图斑 79799 没有找到邻居，跳过
# 2024-09-05 10:56:02,770 - INFO - 图斑 80215 没有找到邻居，跳过
# 2024-09-05 10:56:03,239 - INFO - 图斑 80717 没有找到邻居，跳过
# 2024-09-05 10:56:03,241 - INFO - 图斑 80718 没有找到邻居，跳过
# 2024-09-05 10:56:03,245 - INFO - 图斑 80719 没有找到邻居，跳过
# 2024-09-05 10:56:03,588 - INFO - 图斑 81017 没有找到邻居，跳过
# 2024-09-05 10:56:03,682 - INFO - 图斑 81112 没有找到邻居，跳过
# 2024-09-05 10:56:03,689 - INFO - 图斑 81117 没有找到邻居，跳过
# 2024-09-05 10:56:03,978 - INFO - 图斑 81337 没有找到邻居，跳过
# 2024-09-05 10:56:04,481 - INFO - 图斑 81870 没有找到邻居，跳过
# 2024-09-05 10:56:04,650 - INFO - 图斑 82021 没有找到邻居，跳过
# 2024-09-05 10:56:04,805 - INFO - 图斑 82192 没有找到邻居，跳过
# 2024-09-05 10:56:04,816 - INFO - 图斑 82209 没有找到邻居，跳过
# 2024-09-05 10:56:05,170 - INFO - 图斑 82519 没有找到邻居，跳过
# 2024-09-05 10:56:05,174 - INFO - 图斑 82522 没有找到邻居，跳过
# 2024-09-05 10:56:05,183 - INFO - 图斑 82532 没有找到邻居，跳过
# 2024-09-05 10:56:05,185 - INFO - 图斑 82533 没有找到邻居，跳过
# 2024-09-05 10:56:05,232 - INFO - 图斑 82582 没有找到邻居，跳过
# 2024-09-05 10:56:05,234 - INFO - 图斑 82583 没有找到邻居，跳过
# 2024-09-05 10:56:05,236 - INFO - 图斑 82584 没有找到邻居，跳过
# 2024-09-05 10:56:05,721 - INFO - 图斑 83010 没有找到邻居，跳过
# 2024-09-05 10:56:05,815 - INFO - 图斑 83104 没有找到邻居，跳过
# 2024-09-05 10:56:06,799 - INFO - 图斑 83996 没有找到邻居，跳过
# 2024-09-05 10:56:06,801 - INFO - 图斑 83997 没有找到邻居，跳过
# 2024-09-05 10:56:07,161 - INFO - 图斑 84304 没有找到邻居，跳过
# 2024-09-05 10:56:07,328 - INFO - 图斑 84481 没有找到邻居，跳过
# 2024-09-05 10:56:08,011 - INFO - 图斑 85239 没有找到邻居，跳过
# 2024-09-05 10:56:08,581 - INFO - 图斑 85876 没有找到邻居，跳过
# 2024-09-05 10:56:08,936 - INFO - 图斑 86238 没有找到邻居，跳过
# 2024-09-05 10:56:08,938 - INFO - 图斑 86241 没有找到邻居，跳过
# 2024-09-05 10:56:09,540 - INFO - 图斑 86904 没有找到邻居，跳过
# 2024-09-05 10:56:09,604 - INFO - 图斑 87006 没有找到邻居，跳过
# 2024-09-05 10:56:09,691 - INFO - 图斑 87086 没有找到邻居，跳过
# 2024-09-05 10:56:10,394 - INFO - 图斑 87792 没有找到邻居，跳过
# 2024-09-05 10:56:11,798 - INFO - 图斑 89341 没有找到邻居，跳过
# 2024-09-05 10:56:12,284 - INFO - 图斑 89863 没有找到邻居，跳过
# 2024-09-05 10:56:12,349 - INFO - 图斑 89982 没有找到邻居，跳过
# 2024-09-05 10:56:13,754 - INFO - 图斑 91604 没有找到邻居，跳过
# 2024-09-05 10:56:14,341 - INFO - 图斑 92350 没有找到邻居，跳过
# 2024-09-05 10:56:14,966 - INFO - 图斑 93132 没有找到邻居，跳过
# 2024-09-05 10:56:15,043 - INFO - 图斑 93181 没有找到邻居，跳过
# 2024-09-05 10:56:15,047 - INFO - 图斑 93182 没有找到邻居，跳过
# 2024-09-05 10:56:15,055 - INFO - 图斑 93190 没有找到邻居，跳过
# 2024-09-05 10:56:15,064 - INFO - 图斑 93197 没有找到邻居，跳过
# 2024-09-05 10:56:15,067 - INFO - 图斑 93202 没有找到邻居，跳过
# 2024-09-05 10:56:15,070 - INFO - 图斑 93203 没有找到邻居，跳过
# 2024-09-05 10:56:15,094 - INFO - 图斑 93229 没有找到邻居，跳过
# 2024-09-05 10:56:15,249 - INFO - 图斑 93378 没有找到邻居，跳过
# 2024-09-05 10:56:15,435 - INFO - 图斑 93572 没有找到邻居，跳过
# 2024-09-05 10:56:15,460 - INFO - 图斑 93593 没有找到邻居，跳过
# 2024-09-05 10:56:15,934 - INFO - 图斑 94096 没有找到邻居，跳过
# 2024-09-05 10:56:15,940 - INFO - 图斑 94099 没有找到邻居，跳过
# 2024-09-05 10:56:15,973 - INFO - 图斑 94131 没有找到邻居，跳过
# 2024-09-05 10:56:15,983 - INFO - 图斑 94137 没有找到邻居，跳过
# 2024-09-05 10:56:16,005 - INFO - 图斑 94163 没有找到邻居，跳过
# 2024-09-05 10:56:16,154 - INFO - 图斑 94279 没有找到邻居，跳过
# 2024-09-05 10:56:16,582 - INFO - 图斑 94732 没有找到邻居，跳过
# 2024-09-05 10:56:16,727 - INFO - 图斑 94909 没有找到邻居，跳过
# 2024-09-05 10:56:16,923 - INFO - 图斑 95137 没有找到邻居，跳过
# 2024-09-05 10:56:16,926 - INFO - 图斑 95138 没有找到邻居，跳过
# 2024-09-05 10:56:17,029 - INFO - 图斑 95273 没有找到邻居，跳过
# 2024-09-05 10:56:17,269 - INFO - 图斑 95498 没有找到邻居，跳过
# 2024-09-05 10:56:17,374 - INFO - 图斑 95602 没有找到邻居，跳过
# 2024-09-05 10:56:17,699 - INFO - 图斑 95949 没有找到邻居，跳过
# 2024-09-05 10:56:17,701 - INFO - 图斑 95950 没有找到邻居，跳过
# 2024-09-05 10:56:17,704 - INFO - 图斑 95951 没有找到邻居，跳过
# 2024-09-05 10:56:17,706 - INFO - 图斑 95952 没有找到邻居，跳过
# 2024-09-05 10:56:17,728 - INFO - 图斑 95993 没有找到邻居，跳过
# 2024-09-05 10:56:18,018 - INFO - 图斑 96396 没有找到邻居，跳过
# 2024-09-05 10:56:18,305 - INFO - 图斑 96705 没有找到邻居，跳过
# 2024-09-05 10:56:18,307 - INFO - 图斑 96706 没有找到邻居，跳过
# 2024-09-05 10:56:18,309 - INFO - 图斑 96707 没有找到邻居，跳过
# 2024-09-05 10:56:19,496 - INFO - 图斑 97984 没有找到邻居，跳过
# 2024-09-05 10:56:19,507 - INFO - 图斑 97996 没有找到邻居，跳过
# 2024-09-05 10:56:19,739 - INFO - 图斑 98251 没有找到邻居，跳过
# 2024-09-05 10:56:19,743 - INFO - 图斑 98252 没有找到邻居，跳过
# 2024-09-05 10:56:20,433 - INFO - 图斑 99178 没有找到邻居，跳过
# 2024-09-05 10:56:20,435 - INFO - 图斑 99179 没有找到邻居，跳过
# 2024-09-05 10:56:20,510 - INFO - 图斑 99305 没有找到邻居，跳过
# 2024-09-05 10:56:20,718 - INFO - 图斑 99589 没有找到邻居，跳过
# 2024-09-05 10:56:20,750 - INFO - 图斑 99688 没有找到邻居，跳过
# 2024-09-05 10:56:21,032 - INFO - 图斑 100078 没有找到邻居，跳过
# 2024-09-05 10:56:21,659 - INFO - 图斑 100983 没有找到邻居，跳过
# 2024-09-05 10:56:21,899 - INFO - 图斑 101413 没有找到邻居，跳过
# 2024-09-05 10:56:26,483 - INFO - 图斑 110405 没有找到邻居，跳过
# 2024-09-05 10:56:27,847 - INFO - 图斑 112503 没有找到邻居，跳过
# 2024-09-05 10:56:28,470 - INFO - 图斑 113532 没有找到邻居，跳过
# 2024-09-05 10:56:30,562 - INFO - 图斑 117172 没有找到邻居，跳过
# 2024-09-05 10:56:33,824 - INFO - 图斑 124268 没有找到邻居，跳过
# 2024-09-05 10:56:34,223 - INFO - 图斑 125008 没有找到邻居，跳过
# 2024-09-05 10:56:34,530 - INFO - 图斑 125683 没有找到邻居，跳过
# 2024-09-05 10:56:38,727 - INFO - 图斑 134939 没有找到邻居，跳过
# 2024-09-05 10:56:40,599 - INFO - 图斑 138909 没有找到邻居，跳过
# 2024-09-05 10:56:42,457 - INFO - 图斑 142182 没有找到邻居，跳过
# 2024-09-05 10:56:43,039 - INFO - 图斑 143411 没有找到邻居，跳过
# 2024-09-05 10:56:45,121 - INFO - 图斑 148361 没有找到邻居，跳过
# 2024-09-05 10:56:45,172 - INFO - 图斑 148383 没有找到邻居，跳过
# 2024-09-05 10:56:45,175 - INFO - 图斑 148384 没有找到邻居，跳过
# 2024-09-05 10:56:45,264 - INFO - 图斑 148460 没有找到邻居，跳过
# 2024-09-05 10:56:46,618 - INFO - 图斑 151246 没有找到邻居，跳过
# 2024-09-05 10:56:46,799 - INFO - 图斑 151375 没有找到邻居，跳过
# 2024-09-05 10:56:46,967 - INFO - 图斑 151505 没有找到邻居，跳过
# 2024-09-05 10:56:47,164 - INFO - 图斑 151628 没有找到邻居，跳过
# 2024-09-05 10:56:47,398 - INFO - 图斑 151803 没有找到邻居，跳过
# 2024-09-05 10:56:47,455 - INFO - 图斑 151842 没有找到邻居，跳过
# 2024-09-05 10:56:48,051 - INFO - 图斑 152213 没有找到邻居，跳过
# 2024-09-05 10:56:48,079 - INFO - 图斑 152234 没有找到邻居，跳过
# 2024-09-05 10:56:48,082 - INFO - 图斑 152235 没有找到邻居，跳过
# 2024-09-05 10:56:48,084 - INFO - 图斑 152236 没有找到邻居，跳过
# 2024-09-05 10:56:48,085 - INFO - 图斑 152237 没有找到邻居，跳过
# 2024-09-05 10:56:48,210 - INFO - 图斑 152315 没有找到邻居，跳过
# 2024-09-05 10:56:48,212 - INFO - 图斑 152316 没有找到邻居，跳过
# 2024-09-05 10:56:48,371 - INFO - 图斑 152410 没有找到邻居，跳过
# 2024-09-05 10:56:48,540 - INFO - 图斑 152533 没有找到邻居，跳过
# 2024-09-05 10:56:48,596 - INFO - 图斑 152555 没有找到邻居，跳过
# 2024-09-05 10:56:48,599 - INFO - 图斑 152556 没有找到邻居，跳过
# 2024-09-05 10:56:48,639 - INFO - 图斑 152579 没有找到邻居，跳过
# 2024-09-05 10:56:48,640 - INFO - 图斑 152580 没有找到邻居，跳过
# 2024-09-05 10:56:48,643 - INFO - 图斑 152581 没有找到邻居，跳过
# 2024-09-05 10:56:48,646 - INFO - 图斑 152582 没有找到邻居，跳过
# 2024-09-05 10:56:48,649 - INFO - 图斑 152583 没有找到邻居，跳过
# 2024-09-05 10:56:48,652 - INFO - 图斑 152584 没有找到邻居，跳过
# 2024-09-05 10:56:48,655 - INFO - 图斑 152586 没有找到邻居，跳过
# 2024-09-05 10:56:48,721 - INFO - 图斑 152633 没有找到邻居，跳过
# 2024-09-05 10:56:49,033 - INFO - 图斑 152854 没有找到邻居，跳过
# 2024-09-05 10:56:49,037 - INFO - 图斑 152856 没有找到邻居，跳过
# 2024-09-05 10:56:49,047 - INFO - 图斑 152864 没有找到邻居，跳过
# 2024-09-05 10:56:49,069 - INFO - 图斑 152877 没有找到邻居，跳过
# 2024-09-05 10:56:49,110 - INFO - 图斑 152910 没有找到邻居，跳过
# 2024-09-05 10:56:49,265 - INFO - 图斑 153035 没有找到邻居，跳过
# 2024-09-05 10:56:49,380 - INFO - 图斑 153111 没有找到邻居，跳过
# 2024-09-05 10:56:49,711 - INFO - 图斑 153337 没有找到邻居，跳过
# 2024-09-05 10:56:49,713 - INFO - 图斑 153338 没有找到邻居，跳过
# 2024-09-05 10:56:49,715 - INFO - 图斑 153339 没有找到邻居，跳过
# 2024-09-05 10:56:49,717 - INFO - 图斑 153340 没有找到邻居，跳过
# 2024-09-05 10:56:49,718 - INFO - 图斑 153341 没有找到邻居，跳过
# 2024-09-05 10:56:49,720 - INFO - 图斑 153342 没有找到邻居，跳过
# 2024-09-05 10:56:49,824 - INFO - 图斑 153413 没有找到邻居，跳过
# 2024-09-05 10:56:49,826 - INFO - 图斑 153414 没有找到邻居，跳过
# 2024-09-05 10:56:49,828 - INFO - 图斑 153415 没有找到邻居，跳过
# 2024-09-05 10:56:50,135 - INFO - 图斑 153683 没有找到邻居，跳过
# 2024-09-05 10:56:50,137 - INFO - 图斑 153684 没有找到邻居，跳过
# 2024-09-05 10:56:50,356 - INFO - 图斑 153873 没有找到邻居，跳过
# 2024-09-05 10:56:50,398 - INFO - 图斑 153903 没有找到邻居，跳过
# 2024-09-05 10:56:50,722 - INFO - 图斑 154217 没有找到邻居，跳过
# 2024-09-05 10:56:51,137 - INFO - 图斑 154564 没有找到邻居，跳过
# 2024-09-05 10:56:51,170 - INFO - 图斑 154581 没有找到邻居，跳过
# 2024-09-05 10:56:51,242 - INFO - 图斑 154606 没有找到邻居，跳过
# 2024-09-05 10:56:51,435 - INFO - 图斑 154749 没有找到邻居，跳过
# 2024-09-05 10:56:51,517 - INFO - 图斑 154798 没有找到邻居，跳过
# 2024-09-05 10:56:51,520 - INFO - 图斑 154799 没有找到邻居，跳过
# 2024-09-05 10:56:51,523 - INFO - 图斑 154800 没有找到邻居，跳过
# 2024-09-05 10:56:51,527 - INFO - 图斑 154801 没有找到邻居，跳过
# 2024-09-05 10:56:51,540 - INFO - 图斑 154806 没有找到邻居，跳过
# 2024-09-05 10:56:51,543 - INFO - 图斑 154807 没有找到邻居，跳过
# 2024-09-05 10:56:51,585 - INFO - 图斑 154849 没有找到邻居，跳过
# 2024-09-05 10:56:51,587 - INFO - 图斑 154850 没有找到邻居，跳过
# 2024-09-05 10:56:51,588 - INFO - 图斑 154851 没有找到邻居，跳过
# 2024-09-05 10:56:51,590 - INFO - 图斑 154852 没有找到邻居，跳过
# 2024-09-05 10:56:51,593 - INFO - 图斑 154853 没有找到邻居，跳过
# 2024-09-05 10:56:51,595 - INFO - 图斑 154854 没有找到邻居，跳过
# 2024-09-05 10:56:51,722 - INFO - 图斑 154935 没有找到邻居，跳过
# 2024-09-05 10:56:51,775 - INFO - 图斑 154975 没有找到邻居，跳过
# 2024-09-05 10:56:51,787 - INFO - 图斑 154979 没有找到邻居，跳过
# 2024-09-05 10:56:51,806 - INFO - 图斑 154986 没有找到邻居，跳过
# 2024-09-05 10:56:51,812 - INFO - 图斑 154988 没有找到邻居，跳过
# 2024-09-05 10:56:51,834 - INFO - 图斑 155000 没有找到邻居，跳过
# 2024-09-05 10:56:51,864 - INFO - 图斑 155025 没有找到邻居，跳过
# 2024-09-05 10:56:51,866 - INFO - 图斑 155026 没有找到邻居，跳过
# 2024-09-05 10:56:51,868 - INFO - 图斑 155027 没有找到邻居，跳过
# 2024-09-05 10:56:51,870 - INFO - 图斑 155028 没有找到邻居，跳过
# 2024-09-05 10:56:51,872 - INFO - 图斑 155031 没有找到邻居，跳过
# 2024-09-05 10:56:52,029 - INFO - 图斑 155138 没有找到邻居，跳过
# 2024-09-05 10:56:52,199 - INFO - 图斑 155252 没有找到邻居，跳过
# 2024-09-05 10:56:52,264 - INFO - 图斑 155314 没有找到邻居，跳过
# 2024-09-05 10:56:52,278 - INFO - 图斑 155318 没有找到邻居，跳过
# 2024-09-05 10:56:52,364 - INFO - 图斑 155395 没有找到邻居，跳过
# 2024-09-05 10:56:52,482 - INFO - 图斑 155479 没有找到邻居，跳过
# 2024-09-05 10:56:52,553 - INFO - 图斑 155517 没有找到邻居，跳过
# 2024-09-05 10:56:52,720 - INFO - 图斑 155637 没有找到邻居，跳过
# 2024-09-05 10:56:52,873 - INFO - 图斑 155732 没有找到邻居，跳过
# 2024-09-05 10:56:53,182 - INFO - 图斑 155935 没有找到邻居，跳过
# 2024-09-05 10:56:53,238 - INFO - 图斑 155967 没有找到邻居，跳过
# 2024-09-05 10:56:53,242 - INFO - 图斑 155969 没有找到邻居，跳过
# 2024-09-05 10:56:53,334 - INFO - 图斑 156018 没有找到邻居，跳过
# 2024-09-05 10:56:53,364 - INFO - 图斑 156028 没有找到邻居，跳过
# 2024-09-05 10:56:53,455 - INFO - 图斑 156078 没有找到邻居，跳过
# 2024-09-05 10:56:53,510 - INFO - 图斑 156117 没有找到邻居，跳过
# 2024-09-05 10:56:53,528 - INFO - 图斑 156125 没有找到邻居，跳过
# 2024-09-05 10:56:53,838 - INFO - 图斑 156291 没有找到邻居，跳过
# 2024-09-05 10:56:53,841 - INFO - 图斑 156292 没有找到邻居，跳过
# 2024-09-05 10:56:53,898 - INFO - 图斑 156314 没有找到邻居，跳过
# 2024-09-05 10:56:54,028 - INFO - 图斑 156363 没有找到邻居，跳过
# 2024-09-05 10:56:54,033 - INFO - 图斑 156365 没有找到邻居，跳过
# 2024-09-05 10:56:54,127 - INFO - 图斑 156434 没有找到邻居，跳过
# 2024-09-05 10:56:54,620 - INFO - 图斑 156760 没有找到邻居，跳过
# 2024-09-05 10:56:54,634 - INFO - 图斑 156772 没有找到邻居，跳过
# 2024-09-05 10:56:54,637 - INFO - 图斑 156773 没有找到邻居，跳过
# 2024-09-05 10:56:54,677 - INFO - 图斑 156798 没有找到邻居，跳过
# 2024-09-05 10:56:55,043 - INFO - 图斑 157013 没有找到邻居，跳过
# 2024-09-05 10:56:55,045 - INFO - 图斑 157014 没有找到邻居，跳过
# 2024-09-05 10:56:55,138 - INFO - 图斑 157061 没有找到邻居，跳过
# 2024-09-05 10:56:55,414 - INFO - 图斑 157250 没有找到邻居，跳过
# 2024-09-05 10:56:55,629 - INFO - 图斑 157423 没有找到邻居，跳过
# 2024-09-05 10:56:55,830 - INFO - 图斑 157507 没有找到邻居，跳过
# 2024-09-05 10:56:55,942 - INFO - 图斑 157599 没有找到邻居，跳过
# 2024-09-05 10:56:56,021 - INFO - 图斑 157642 没有找到邻居，跳过
# 2024-09-05 10:56:56,052 - INFO - 图斑 157669 没有找到邻居，跳过
# 2024-09-05 10:56:56,054 - INFO - 图斑 157670 没有找到邻居，跳过
# 2024-09-05 10:56:56,056 - INFO - 图斑 157671 没有找到邻居，跳过
# 2024-09-05 10:56:56,173 - INFO - 图斑 157791 没有找到邻居，跳过
# 2024-09-05 10:56:56,502 - INFO - 图斑 158027 没有找到邻居，跳过
# 2024-09-05 10:56:56,530 - INFO - 图斑 158039 没有找到邻居，跳过
# 2024-09-05 10:56:56,534 - INFO - 图斑 158040 没有找到邻居，跳过
# 2024-09-05 10:56:56,537 - INFO - 图斑 158041 没有找到邻居，跳过
# 2024-09-05 10:56:57,169 - INFO - 图斑 158475 没有找到邻居，跳过
# 2024-09-05 10:56:57,174 - INFO - 图斑 158479 没有找到邻居，跳过
# 2024-09-05 10:56:57,304 - INFO - 图斑 158576 没有找到邻居，跳过
# 2024-09-05 10:56:57,306 - INFO - 图斑 158577 没有找到邻居，跳过
# 2024-09-05 10:56:57,308 - INFO - 图斑 158578 没有找到邻居，跳过
# 2024-09-05 10:56:58,263 - INFO - 图斑 159229 没有找到邻居，跳过
# 2024-09-05 10:56:58,271 - INFO - 图斑 159234 没有找到邻居，跳过
# 2024-09-05 10:56:58,330 - INFO - 图斑 159273 没有找到邻居，跳过
# 2024-09-05 10:56:58,355 - INFO - 图斑 159283 没有找到邻居，跳过
# 2024-09-05 10:56:58,413 - INFO - 图斑 159315 没有找到邻居，跳过
# 2024-09-05 10:56:58,628 - INFO - 图斑 159449 没有找到邻居，跳过
# 2024-09-05 10:56:58,635 - INFO - 图斑 159455 没有找到邻居，跳过
# 2024-09-05 10:56:58,655 - INFO - 图斑 159464 没有找到邻居，跳过
# 2024-09-05 10:56:58,714 - INFO - 图斑 159500 没有找到邻居，跳过
# 2024-09-05 10:56:58,743 - INFO - 图斑 159511 没有找到邻居，跳过
# 2024-09-05 10:56:58,768 - INFO - 图斑 159522 没有找到邻居，跳过
# 2024-09-05 10:56:58,770 - INFO - 图斑 159523 没有找到邻居，跳过
# 2024-09-05 10:56:58,772 - INFO - 图斑 159524 没有找到邻居，跳过
# 2024-09-05 10:56:58,775 - INFO - 图斑 159525 没有找到邻居，跳过
# 2024-09-05 10:56:58,794 - INFO - 图斑 159531 没有找到邻居，跳过
# 2024-09-05 10:56:58,797 - INFO - 图斑 159532 没有找到邻居，跳过
# 2024-09-05 10:56:58,803 - INFO - 图斑 159534 没有找到邻居，跳过
# 2024-09-05 10:56:58,805 - INFO - 图斑 159535 没有找到邻居，跳过
# 2024-09-05 10:56:58,809 - INFO - 图斑 159537 没有找到邻居，跳过
# 2024-09-05 10:56:58,812 - INFO - 图斑 159538 没有找到邻居，跳过
# 2024-09-05 10:56:58,814 - INFO - 图斑 159539 没有找到邻居，跳过
# 2024-09-05 10:56:58,816 - INFO - 图斑 159540 没有找到邻居，跳过
# 2024-09-05 10:56:58,819 - INFO - 图斑 159541 没有找到邻居，跳过
# 2024-09-05 10:56:58,826 - INFO - 图斑 159543 没有找到邻居，跳过
# 2024-09-05 10:56:58,828 - INFO - 图斑 159544 没有找到邻居，跳过
# 2024-09-05 10:56:58,851 - INFO - 图斑 159557 没有找到邻居，跳过
# 2024-09-05 10:56:58,860 - INFO - 图斑 159561 没有找到邻居，跳过
# 2024-09-05 10:56:58,871 - INFO - 图斑 159566 没有找到邻居，跳过
# 2024-09-05 10:56:58,880 - INFO - 图斑 159570 没有找到邻居，跳过
# 2024-09-05 10:56:58,899 - INFO - 图斑 159575 没有找到邻居，跳过
# 2024-09-05 10:56:58,910 - INFO - 图斑 159582 没有找到邻居，跳过
# 2024-09-05 10:56:58,915 - INFO - 图斑 159584 没有找到邻居，跳过
# 2024-09-05 10:56:58,922 - INFO - 图斑 159589 没有找到邻居，跳过
# 2024-09-05 10:56:58,957 - INFO - 图斑 159610 没有找到邻居，跳过
# 2024-09-05 10:56:59,049 - INFO - 图斑 159671 没有找到邻居，跳过
# 2024-09-05 10:56:59,064 - INFO - 图斑 159677 没有找到邻居，跳过
# 2024-09-05 10:56:59,164 - INFO - 图斑 159745 没有找到邻居，跳过
# 2024-09-05 10:56:59,166 - INFO - 图斑 159746 没有找到邻居，跳过
# 2024-09-05 10:56:59,168 - INFO - 图斑 159747 没有找到邻居，跳过
# 2024-09-05 10:56:59,244 - INFO - 图斑 159790 没有找到邻居，跳过
# 2024-09-05 10:56:59,247 - INFO - 图斑 159791 没有找到邻居，跳过
# 2024-09-05 10:56:59,382 - INFO - 图斑 159838 没有找到邻居，跳过
# 2024-09-05 10:56:59,394 - INFO - 图斑 159845 没有找到邻居，跳过
# 2024-09-05 10:56:59,421 - INFO - 图斑 159862 没有找到邻居，跳过
# 2024-09-05 10:56:59,423 - INFO - 图斑 159863 没有找到邻居，跳过
# 2024-09-05 10:56:59,434 - INFO - 图斑 159872 没有找到邻居，跳过
# 2024-09-05 10:56:59,482 - INFO - 图斑 159906 没有找到邻居，跳过
# 2024-09-05 10:56:59,614 - INFO - 图斑 159993 没有找到邻居，跳过
# 2024-09-05 10:56:59,616 - INFO - 图斑 159994 没有找到邻居，跳过
# 2024-09-05 10:57:00,327 - INFO - 图斑 160421 没有找到邻居，跳过
# 2024-09-05 10:57:00,330 - INFO - 图斑 160422 没有找到邻居，跳过
# 2024-09-05 10:57:00,356 - INFO - 图斑 160435 没有找到邻居，跳过
# 2024-09-05 10:57:00,415 - INFO - 图斑 160457 没有找到邻居，跳过
# 2024-09-05 10:57:00,597 - INFO - 图斑 160593 没有找到邻居，跳过
# 2024-09-05 10:57:00,660 - INFO - 图斑 160637 没有找到邻居，跳过
# 2024-09-05 10:57:00,973 - INFO - 图斑 160799 没有找到邻居，跳过
# 2024-09-05 10:57:00,980 - INFO - 图斑 160801 没有找到邻居，跳过
# 2024-09-05 10:57:01,640 - INFO - 图斑 161083 没有找到邻居，跳过
# 2024-09-05 10:57:02,224 - INFO - 图斑 161283 没有找到邻居，跳过
# 2024-09-05 10:57:02,418 - INFO - 图斑 161383 没有找到邻居，跳过
# 2024-09-05 10:57:02,835 - INFO - 图斑 161601 没有找到邻居，跳过
# 2024-09-05 10:57:02,923 - INFO - 图斑 161645 没有找到邻居，跳过
# 2024-09-05 10:57:02,981 - INFO - 图斑 161667 没有找到邻居，跳过
# 2024-09-05 10:57:02,985 - INFO - 图斑 161670 没有找到邻居，跳过
# 2024-09-05 10:57:03,323 - INFO - 图斑 161876 没有找到邻居，跳过
# 2024-09-05 10:57:03,331 - INFO - 图斑 161879 没有找到邻居，跳过
# 2024-09-05 10:57:03,341 - INFO - 图斑 161883 没有找到邻居，跳过
# 2024-09-05 10:57:03,348 - INFO - 图斑 161886 没有找到邻居，跳过
# 2024-09-05 10:57:03,439 - INFO - 图斑 161926 没有找到邻居，跳过
# 2024-09-05 10:57:03,515 - INFO - 图斑 161995 没有找到邻居，跳过
# 2024-09-05 10:57:03,518 - INFO - 图斑 161996 没有找到邻居，跳过
# 2024-09-05 10:57:03,521 - INFO - 图斑 161997 没有找到邻居，跳过
# 2024-09-05 10:57:03,608 - INFO - 图斑 162046 没有找到邻居，跳过
# 2024-09-05 10:57:03,611 - INFO - 图斑 162047 没有找到邻居，跳过
# 2024-09-05 10:57:04,063 - INFO - 图斑 162308 没有找到邻居，跳过
# 2024-09-05 10:57:04,077 - INFO - 图斑 162314 没有找到邻居，跳过
# 2024-09-05 10:57:04,241 - INFO - 图斑 162400 没有找到邻居，跳过
# 2024-09-05 10:57:04,267 - INFO - 图斑 162409 没有找到邻居，跳过
# 2024-09-05 10:57:04,322 - INFO - 图斑 162448 没有找到邻居，跳过
# 2024-09-05 10:57:04,325 - INFO - 图斑 162449 没有找到邻居，跳过
# 2024-09-05 10:57:04,384 - INFO - 图斑 162482 没有找到邻居，跳过
# 2024-09-05 10:57:04,414 - INFO - 图斑 162497 没有找到邻居，跳过
# 2024-09-05 10:57:04,660 - INFO - 图斑 162669 没有找到邻居，跳过
# 2024-09-05 10:57:04,666 - INFO - 图斑 162671 没有找到邻居，跳过
# 2024-09-05 10:57:05,129 - INFO - 图斑 162935 没有找到邻居，跳过
# 2024-09-05 10:57:05,134 - INFO - 图斑 162937 没有找到邻居，跳过
# 2024-09-05 10:57:05,253 - INFO - 图斑 162990 没有找到邻居，跳过
# 2024-09-05 10:57:05,256 - INFO - 图斑 162991 没有找到邻居，跳过
# 2024-09-05 10:57:05,568 - INFO - 图斑 163152 没有找到邻居，跳过
# 2024-09-05 10:57:05,754 - INFO - 图斑 163284 没有找到邻居，跳过
# 2024-09-05 10:57:06,290 - INFO - 图斑 163521 没有找到邻居，跳过
# 2024-09-05 10:57:06,667 - INFO - 图斑 163718 没有找到邻居，跳过
# 2024-09-05 10:57:06,670 - INFO - 图斑 163719 没有找到邻居，跳过
# 2024-09-05 10:57:06,674 - INFO - 图斑 163721 没有找到邻居，跳过
# 2024-09-05 10:57:06,678 - INFO - 图斑 163723 没有找到邻居，跳过
# 2024-09-05 10:57:06,680 - INFO - 图斑 163724 没有找到邻居，跳过
# 2024-09-05 10:57:06,683 - INFO - 图斑 163725 没有找到邻居，跳过
# 2024-09-05 10:57:06,948 - INFO - 图斑 163866 没有找到邻居，跳过
# 2024-09-05 10:57:07,068 - INFO - 图斑 163938 没有找到邻居，跳过
# 2024-09-05 10:57:07,684 - INFO - 图斑 164337 没有找到邻居，跳过
# 2024-09-05 10:57:07,687 - INFO - 图斑 164338 没有找到邻居，跳过
# 2024-09-05 10:57:07,710 - INFO - 图斑 164346 没有找到邻居，跳过
# 2024-09-05 10:57:07,839 - INFO - 图斑 164421 没有找到邻居，跳过
# 2024-09-05 10:57:07,850 - INFO - 图斑 164425 没有找到邻居，跳过
# 2024-09-05 10:57:08,151 - INFO - 图斑 164556 没有找到邻居，跳过
# 2024-09-05 10:57:08,239 - INFO - 图斑 164583 没有找到邻居，跳过
# 2024-09-05 10:57:08,450 - INFO - 图斑 164675 没有找到邻居，跳过
# 2024-09-05 10:57:08,533 - INFO - 图斑 164714 没有找到邻居，跳过
# 2024-09-05 10:57:08,540 - INFO - 图斑 164719 没有找到邻居，跳过
# 2024-09-05 10:57:08,721 - INFO - 图斑 164803 没有找到邻居，跳过
# 2024-09-05 10:57:08,799 - INFO - 图斑 164839 没有找到邻居，跳过
# 2024-09-05 10:57:08,801 - INFO - 图斑 164840 没有找到邻居，跳过
# 2024-09-05 10:57:08,882 - INFO - 图斑 164874 没有找到邻居，跳过
# 2024-09-05 10:57:09,068 - INFO - 图斑 164979 没有找到邻居，跳过
# 2024-09-05 10:57:09,192 - INFO - 图斑 165026 没有找到邻居，跳过
# 2024-09-05 10:57:09,396 - INFO - 图斑 165134 没有找到邻居，跳过
# 2024-09-05 10:57:09,399 - INFO - 图斑 165135 没有找到邻居，跳过
# 2024-09-05 10:57:09,426 - INFO - 图斑 165146 没有找到邻居，跳过
# 2024-09-05 10:57:09,436 - INFO - 图斑 165150 没有找到邻居，跳过
# 2024-09-05 10:57:09,493 - INFO - 图斑 165187 没有找到邻居，跳过
# 2024-09-05 10:57:09,668 - INFO - 图斑 165286 没有找到邻居，跳过
# 2024-09-05 10:57:10,030 - INFO - 图斑 165557 没有找到邻居，跳过
# 2024-09-05 10:57:10,033 - INFO - 图斑 165558 没有找到邻居，跳过
# 2024-09-05 10:57:10,620 - INFO - 图斑 165913 没有找到邻居，跳过
# 2024-09-05 10:57:10,729 - INFO - 图斑 165976 没有找到邻居，跳过
# 2024-09-05 10:57:10,731 - INFO - 图斑 165977 没有找到邻居，跳过
# 2024-09-05 10:57:10,980 - INFO - 图斑 166137 没有找到邻居，跳过
# 2024-09-05 10:57:10,985 - INFO - 图斑 166139 没有找到邻居，跳过
# 2024-09-05 10:57:11,002 - INFO - 图斑 166157 没有找到邻居，跳过
# 2024-09-05 10:57:11,182 - INFO - 图斑 166239 没有找到邻居，跳过
# 2024-09-05 10:57:11,503 - INFO - 图斑 166406 没有找到邻居，跳过
# 2024-09-05 10:57:11,533 - INFO - 图斑 166427 没有找到邻居，跳过
# 2024-09-05 10:57:11,878 - INFO - 图斑 166590 没有找到邻居，跳过
# 2024-09-05 10:57:11,883 - INFO - 图斑 166593 没有找到邻居，跳过
# 2024-09-05 10:57:11,899 - INFO - 图斑 166598 没有找到邻居，跳过
# 2024-09-05 10:57:12,166 - INFO - 图斑 166749 没有找到邻居，跳过
# 2024-09-05 10:57:12,171 - INFO - 图斑 166751 没有找到邻居，跳过
# 2024-09-05 10:57:12,398 - INFO - 图斑 166874 没有找到邻居，跳过
# 2024-09-05 10:57:12,507 - INFO - 图斑 166932 没有找到邻居，跳过
# 2024-09-05 10:57:12,657 - INFO - 图斑 166999 没有找到邻居，跳过
# 2024-09-05 10:57:12,660 - INFO - 图斑 167000 没有找到邻居，跳过
# 2024-09-05 10:57:12,774 - INFO - 图斑 167076 没有找到邻居，跳过
# 2024-09-05 10:57:12,889 - INFO - 图斑 167140 没有找到邻居，跳过
# 2024-09-05 10:57:12,891 - INFO - 图斑 167141 没有找到邻居，跳过
# 2024-09-05 10:57:12,900 - INFO - 图斑 167146 没有找到邻居，跳过
# 2024-09-05 10:57:13,021 - INFO - 图斑 167206 没有找到邻居，跳过
# 2024-09-05 10:57:13,024 - INFO - 图斑 167207 没有找到邻居，跳过
# 2024-09-05 10:57:13,280 - INFO - 图斑 167401 没有找到邻居，跳过
# 2024-09-05 10:57:13,539 - INFO - 图斑 167579 没有找到邻居，跳过
# 2024-09-05 10:57:13,542 - INFO - 图斑 167580 没有找到邻居，跳过
# 2024-09-05 10:57:13,544 - INFO - 图斑 167581 没有找到邻居，跳过
# 2024-09-05 10:57:13,546 - INFO - 图斑 167582 没有找到邻居，跳过
# 2024-09-05 10:57:14,032 - INFO - 图斑 167932 没有找到邻居，跳过
# 2024-09-05 10:57:14,499 - INFO - 图斑 168124 没有找到邻居，跳过
# 2024-09-05 10:57:14,503 - INFO - 图斑 168125 没有找到邻居，跳过
# 2024-09-05 10:57:14,508 - INFO - 图斑 168128 没有找到邻居，跳过
# 2024-09-05 10:57:14,686 - INFO - 图斑 168193 没有找到邻居，跳过
# 2024-09-05 10:57:14,942 - INFO - 图斑 168296 没有找到邻居，跳过
# 2024-09-05 10:57:15,085 - INFO - 图斑 168358 没有找到邻居，跳过
# 2024-09-05 10:57:15,090 - INFO - 图斑 168360 没有找到邻居，跳过
# 2024-09-05 10:57:15,093 - INFO - 图斑 168361 没有找到邻居，跳过
# 2024-09-05 10:57:15,215 - INFO - 图斑 168413 没有找到邻居，跳过
# 2024-09-05 10:57:15,392 - INFO - 图斑 168524 没有找到邻居，跳过
# 2024-09-05 10:57:15,400 - INFO - 图斑 168526 没有找到邻居，跳过
# 2024-09-05 10:57:15,459 - INFO - 图斑 168553 没有找到邻居，跳过
# 2024-09-05 10:57:15,706 - INFO - 图斑 168679 没有找到邻居，跳过
# 2024-09-05 10:57:15,715 - INFO - 图斑 168683 没有找到邻居，跳过
# 2024-09-05 10:57:15,798 - INFO - 图斑 168743 没有找到邻居，跳过
# 2024-09-05 10:57:15,852 - INFO - 图斑 168779 没有找到邻居，跳过
# 2024-09-05 10:57:15,854 - INFO - 图斑 168780 没有找到邻居，跳过
# 2024-09-05 10:57:16,097 - INFO - 图斑 168920 没有找到邻居，跳过
# 2024-09-05 10:57:16,387 - INFO - 图斑 169084 没有找到邻居，跳过
# 2024-09-05 10:57:16,416 - INFO - 图斑 169093 没有找到邻居，跳过
# 2024-09-05 10:57:16,471 - INFO - 图斑 169130 没有找到邻居，跳过
# 2024-09-05 10:57:16,612 - INFO - 图斑 169204 没有找到邻居，跳过
# 2024-09-05 10:57:16,651 - INFO - 图斑 169229 没有找到邻居，跳过
# 2024-09-05 10:57:16,987 - INFO - 图斑 169425 没有找到邻居，跳过
# 2024-09-05 10:57:17,088 - INFO - 图斑 169510 没有找到邻居，跳过
# 2024-09-05 10:57:17,090 - INFO - 图斑 169511 没有找到邻居，跳过
# 2024-09-05 10:57:17,218 - INFO - 图斑 169566 没有找到邻居，跳过
# 2024-09-05 10:57:17,547 - INFO - 图斑 169742 没有找到邻居，跳过
# 2024-09-05 10:57:17,633 - INFO - 图斑 169779 没有找到邻居，跳过
# 2024-09-05 10:57:17,672 - INFO - 图斑 169795 没有找到邻居，跳过
# 2024-09-05 10:57:17,690 - INFO - 图斑 169805 没有找到邻居，跳过
# 2024-09-05 10:57:17,693 - INFO - 图斑 169806 没有找到邻居，跳过
# 2024-09-05 10:57:17,731 - INFO - 图斑 169829 没有找到邻居，跳过
# 2024-09-05 10:57:17,752 - INFO - 图斑 169835 没有找到邻居，跳过
# 2024-09-05 10:57:17,791 - INFO - 图斑 169851 没有找到邻居，跳过
# 2024-09-05 10:57:17,795 - INFO - 图斑 169852 没有找到邻居，跳过
# 2024-09-05 10:57:17,798 - INFO - 图斑 169853 没有找到邻居，跳过
# 2024-09-05 10:57:17,828 - INFO - 图斑 169863 没有找到邻居，跳过
# 2024-09-05 10:57:17,838 - INFO - 图斑 169868 没有找到邻居，跳过
# 2024-09-05 10:57:17,883 - INFO - 图斑 169890 没有找到邻居，跳过
# 2024-09-05 10:57:17,950 - INFO - 图斑 169914 没有找到邻居，跳过
# 2024-09-05 10:57:17,958 - INFO - 图斑 169916 没有找到邻居，跳过
# 2024-09-05 10:57:17,966 - INFO - 图斑 169918 没有找到邻居，跳过
# 2024-09-05 10:57:17,969 - INFO - 图斑 169919 没有找到邻居，跳过
# 2024-09-05 10:57:18,004 - INFO - 图斑 169930 没有找到邻居，跳过
# 2024-09-05 10:57:18,007 - INFO - 图斑 169931 没有找到邻居，跳过
# 2024-09-05 10:57:18,068 - INFO - 图斑 169960 没有找到邻居，跳过
# 2024-09-05 10:57:18,070 - INFO - 图斑 169961 没有找到邻居，跳过
# 2024-09-05 10:57:18,071 - INFO - 图斑 169962 没有找到邻居，跳过
# 2024-09-05 10:57:18,242 - INFO - 图斑 170024 没有找到邻居，跳过
# 2024-09-05 10:57:18,384 - INFO - 图斑 170163 没有找到邻居，跳过
# 2024-09-05 10:57:18,386 - INFO - 图斑 170164 没有找到邻居，跳过
# 2024-09-05 10:57:18,611 - INFO - 图斑 170600 没有找到邻居，跳过
# 2024-09-05 10:57:18,613 - INFO - 图斑 170601 没有找到邻居，跳过
# 2024-09-05 10:57:21,212 - INFO - 图斑 174592 没有找到邻居，跳过
# 2024-09-05 10:57:21,629 - INFO - 图斑 174862 没有找到邻居，跳过
# 2024-09-05 10:57:22,198 - INFO - 图斑 175388 没有找到邻居，跳过
# 2024-09-05 10:57:22,224 - INFO - 图斑 175401 没有找到邻居，跳过
# 2024-09-05 10:57:22,851 - INFO - 图斑 175802 没有找到邻居，跳过
# 2024-09-05 10:57:22,862 - INFO - 图斑 175808 没有找到邻居，跳过
# 2024-09-05 10:57:22,874 - INFO - 图斑 175818 没有找到邻居，跳过
# 2024-09-05 10:57:22,882 - INFO - 图斑 175820 没有找到邻居，跳过
# 2024-09-05 10:57:22,884 - INFO - 图斑 175821 没有找到邻居，跳过
# 2024-09-05 10:57:22,952 - INFO - 图斑 175869 没有找到邻居，跳过
# 2024-09-05 10:57:23,080 - INFO - 图斑 175942 没有找到邻居，跳过
# 2024-09-05 10:57:24,632 - INFO - 图斑 176991 没有找到邻居，跳过
# 2024-09-05 10:57:24,634 - INFO - 图斑 176992 没有找到邻居，跳过
# 2024-09-05 10:57:24,639 - INFO - 图斑 176993 没有找到邻居，跳过
# 2024-09-05 10:57:24,858 - INFO - 图斑 177144 没有找到邻居，跳过
# 2024-09-05 10:57:24,861 - INFO - 图斑 177145 没有找到邻居，跳过
# 2024-09-05 10:57:24,967 - INFO - 图斑 177197 没有找到邻居，跳过
# 2024-09-05 10:57:25,000 - INFO - 图斑 177213 没有找到邻居，跳过
# 2024-09-05 10:57:25,003 - INFO - 图斑 177214 没有找到邻居，跳过
# 2024-09-05 10:57:25,005 - INFO - 图斑 177215 没有找到邻居，跳过
# 2024-09-05 10:57:25,008 - INFO - 图斑 177216 没有找到邻居，跳过
# 2024-09-05 10:57:25,011 - INFO - 图斑 177217 没有找到邻居，跳过
# 2024-09-05 10:57:25,083 - INFO - 图斑 177253 没有找到邻居，跳过
# 2024-09-05 10:57:25,114 - INFO - 图斑 177274 没有找到邻居，跳过
# 2024-09-05 10:57:25,312 - INFO - 图斑 177401 没有找到邻居，跳过
# 2024-09-05 10:57:25,393 - INFO - 图斑 177466 没有找到邻居，跳过
# 2024-09-05 10:57:25,406 - INFO - 图斑 177473 没有找到邻居，跳过
# 2024-09-05 10:57:25,478 - INFO - 图斑 177537 没有找到邻居，跳过
# 2024-09-05 10:57:25,532 - INFO - 图斑 177570 没有找到邻居，跳过
# 2024-09-05 10:57:25,535 - INFO - 图斑 177571 没有找到邻居，跳过
# 2024-09-05 10:57:25,662 - INFO - 图斑 177630 没有找到邻居，跳过
# 2024-09-05 10:57:25,664 - INFO - 图斑 177631 没有找到邻居，跳过
# 2024-09-05 10:57:25,685 - INFO - 图斑 177642 没有找到邻居，跳过
# 2024-09-05 10:57:25,687 - INFO - 图斑 177643 没有找到邻居，跳过
# 2024-09-05 10:57:25,688 - INFO - 图斑 177644 没有找到邻居，跳过
# 2024-09-05 10:57:25,690 - INFO - 图斑 177645 没有找到邻居，跳过
# 2024-09-05 10:57:25,696 - INFO - 图斑 177648 没有找到邻居，跳过
# 2024-09-05 10:57:25,748 - INFO - 图斑 177688 没有找到邻居，跳过
# 2024-09-05 10:57:25,803 - INFO - 图斑 177736 没有找到邻居，跳过
# 2024-09-05 10:57:25,806 - INFO - 图斑 177737 没有找到邻居，跳过
# 2024-09-05 10:57:26,044 - INFO - 图斑 177841 没有找到邻居，跳过
# 2024-09-05 10:57:26,190 - INFO - 图斑 177926 没有找到邻居，跳过
# 2024-09-05 10:57:26,250 - INFO - 图斑 177949 没有找到邻居，跳过
# 2024-09-05 10:57:26,253 - INFO - 图斑 177950 没有找到邻居，跳过
# 2024-09-05 10:57:26,282 - INFO - 图斑 177959 没有找到邻居，跳过
# 2024-09-05 10:57:26,284 - INFO - 图斑 177960 没有找到邻居，跳过
# 2024-09-05 10:57:26,364 - INFO - 图斑 177982 没有找到邻居，跳过
# 2024-09-05 10:57:26,440 - INFO - 图斑 178017 没有找到邻居，跳过
# 2024-09-05 10:57:26,443 - INFO - 图斑 178018 没有找到邻居，跳过
# 2024-09-05 10:57:26,470 - INFO - 图斑 178034 没有找到邻居，跳过
# 2024-09-05 10:57:26,472 - INFO - 图斑 178035 没有找到邻居，跳过
# 2024-09-05 10:57:26,499 - INFO - 图斑 178054 没有找到邻居，跳过
# 2024-09-05 10:57:26,501 - INFO - 图斑 178055 没有找到邻居，跳过
# 2024-09-05 10:57:26,664 - INFO - 图斑 178166 没有找到邻居，跳过
# 2024-09-05 10:57:26,955 - INFO - 图斑 178376 没有找到邻居，跳过
# 2024-09-05 10:57:27,013 - INFO - 图斑 178419 没有找到邻居，跳过
# 2024-09-05 10:57:27,368 - INFO - 图斑 178661 没有找到邻居，跳过
# 2024-09-05 10:57:28,780 - INFO - 图斑 180717 没有找到邻居，跳过
# 2024-09-05 10:57:29,955 - INFO - 图斑 182774 没有找到邻居，跳过
# 2024-09-05 10:57:30,060 - INFO - 图斑 183028 没有找到邻居，跳过
# 2024-09-05 10:57:30,421 - INFO - 图斑 183720 没有找到邻居，跳过
# 2024-09-05 10:57:32,531 - INFO - 图斑 186927 没有找到邻居，跳过
# 2024-09-05 10:57:33,919 - INFO - 图斑 189020 没有找到邻居，跳过
# 2024-09-05 10:57:35,706 - INFO - 图斑 191911 没有找到邻居，跳过
# 2024-09-05 10:57:43,269 - INFO - 图斑 206740 没有找到邻居，跳过
# 2024-09-05 10:57:43,637 - INFO - 图斑 207071 没有找到邻居，跳过
# 2024-09-05 10:57:43,641 - INFO - 图斑 207074 没有找到邻居，跳过
# 2024-09-05 10:57:43,646 - INFO - 图斑 207076 没有找到邻居，跳过
# 2024-09-05 10:57:43,704 - INFO - 图斑 207127 没有找到邻居，跳过
# ...
# 2024-09-05 11:00:22,940 - INFO - 图斑 29325 没有找到邻居，跳过
# 2024-09-05 11:00:22,942 - INFO - 图斑 29326 没有找到邻居，跳过
# 2024-09-05 11:00:22,944 - INFO - 图斑 29344 没有找到邻居，跳过
# 2024-09-05 11:00:22,944 - INFO - 图斑 29345 没有找到邻居，跳过
# 2024-09-05 11:00:22,944 - INFO - 图斑 29431 没有找到邻居，跳过
# 2024-09-05 11:00:22,959 - INFO - 图斑 29432 没有找到邻居，跳过
# 2024-09-05 11:00:22,961 - INFO - 图斑 30832 没有找到邻居，跳过
# 2024-09-05 11:00:22,964 - INFO - 图斑 31087 没有找到邻居，跳过
# 2024-09-05 11:00:22,969 - INFO - 图斑 31106 没有找到邻居，跳过
# 2024-09-05 11:00:22,972 - INFO - 图斑 31308 没有找到邻居，跳过
# 2024-09-05 11:00:22,979 - INFO - 图斑 31498 没有找到邻居，跳过
# 2024-09-05 11:00:22,979 - INFO - 图斑 31499 没有找到邻居，跳过
# 2024-09-05 11:00:22,979 - INFO - 图斑 32848 没有找到邻居，跳过
# 2024-09-05 11:00:22,979 - INFO - 图斑 33874 没有找到邻居，跳过
# 2024-09-05 11:00:22,990 - INFO - 图斑 34076 没有找到邻居，跳过
# 2024-09-05 11:00:22,995 - INFO - 图斑 36236 没有找到邻居，跳过
# 2024-09-05 11:00:22,995 - INFO - 图斑 39309 没有找到邻居，跳过
# 2024-09-05 11:00:22,995 - INFO - 图斑 39532 没有找到邻居，跳过
# 2024-09-05 11:00:23,009 - INFO - 图斑 39533 没有找到邻居，跳过
# 2024-09-05 11:00:23,009 - INFO - 图斑 39534 没有找到邻居，跳过
# 2024-09-05 11:00:23,009 - INFO - 图斑 39548 没有找到邻居，跳过
# 2024-09-05 11:00:23,009 - INFO - 图斑 39728 没有找到邻居，跳过
# 2024-09-05 11:00:23,023 - INFO - 图斑 40268 没有找到邻居，跳过
# 2024-09-05 11:00:23,026 - INFO - 图斑 40564 没有找到邻居，跳过
# 2024-09-05 11:00:23,026 - INFO - 图斑 40565 没有找到邻居，跳过
# 2024-09-05 11:00:23,026 - INFO - 图斑 40569 没有找到邻居，跳过
# 2024-09-05 11:00:23,036 - INFO - 图斑 40570 没有找到邻居，跳过
# 2024-09-05 11:00:23,041 - INFO - 图斑 40629 没有找到邻居，跳过
# 2024-09-05 11:00:23,046 - INFO - 图斑 40630 没有找到邻居，跳过
# 2024-09-05 11:00:23,058 - INFO - 图斑 40897 没有找到邻居，跳过
# 2024-09-05 11:00:23,061 - INFO - 图斑 41603 没有找到邻居，跳过
# 2024-09-05 11:00:23,066 - INFO - 图斑 41837 没有找到邻居，跳过
# 2024-09-05 11:00:23,068 - INFO - 图斑 41838 没有找到邻居，跳过
# 2024-09-05 11:00:23,073 - INFO - 图斑 42882 没有找到邻居，跳过
# 2024-09-05 11:00:23,075 - INFO - 图斑 42883 没有找到邻居，跳过
# 2024-09-05 11:00:23,078 - INFO - 图斑 42884 没有找到邻居，跳过
# 2024-09-05 11:00:23,078 - INFO - 图斑 43506 没有找到邻居，跳过
# 2024-09-05 11:00:23,078 - INFO - 图斑 43507 没有找到邻居，跳过
# 2024-09-05 11:00:23,078 - INFO - 图斑 43768 没有找到邻居，跳过
# 2024-09-05 11:00:23,078 - INFO - 图斑 43792 没有找到邻居，跳过
# 2024-09-05 11:00:23,078 - INFO - 图斑 44058 没有找到邻居，跳过
# 2024-09-05 11:00:23,089 - INFO - 图斑 44059 没有找到邻居，跳过
# 2024-09-05 11:00:23,091 - INFO - 图斑 44592 没有找到邻居，跳过
# 2024-09-05 11:00:23,093 - INFO - 图斑 44593 没有找到邻居，跳过
# 2024-09-05 11:00:23,095 - INFO - 图斑 44632 没有找到邻居，跳过
# 2024-09-05 11:00:23,097 - INFO - 图斑 44634 没有找到邻居，跳过
# 2024-09-05 11:00:23,099 - INFO - 图斑 46309 没有找到邻居，跳过
# 2024-09-05 11:00:23,100 - INFO - 图斑 46310 没有找到邻居，跳过
# 2024-09-05 11:00:23,100 - INFO - 图斑 46311 没有找到邻居，跳过
# 2024-09-05 11:00:23,100 - INFO - 图斑 47839 没有找到邻居，跳过
# 2024-09-05 11:00:23,109 - INFO - 图斑 48132 没有找到邻居，跳过
# 2024-09-05 11:00:23,112 - INFO - 图斑 48133 没有找到邻居，跳过
# 2024-09-05 11:00:23,116 - INFO - 图斑 48134 没有找到邻居，跳过
# 2024-09-05 11:00:23,119 - INFO - 图斑 48135 没有找到邻居，跳过
# 2024-09-05 11:00:23,127 - INFO - 图斑 48136 没有找到邻居，跳过
# 2024-09-05 11:00:23,130 - INFO - 图斑 48137 没有找到邻居，跳过
# 2024-09-05 11:00:23,130 - INFO - 图斑 48138 没有找到邻居，跳过
# 2024-09-05 11:00:23,130 - INFO - 图斑 53095 没有找到邻居，跳过
# 2024-09-05 11:00:23,139 - INFO - 图斑 53139 没有找到邻居，跳过
# 2024-09-05 11:00:23,142 - INFO - 图斑 53140 没有找到邻居，跳过
# 2024-09-05 11:00:23,144 - INFO - 图斑 53801 没有找到邻居，跳过
# 2024-09-05 11:00:23,146 - INFO - 图斑 53846 没有找到邻居，跳过
# 2024-09-05 11:00:23,146 - INFO - 图斑 54917 没有找到邻居，跳过
# 2024-09-05 11:00:23,146 - INFO - 图斑 56242 没有找到邻居，跳过
# 2024-09-05 11:00:23,146 - INFO - 图斑 56243 没有找到邻居，跳过
# 2024-09-05 11:00:23,146 - INFO - 图斑 56244 没有找到邻居，跳过
# 2024-09-05 11:00:23,146 - INFO - 图斑 56613 没有找到邻居，跳过
# 2024-09-05 11:00:23,156 - INFO - 图斑 56614 没有找到邻居，跳过
# 2024-09-05 11:00:23,160 - INFO - 图斑 56944 没有找到邻居，跳过
# 2024-09-05 11:00:23,166 - INFO - 图斑 57392 没有找到邻居，跳过
# 2024-09-05 11:00:23,170 - INFO - 图斑 57393 没有找到邻居，跳过
# 2024-09-05 11:00:23,175 - INFO - 图斑 58747 没有找到邻居，跳过
# 2024-09-05 11:00:23,180 - INFO - 图斑 58766 没有找到邻居，跳过
# 2024-09-05 11:00:23,182 - INFO - 图斑 58767 没有找到邻居，跳过
# 2024-09-05 11:00:23,189 - INFO - 图斑 59832 没有找到邻居，跳过
# 2024-09-05 11:00:23,193 - INFO - 图斑 60356 没有找到邻居，跳过
# 2024-09-05 11:00:23,196 - INFO - 图斑 60357 没有找到邻居，跳过
# 2024-09-05 11:00:23,196 - INFO - 图斑 63790 没有找到邻居，跳过
# 2024-09-05 11:00:23,196 - INFO - 图斑 67031 没有找到邻居，跳过
# 2024-09-05 11:00:23,196 - INFO - 图斑 69018 没有找到邻居，跳过
# 2024-09-05 11:00:23,196 - INFO - 图斑 69290 没有找到邻居，跳过
# 2024-09-05 11:00:23,207 - INFO - 图斑 69293 没有找到邻居，跳过
# 2024-09-05 11:00:23,210 - INFO - 图斑 69294 没有找到邻居，跳过
# 2024-09-05 11:00:23,211 - INFO - 图斑 69297 没有找到邻居，跳过
# 2024-09-05 11:00:23,211 - INFO - 图斑 69305 没有找到邻居，跳过
# 2024-09-05 11:00:23,211 - INFO - 图斑 69307 没有找到邻居，跳过
# 2024-09-05 11:00:23,224 - INFO - 图斑 71109 没有找到邻居，跳过
# 2024-09-05 11:00:23,228 - INFO - 图斑 73398 没有找到邻居，跳过
# 2024-09-05 11:00:23,228 - INFO - 图斑 73399 没有找到邻居，跳过
# 2024-09-05 11:00:23,228 - INFO - 图斑 80215 没有找到邻居，跳过
# 2024-09-05 11:00:23,228 - INFO - 图斑 82192 没有找到邻居，跳过
# 2024-09-05 11:00:23,228 - INFO - 图斑 82582 没有找到邻居，跳过
# 2024-09-05 11:00:23,240 - INFO - 图斑 82583 没有找到邻居，跳过
# 2024-09-05 11:00:23,242 - INFO - 图斑 82584 没有找到邻居，跳过
# 2024-09-05 11:00:23,244 - INFO - 图斑 83996 没有找到邻居，跳过
# 2024-09-05 11:00:23,245 - INFO - 图斑 83997 没有找到邻居，跳过
# 2024-09-05 11:00:23,248 - INFO - 图斑 86238 没有找到邻居，跳过
# 2024-09-05 11:00:23,248 - INFO - 图斑 86241 没有找到邻居，跳过
# 2024-09-05 11:00:23,248 - INFO - 图斑 89863 没有找到邻居，跳过
# 2024-09-05 11:00:23,248 - INFO - 图斑 92350 没有找到邻居，跳过
# 2024-09-05 11:00:23,256 - INFO - 图斑 93181 没有找到邻居，跳过
# 2024-09-05 11:00:23,259 - INFO - 图斑 93182 没有找到邻居，跳过
# 2024-09-05 11:00:23,260 - INFO - 图斑 93190 没有找到邻居，跳过
# 2024-09-05 11:00:23,260 - INFO - 图斑 93197 没有找到邻居，跳过
# 2024-09-05 11:00:23,260 - INFO - 图斑 93202 没有找到邻居，跳过
# 2024-09-05 11:00:23,260 - INFO - 图斑 93203 没有找到邻居，跳过
# 2024-09-05 11:00:23,260 - INFO - 图斑 93229 没有找到邻居，跳过
# 2024-09-05 11:00:23,272 - INFO - 图斑 93572 没有找到邻居，跳过
# 2024-09-05 11:00:23,278 - INFO - 图斑 93593 没有找到邻居，跳过
# 2024-09-05 11:00:23,279 - INFO - 图斑 95137 没有找到邻居，跳过
# 2024-09-05 11:00:23,289 - INFO - 图斑 95138 没有找到邻居，跳过
# 2024-09-05 11:00:23,294 - INFO - 图斑 95498 没有找到邻居，跳过
# 2024-09-05 11:00:23,295 - INFO - 图斑 96396 没有找到邻居，跳过
# 2024-09-05 11:00:23,295 - INFO - 图斑 96705 没有找到邻居，跳过
# 2024-09-05 11:00:23,307 - INFO - 图斑 96706 没有找到邻居，跳过
# 2024-09-05 11:00:23,309 - INFO - 图斑 96707 没有找到邻居，跳过
# 2024-09-05 11:00:23,310 - INFO - 图斑 99178 没有找到邻居，跳过
# 2024-09-05 11:00:23,310 - INFO - 图斑 99179 没有找到邻居，跳过
# 2024-09-05 11:00:23,310 - INFO - 图斑 152234 没有找到邻居，跳过
# 2024-09-05 11:00:23,310 - INFO - 图斑 152235 没有找到邻居，跳过
# 2024-09-05 11:00:23,310 - INFO - 图斑 152236 没有找到邻居，跳过
# 2024-09-05 11:00:23,323 - INFO - 图斑 152237 没有找到邻居，跳过
# 2024-09-05 11:00:23,326 - INFO - 图斑 152315 没有找到邻居，跳过
# 2024-09-05 11:00:23,327 - INFO - 图斑 152316 没有找到邻居，跳过
# 2024-09-05 11:00:23,327 - INFO - 图斑 152555 没有找到邻居，跳过
# 2024-09-05 11:00:23,327 - INFO - 图斑 152556 没有找到邻居，跳过
# 2024-09-05 11:00:23,327 - INFO - 图斑 153337 没有找到邻居，跳过
# 2024-09-05 11:00:23,327 - INFO - 图斑 153338 没有找到邻居，跳过
# 2024-09-05 11:00:23,327 - INFO - 图斑 153339 没有找到邻居，跳过
# 2024-09-05 11:00:23,341 - INFO - 图斑 153340 没有找到邻居，跳过
# 2024-09-05 11:00:23,343 - INFO - 图斑 153341 没有找到邻居，跳过
# 2024-09-05 11:00:23,346 - INFO - 图斑 153342 没有找到邻居，跳过
# 2024-09-05 11:00:23,347 - INFO - 图斑 153413 没有找到邻居，跳过
# 2024-09-05 11:00:23,347 - INFO - 图斑 153414 没有找到邻居，跳过
# 2024-09-05 11:00:23,347 - INFO - 图斑 153415 没有找到邻居，跳过
# 2024-09-05 11:00:23,347 - INFO - 图斑 153873 没有找到邻居，跳过
# 2024-09-05 11:00:23,347 - INFO - 图斑 154606 没有找到邻居，跳过
# 2024-09-05 11:00:23,357 - INFO - 图斑 154798 没有找到邻居，跳过
# 2024-09-05 11:00:23,359 - INFO - 图斑 154799 没有找到邻居，跳过
# 2024-09-05 11:00:23,360 - INFO - 图斑 154800 没有找到邻居，跳过
# 2024-09-05 11:00:23,360 - INFO - 图斑 154801 没有找到邻居，跳过
# 2024-09-05 11:00:23,360 - INFO - 图斑 154807 没有找到邻居，跳过
# 2024-09-05 11:00:23,360 - INFO - 图斑 154849 没有找到邻居，跳过
# 2024-09-05 11:00:23,360 - INFO - 图斑 154850 没有找到邻居，跳过
# 2024-09-05 11:00:23,360 - INFO - 图斑 154851 没有找到邻居，跳过
# 2024-09-05 11:00:23,360 - INFO - 图斑 154852 没有找到邻居，跳过
# 2024-09-05 11:00:23,372 - INFO - 图斑 154853 没有找到邻居，跳过
# 2024-09-05 11:00:23,374 - INFO - 图斑 154854 没有找到邻居，跳过
# 2024-09-05 11:00:23,376 - INFO - 图斑 154935 没有找到邻居，跳过
# 2024-09-05 11:00:23,376 - INFO - 图斑 154975 没有找到邻居，跳过
# 2024-09-05 11:00:23,376 - INFO - 图斑 155025 没有找到邻居，跳过
# 2024-09-05 11:00:23,376 - INFO - 图斑 155026 没有找到邻居，跳过
# 2024-09-05 11:00:23,376 - INFO - 图斑 155027 没有找到邻居，跳过
# 2024-09-05 11:00:23,376 - INFO - 图斑 155028 没有找到邻居，跳过
# 2024-09-05 11:00:23,376 - INFO - 图斑 155479 没有找到邻居，跳过
# 2024-09-05 11:00:23,376 - INFO - 图斑 156078 没有找到邻居，跳过
# 2024-09-05 11:00:23,390 - INFO - 图斑 157013 没有找到邻居，跳过
# 2024-09-05 11:00:23,392 - INFO - 图斑 157014 没有找到邻居，跳过
# 2024-09-05 11:00:23,395 - INFO - 图斑 157599 没有找到邻居，跳过
# 2024-09-05 11:00:23,397 - INFO - 图斑 157642 没有找到邻居，跳过
# 2024-09-05 11:00:23,399 - INFO - 图斑 157669 没有找到邻居，跳过
# 2024-09-05 11:00:23,401 - INFO - 图斑 157670 没有找到邻居，跳过
# 2024-09-05 11:00:23,402 - INFO - 图斑 157671 没有找到邻居，跳过
# 2024-09-05 11:00:23,403 - INFO - 图斑 157791 没有找到邻居，跳过
# 2024-09-05 11:00:23,405 - INFO - 图斑 158027 没有找到邻居，跳过
# 2024-09-05 11:00:23,410 - INFO - 图斑 158039 没有找到邻居，跳过
# 2024-09-05 11:00:23,410 - INFO - 图斑 158040 没有找到邻居，跳过
# 2024-09-05 11:00:23,410 - INFO - 图斑 158041 没有找到邻居，跳过
# 2024-09-05 11:00:23,410 - INFO - 图斑 158576 没有找到邻居，跳过
# 2024-09-05 11:00:23,410 - INFO - 图斑 158577 没有找到邻居，跳过
# 2024-09-05 11:00:23,410 - INFO - 图斑 159229 没有找到邻居，跳过
# 2024-09-05 11:00:23,422 - INFO - 图斑 159234 没有找到邻居，跳过
# 2024-09-05 11:00:23,424 - INFO - 图斑 159534 没有找到邻居，跳过
# 2024-09-05 11:00:23,426 - INFO - 图斑 159535 没有找到邻居，跳过
# 2024-09-05 11:00:23,426 - INFO - 图斑 159537 没有找到邻居，跳过
# 2024-09-05 11:00:23,426 - INFO - 图斑 159538 没有找到邻居，跳过
# 2024-09-05 11:00:23,426 - INFO - 图斑 159539 没有找到邻居，跳过
# 2024-09-05 11:00:23,426 - INFO - 图斑 159540 没有找到邻居，跳过
# 2024-09-05 11:00:23,426 - INFO - 图斑 159541 没有找到邻居，跳过
# 2024-09-05 11:00:23,447 - INFO - 图斑 159575 没有找到邻居，跳过
# 2024-09-05 11:00:23,452 - INFO - 图斑 159745 没有找到邻居，跳过
# 2024-09-05 11:00:23,456 - INFO - 图斑 159746 没有找到邻居，跳过
# 2024-09-05 11:00:23,461 - INFO - 图斑 159747 没有找到邻居，跳过
# 2024-09-05 11:00:23,463 - INFO - 图斑 159790 没有找到邻居，跳过
# 2024-09-05 11:00:23,465 - INFO - 图斑 159791 没有找到邻居，跳过
# 2024-09-05 11:00:23,465 - INFO - 图斑 159993 没有找到邻居，跳过
# 2024-09-05 11:00:23,472 - INFO - 图斑 159994 没有找到邻居，跳过
# 2024-09-05 11:00:23,475 - INFO - 图斑 160421 没有找到邻居，跳过
# 2024-09-05 11:00:23,477 - INFO - 图斑 160422 没有找到邻居，跳过
# 2024-09-05 11:00:23,481 - INFO - 图斑 161383 没有找到邻居，跳过
# 2024-09-05 11:00:23,482 - INFO - 图斑 161995 没有找到邻居，跳过
# 2024-09-05 11:00:23,482 - INFO - 图斑 161996 没有找到邻居，跳过
# 2024-09-05 11:00:23,482 - INFO - 图斑 161997 没有找到邻居，跳过
# 2024-09-05 11:00:23,489 - INFO - 图斑 162046 没有找到邻居，跳过
# 2024-09-05 11:00:23,491 - INFO - 图斑 162047 没有找到邻居，跳过
# 2024-09-05 11:00:23,496 - INFO - 图斑 162314 没有找到邻居，跳过
# 2024-09-05 11:00:23,498 - INFO - 图斑 162409 没有找到邻居，跳过
# 2024-09-05 11:00:23,500 - INFO - 图斑 162448 没有找到邻居，跳过
# 2024-09-05 11:00:23,502 - INFO - 图斑 162449 没有找到邻居，跳过
# 2024-09-05 11:00:23,504 - INFO - 图斑 162497 没有找到邻居，跳过
# 2024-09-05 11:00:23,505 - INFO - 图斑 162669 没有找到邻居，跳过
# 2024-09-05 11:00:23,508 - INFO - 图斑 162990 没有找到邻居，跳过
# 2024-09-05 11:00:23,510 - INFO - 图斑 162991 没有找到邻居，跳过
# 2024-09-05 11:00:23,510 - INFO - 图斑 164337 没有找到邻居，跳过
# 2024-09-05 11:00:23,510 - INFO - 图斑 164338 没有找到邻居，跳过
# 2024-09-05 11:00:23,510 - INFO - 图斑 164421 没有找到邻居，跳过
# 2024-09-05 11:00:23,510 - INFO - 图斑 164583 没有找到邻居，跳过
# 2024-09-05 11:00:23,510 - INFO - 图斑 165134 没有找到邻居，跳过
# 2024-09-05 11:00:23,522 - INFO - 图斑 165135 没有找到邻居，跳过
# 2024-09-05 11:00:23,523 - INFO - 图斑 165150 没有找到邻居，跳过
# 2024-09-05 11:00:23,526 - INFO - 图斑 165557 没有找到邻居，跳过
# 2024-09-05 11:00:23,527 - INFO - 图斑 165558 没有找到邻居，跳过
# 2024-09-05 11:00:23,529 - INFO - 图斑 165976 没有找到邻居，跳过
# 2024-09-05 11:00:23,529 - INFO - 图斑 165977 没有找到邻居，跳过
# 2024-09-05 11:00:23,529 - INFO - 图斑 166137 没有找到邻居，跳过
# 2024-09-05 11:00:23,529 - INFO - 图斑 166406 没有找到邻居，跳过
# 2024-09-05 11:00:23,540 - INFO - 图斑 166874 没有找到邻居，跳过
# 2024-09-05 11:00:23,546 - INFO - 图斑 167076 没有找到邻居，跳过
# 2024-09-05 11:00:23,548 - INFO - 图斑 167579 没有找到邻居，跳过
# 2024-09-05 11:00:23,555 - INFO - 图斑 167580 没有找到邻居，跳过
# 2024-09-05 11:00:23,559 - INFO - 图斑 167581 没有找到邻居，跳过
# 2024-09-05 11:00:23,563 - INFO - 图斑 167582 没有找到邻居，跳过
# 2024-09-05 11:00:23,563 - INFO - 图斑 168124 没有找到邻居，跳过
# 2024-09-05 11:00:23,572 - INFO - 图斑 168125 没有找到邻居，跳过
# 2024-09-05 11:00:23,579 - INFO - 图斑 168360 没有找到邻居，跳过
# 2024-09-05 11:00:23,582 - INFO - 图斑 168361 没有找到邻居，跳过
# 2024-09-05 11:00:23,586 - INFO - 图斑 168413 没有找到邻居，跳过
# 2024-09-05 11:00:23,587 - INFO - 图斑 168743 没有找到邻居，跳过
# 2024-09-05 11:00:23,590 - INFO - 图斑 168779 没有找到邻居，跳过
# 2024-09-05 11:00:23,593 - INFO - 图斑 168780 没有找到邻居，跳过
# 2024-09-05 11:00:23,593 - INFO - 图斑 168920 没有找到邻居，跳过
# 2024-09-05 11:00:23,593 - INFO - 图斑 169093 没有找到邻居，跳过
# 2024-09-05 11:00:23,593 - INFO - 图斑 169510 没有找到邻居，跳过
# 2024-09-05 11:00:23,605 - INFO - 图斑 169511 没有找到邻居，跳过
# 2024-09-05 11:00:23,607 - INFO - 图斑 169742 没有找到邻居，跳过
# 2024-09-05 11:00:23,609 - INFO - 图斑 169795 没有找到邻居，跳过
# 2024-09-05 11:00:23,611 - INFO - 图斑 169805 没有找到邻居，跳过
# 2024-09-05 11:00:23,613 - INFO - 图斑 169960 没有找到邻居，跳过
# 2024-09-05 11:00:23,615 - INFO - 图斑 169961 没有找到邻居，跳过
# 2024-09-05 11:00:23,618 - INFO - 图斑 169962 没有找到邻居，跳过
# 2024-09-05 11:00:23,618 - INFO - 图斑 170024 没有找到邻居，跳过
# 2024-09-05 11:00:23,622 - INFO - 图斑 170163 没有找到邻居，跳过
# 2024-09-05 11:00:23,624 - INFO - 图斑 170164 没有找到邻居，跳过
# 2024-09-05 11:00:23,626 - INFO - 图斑 174592 没有找到邻居，跳过
# 2024-09-05 11:00:23,628 - INFO - 图斑 175820 没有找到邻居，跳过
# 2024-09-05 11:00:23,629 - INFO - 图斑 175821 没有找到邻居，跳过
# 2024-09-05 11:00:23,629 - INFO - 图斑 176992 没有找到邻居，跳过
# 2024-09-05 11:00:23,629 - INFO - 图斑 176993 没有找到邻居，跳过
# 2024-09-05 11:00:23,629 - INFO - 图斑 177144 没有找到邻居，跳过
# 2024-09-05 11:00:23,639 - INFO - 图斑 177145 没有找到邻居，跳过
# 2024-09-05 11:00:23,642 - INFO - 图斑 177197 没有找到邻居，跳过
# 2024-09-05 11:00:23,646 - INFO - 图斑 177214 没有找到邻居，跳过
# 2024-09-05 11:00:23,651 - INFO - 图斑 177215 没有找到邻居，跳过
# 2024-09-05 11:00:23,652 - INFO - 图斑 177216 没有找到邻居，跳过
# 2024-09-05 11:00:23,656 - INFO - 图斑 177217 没有找到邻居，跳过
# 2024-09-05 11:00:23,659 - INFO - 图斑 177253 没有找到邻居，跳过
# 2024-09-05 11:00:23,659 - INFO - 图斑 177274 没有找到邻居，跳过
# 2024-09-05 11:00:23,659 - INFO - 图斑 177570 没有找到邻居，跳过
# 2024-09-05 11:00:23,659 - INFO - 图斑 177571 没有找到邻居，跳过
# 2024-09-05 11:00:23,659 - INFO - 图斑 177642 没有找到邻居，跳过
# 2024-09-05 11:00:23,659 - INFO - 图斑 177643 没有找到邻居，跳过
# 2024-09-05 11:00:23,678 - INFO - 图斑 177644 没有找到邻居，跳过
# 2024-09-05 11:00:23,682 - INFO - 图斑 177645 没有找到邻居，跳过
# 2024-09-05 11:00:23,686 - INFO - 图斑 177736 没有找到邻居，跳过
# 2024-09-05 11:00:23,691 - INFO - 图斑 177737 没有找到邻居，跳过
# 2024-09-05 11:00:23,697 - INFO - 图斑 177926 没有找到邻居，跳过
# 2024-09-05 11:00:23,701 - INFO - 图斑 177949 没有找到邻居，跳过
# 2024-09-05 11:00:23,706 - INFO - 图斑 177950 没有找到邻居，跳过
# 2024-09-05 11:00:23,709 - INFO - 图斑 177959 没有找到邻居，跳过
# 2024-09-05 11:00:23,711 - INFO - 图斑 177960 没有找到邻居，跳过
# 2024-09-05 11:00:23,713 - INFO - 图斑 178018 没有找到邻居，跳过
# 2024-09-05 11:00:23,713 - INFO - 图斑 178034 没有找到邻居，跳过
# 2024-09-05 11:00:23,713 - INFO - 图斑 178035 没有找到邻居，跳过
# 2024-09-05 11:00:23,713 - INFO - 图斑 178054 没有找到邻居，跳过
# 2024-09-05 11:00:23,713 - INFO - 图斑 178055 没有找到邻居，跳过
# 2024-09-05 11:00:23,722 - INFO - 图斑 178376 没有找到邻居，跳过
# 2024-09-05 11:00:23,725 - INFO - 图斑 206740 没有找到邻居，跳过
# 2024-09-05 11:00:23,727 - INFO - 图斑 214782 没有找到邻居，跳过
# 2024-09-05 11:00:23,729 - INFO - 图斑 217450 没有找到邻居，跳过
# 2024-09-05 11:00:23,729 - INFO - 图斑 217451 没有找到邻居，跳过
# 2024-09-05 11:00:23,729 - INFO - 图斑 242913 没有找到邻居，跳过
# 2024-09-05 11:00:23,729 - INFO - 图斑 242914 没有找到邻居，跳过
# 2024-09-05 11:00:23,729 - INFO - 图斑 250120 没有找到邻居，跳过
# 2024-09-05 11:00:23,739 - INFO - 图斑 254197 没有找到邻居，跳过
# 2024-09-05 11:00:23,741 - INFO - 图斑 254198 没有找到邻居，跳过
# 2024-09-05 11:00:23,741 - INFO - 图斑 254199 没有找到邻居，跳过
# 2024-09-05 11:00:23,741 - INFO - 图斑 254200 没有找到邻居，跳过
# 2024-09-05 11:00:23,741 - INFO - 图斑 254201 没有找到邻居，跳过
# 2024-09-05 11:00:23,741 - INFO - 图斑 255830 没有找到邻居，跳过
# 2024-09-05 11:00:23,741 - INFO - 图斑 255831 没有找到邻居，跳过
# 执行合并操作: 0it [00:00, ?it/s]
# 2024-09-05 11:00:23,906 - INFO - 合并了 0 个图斑，跳过了 0 个图斑
# 2024-09-05 11:00:23,906 - INFO - 总面积变化: 0
# 2024-09-05 11:00:24,038 - INFO - 第 8 轮处理完成。本轮合并 0 个图斑。当前总面积: 1463055810.0204847
# 2024-09-05 11:00:24,039 - INFO - 累计面积变化: 3.751982546873478e-08
# 2024-09-05 11:00:24,040 - INFO - 没有更多图斑可以合并，处理结束。
# 2024-09-05 11:00:24,040 - INFO - 处理完成。总共合并 76781 个图斑。
# 2024-09-05 11:00:24,110 - INFO - 最终总面积: 1463055810.0204847
# 2024-09-05 11:00:24,110 - INFO - 总面积变化: -2.384185791015625e-07
# 2024-09-05 11:01:02,843 - INFO - 结果保存为SHP（字段名已截断）: C:\Users\Runker\Desktop\ele_test\sb_merge_data_result_2.shp
# 2024-09-05 11:01:02,844 - INFO - 总处理时间: 7.60 分钟
# 2024-09-05 11:01:02,844 - INFO - 最终图斑数量: 179460
# 2024-09-05 11:01:02,844 - INFO - 减少的图斑数量: -13903

# %% [markdown]
# # 方法2

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
from shapely.ops import unary_union
from shapely.validation import make_valid
from shapely.geometry import Polygon, MultiPolygon
from shapely.affinity import scale
from tqdm import tqdm
import time
import logging

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def safe_union(geom1, geom2):
    try:
        union = unary_union([geom1, geom2])
        if not union.is_valid:
            union = make_valid(union)
        return union.buffer(0)  # 使用buffer(0)来修复可能的拓扑错误
    except Exception as e:
        logging.error(f"合并几何形状时出错: {str(e)}")
        return None

def adjust_geometry(geometry, target_area):
    current_area = geometry.area
    scale_factor = np.sqrt(target_area / current_area)
    adjusted = scale(geometry, xfact=scale_factor, yfact=scale_factor, origin='centroid')
    return adjusted

def find_neighbors(parcel, gdf):
    try:
        possible_matches_index = list(gdf.sindex.intersection(parcel.geometry.bounds))
        possible_matches = gdf.iloc[possible_matches_index]
        return possible_matches[possible_matches.geometry.touches(parcel.geometry)]
    except Exception as e:
        logging.error(f"在查找邻居时出错: {str(e)}")
        return gpd.GeoDataFrame()

def mark_small_parcels_for_merging(gdf, small_parcels, large_parcels, dldm_field, dlmc_field):
    merge_operations = []
    for index, small_parcel in small_parcels.iterrows():
        neighbors = find_neighbors(small_parcel, large_parcels)
        if neighbors.empty:
            logging.info(f"图斑 {index} 没有找到邻居，跳过")
            continue
        
        same_dlmc_neighbors = neighbors[neighbors[dlmc_field] == small_parcel[dlmc_field]]
        if not same_dlmc_neighbors.empty:
            target = same_dlmc_neighbors.loc[same_dlmc_neighbors['area'].idxmax()]
        else:
            target = neighbors.loc[neighbors['area'].idxmax()]
        
        merge_operations.append((index, target.name))
    
    return merge_operations

def execute_merges(gdf, merge_operations, area_change_threshold=1.0):
    merged_count = 0
    skipped_count = 0
    total_area_change = 0
    area_changes = []
    
    gdf['to_delete'] = False
    
    for small_index, large_index in tqdm(merge_operations, desc="执行合并操作"):
        if small_index not in gdf.index or large_index not in gdf.index:
            skipped_count += 1
            logging.info(f"跳过合并操作：小图斑 {small_index} 或大图斑 {large_index} 不在索引中")
            continue
        
        small_geom = gdf.loc[small_index, 'geometry']
        large_geom = gdf.loc[large_index, 'geometry']
        
        original_area = small_geom.area + large_geom.area
        new_geometry = safe_union(small_geom, large_geom)
        
        if new_geometry is None:
            skipped_count += 1
            logging.info(f"跳过合并操作：无法合并图斑 {small_index} 和 {large_index}")
            continue
        
        new_area = new_geometry.area
        area_change = new_area - original_area
        
        if abs(area_change) > area_change_threshold:
            adjusted_geometry = adjust_geometry(new_geometry, original_area)
            new_area = adjusted_geometry.area
            area_change = new_area - original_area
            logging.info(f"调整了合并后的几何形状。原面积: {original_area}, 调整后面积: {new_area}, 剩余差异: {area_change}")
            new_geometry = adjusted_geometry
        
        total_area_change += area_change
        area_changes.append(area_change)
        
        gdf.loc[large_index, 'geometry'] = new_geometry
        gdf.loc[large_index, 'area'] = new_area
        gdf.loc[small_index, 'to_delete'] = True
        
        merged_count += 1
    
    gdf = gdf[~gdf['to_delete']]
    gdf = gdf.drop(columns=['to_delete'])
    
    logging.info(f"合并了 {merged_count} 个图斑，跳过了 {skipped_count} 个图斑")
    logging.info(f"总面积变化: {total_area_change}")
    
    if area_changes:
        logging.info(f"最大面积变化: {max(abs(change) for change in area_changes)}")
        logging.info(f"平均面积变化: {sum(abs(change) for change in area_changes) / len(area_changes)}")
    else:
        logging.info("没有执行任何合并操作")
    
    return gdf, merged_count, total_area_change

def merge_small_parcels(input_shp, output_base, dldm_field, dlmc_field, thresholds, default_threshold=50, max_iterations=10, area_change_threshold=1.0):
    start_time = time.time()
    logging.info(f"开始处理。输入Shapefile: {input_shp}")
    
    try:
        gdf = gpd.read_file(input_shp)
    except Exception as e:
        logging.error(f"读取shapefile时出错: {str(e)}")
        return
    
    original_count = len(gdf)
    original_area = gdf.geometry.area.sum()
    logging.info(f"读取了 {original_count} 个图斑，总面积: {original_area}")
    
    # 检查DLDM字段的唯一值
    unique_dldm = gdf[dldm_field].unique()
    logging.info(f"DLDM字段的唯一值: {unique_dldm}")
    
    logging.info("正在将多部件要素转换为单部件...")
    gdf = gdf.explode(index_parts=True).reset_index(drop=True)
    logging.info(f"转换后共有 {len(gdf)} 个图斑")
    
    iteration = 0
    total_merged = 0
    total_area_change = 0
    
    while iteration < max_iterations:
        iteration += 1
        logging.info(f"开始第 {iteration} 轮处理")
        
        gdf['area'] = gdf.geometry.area
        
        # 改进的筛选逻辑
        def get_threshold(row):
            dldm = row[dldm_field]
            if pd.isna(dldm) or dldm not in thresholds:
                return default_threshold
            return thresholds[dldm]
        
        gdf['threshold'] = gdf.apply(get_threshold, axis=1)
        small_parcels = gdf[gdf['area'] < gdf['threshold']]
        large_parcels = gdf[gdf['area'] >= gdf['threshold']]
        
        logging.info(f"小面积图斑数量: {len(small_parcels)}, 大面积图斑数量: {len(large_parcels)}")
        logging.info(f"小面积图斑DLDM分布: {small_parcels[dldm_field].value_counts().to_dict()}")
        
        if len(small_parcels) == 0:
            logging.info("没有找到小面积图斑，处理结束。")
            break
        
        merge_operations = mark_small_parcels_for_merging(gdf, small_parcels, large_parcels, dldm_field, dlmc_field)
        
        if not merge_operations:
            logging.info("没有可以合并的图斑，处理结束。")
            break
        
        gdf, merged_count, area_change = execute_merges(gdf, merge_operations, area_change_threshold)
        
        total_merged += merged_count
        total_area_change += area_change
        
        current_area = gdf.geometry.area.sum()
        logging.info(f"第 {iteration} 轮处理完成。本轮合并 {merged_count} 个图斑。当前总面积: {current_area}")
        logging.info(f"累计面积变化: {total_area_change}")
        
        if merged_count == 0:
            logging.info("没有更多图斑可以合并，处理结束。")
            break
    
    logging.info(f"处理完成。总共合并 {total_merged} 个图斑。")
    
    final_area = gdf.geometry.area.sum()
    logging.info(f"最终总面积: {final_area}")
    logging.info(f"总面积变化: {final_area - original_area}")
    
    # 保存结果到SHP（截断字段名）
    output_shp = f"{output_base}.shp"
    result_truncated = gdf.rename(columns={col: col[:10] for col in gdf.columns if len(col) > 10})
    result_truncated.to_file(output_shp, encoding='utf-8')
    logging.info(f"结果保存为SHP（字段名已截断）: {output_shp}")
    
    end_time = time.time()
    logging.info(f"总处理时间: {(end_time - start_time) / 60:.2f} 分钟")
    logging.info(f"最终图斑数量: {len(gdf)}")
    logging.info(f"减少的图斑数量: {original_count - len(gdf)}")

# 使用示例
input_shp = r"C:\Users\Runker\Desktop\ele_sb\sb_merge_data_single.shp"
output_base = r"C:\Users\Runker\Desktop\ele_sb\sb_merge_data_single_moudle2"
dldm_field = "DLDM"
dlmc_field = "DLMC"
thresholds = {"01": 50, "02": 50, "03": 1000, "04": 1000}
default_threshold = 50  # 为未指定的DLDM类型设置默认阈值
area_change_threshold = 1.0  # 面积变化阈值（平方米）

merge_small_parcels(input_shp, output_base, dldm_field, dlmc_field, thresholds, default_threshold, area_change_threshold=area_change_threshold)
# Out:
# 2024-10-29 19:22:49,137 - INFO - 开始处理。输入Shapefile: C:\Users\Runker\Desktop\ele_sb\sb_merge_data_single.shp
# 2024-10-29 19:23:26,426 - INFO - 读取了 261981 个图斑，总面积: 1462965997.409759
# 2024-10-29 19:23:26,444 - INFO - DLDM字段的唯一值: ['01' '02' '03' '12' '04']
# 2024-10-29 19:23:26,444 - INFO - 正在将多部件要素转换为单部件...
# 2024-10-29 19:23:27,625 - INFO - 转换后共有 261981 个图斑
# 2024-10-29 19:23:27,625 - INFO - 开始第 1 轮处理
# 2024-10-29 19:23:28,589 - INFO - 小面积图斑数量: 94837, 大面积图斑数量: 167144
# 2024-10-29 19:23:28,592 - INFO - 小面积图斑DLDM分布: {'03': 67195, '01': 24358, '04': 1985, '02': 917, '12': 382}
# 2024-10-29 19:23:29,136 - INFO - 图斑 467 没有找到邻居，跳过
# 2024-10-29 19:23:29,144 - INFO - 图斑 496 没有找到邻居，跳过
# 2024-10-29 19:23:29,319 - INFO - 图斑 701 没有找到邻居，跳过
# 2024-10-29 19:23:29,319 - INFO - 图斑 709 没有找到邻居，跳过
# 2024-10-29 19:23:29,319 - INFO - 图斑 710 没有找到邻居，跳过
# 2024-10-29 19:23:29,319 - INFO - 图斑 711 没有找到邻居，跳过
# 2024-10-29 19:23:29,461 - INFO - 图斑 894 没有找到邻居，跳过
# 2024-10-29 19:23:29,492 - INFO - 图斑 944 没有找到邻居，跳过
# 2024-10-29 19:23:29,602 - INFO - 图斑 1114 没有找到邻居，跳过
# 2024-10-29 19:23:29,709 - INFO - 图斑 1258 没有找到邻居，跳过
# 2024-10-29 19:23:29,834 - INFO - 图斑 1455 没有找到邻居，跳过
# 2024-10-29 19:23:29,865 - INFO - 图斑 1473 没有找到邻居，跳过
# 2024-10-29 19:23:29,929 - INFO - 图斑 1548 没有找到邻居，跳过
# 2024-10-29 19:23:29,978 - INFO - 图斑 1603 没有找到邻居，跳过
# 2024-10-29 19:23:30,193 - INFO - 图斑 1767 没有找到邻居，跳过
# 2024-10-29 19:23:30,527 - INFO - 图斑 2323 没有找到邻居，跳过
# 2024-10-29 19:23:31,256 - INFO - 图斑 3707 没有找到邻居，跳过
# 2024-10-29 19:23:32,026 - INFO - 图斑 5244 没有找到邻居，跳过
# 2024-10-29 19:23:32,026 - INFO - 图斑 5245 没有找到邻居，跳过
# 2024-10-29 19:23:32,039 - INFO - 图斑 5246 没有找到邻居，跳过
# 2024-10-29 19:23:32,142 - INFO - 图斑 5312 没有找到邻居，跳过
# 2024-10-29 19:23:32,420 - INFO - 图斑 5534 没有找到邻居，跳过
# 2024-10-29 19:23:32,420 - INFO - 图斑 5535 没有找到邻居，跳过
# 2024-10-29 19:23:33,022 - INFO - 图斑 5893 没有找到邻居，跳过
# 2024-10-29 19:23:33,038 - INFO - 图斑 5895 没有找到邻居，跳过
# 2024-10-29 19:23:33,038 - INFO - 图斑 5897 没有找到邻居，跳过
# 2024-10-29 19:23:33,038 - INFO - 图斑 5898 没有找到邻居，跳过
# 2024-10-29 19:23:33,182 - INFO - 图斑 6007 没有找到邻居，跳过
# 2024-10-29 19:23:33,216 - INFO - 图斑 6024 没有找到邻居，跳过
# 2024-10-29 19:23:33,331 - INFO - 图斑 6082 没有找到邻居，跳过
# 2024-10-29 19:23:33,334 - INFO - 图斑 6083 没有找到邻居，跳过
# 2024-10-29 19:23:33,342 - INFO - 图斑 6088 没有找到邻居，跳过
# 2024-10-29 19:23:33,342 - INFO - 图斑 6089 没有找到邻居，跳过
# 2024-10-29 19:23:33,407 - INFO - 图斑 6124 没有找到邻居，跳过
# 2024-10-29 19:23:33,475 - INFO - 图斑 6165 没有找到邻居，跳过
# 2024-10-29 19:23:33,537 - INFO - 图斑 6231 没有找到邻居，跳过
# 2024-10-29 19:23:33,619 - INFO - 图斑 6293 没有找到邻居，跳过
# 2024-10-29 19:23:33,905 - INFO - 图斑 6574 没有找到邻居，跳过
# 2024-10-29 19:23:34,593 - INFO - 图斑 7918 没有找到邻居，跳过
# 2024-10-29 19:23:34,907 - INFO - 图斑 8149 没有找到邻居，跳过
# 2024-10-29 19:23:34,969 - INFO - 图斑 8201 没有找到邻居，跳过
# 2024-10-29 19:23:35,047 - INFO - 图斑 8243 没有找到邻居，跳过
# 2024-10-29 19:23:35,141 - INFO - 图斑 8321 没有找到邻居，跳过
# 2024-10-29 19:23:35,141 - INFO - 图斑 8329 没有找到邻居，跳过
# 2024-10-29 19:23:35,157 - INFO - 图斑 8330 没有找到邻居，跳过
# 2024-10-29 19:23:35,220 - INFO - 图斑 8371 没有找到邻居，跳过
# 2024-10-29 19:23:35,236 - INFO - 图斑 8378 没有找到邻居，跳过
# 2024-10-29 19:23:35,251 - INFO - 图斑 8384 没有找到邻居，跳过
# 2024-10-29 19:23:35,283 - INFO - 图斑 8420 没有找到邻居，跳过
# 2024-10-29 19:23:35,720 - INFO - 图斑 8676 没有找到邻居，跳过
# 2024-10-29 19:23:35,720 - INFO - 图斑 8677 没有找到邻居，跳过
# 2024-10-29 19:23:36,156 - INFO - 图斑 8996 没有找到邻居，跳过
# 2024-10-29 19:23:36,235 - INFO - 图斑 9098 没有找到邻居，跳过
# 2024-10-29 19:23:36,281 - INFO - 图斑 9159 没有找到邻居，跳过
# 2024-10-29 19:23:36,923 - INFO - 图斑 9902 没有找到邻居，跳过
# 2024-10-29 19:23:37,001 - INFO - 图斑 9984 没有找到邻居，跳过
# 2024-10-29 19:23:37,001 - INFO - 图斑 9985 没有找到邻居，跳过
# 2024-10-29 19:23:37,269 - INFO - 图斑 10288 没有找到邻居，跳过
# 2024-10-29 19:23:37,308 - INFO - 图斑 10346 没有找到邻居，跳过
# 2024-10-29 19:23:37,324 - INFO - 图斑 10348 没有找到邻居，跳过
# 2024-10-29 19:23:37,324 - INFO - 图斑 10349 没有找到邻居，跳过
# 2024-10-29 19:23:37,523 - INFO - 图斑 10617 没有找到邻居，跳过
# 2024-10-29 19:23:37,791 - INFO - 图斑 11047 没有找到邻居，跳过
# 2024-10-29 19:23:37,854 - INFO - 图斑 11111 没有找到邻居，跳过
# 2024-10-29 19:23:38,121 - INFO - 图斑 11461 没有找到邻居，跳过
# 2024-10-29 19:23:38,629 - INFO - 图斑 12110 没有找到邻居，跳过
# 2024-10-29 19:23:38,676 - INFO - 图斑 12198 没有找到邻居，跳过
# 2024-10-29 19:23:38,740 - INFO - 图斑 12241 没有找到邻居，跳过
# 2024-10-29 19:23:38,786 - INFO - 图斑 12288 没有找到邻居，跳过
# 2024-10-29 19:23:38,786 - INFO - 图斑 12296 没有找到邻居，跳过
# 2024-10-29 19:23:39,011 - INFO - 图斑 12532 没有找到邻居，跳过
# 2024-10-29 19:23:39,015 - INFO - 图斑 12535 没有找到邻居，跳过
# 2024-10-29 19:23:39,018 - INFO - 图斑 12536 没有找到邻居，跳过
# 2024-10-29 19:23:39,018 - INFO - 图斑 12539 没有找到邻居，跳过
# 2024-10-29 19:23:39,031 - INFO - 图斑 12547 没有找到邻居，跳过
# 2024-10-29 19:23:39,034 - INFO - 图斑 12549 没有找到邻居，跳过
# 2024-10-29 19:23:39,209 - INFO - 图斑 12972 没有找到邻居，跳过
# 2024-10-29 19:23:39,390 - INFO - 图斑 13326 没有找到邻居，跳过
# 2024-10-29 19:23:39,421 - INFO - 图斑 13361 没有找到邻居，跳过
# 2024-10-29 19:23:39,515 - INFO - 图斑 13479 没有找到邻居，跳过
# 2024-10-29 19:23:39,578 - INFO - 图斑 13570 没有找到邻居，跳过
# 2024-10-29 19:23:39,593 - INFO - 图斑 13575 没有找到邻居，跳过
# 2024-10-29 19:23:39,692 - INFO - 图斑 13700 没有找到邻居，跳过
# 2024-10-29 19:23:39,911 - INFO - 图斑 14009 没有找到邻居，跳过
# 2024-10-29 19:23:39,942 - INFO - 图斑 14071 没有找到邻居，跳过
# 2024-10-29 19:23:39,989 - INFO - 图斑 14122 没有找到邻居，跳过
# 2024-10-29 19:23:40,036 - INFO - 图斑 14167 没有找到邻居，跳过
# 2024-10-29 19:23:40,419 - INFO - 图斑 14622 没有找到邻居，跳过
# 2024-10-29 19:23:40,492 - INFO - 图斑 14701 没有找到邻居，跳过
# 2024-10-29 19:23:40,524 - INFO - 图斑 14773 没有找到邻居，跳过
# 2024-10-29 19:23:40,577 - INFO - 图斑 14824 没有找到邻居，跳过
# 2024-10-29 19:23:40,957 - INFO - 图斑 15266 没有找到邻居，跳过
# 2024-10-29 19:23:41,019 - INFO - 图斑 15354 没有找到邻居，跳过
# 2024-10-29 19:23:41,081 - INFO - 图斑 15431 没有找到邻居，跳过
# 2024-10-29 19:23:41,083 - INFO - 图斑 15432 没有找到邻居，跳过
# 2024-10-29 19:23:41,085 - INFO - 图斑 15433 没有找到邻居，跳过
# 2024-10-29 19:23:41,392 - INFO - 图斑 15791 没有找到邻居，跳过
# 2024-10-29 19:23:41,392 - INFO - 图斑 15792 没有找到邻居，跳过
# 2024-10-29 19:23:41,392 - INFO - 图斑 15799 没有找到邻居，跳过
# 2024-10-29 19:23:41,407 - INFO - 图斑 15806 没有找到邻居，跳过
# 2024-10-29 19:23:41,416 - INFO - 图斑 15811 没有找到邻居，跳过
# 2024-10-29 19:23:41,419 - INFO - 图斑 15812 没有找到邻居，跳过
# 2024-10-29 19:23:41,435 - INFO - 图斑 15838 没有找到邻居，跳过
# 2024-10-29 19:23:41,552 - INFO - 图斑 15995 没有找到邻居，跳过
# 2024-10-29 19:23:41,584 - INFO - 图斑 16020 没有找到邻居，跳过
# 2024-10-29 19:23:41,584 - INFO - 图斑 16023 没有找到邻居，跳过
# 2024-10-29 19:23:41,958 - INFO - 图斑 16474 没有找到邻居，跳过
# 2024-10-29 19:23:42,196 - INFO - 图斑 16807 没有找到邻居，跳过
# 2024-10-29 19:23:42,258 - INFO - 图斑 16894 没有找到邻居，跳过
# 2024-10-29 19:23:42,258 - INFO - 图斑 16895 没有找到邻居，跳过
# 2024-10-29 19:23:42,368 - INFO - 图斑 17080 没有找到邻居，跳过
# 2024-10-29 19:23:42,368 - INFO - 图斑 17081 没有找到邻居，跳过
# 2024-10-29 19:23:42,877 - INFO - 图斑 17911 没有找到邻居，跳过
# 2024-10-29 19:23:43,059 - INFO - 图斑 18190 没有找到邻居，跳过
# 2024-10-29 19:23:43,061 - INFO - 图斑 18191 没有找到邻居，跳过
# 2024-10-29 19:23:43,090 - INFO - 图斑 18281 没有找到邻居，跳过
# 2024-10-29 19:23:43,090 - INFO - 图斑 18282 没有找到邻居，跳过
# 2024-10-29 19:23:43,090 - INFO - 图斑 18283 没有找到邻居，跳过
# 2024-10-29 19:23:43,374 - INFO - 图斑 18848 没有找到邻居，跳过
# 2024-10-29 19:23:43,374 - INFO - 图斑 18849 没有找到邻居，跳过
# 2024-10-29 19:23:45,191 - INFO - 图斑 23680 没有找到邻居，跳过
# 2024-10-29 19:23:45,191 - INFO - 图斑 23681 没有找到邻居，跳过
# 2024-10-29 19:23:45,264 - INFO - 图斑 23737 没有找到邻居，跳过
# 2024-10-29 19:23:45,291 - INFO - 图斑 23756 没有找到邻居，跳过
# 2024-10-29 19:23:45,425 - INFO - 图斑 23867 没有找到邻居，跳过
# 2024-10-29 19:23:45,425 - INFO - 图斑 23877 没有找到邻居，跳过
# 2024-10-29 19:23:45,425 - INFO - 图斑 23879 没有找到邻居，跳过
# 2024-10-29 19:23:45,425 - INFO - 图斑 23880 没有找到邻居，跳过
# 2024-10-29 19:23:45,441 - INFO - 图斑 23881 没有找到邻居，跳过
# 2024-10-29 19:23:45,554 - INFO - 图斑 23971 没有找到邻居，跳过
# 2024-10-29 19:23:45,555 - INFO - 图斑 23975 没有找到邻居，跳过
# 2024-10-29 19:23:45,557 - INFO - 图斑 23976 没有找到邻居，跳过
# 2024-10-29 19:23:45,590 - INFO - 图斑 24004 没有找到邻居，跳过
# 2024-10-29 19:23:45,882 - INFO - 图斑 24264 没有找到邻居，跳过
# 2024-10-29 19:23:46,148 - INFO - 图斑 24564 没有找到邻居，跳过
# 2024-10-29 19:23:46,228 - INFO - 图斑 24615 没有找到邻居，跳过
# 2024-10-29 19:23:46,230 - INFO - 图斑 24616 没有找到邻居，跳过
# 2024-10-29 19:23:46,233 - INFO - 图斑 24618 没有找到邻居，跳过
# 2024-10-29 19:23:46,235 - INFO - 图斑 24619 没有找到邻居，跳过
# 2024-10-29 19:23:46,242 - INFO - 图斑 24621 没有找到邻居，跳过
# 2024-10-29 19:23:46,242 - INFO - 图斑 24626 没有找到邻居，跳过
# 2024-10-29 19:23:46,242 - INFO - 图斑 24627 没有找到邻居，跳过
# 2024-10-29 19:23:46,390 - INFO - 图斑 24737 没有找到邻居，跳过
# 2024-10-29 19:23:46,521 - INFO - 图斑 24851 没有找到邻居，跳过
# 2024-10-29 19:23:46,656 - INFO - 图斑 24955 没有找到邻居，跳过
# 2024-10-29 19:23:46,757 - INFO - 图斑 25035 没有找到邻居，跳过
# 2024-10-29 19:23:46,772 - INFO - 图斑 25048 没有找到邻居，跳过
# 2024-10-29 19:23:46,835 - INFO - 图斑 25111 没有找到邻居，跳过
# 2024-10-29 19:23:47,134 - INFO - 图斑 25362 没有找到邻居，跳过
# 2024-10-29 19:23:47,258 - INFO - 图斑 25440 没有找到邻居，跳过
# 2024-10-29 19:23:47,540 - INFO - 图斑 25668 没有找到邻居，跳过
# 2024-10-29 19:23:47,572 - INFO - 图斑 25688 没有找到邻居，跳过
# 2024-10-29 19:23:47,572 - INFO - 图斑 25689 没有找到邻居，跳过
# 2024-10-29 19:23:47,757 - INFO - 图斑 25842 没有找到邻居，跳过
# 2024-10-29 19:23:47,804 - INFO - 图斑 25865 没有找到邻居，跳过
# 2024-10-29 19:23:47,835 - INFO - 图斑 25892 没有找到邻居，跳过
# 2024-10-29 19:23:48,188 - INFO - 图斑 26388 没有找到邻居，跳过
# 2024-10-29 19:23:48,235 - INFO - 图斑 26432 没有找到邻居，跳过
# 2024-10-29 19:23:48,282 - INFO - 图斑 26466 没有找到邻居，跳过
# 2024-10-29 19:23:48,476 - INFO - 图斑 26594 没有找到邻居，跳过
# 2024-10-29 19:23:48,478 - INFO - 图斑 26595 没有找到邻居，跳过
# 2024-10-29 19:23:48,488 - INFO - 图斑 26601 没有找到邻居，跳过
# 2024-10-29 19:23:48,488 - INFO - 图斑 26602 没有找到邻居，跳过
# 2024-10-29 19:23:48,658 - INFO - 图斑 26711 没有找到邻居，跳过
# 2024-10-29 19:23:48,674 - INFO - 图斑 26712 没有找到邻居，跳过
# 2024-10-29 19:23:48,683 - INFO - 图斑 26716 没有找到邻居，跳过
# 2024-10-29 19:23:48,703 - INFO - 图斑 26725 没有找到邻居，跳过
# 2024-10-29 19:23:48,709 - INFO - 图斑 26733 没有找到邻居，跳过
# 2024-10-29 19:23:48,709 - INFO - 图斑 26734 没有找到邻居，跳过
# 2024-10-29 19:23:48,724 - INFO - 图斑 26753 没有找到邻居，跳过
# 2024-10-29 19:23:49,723 - INFO - 图斑 29015 没有找到邻居，跳过
# 2024-10-29 19:23:50,341 - INFO - 图斑 29566 没有找到邻居，跳过
# 2024-10-29 19:23:50,357 - INFO - 图斑 29601 没有找到邻居，跳过
# 2024-10-29 19:23:50,570 - INFO - 图斑 29791 没有找到邻居，跳过
# 2024-10-29 19:23:50,633 - INFO - 图斑 29833 没有找到邻居，跳过
# 2024-10-29 19:23:51,399 - INFO - 图斑 30509 没有找到邻居，跳过
# 2024-10-29 19:23:52,383 - INFO - 图斑 31119 没有找到邻居，跳过
# 2024-10-29 19:23:52,919 - INFO - 图斑 31390 没有找到邻居，跳过
# 2024-10-29 19:23:52,997 - INFO - 图斑 31421 没有找到邻居，跳过
# 2024-10-29 19:23:53,156 - INFO - 图斑 31597 没有找到邻居，跳过
# 2024-10-29 19:23:53,445 - INFO - 图斑 31780 没有找到邻居，跳过
# 2024-10-29 19:23:53,445 - INFO - 图斑 31781 没有找到邻居，跳过
# 2024-10-29 19:23:53,554 - INFO - 图斑 31899 没有找到邻居，跳过
# 2024-10-29 19:23:53,835 - INFO - 图斑 32232 没有找到邻居，跳过
# 2024-10-29 19:23:54,181 - INFO - 图斑 32623 没有找到邻居，跳过
# 2024-10-29 19:23:54,315 - INFO - 图斑 32758 没有找到邻居，跳过
# 2024-10-29 19:23:54,888 - INFO - 图斑 33237 没有找到邻居，跳过
# 2024-10-29 19:23:54,908 - INFO - 图斑 33256 没有找到邻居，跳过
# 2024-10-29 19:23:54,908 - INFO - 图斑 33257 没有找到邻居，跳过
# 2024-10-29 19:23:54,987 - INFO - 图斑 33351 没有找到邻居，跳过
# 2024-10-29 19:23:54,987 - INFO - 图斑 33352 没有找到邻居，跳过
# 2024-10-29 19:23:55,096 - INFO - 图斑 33440 没有找到邻居，跳过
# 2024-10-29 19:23:55,222 - INFO - 图斑 33527 没有找到邻居，跳过
# 2024-10-29 19:23:55,237 - INFO - 图斑 33530 没有找到邻居，跳过
# 2024-10-29 19:23:55,769 - INFO - 图斑 34063 没有找到邻居，跳过
# 2024-10-29 19:23:56,363 - INFO - 图斑 34687 没有找到邻居，跳过
# 2024-10-29 19:23:56,389 - INFO - 图斑 34711 没有找到邻居，跳过
# 2024-10-29 19:23:56,771 - INFO - 图斑 35126 没有找到邻居，跳过
# 2024-10-29 19:23:56,787 - INFO - 图斑 35127 没有找到邻居，跳过
# 2024-10-29 19:23:56,941 - INFO - 图斑 35308 没有找到邻居，跳过
# 2024-10-29 19:23:57,097 - INFO - 图斑 35442 没有找到邻居，跳过
# 2024-10-29 19:23:57,114 - INFO - 图斑 35458 没有找到邻居，跳过
# 2024-10-29 19:23:57,593 - INFO - 图斑 36052 没有找到邻居，跳过
# 2024-10-29 19:23:57,607 - INFO - 图斑 36054 没有找到邻居，跳过
# 2024-10-29 19:23:57,607 - INFO - 图斑 36056 没有找到邻居，跳过
# 2024-10-29 19:23:57,669 - INFO - 图斑 36121 没有找到邻居，跳过
# 2024-10-29 19:23:57,822 - INFO - 图斑 36238 没有找到邻居，跳过
# 2024-10-29 19:23:57,837 - INFO - 图斑 36239 没有找到邻居，跳过
# 2024-10-29 19:23:57,837 - INFO - 图斑 36240 没有找到邻居，跳过
# 2024-10-29 19:23:57,855 - INFO - 图斑 36256 没有找到邻居，跳过
# 2024-10-29 19:23:57,855 - INFO - 图斑 36257 没有找到邻居，跳过
# 2024-10-29 19:23:57,916 - INFO - 图斑 36315 没有找到邻居，跳过
# 2024-10-29 19:23:57,916 - INFO - 图斑 36316 没有找到邻居，跳过
# 2024-10-29 19:23:57,916 - INFO - 图斑 36317 没有找到邻居，跳过
# 2024-10-29 19:23:57,964 - INFO - 图斑 36384 没有找到邻居，跳过
# 2024-10-29 19:23:58,026 - INFO - 图斑 36466 没有找到邻居，跳过
# 2024-10-29 19:23:58,104 - INFO - 图斑 36565 没有找到邻居，跳过
# 2024-10-29 19:23:58,269 - INFO - 图斑 36783 没有找到邻居，跳过
# 2024-10-29 19:23:58,377 - INFO - 图斑 36878 没有找到邻居，跳过
# 2024-10-29 19:23:58,408 - INFO - 图斑 36939 没有找到邻居，跳过
# 2024-10-29 19:23:58,493 - INFO - 图斑 37049 没有找到邻居，跳过
# 2024-10-29 19:23:58,603 - INFO - 图斑 37205 没有找到邻居，跳过
# 2024-10-29 19:23:58,603 - INFO - 图斑 37209 没有找到邻居，跳过
# 2024-10-29 19:23:58,618 - INFO - 图斑 37222 没有找到邻居，跳过
# 2024-10-29 19:23:58,709 - INFO - 图斑 37338 没有找到邻居，跳过
# 2024-10-29 19:23:58,713 - INFO - 图斑 37340 没有找到邻居，跳过
# 2024-10-29 19:23:58,772 - INFO - 图斑 37383 没有找到邻居，跳过
# 2024-10-29 19:23:58,885 - INFO - 图斑 37515 没有找到邻居，跳过
# 2024-10-29 19:23:58,889 - INFO - 图斑 37516 没有找到邻居，跳过
# 2024-10-29 19:23:58,970 - INFO - 图斑 37553 没有找到邻居，跳过
# 2024-10-29 19:23:59,245 - INFO - 图斑 37714 没有找到邻居，跳过
# 2024-10-29 19:23:59,370 - INFO - 图斑 37870 没有找到邻居，跳过
# 2024-10-29 19:23:59,433 - INFO - 图斑 37920 没有找到邻居，跳过
# 2024-10-29 19:23:59,500 - INFO - 图斑 37994 没有找到邻居，跳过
# 2024-10-29 19:23:59,508 - INFO - 图斑 38001 没有找到邻居，跳过
# 2024-10-29 19:23:59,524 - INFO - 图斑 38013 没有找到邻居，跳过
# 2024-10-29 19:23:59,572 - INFO - 图斑 38056 没有找到邻居，跳过
# 2024-10-29 19:23:59,572 - INFO - 图斑 38060 没有找到邻居，跳过
# 2024-10-29 19:23:59,619 - INFO - 图斑 38106 没有找到邻居，跳过
# 2024-10-29 19:23:59,713 - INFO - 图斑 38202 没有找到邻居，跳过
# 2024-10-29 19:23:59,989 - INFO - 图斑 38482 没有找到邻居，跳过
# 2024-10-29 19:24:00,142 - INFO - 图斑 38658 没有找到邻居，跳过
# 2024-10-29 19:24:00,142 - INFO - 图斑 38659 没有找到邻居，跳过
# 2024-10-29 19:24:00,142 - INFO - 图斑 38660 没有找到邻居，跳过
# 2024-10-29 19:24:00,156 - INFO - 图斑 38669 没有找到邻居，跳过
# 2024-10-29 19:24:00,250 - INFO - 图斑 38791 没有找到邻居，跳过
# 2024-10-29 19:24:00,266 - INFO - 图斑 38817 没有找到邻居，跳过
# 2024-10-29 19:24:00,266 - INFO - 图斑 38819 没有找到邻居，跳过
# 2024-10-29 19:24:00,314 - INFO - 图斑 38882 没有找到邻居，跳过
# 2024-10-29 19:24:00,345 - INFO - 图斑 38916 没有找到邻居，跳过
# 2024-10-29 19:24:00,589 - INFO - 图斑 39134 没有找到邻居，跳过
# 2024-10-29 19:24:01,000 - INFO - 图斑 39577 没有找到邻居，跳过
# 2024-10-29 19:24:01,025 - INFO - 图斑 39624 没有找到邻居，跳过
# 2024-10-29 19:24:01,088 - INFO - 图斑 39677 没有找到邻居，跳过
# 2024-10-29 19:24:01,556 - INFO - 图斑 40182 没有找到邻居，跳过
# 2024-10-29 19:24:01,667 - INFO - 图斑 40342 没有找到邻居，跳过
# 2024-10-29 19:24:01,762 - INFO - 图斑 40428 没有找到邻居，跳过
# 2024-10-29 19:24:01,809 - INFO - 图斑 40476 没有找到邻居，跳过
# 2024-10-29 19:24:01,809 - INFO - 图斑 40483 没有找到邻居，跳过
# 2024-10-29 19:24:01,824 - INFO - 图斑 40493 没有找到邻居，跳过
# 2024-10-29 19:24:01,887 - INFO - 图斑 40563 没有找到邻居，跳过
# 2024-10-29 19:24:02,088 - INFO - 图斑 40737 没有找到邻居，跳过
# 2024-10-29 19:24:02,088 - INFO - 图斑 40752 没有找到邻居，跳过
# 2024-10-29 19:24:02,200 - INFO - 图斑 40887 没有找到邻居，跳过
# 2024-10-29 19:24:02,329 - INFO - 图斑 41039 没有找到邻居，跳过
# 2024-10-29 19:24:02,329 - INFO - 图斑 41040 没有找到邻居，跳过
# 2024-10-29 19:24:02,329 - INFO - 图斑 41042 没有找到邻居，跳过
# 2024-10-29 19:24:02,329 - INFO - 图斑 41043 没有找到邻居，跳过
# 2024-10-29 19:24:02,343 - INFO - 图斑 41049 没有找到邻居，跳过
# 2024-10-29 19:24:02,348 - INFO - 图斑 41050 没有找到邻居，跳过
# 2024-10-29 19:24:02,458 - INFO - 图斑 41156 没有找到邻居，跳过
# 2024-10-29 19:24:02,458 - INFO - 图斑 41157 没有找到邻居，跳过
# 2024-10-29 19:24:02,458 - INFO - 图斑 41158 没有找到邻居，跳过
# 2024-10-29 19:24:02,458 - INFO - 图斑 41159 没有找到邻居，跳过
# 2024-10-29 19:24:02,474 - INFO - 图斑 41160 没有找到邻居，跳过
# 2024-10-29 19:24:02,475 - INFO - 图斑 41161 没有找到邻居，跳过
# 2024-10-29 19:24:02,475 - INFO - 图斑 41162 没有找到邻居，跳过
# 2024-10-29 19:24:02,678 - INFO - 图斑 41301 没有找到邻居，跳过
# 2024-10-29 19:24:03,268 - INFO - 图斑 41943 没有找到邻居，跳过
# 2024-10-29 19:24:03,269 - INFO - 图斑 41944 没有找到邻居，跳过
# 2024-10-29 19:24:03,269 - INFO - 图斑 41945 没有找到邻居，跳过
# 2024-10-29 19:24:03,762 - INFO - 图斑 42466 没有找到邻居，跳过
# 2024-10-29 19:24:03,824 - INFO - 图斑 42524 没有找到邻居，跳过
# 2024-10-29 19:24:03,871 - INFO - 图斑 42552 没有找到邻居，跳过
# 2024-10-29 19:24:04,262 - INFO - 图斑 43004 没有找到邻居，跳过
# 2024-10-29 19:24:04,277 - INFO - 图斑 43012 没有找到邻居，跳过
# 2024-10-29 19:24:04,325 - INFO - 图斑 43073 没有找到邻居，跳过
# 2024-10-29 19:24:04,667 - INFO - 图斑 43500 没有找到邻居，跳过
# 2024-10-29 19:24:04,747 - INFO - 图斑 43560 没有找到邻居，跳过
# 2024-10-29 19:24:05,151 - INFO - 图斑 44048 没有找到邻居，跳过
# 2024-10-29 19:24:05,358 - INFO - 图斑 44313 没有找到邻居，跳过
# 2024-10-29 19:24:06,254 - INFO - 图斑 45420 没有找到邻居，跳过
# 2024-10-29 19:24:06,285 - INFO - 图斑 45453 没有找到邻居，跳过
# 2024-10-29 19:24:06,364 - INFO - 图斑 45523 没有找到邻居，跳过
# 2024-10-29 19:24:06,364 - INFO - 图斑 45524 没有找到邻居，跳过
# 2024-10-29 19:24:06,364 - INFO - 图斑 45528 没有找到邻居，跳过
# 2024-10-29 19:24:06,538 - INFO - 图斑 45796 没有找到邻居，跳过
# 2024-10-29 19:24:08,534 - INFO - 图斑 48815 没有找到邻居，跳过
# 2024-10-29 19:24:08,541 - INFO - 图斑 48824 没有找到邻居，跳过
# 2024-10-29 19:24:10,608 - INFO - 图斑 52823 没有找到邻居，跳过
# 2024-10-29 19:24:10,631 - INFO - 图斑 52829 没有找到邻居，跳过
# 2024-10-29 19:24:11,001 - INFO - 图斑 53363 没有找到邻居，跳过
# 2024-10-29 19:24:11,008 - INFO - 图斑 53374 没有找到邻居，跳过
# 2024-10-29 19:24:11,170 - INFO - 图斑 53500 没有找到邻居，跳过
# 2024-10-29 19:24:11,258 - INFO - 图斑 53601 没有找到邻居，跳过
# 2024-10-29 19:24:11,479 - INFO - 图斑 53788 没有找到邻居，跳过
# 2024-10-29 19:24:11,542 - INFO - 图斑 53830 没有找到邻居，跳过
# 2024-10-29 19:24:11,542 - INFO - 图斑 53834 没有找到邻居，跳过
# 2024-10-29 19:24:11,558 - INFO - 图斑 53835 没有找到邻居，跳过
# 2024-10-29 19:24:12,129 - INFO - 图斑 54178 没有找到邻居，跳过
# 2024-10-29 19:24:12,142 - INFO - 图斑 54179 没有找到邻居，跳过
# 2024-10-29 19:24:12,144 - INFO - 图斑 54180 没有找到邻居，跳过
# 2024-10-29 19:24:12,148 - INFO - 图斑 54182 没有找到邻居，跳过
# 2024-10-29 19:24:12,149 - INFO - 图斑 54183 没有找到邻居，跳过
# 2024-10-29 19:24:12,151 - INFO - 图斑 54184 没有找到邻居，跳过
# 2024-10-29 19:24:12,153 - INFO - 图斑 54185 没有找到邻居，跳过
# 2024-10-29 19:24:12,155 - INFO - 图斑 54186 没有找到邻居，跳过
# 2024-10-29 19:24:12,174 - INFO - 图斑 54211 没有找到邻居，跳过
# 2024-10-29 19:24:12,363 - INFO - 图斑 54309 没有找到邻居，跳过
# 2024-10-29 19:24:12,363 - INFO - 图斑 54312 没有找到邻居，跳过
# 2024-10-29 19:24:12,404 - INFO - 图斑 54323 没有找到邻居，跳过
# 2024-10-29 19:24:12,411 - INFO - 图斑 54329 没有找到邻居，跳过
# 2024-10-29 19:24:12,491 - INFO - 图斑 54373 没有找到邻居，跳过
# 2024-10-29 19:24:12,508 - INFO - 图斑 54378 没有找到邻居，跳过
# 2024-10-29 19:24:12,524 - INFO - 图斑 54395 没有找到邻居，跳过
# 2024-10-29 19:24:12,689 - INFO - 图斑 54507 没有找到邻居，跳过
# 2024-10-29 19:24:12,755 - INFO - 图斑 54552 没有找到邻居，跳过
# 2024-10-29 19:24:12,857 - INFO - 图斑 54631 没有找到邻居，跳过
# 2024-10-29 19:24:12,890 - INFO - 图斑 54663 没有找到邻居，跳过
# 2024-10-29 19:24:12,890 - INFO - 图斑 54666 没有找到邻居，跳过
# 2024-10-29 19:24:12,967 - INFO - 图斑 54709 没有找到邻居，跳过
# 2024-10-29 19:24:13,030 - INFO - 图斑 54746 没有找到邻居，跳过
# 2024-10-29 19:24:13,030 - INFO - 图斑 54747 没有找到邻居，跳过
# 2024-10-29 19:24:13,030 - INFO - 图斑 54749 没有找到邻居，跳过
# 2024-10-29 19:24:13,061 - INFO - 图斑 54768 没有找到邻居，跳过
# 2024-10-29 19:24:13,077 - INFO - 图斑 54774 没有找到邻居，跳过
# 2024-10-29 19:24:13,357 - INFO - 图斑 54898 没有找到邻居，跳过
# 2024-10-29 19:24:13,420 - INFO - 图斑 54941 没有找到邻居，跳过
# 2024-10-29 19:24:13,420 - INFO - 图斑 54942 没有找到邻居，跳过
# 2024-10-29 19:24:13,436 - INFO - 图斑 54943 没有找到邻居，跳过
# 2024-10-29 19:24:13,615 - INFO - 图斑 55053 没有找到邻居，跳过
# 2024-10-29 19:24:13,623 - INFO - 图斑 55059 没有找到邻居，跳过
# 2024-10-29 19:24:13,632 - INFO - 图斑 55066 没有找到邻居，跳过
# 2024-10-29 19:24:13,641 - INFO - 图斑 55085 没有找到邻居，跳过
# 2024-10-29 19:24:13,657 - INFO - 图斑 55086 没有找到邻居，跳过
# 2024-10-29 19:24:13,657 - INFO - 图斑 55087 没有找到邻居，跳过
# 2024-10-29 19:24:13,657 - INFO - 图斑 55088 没有找到邻居，跳过
# 2024-10-29 19:24:14,453 - INFO - 图斑 56051 没有找到邻居，跳过
# 2024-10-29 19:24:14,469 - INFO - 图斑 56052 没有找到邻居，跳过
# 2024-10-29 19:24:14,845 - INFO - 图斑 56320 没有找到邻居，跳过
# 2024-10-29 19:24:14,861 - INFO - 图斑 56324 没有找到邻居，跳过
# 2024-10-29 19:24:14,861 - INFO - 图斑 56325 没有找到邻居，跳过
# 2024-10-29 19:24:14,861 - INFO - 图斑 56326 没有找到邻居，跳过
# 2024-10-29 19:24:14,861 - INFO - 图斑 56327 没有找到邻居，跳过
# 2024-10-29 19:24:14,923 - INFO - 图斑 56366 没有找到邻居，跳过
# 2024-10-29 19:24:14,938 - INFO - 图斑 56377 没有找到邻居，跳过
# 2024-10-29 19:24:14,938 - INFO - 图斑 56384 没有找到邻居，跳过
# 2024-10-29 19:24:14,971 - INFO - 图斑 56401 没有找到邻居，跳过
# 2024-10-29 19:24:15,017 - INFO - 图斑 56418 没有找到邻居，跳过
# 2024-10-29 19:24:15,622 - INFO - 图斑 57567 没有找到邻居，跳过
# 2024-10-29 19:24:17,471 - INFO - 图斑 61162 没有找到邻居，跳过
# 2024-10-29 19:24:17,740 - INFO - 图斑 61362 没有找到邻居，跳过
# 2024-10-29 19:24:17,924 - INFO - 图斑 61489 没有找到邻居，跳过
# 2024-10-29 19:24:19,452 - INFO - 图斑 62716 没有找到邻居，跳过
# 2024-10-29 19:24:19,467 - INFO - 图斑 62717 没有找到邻居，跳过
# 2024-10-29 19:24:19,745 - INFO - 图斑 62908 没有找到邻居，跳过
# 2024-10-29 19:24:20,874 - INFO - 图斑 63633 没有找到邻居，跳过
# 2024-10-29 19:24:20,890 - INFO - 图斑 63643 没有找到邻居，跳过
# 2024-10-29 19:24:22,440 - INFO - 图斑 64765 没有找到邻居，跳过
# 2024-10-29 19:24:22,440 - INFO - 图斑 64766 没有找到邻居，跳过
# 2024-10-29 19:24:22,519 - INFO - 图斑 64821 没有找到邻居，跳过
# 2024-10-29 19:24:22,551 - INFO - 图斑 64850 没有找到邻居，跳过
# 2024-10-29 19:24:22,641 - INFO - 图斑 64885 没有找到邻居，跳过
# 2024-10-29 19:24:23,661 - INFO - 图斑 65378 没有找到邻居，跳过
# 2024-10-29 19:24:23,679 - INFO - 图斑 65382 没有找到邻居，跳过
# 2024-10-29 19:24:24,007 - INFO - 图斑 65595 没有找到邻居，跳过
# 2024-10-29 19:24:24,733 - INFO - 图斑 65848 没有找到邻居，跳过
# 2024-10-29 19:24:25,071 - INFO - 图斑 66052 没有找到邻居，跳过
# 2024-10-29 19:24:26,697 - INFO - 图斑 67283 没有找到邻居，跳过
# 2024-10-29 19:24:27,124 - INFO - 图斑 67556 没有找到邻居，跳过
# 2024-10-29 19:24:28,305 - INFO - 图斑 68155 没有找到邻居，跳过
# 2024-10-29 19:24:28,462 - INFO - 图斑 68241 没有找到邻居，跳过
# 2024-10-29 19:24:28,649 - INFO - 图斑 68340 没有找到邻居，跳过
# 2024-10-29 19:24:28,681 - INFO - 图斑 68367 没有找到邻居，跳过
# 2024-10-29 19:24:28,681 - INFO - 图斑 68368 没有找到邻居，跳过
# 2024-10-29 19:24:28,712 - INFO - 图斑 68406 没有找到邻居，跳过
# 2024-10-29 19:24:28,790 - INFO - 图斑 68475 没有找到邻居，跳过
# 2024-10-29 19:24:29,198 - INFO - 图斑 68769 没有找到邻居，跳过
# 2024-10-29 19:24:29,213 - INFO - 图斑 68780 没有找到邻居，跳过
# 2024-10-29 19:24:29,384 - INFO - 图斑 68961 没有找到邻居，跳过
# 2024-10-29 19:24:29,447 - INFO - 图斑 69042 没有找到邻居，跳过
# 2024-10-29 19:24:29,447 - INFO - 图斑 69043 没有找到邻居，跳过
# 2024-10-29 19:24:29,605 - INFO - 图斑 69250 没有找到邻居，跳过
# 2024-10-29 19:24:29,775 - INFO - 图斑 69446 没有找到邻居，跳过
# 2024-10-29 19:24:29,775 - INFO - 图斑 69447 没有找到邻居，跳过
# 2024-10-29 19:24:29,979 - INFO - 图斑 69704 没有找到邻居，跳过
# 2024-10-29 19:24:30,104 - INFO - 图斑 69896 没有找到邻居，跳过
# 2024-10-29 19:24:30,120 - INFO - 图斑 69901 没有找到邻居，跳过
# 2024-10-29 19:24:30,182 - INFO - 图斑 69981 没有找到邻居，跳过
# 2024-10-29 19:24:30,182 - INFO - 图斑 69982 没有找到邻居，跳过
# 2024-10-29 19:24:30,447 - INFO - 图斑 70377 没有找到邻居，跳过
# 2024-10-29 19:24:30,463 - INFO - 图斑 70394 没有找到邻居，跳过
# 2024-10-29 19:24:30,463 - INFO - 图斑 70395 没有找到邻居，跳过
# 2024-10-29 19:24:30,463 - INFO - 图斑 70406 没有找到邻居，跳过
# 2024-10-29 19:24:30,494 - INFO - 图斑 70448 没有找到邻居，跳过
# 2024-10-29 19:24:30,770 - INFO - 图斑 70743 没有找到邻居，跳过
# 2024-10-29 19:24:30,773 - INFO - 图斑 70744 没有找到邻居，跳过
# 2024-10-29 19:24:30,774 - INFO - 图斑 70745 没有找到邻居，跳过
# 2024-10-29 19:24:30,900 - INFO - 图斑 70848 没有找到邻居，跳过
# 2024-10-29 19:24:30,916 - INFO - 图斑 70872 没有找到邻居，跳过
# 2024-10-29 19:24:31,010 - INFO - 图斑 70948 没有找到邻居，跳过
# 2024-10-29 19:24:31,088 - INFO - 图斑 71013 没有找到邻居，跳过
# 2024-10-29 19:24:31,166 - INFO - 图斑 71096 没有找到邻居，跳过
# 2024-10-29 19:24:31,166 - INFO - 图斑 71097 没有找到邻居，跳过
# 2024-10-29 19:24:31,214 - INFO - 图斑 71138 没有找到邻居，跳过
# 2024-10-29 19:24:31,260 - INFO - 图斑 71207 没有找到邻居，跳过
# 2024-10-29 19:24:31,274 - INFO - 图斑 71257 没有找到邻居，跳过
# 2024-10-29 19:24:31,290 - INFO - 图斑 71258 没有找到邻居，跳过
# 2024-10-29 19:24:31,290 - INFO - 图斑 71259 没有找到邻居，跳过
# 2024-10-29 19:24:31,290 - INFO - 图斑 71260 没有找到邻居，跳过
# 2024-10-29 19:24:31,337 - INFO - 图斑 71289 没有找到邻居，跳过
# 2024-10-29 19:24:31,337 - INFO - 图斑 71292 没有找到邻居，跳过
# 2024-10-29 19:24:31,353 - INFO - 图斑 71315 没有找到邻居，跳过
# 2024-10-29 19:24:31,478 - INFO - 图斑 71437 没有找到邻居，跳过
# 2024-10-29 19:24:31,556 - INFO - 图斑 71547 没有找到邻居，跳过
# 2024-10-29 19:24:31,556 - INFO - 图斑 71548 没有找到邻居，跳过
# 2024-10-29 19:24:31,572 - INFO - 图斑 71551 没有找到邻居，跳过
# 2024-10-29 19:24:31,681 - INFO - 图斑 71643 没有找到邻居，跳过
# 2024-10-29 19:24:31,763 - INFO - 图斑 71735 没有找到邻居，跳过
# 2024-10-29 19:24:31,765 - INFO - 图斑 71736 没有找到邻居，跳过
# 2024-10-29 19:24:31,996 - INFO - 图斑 72117 没有找到邻居，跳过
# 2024-10-29 19:24:32,074 - INFO - 图斑 72188 没有找到邻居，跳过
# 2024-10-29 19:24:32,473 - INFO - 图斑 72864 没有找到邻居，跳过
# 2024-10-29 19:24:32,538 - INFO - 图斑 72991 没有找到邻居，跳过
# 2024-10-29 19:24:33,090 - INFO - 图斑 74036 没有找到邻居，跳过
# 2024-10-29 19:24:33,105 - INFO - 图斑 74037 没有找到邻居，跳过
# 2024-10-29 19:24:33,173 - INFO - 图斑 74079 没有找到邻居，跳过
# 2024-10-29 19:24:33,188 - INFO - 图斑 74084 没有找到邻居，跳过
# 2024-10-29 19:24:33,219 - INFO - 图斑 74109 没有找到邻居，跳过
# 2024-10-29 19:24:33,283 - INFO - 图斑 74157 没有找到邻居，跳过
# 2024-10-29 19:24:33,623 - INFO - 图斑 74445 没有找到邻居，跳过
# 2024-10-29 19:24:33,812 - INFO - 图斑 74570 没有找到邻居，跳过
# 2024-10-29 19:24:33,814 - INFO - 图斑 74571 没有找到邻居，跳过
# 2024-10-29 19:24:33,821 - INFO - 图斑 74575 没有找到邻居，跳过
# 2024-10-29 19:24:33,851 - INFO - 图斑 74600 没有找到邻居，跳过
# 2024-10-29 19:24:34,076 - INFO - 图斑 74823 没有找到邻居，跳过
# 2024-10-29 19:24:34,138 - INFO - 图斑 74871 没有找到邻居，跳过
# 2024-10-29 19:24:34,138 - INFO - 图斑 74872 没有找到邻居，跳过
# 2024-10-29 19:24:34,201 - INFO - 图斑 74983 没有找到邻居，跳过
# 2024-10-29 19:24:34,202 - INFO - 图斑 74984 没有找到邻居，跳过
# 2024-10-29 19:24:34,202 - INFO - 图斑 74985 没有找到邻居，跳过
# 2024-10-29 19:24:34,202 - INFO - 图斑 74986 没有找到邻居，跳过
# 2024-10-29 19:24:34,202 - INFO - 图斑 74987 没有找到邻居，跳过
# 2024-10-29 19:24:34,202 - INFO - 图斑 74988 没有找到邻居，跳过
# 2024-10-29 19:24:34,295 - INFO - 图斑 75106 没有找到邻居，跳过
# 2024-10-29 19:24:34,296 - INFO - 图斑 75107 没有找到邻居，跳过
# 2024-10-29 19:24:34,340 - INFO - 图斑 75162 没有找到邻居，跳过
# 2024-10-29 19:24:35,120 - INFO - 图斑 76271 没有找到邻居，跳过
# 2024-10-29 19:24:35,804 - INFO - 图斑 76698 没有找到邻居，跳过
# 2024-10-29 19:24:35,987 - INFO - 图斑 76834 没有找到邻居，跳过
# 2024-10-29 19:24:36,780 - INFO - 图斑 77295 没有找到邻居，跳过
# 2024-10-29 19:24:36,782 - INFO - 图斑 77296 没有找到邻居，跳过
# 2024-10-29 19:24:36,816 - INFO - 图斑 77328 没有找到邻居，跳过
# 2024-10-29 19:24:37,100 - INFO - 图斑 77503 没有找到邻居，跳过
# 2024-10-29 19:24:38,118 - INFO - 图斑 78508 没有找到邻居，跳过
# 2024-10-29 19:24:38,118 - INFO - 图斑 78509 没有找到邻居，跳过
# 2024-10-29 19:24:38,118 - INFO - 图斑 78510 没有找到邻居，跳过
# 2024-10-29 19:24:38,508 - INFO - 图斑 78850 没有找到邻居，跳过
# 2024-10-29 19:24:38,524 - INFO - 图斑 78851 没有找到邻居，跳过
# 2024-10-29 19:24:38,524 - INFO - 图斑 78852 没有找到邻居，跳过
# 2024-10-29 19:24:38,640 - INFO - 图斑 79022 没有找到邻居，跳过
# 2024-10-29 19:24:39,827 - INFO - 图斑 80344 没有找到邻居，跳过
# 2024-10-29 19:24:39,889 - INFO - 图斑 80415 没有找到邻居，跳过
# 2024-10-29 19:24:40,074 - INFO - 图斑 80720 没有找到邻居，跳过
# 2024-10-29 19:24:40,090 - INFO - 图斑 80721 没有找到邻居，跳过
# 2024-10-29 19:24:40,244 - INFO - 图斑 80955 没有找到邻居，跳过
# 2024-10-29 19:24:40,285 - INFO - 图斑 80999 没有找到邻居，跳过
# 2024-10-29 19:24:40,490 - INFO - 图斑 81321 没有找到邻居，跳过
# 2024-10-29 19:24:40,899 - INFO - 图斑 81868 没有找到邻居，跳过
# 2024-10-29 19:24:40,901 - INFO - 图斑 81869 没有找到邻居，跳过
# 2024-10-29 19:24:40,903 - INFO - 图斑 81870 没有找到邻居，跳过
# 2024-10-29 19:24:40,907 - INFO - 图斑 81877 没有找到邻居，跳过
# 2024-10-29 19:24:40,958 - INFO - 图斑 81964 没有找到邻居，跳过
# 2024-10-29 19:24:40,958 - INFO - 图斑 81966 没有找到邻居，跳过
# 2024-10-29 19:24:41,043 - INFO - 图斑 82074 没有找到邻居，跳过
# 2024-10-29 19:24:41,109 - INFO - 图斑 82162 没有找到邻居，跳过
# 2024-10-29 19:24:41,278 - INFO - 图斑 82456 没有找到邻居，跳过
# 2024-10-29 19:24:41,434 - INFO - 图斑 82644 没有找到邻居，跳过
# 2024-10-29 19:24:41,877 - INFO - 图斑 83367 没有找到邻居，跳过
# 2024-10-29 19:24:41,946 - INFO - 图斑 83426 没有找到邻居，跳过
# 2024-10-29 19:24:42,194 - INFO - 图斑 83788 没有找到邻居，跳过
# 2024-10-29 19:24:42,223 - INFO - 图斑 83829 没有找到邻居，跳过
# 2024-10-29 19:24:42,274 - INFO - 图斑 83912 没有找到邻居，跳过
# 2024-10-29 19:24:42,861 - INFO - 图斑 84702 没有找到邻居，跳过
# 2024-10-29 19:24:42,936 - INFO - 图斑 84789 没有找到邻居，跳过
# 2024-10-29 19:24:43,022 - INFO - 图斑 84933 没有找到邻居，跳过
# 2024-10-29 19:24:43,116 - INFO - 图斑 85058 没有找到邻居，跳过
# 2024-10-29 19:24:43,351 - INFO - 图斑 85423 没有找到邻居，跳过
# 2024-10-29 19:24:45,224 - INFO - 图斑 88039 没有找到邻居，跳过
# 2024-10-29 19:24:45,224 - INFO - 图斑 88040 没有找到邻居，跳过
# 2024-10-29 19:24:45,291 - INFO - 图斑 88166 没有找到邻居，跳过
# 2024-10-29 19:24:45,291 - INFO - 图斑 88167 没有找到邻居，跳过
# 2024-10-29 19:24:45,597 - INFO - 图斑 88554 没有找到邻居，跳过
# 2024-10-29 19:24:45,600 - INFO - 图斑 88564 没有找到邻居，跳过
# 2024-10-29 19:24:45,600 - INFO - 图斑 88565 没有找到邻居，跳过
# 2024-10-29 19:24:46,042 - INFO - 图斑 89303 没有找到邻居，跳过
# 2024-10-29 19:24:46,057 - INFO - 图斑 89304 没有找到邻居，跳过
# 2024-10-29 19:24:46,057 - INFO - 图斑 89305 没有找到邻居，跳过
# 2024-10-29 19:24:46,057 - INFO - 图斑 89306 没有找到邻居，跳过
# 2024-10-29 19:24:46,088 - INFO - 图斑 89367 没有找到邻居，跳过
# 2024-10-29 19:24:46,236 - INFO - 图斑 89571 没有找到邻居，跳过
# 2024-10-29 19:24:46,313 - INFO - 图斑 89666 没有找到邻居，跳过
# 2024-10-29 19:24:46,387 - INFO - 图斑 89757 没有找到邻居，跳过
# 2024-10-29 19:24:46,594 - INFO - 图斑 90005 没有找到邻居，跳过
# 2024-10-29 19:24:46,597 - INFO - 图斑 90006 没有找到邻居，跳过
# 2024-10-29 19:24:46,749 - INFO - 图斑 90199 没有找到邻居，跳过
# 2024-10-29 19:24:46,756 - INFO - 图斑 90200 没有找到邻居，跳过
# 2024-10-29 19:24:46,990 - INFO - 图斑 90451 没有找到邻居，跳过
# 2024-10-29 19:24:47,395 - INFO - 图斑 91058 没有找到邻居，跳过
# 2024-10-29 19:24:47,399 - INFO - 图斑 91060 没有找到邻居，跳过
# 2024-10-29 19:24:48,321 - INFO - 图斑 92690 没有找到邻居，跳过
# 2024-10-29 19:24:49,412 - INFO - 图斑 94448 没有找到邻居，跳过
# 2024-10-29 19:24:49,414 - INFO - 图斑 94449 没有找到邻居，跳过
# 2024-10-29 19:24:50,811 - INFO - 图斑 96561 没有找到邻居，跳过
# 2024-10-29 19:24:51,223 - INFO - 图斑 97202 没有找到邻居，跳过
# 2024-10-29 19:24:51,230 - INFO - 图斑 97212 没有找到邻居，跳过
# 2024-10-29 19:24:51,377 - INFO - 图斑 97544 没有找到邻居，跳过
# 2024-10-29 19:24:51,874 - INFO - 图斑 98711 没有找到邻居，跳过
# 2024-10-29 19:24:52,373 - INFO - 图斑 100138 没有找到邻居，跳过
# 2024-10-29 19:24:53,114 - INFO - 图斑 102077 没有找到邻居，跳过
# 2024-10-29 19:24:53,241 - INFO - 图斑 102341 没有找到邻居，跳过
# 2024-10-29 19:24:54,668 - INFO - 图斑 106074 没有找到邻居，跳过
# 2024-10-29 19:24:54,790 - INFO - 图斑 106167 没有找到邻居，跳过
# 2024-10-29 19:24:54,919 - INFO - 图斑 106286 没有找到邻居，跳过
# 2024-10-29 19:24:55,066 - INFO - 图斑 106457 没有找到邻居，跳过
# 2024-10-29 19:24:55,097 - INFO - 图斑 106479 没有找到邻居，跳过
# 2024-10-29 19:24:55,223 - INFO - 图斑 106610 没有找到邻居，跳过
# 2024-10-29 19:24:55,254 - INFO - 图斑 106630 没有找到邻居，跳过
# 2024-10-29 19:24:55,254 - INFO - 图斑 106631 没有找到邻居，跳过
# 2024-10-29 19:24:55,254 - INFO - 图斑 106632 没有找到邻居，跳过
# 2024-10-29 19:24:55,270 - INFO - 图斑 106634 没有找到邻居，跳过
# 2024-10-29 19:24:55,437 - INFO - 图斑 106778 没有找到邻居，跳过
# 2024-10-29 19:24:55,437 - INFO - 图斑 106779 没有找到邻居，跳过
# 2024-10-29 19:24:55,484 - INFO - 图斑 106817 没有找到邻居，跳过
# 2024-10-29 19:24:55,797 - INFO - 图斑 107022 没有找到邻居，跳过
# 2024-10-29 19:24:55,863 - INFO - 图斑 107087 没有找到邻居，跳过
# 2024-10-29 19:24:56,266 - INFO - 图斑 107374 没有找到邻居，跳过
# 2024-10-29 19:24:56,266 - INFO - 图斑 107375 没有找到邻居，跳过
# 2024-10-29 19:24:56,282 - INFO - 图斑 107376 没有找到邻居，跳过
# 2024-10-29 19:24:56,282 - INFO - 图斑 107377 没有找到邻居，跳过
# 2024-10-29 19:24:56,282 - INFO - 图斑 107378 没有找到邻居，跳过
# 2024-10-29 19:24:56,282 - INFO - 图斑 107379 没有找到邻居，跳过
# 2024-10-29 19:24:56,282 - INFO - 图斑 107389 没有找到邻居，跳过
# 2024-10-29 19:24:56,298 - INFO - 图斑 107390 没有找到邻居，跳过
# 2024-10-29 19:24:56,298 - INFO - 图斑 107391 没有找到邻居，跳过
# 2024-10-29 19:24:56,405 - INFO - 图斑 107503 没有找到邻居，跳过
# 2024-10-29 19:24:56,578 - INFO - 图斑 107708 没有找到邻居，跳过
# 2024-10-29 19:24:56,874 - INFO - 图斑 108058 没有找到邻居，跳过
# 2024-10-29 19:24:56,874 - INFO - 图斑 108065 没有找到邻居，跳过
# 2024-10-29 19:24:56,906 - INFO - 图斑 108076 没有找到邻居，跳过
# 2024-10-29 19:24:56,906 - INFO - 图斑 108079 没有找到邻居，跳过
# 2024-10-29 19:24:56,906 - INFO - 图斑 108081 没有找到邻居，跳过
# 2024-10-29 19:24:56,906 - INFO - 图斑 108083 没有找到邻居，跳过
# 2024-10-29 19:24:56,921 - INFO - 图斑 108087 没有找到邻居，跳过
# 2024-10-29 19:24:57,031 - INFO - 图斑 108186 没有找到邻居，跳过
# 2024-10-29 19:24:57,110 - INFO - 图斑 108252 没有找到邻居，跳过
# 2024-10-29 19:24:57,110 - INFO - 图斑 108253 没有找到邻居，跳过
# 2024-10-29 19:24:57,324 - INFO - 图斑 108426 没有找到邻居，跳过
# 2024-10-29 19:24:57,324 - INFO - 图斑 108427 没有找到邻居，跳过
# 2024-10-29 19:24:57,540 - INFO - 图斑 108615 没有找到邻居，跳过
# 2024-10-29 19:24:57,540 - INFO - 图斑 108616 没有找到邻居，跳过
# 2024-10-29 19:24:57,573 - INFO - 图斑 108629 没有找到邻居，跳过
# 2024-10-29 19:24:57,607 - INFO - 图斑 108651 没有找到邻居，跳过
# 2024-10-29 19:24:57,709 - INFO - 图斑 108772 没有找到邻居，跳过
# 2024-10-29 19:24:57,757 - INFO - 图斑 108813 没有找到邻居，跳过
# 2024-10-29 19:24:57,894 - INFO - 图斑 108930 没有找到邻居，跳过
# 2024-10-29 19:24:58,166 - INFO - 图斑 109155 没有找到邻居，跳过
# 2024-10-29 19:24:58,166 - INFO - 图斑 109156 没有找到邻居，跳过
# 2024-10-29 19:24:58,166 - INFO - 图斑 109157 没有找到邻居，跳过
# 2024-10-29 19:24:58,166 - INFO - 图斑 109158 没有找到邻居，跳过
# 2024-10-29 19:24:58,339 - INFO - 图斑 109294 没有找到邻居，跳过
# 2024-10-29 19:24:58,339 - INFO - 图斑 109295 没有找到邻居，跳过
# 2024-10-29 19:24:58,440 - INFO - 图斑 109398 没有找到邻居，跳过
# 2024-10-29 19:24:58,457 - INFO - 图斑 109405 没有找到邻居，跳过
# 2024-10-29 19:24:58,534 - INFO - 图斑 109467 没有找到邻居，跳过
# 2024-10-29 19:24:58,534 - INFO - 图斑 109468 没有找到邻居，跳过
# 2024-10-29 19:24:58,550 - INFO - 图斑 109478 没有找到邻居，跳过
# 2024-10-29 19:24:58,598 - INFO - 图斑 109513 没有找到邻居，跳过
# 2024-10-29 19:24:58,598 - INFO - 图斑 109514 没有找到邻居，跳过
# 2024-10-29 19:24:58,598 - INFO - 图斑 109530 没有找到邻居，跳过
# 2024-10-29 19:24:59,000 - INFO - 图斑 109885 没有找到邻居，跳过
# 2024-10-29 19:24:59,110 - INFO - 图斑 110002 没有找到邻居，跳过
# 2024-10-29 19:24:59,468 - INFO - 图斑 110271 没有找到邻居，跳过
# 2024-10-29 19:24:59,484 - INFO - 图斑 110275 没有找到邻居，跳过
# 2024-10-29 19:24:59,484 - INFO - 图斑 110279 没有找到邻居，跳过
# 2024-10-29 19:24:59,547 - INFO - 图斑 110317 没有找到邻居，跳过
# 2024-10-29 19:24:59,672 - INFO - 图斑 110434 没有找到邻居，跳过
# 2024-10-29 19:25:00,142 - INFO - 图斑 110829 没有找到邻居，跳过
# 2024-10-29 19:25:00,142 - INFO - 图斑 110830 没有找到邻居，跳过
# 2024-10-29 19:25:00,188 - INFO - 图斑 111015 没有找到邻居，跳过
# 2024-10-29 19:25:00,188 - INFO - 图斑 111016 没有找到邻居，跳过
# 2024-10-29 19:25:00,765 - INFO - 图斑 111845 没有找到邻居，跳过
# 2024-10-29 19:25:00,874 - INFO - 图斑 111952 没有找到邻居，跳过
# 2024-10-29 19:25:00,936 - INFO - 图斑 112010 没有找到邻居，跳过
# 2024-10-29 19:25:01,031 - INFO - 图斑 112085 没有找到邻居，跳过
# 2024-10-29 19:25:01,078 - INFO - 图斑 112126 没有找到邻居，跳过
# 2024-10-29 19:25:01,187 - INFO - 图斑 112209 没有找到邻居，跳过
# 2024-10-29 19:25:01,483 - INFO - 图斑 112482 没有找到邻居，跳过
# 2024-10-29 19:25:01,750 - INFO - 图斑 112956 没有找到邻居，跳过
# 2024-10-29 19:25:02,374 - INFO - 图斑 114496 没有找到邻居，跳过
# 2024-10-29 19:25:02,756 - INFO - 图斑 115552 没有找到邻居，跳过
# 2024-10-29 19:25:04,655 - INFO - 图斑 117690 没有找到邻居，跳过
# 2024-10-29 19:25:04,703 - INFO - 图斑 117733 没有找到邻居，跳过
# 2024-10-29 19:25:05,049 - INFO - 图斑 118100 没有找到邻居，跳过
# 2024-10-29 19:25:05,674 - INFO - 图斑 118549 没有找到邻居，跳过
# 2024-10-29 19:25:06,239 - INFO - 图斑 118966 没有找到邻居，跳过
# 2024-10-29 19:25:06,254 - INFO - 图斑 118974 没有找到邻居，跳过
# 2024-10-29 19:25:07,013 - INFO - 图斑 119757 没有找到邻居，跳过
# 2024-10-29 19:25:07,186 - INFO - 图斑 119829 没有找到邻居，跳过
# 2024-10-29 19:25:07,420 - INFO - 图斑 120085 没有找到邻居，跳过
# 2024-10-29 19:25:07,781 - INFO - 图斑 120516 没有找到邻居，跳过
# 2024-10-29 19:25:07,932 - INFO - 图斑 120652 没有找到邻居，跳过
# 2024-10-29 19:25:08,688 - INFO - 图斑 121470 没有找到邻居，跳过
# 2024-10-29 19:25:08,688 - INFO - 图斑 121471 没有找到邻居，跳过
# 2024-10-29 19:25:08,704 - INFO - 图斑 121472 没有找到邻居，跳过
# 2024-10-29 19:25:08,857 - INFO - 图斑 121664 没有找到邻居，跳过
# 2024-10-29 19:25:09,054 - INFO - 图斑 121822 没有找到邻居，跳过
# 2024-10-29 19:25:09,056 - INFO - 图斑 121824 没有找到邻居，跳过
# 2024-10-29 19:25:09,281 - INFO - 图斑 122026 没有找到邻居，跳过
# 2024-10-29 19:25:09,388 - INFO - 图斑 122107 没有找到邻居，跳过
# 2024-10-29 19:25:09,391 - INFO - 图斑 122108 没有找到邻居，跳过
# 2024-10-29 19:25:09,393 - INFO - 图斑 122109 没有找到邻居，跳过
# 2024-10-29 19:25:09,568 - INFO - 图斑 122236 没有找到邻居，跳过
# 2024-10-29 19:25:10,037 - INFO - 图斑 122750 没有找到邻居，跳过
# 2024-10-29 19:25:10,990 - INFO - 图斑 123686 没有找到邻居，跳过
# 2024-10-29 19:25:12,272 - INFO - 图斑 124906 没有找到邻居，跳过
# 2024-10-29 19:25:12,319 - INFO - 图斑 124949 没有找到邻居，跳过
# 2024-10-29 19:25:13,581 - INFO - 图斑 126451 没有找到邻居，跳过
# 2024-10-29 19:25:13,754 - INFO - 图斑 126653 没有找到邻居，跳过
# 2024-10-29 19:25:14,053 - INFO - 图斑 126948 没有找到邻居，跳过
# 2024-10-29 19:25:14,246 - INFO - 图斑 127181 没有找到邻居，跳过
# 2024-10-29 19:25:14,526 - INFO - 图斑 127682 没有找到邻居，跳过
# 2024-10-29 19:25:14,739 - INFO - 图斑 127943 没有找到邻居，跳过
# 2024-10-29 19:25:14,755 - INFO - 图斑 127969 没有找到邻居，跳过
# 2024-10-29 19:25:14,755 - INFO - 图斑 127970 没有找到邻居，跳过
# 2024-10-29 19:25:14,755 - INFO - 图斑 127989 没有找到邻居，跳过
# 2024-10-29 19:25:15,419 - INFO - 图斑 128873 没有找到邻居，跳过
# 2024-10-29 19:25:15,648 - INFO - 图斑 129272 没有找到邻居，跳过
# 2024-10-29 19:25:15,880 - INFO - 图斑 129676 没有找到邻居，跳过
# 2024-10-29 19:25:15,880 - INFO - 图斑 129677 没有找到邻居，跳过
# 2024-10-29 19:25:16,005 - INFO - 图斑 129811 没有找到邻居，跳过
# 2024-10-29 19:25:16,021 - INFO - 图斑 129848 没有找到邻居，跳过
# 2024-10-29 19:25:16,224 - INFO - 图斑 130172 没有找到邻居，跳过
# 2024-10-29 19:25:16,240 - INFO - 图斑 130196 没有找到邻居，跳过
# 2024-10-29 19:25:16,288 - INFO - 图斑 130264 没有找到邻居，跳过
# 2024-10-29 19:25:16,288 - INFO - 图斑 130265 没有找到邻居，跳过
# 2024-10-29 19:25:16,319 - INFO - 图斑 130299 没有找到邻居，跳过
# 2024-10-29 19:25:16,366 - INFO - 图斑 130359 没有找到邻居，跳过
# 2024-10-29 19:25:16,413 - INFO - 图斑 130422 没有找到邻居，跳过
# 2024-10-29 19:25:16,772 - INFO - 图斑 130853 没有找到邻居，跳过
# 2024-10-29 19:25:17,060 - INFO - 图斑 131240 没有找到邻居，跳过
# 2024-10-29 19:25:17,740 - INFO - 图斑 132073 没有找到邻居，跳过
# 2024-10-29 19:25:18,071 - INFO - 图斑 132546 没有找到邻居，跳过
# 2024-10-29 19:25:18,419 - INFO - 图斑 133056 没有找到邻居，跳过
# 2024-10-29 19:25:18,435 - INFO - 图斑 133059 没有找到邻居，跳过
# 2024-10-29 19:25:18,562 - INFO - 图斑 133228 没有找到邻居，跳过
# 2024-10-29 19:25:18,588 - INFO - 图斑 133250 没有找到邻居，跳过
# 2024-10-29 19:25:18,610 - INFO - 图斑 133288 没有找到邻居，跳过
# 2024-10-29 19:25:18,610 - INFO - 图斑 133289 没有找到邻居，跳过
# 2024-10-29 19:25:18,865 - INFO - 图斑 133576 没有找到邻居，跳过
# 2024-10-29 19:25:18,881 - INFO - 图斑 133610 没有找到邻居，跳过
# 2024-10-29 19:25:18,925 - INFO - 图斑 133653 没有找到邻居，跳过
# 2024-10-29 19:25:19,373 - INFO - 图斑 134223 没有找到邻居，跳过
# 2024-10-29 19:25:19,559 - INFO - 图斑 134448 没有找到邻居，跳过
# 2024-10-29 19:25:19,630 - INFO - 图斑 134544 没有找到邻居，跳过
# 2024-10-29 19:25:19,852 - INFO - 图斑 134934 没有找到邻居，跳过
# 2024-10-29 19:25:20,082 - INFO - 图斑 135301 没有找到邻居，跳过
# 2024-10-29 19:25:20,084 - INFO - 图斑 135302 没有找到邻居，跳过
# 2024-10-29 19:25:20,174 - INFO - 图斑 135433 没有找到邻居，跳过
# 2024-10-29 19:25:20,256 - INFO - 图斑 135543 没有找到邻居，跳过
# 2024-10-29 19:25:20,287 - INFO - 图斑 135576 没有找到邻居，跳过
# 2024-10-29 19:25:20,287 - INFO - 图斑 135577 没有找到邻居，跳过
# 2024-10-29 19:25:20,306 - INFO - 图斑 135582 没有找到邻居，跳过
# 2024-10-29 19:25:20,312 - INFO - 图斑 135588 没有找到邻居，跳过
# 2024-10-29 19:25:20,344 - INFO - 图斑 135644 没有找到邻居，跳过
# 2024-10-29 19:25:20,443 - INFO - 图斑 135799 没有找到邻居，跳过
# 2024-10-29 19:25:20,593 - INFO - 图斑 136040 没有找到邻居，跳过
# 2024-10-29 19:25:20,593 - INFO - 图斑 136041 没有找到邻居，跳过
# 2024-10-29 19:25:20,593 - INFO - 图斑 136043 没有找到邻居，跳过
# 2024-10-29 19:25:20,642 - INFO - 图斑 136090 没有找到邻居，跳过
# 2024-10-29 19:25:20,999 - INFO - 图斑 136624 没有找到邻居，跳过
# 2024-10-29 19:25:21,017 - INFO - 图斑 136639 没有找到邻居，跳过
# 2024-10-29 19:25:21,020 - INFO - 图斑 136640 没有找到邻居，跳过
# 2024-10-29 19:25:21,435 - INFO - 图斑 137259 没有找到邻居，跳过
# 2024-10-29 19:25:21,553 - INFO - 图斑 137448 没有找到邻居，跳过
# 2024-10-29 19:25:21,831 - INFO - 图斑 137751 没有找到邻居，跳过
# 2024-10-29 19:25:21,835 - INFO - 图斑 137753 没有找到邻居，跳过
# 2024-10-29 19:25:21,844 - INFO - 图斑 137765 没有找到邻居，跳过
# 2024-10-29 19:25:21,847 - INFO - 图斑 137766 没有找到邻居，跳过
# 2024-10-29 19:25:21,869 - INFO - 图斑 137804 没有找到邻居，跳过
# 2024-10-29 19:25:22,351 - INFO - 图斑 138373 没有找到邻居，跳过
# 2024-10-29 19:25:22,362 - INFO - 图斑 138379 没有找到邻居，跳过
# 2024-10-29 19:25:22,651 - INFO - 图斑 138723 没有找到邻居，跳过
# 2024-10-29 19:25:22,820 - INFO - 图斑 138947 没有找到邻居，跳过
# 2024-10-29 19:25:22,940 - INFO - 图斑 139107 没有找到邻居，跳过
# 2024-10-29 19:25:23,158 - INFO - 图斑 139424 没有找到邻居，跳过
# 2024-10-29 19:25:23,158 - INFO - 图斑 139425 没有找到邻居，跳过
# 2024-10-29 19:25:23,525 - INFO - 图斑 140011 没有找到邻居，跳过
# 2024-10-29 19:25:23,578 - INFO - 图斑 140110 没有找到邻居，跳过
# 2024-10-29 19:25:23,630 - INFO - 图斑 140186 没有找到邻居，跳过
# 2024-10-29 19:25:24,225 - INFO - 图斑 140935 没有找到邻居，跳过
# 2024-10-29 19:25:24,372 - INFO - 图斑 141128 没有找到邻居，跳过
# 2024-10-29 19:25:24,374 - INFO - 图斑 141129 没有找到邻居，跳过
# 2024-10-29 19:25:25,345 - INFO - 图斑 142310 没有找到邻居，跳过
# 2024-10-29 19:25:25,347 - INFO - 图斑 142311 没有找到邻居，跳过
# 2024-10-29 19:25:25,369 - INFO - 图斑 142333 没有找到邻居，跳过
# 2024-10-29 19:25:25,373 - INFO - 图斑 142335 没有找到邻居，跳过
# 2024-10-29 19:25:25,401 - INFO - 图斑 142363 没有找到邻居，跳过
# 2024-10-29 19:25:25,494 - INFO - 图斑 142454 没有找到邻居，跳过
# 2024-10-29 19:25:25,840 - INFO - 图斑 142924 没有找到邻居，跳过
# 2024-10-29 19:25:25,842 - INFO - 图斑 142925 没有找到邻居，跳过
# 2024-10-29 19:25:25,844 - INFO - 图斑 142926 没有找到邻居，跳过
# 2024-10-29 19:25:26,007 - INFO - 图斑 143126 没有找到邻居，跳过
# 2024-10-29 19:25:26,253 - INFO - 图斑 143432 没有找到邻居，跳过
# 2024-10-29 19:25:26,256 - INFO - 图斑 143433 没有找到邻居，跳过
# 2024-10-29 19:25:26,259 - INFO - 图斑 143434 没有找到邻居，跳过
# 2024-10-29 19:25:26,279 - INFO - 图斑 143475 没有找到邻居，跳过
# 2024-10-29 19:25:26,443 - INFO - 图斑 143742 没有找到邻居，跳过
# 2024-10-29 19:25:26,657 - INFO - 图斑 144042 没有找到邻居，跳过
# 2024-10-29 19:25:27,057 - INFO - 图斑 144581 没有找到邻居，跳过
# 2024-10-29 19:25:27,108 - INFO - 图斑 144654 没有找到邻居，跳过
# 2024-10-29 19:25:27,123 - INFO - 图斑 144692 没有找到邻居，跳过
# 2024-10-29 19:25:27,209 - INFO - 图斑 144860 没有找到邻居，跳过
# 2024-10-29 19:25:27,288 - INFO - 图斑 145059 没有找到邻居，跳过
# 2024-10-29 19:25:27,455 - INFO - 图斑 145473 没有找到邻居，跳过
# 2024-10-29 19:25:29,849 - INFO - 图斑 151415 没有找到邻居，跳过
# 2024-10-29 19:25:30,040 - INFO - 图斑 151604 没有找到邻居，跳过
# 2024-10-29 19:25:30,060 - INFO - 图斑 151617 没有找到邻居，跳过
# 2024-10-29 19:25:30,089 - INFO - 图斑 151631 没有找到邻居，跳过
# 2024-10-29 19:25:30,257 - INFO - 图斑 151799 没有找到邻居，跳过
# 2024-10-29 19:25:30,257 - INFO - 图斑 151800 没有找到邻居，跳过
# 2024-10-29 19:25:30,257 - INFO - 图斑 151801 没有找到邻居，跳过
# 2024-10-29 19:25:30,273 - INFO - 图斑 151802 没有找到邻居，跳过
# 2024-10-29 19:25:30,273 - INFO - 图斑 151804 没有找到邻居，跳过
# 2024-10-29 19:25:30,307 - INFO - 图斑 151831 没有找到邻居，跳过
# 2024-10-29 19:25:30,307 - INFO - 图斑 151832 没有找到邻居，跳过
# 2024-10-29 19:25:30,307 - INFO - 图斑 151833 没有找到邻居，跳过
# 2024-10-29 19:25:30,307 - INFO - 图斑 151834 没有找到邻居，跳过
# 2024-10-29 19:25:30,307 - INFO - 图斑 151835 没有找到邻居，跳过
# 2024-10-29 19:25:30,307 - INFO - 图斑 151836 没有找到邻居，跳过
# 2024-10-29 19:25:30,357 - INFO - 图斑 151871 没有找到邻居，跳过
# 2024-10-29 19:25:30,373 - INFO - 图斑 151876 没有找到邻居，跳过
# 2024-10-29 19:25:30,390 - INFO - 图斑 151897 没有找到邻居，跳过
# 2024-10-29 19:25:30,407 - INFO - 图斑 151904 没有找到邻居，跳过
# 2024-10-29 19:25:30,407 - INFO - 图斑 151909 没有找到邻居，跳过
# 2024-10-29 19:25:30,423 - INFO - 图斑 151914 没有找到邻居，跳过
# 2024-10-29 19:25:30,444 - INFO - 图斑 151927 没有找到邻居，跳过
# 2024-10-29 19:25:30,456 - INFO - 图斑 151943 没有找到邻居，跳过
# 2024-10-29 19:25:30,456 - INFO - 图斑 151944 没有找到邻居，跳过
# 2024-10-29 19:25:30,456 - INFO - 图斑 151945 没有找到邻居，跳过
# 2024-10-29 19:25:30,456 - INFO - 图斑 151946 没有找到邻居，跳过
# 2024-10-29 19:25:30,456 - INFO - 图斑 151947 没有找到邻居，跳过
# 2024-10-29 19:25:30,622 - INFO - 图斑 152129 没有找到邻居，跳过
# 2024-10-29 19:25:30,741 - INFO - 图斑 152240 没有找到邻居，跳过
# 2024-10-29 19:25:30,860 - INFO - 图斑 152331 没有找到邻居，跳过
# 2024-10-29 19:25:30,860 - INFO - 图斑 152332 没有找到邻居，跳过
# 2024-10-29 19:25:30,891 - INFO - 图斑 152343 没有找到邻居，跳过
# 2024-10-29 19:25:30,923 - INFO - 图斑 152374 没有找到邻居，跳过
# 2024-10-29 19:25:31,176 - INFO - 图斑 152639 没有找到邻居，跳过
# 2024-10-29 19:25:31,178 - INFO - 图斑 152640 没有找到邻居，跳过
# 2024-10-29 19:25:31,180 - INFO - 图斑 152641 没有找到邻居，跳过
# 2024-10-29 19:25:31,182 - INFO - 图斑 152642 没有找到邻居，跳过
# 2024-10-29 19:25:31,405 - INFO - 图斑 152827 没有找到邻居，跳过
# 2024-10-29 19:25:31,523 - INFO - 图斑 152936 没有找到邻居，跳过
# 2024-10-29 19:25:31,523 - INFO - 图斑 152937 没有找到邻居，跳过
# 2024-10-29 19:25:31,590 - INFO - 图斑 152999 没有找到邻居，跳过
# 2024-10-29 19:25:31,606 - INFO - 图斑 153000 没有找到邻居，跳过
# 2024-10-29 19:25:31,606 - INFO - 图斑 153001 没有找到邻居，跳过
# 2024-10-29 19:25:31,908 - INFO - 图斑 153250 没有找到邻居，跳过
# 2024-10-29 19:25:31,974 - INFO - 图斑 153315 没有找到邻居，跳过
# 2024-10-29 19:25:32,253 - INFO - 图斑 153625 没有找到邻居，跳过
# 2024-10-29 19:25:32,557 - INFO - 图斑 153954 没有找到邻居，跳过
# 2024-10-29 19:25:32,557 - INFO - 图斑 153955 没有找到邻居，跳过
# 2024-10-29 19:25:32,723 - INFO - 图斑 154126 没有找到邻居，跳过
# 2024-10-29 19:25:32,766 - INFO - 图斑 154156 没有找到邻居，跳过
# 2024-10-29 19:25:32,768 - INFO - 图斑 154157 没有找到邻居，跳过
# 2024-10-29 19:25:32,774 - INFO - 图斑 154163 没有找到邻居，跳过
# 2024-10-29 19:25:32,809 - INFO - 图斑 154185 没有找到邻居，跳过
# 2024-10-29 19:25:32,907 - INFO - 图斑 154276 没有找到邻居，跳过
# 2024-10-29 19:25:32,907 - INFO - 图斑 154277 没有找到邻居，跳过
# 2024-10-29 19:25:33,023 - INFO - 图斑 154388 没有找到邻居，跳过
# 2024-10-29 19:25:33,040 - INFO - 图斑 154408 没有找到邻居，跳过
# 2024-10-29 19:25:33,222 - INFO - 图斑 154543 没有找到邻居，跳过
# 2024-10-29 19:25:33,223 - INFO - 图斑 154544 没有找到邻居，跳过
# 2024-10-29 19:25:33,223 - INFO - 图斑 154550 没有找到邻居，跳过
# 2024-10-29 19:25:33,240 - INFO - 图斑 154560 没有找到邻居，跳过
# 2024-10-29 19:25:33,573 - INFO - 图斑 155262 没有找到邻居，跳过
# 2024-10-29 19:25:33,723 - INFO - 图斑 155445 没有找到邻居，跳过
# 2024-10-29 19:25:34,056 - INFO - 图斑 155768 没有找到邻居，跳过
# 2024-10-29 19:25:34,106 - INFO - 图斑 155815 没有找到邻居，跳过
# 2024-10-29 19:25:34,106 - INFO - 图斑 155816 没有找到邻居，跳过
# 2024-10-29 19:25:34,173 - INFO - 图斑 155883 没有找到邻居，跳过
# 2024-10-29 19:25:34,223 - INFO - 图斑 155921 没有找到邻居，跳过
# 2024-10-29 19:25:35,518 - INFO - 图斑 158674 没有找到邻居，跳过
# 2024-10-29 19:25:35,717 - INFO - 图斑 159195 没有找到邻居，跳过
# 2024-10-29 19:25:35,803 - INFO - 图斑 159460 没有找到邻居，跳过
# 2024-10-29 19:25:37,406 - INFO - 图斑 161024 没有找到邻居，跳过
# 2024-10-29 19:25:37,490 - INFO - 图斑 161086 没有找到邻居，跳过
# 2024-10-29 19:25:37,506 - INFO - 图斑 161087 没有找到邻居，跳过
# 2024-10-29 19:25:37,540 - INFO - 图斑 161122 没有找到邻居，跳过
# 2024-10-29 19:25:37,690 - INFO - 图斑 161229 没有找到邻居，跳过
# 2024-10-29 19:25:37,981 - INFO - 图斑 161509 没有找到邻居，跳过
# 2024-10-29 19:25:38,151 - INFO - 图斑 161663 没有找到邻居，跳过
# 2024-10-29 19:25:38,358 - INFO - 图斑 161820 没有找到邻居，跳过
# 2024-10-29 19:25:38,525 - INFO - 图斑 161941 没有找到邻居，跳过
# 2024-10-29 19:25:39,443 - INFO - 图斑 162778 没有找到邻居，跳过
# 2024-10-29 19:25:40,240 - INFO - 图斑 163445 没有找到邻居，跳过
# 2024-10-29 19:25:41,223 - INFO - 图斑 164414 没有找到邻居，跳过
# 2024-10-29 19:25:41,545 - INFO - 图斑 164721 没有找到邻居，跳过
# 2024-10-29 19:25:41,554 - INFO - 图斑 164727 没有找到邻居，跳过
# 2024-10-29 19:25:41,657 - INFO - 图斑 164879 没有找到邻居，跳过
# 2024-10-29 19:25:43,243 - INFO - 图斑 166391 没有找到邻居，跳过
# 2024-10-29 19:25:43,319 - INFO - 图斑 166479 没有找到邻居，跳过
# 2024-10-29 19:25:43,322 - INFO - 图斑 166480 没有找到邻居，跳过
# 2024-10-29 19:25:43,326 - INFO - 图斑 166482 没有找到邻居，跳过
# 2024-10-29 19:25:43,715 - INFO - 图斑 166984 没有找到邻居，跳过
# 2024-10-29 19:25:44,350 - INFO - 图斑 167692 没有找到邻居，跳过
# 2024-10-29 19:25:45,523 - INFO - 图斑 169026 没有找到邻居，跳过
# 2024-10-29 19:25:45,693 - INFO - 图斑 169288 没有找到邻居，跳过
# 2024-10-29 19:25:46,093 - INFO - 图斑 169636 没有找到邻居，跳过
# 2024-10-29 19:25:46,107 - INFO - 图斑 169638 没有找到邻居，跳过
# 2024-10-29 19:25:46,189 - INFO - 图斑 169747 没有找到邻居，跳过
# 2024-10-29 19:25:47,003 - INFO - 图斑 170462 没有找到邻居，跳过
# 2024-10-29 19:25:47,004 - INFO - 图斑 170463 没有找到邻居，跳过
# 2024-10-29 19:25:47,004 - INFO - 图斑 170464 没有找到邻居，跳过
# 2024-10-29 19:25:47,226 - INFO - 图斑 170677 没有找到邻居，跳过
# 2024-10-29 19:25:47,226 - INFO - 图斑 170678 没有找到邻居，跳过
# 2024-10-29 19:25:47,226 - INFO - 图斑 170679 没有找到邻居，跳过
# 2024-10-29 19:25:47,426 - INFO - 图斑 170897 没有找到邻居，跳过
# 2024-10-29 19:25:47,891 - INFO - 图斑 171332 没有找到邻居，跳过
# 2024-10-29 19:25:47,894 - INFO - 图斑 171333 没有找到邻居，跳过
# 2024-10-29 19:25:48,157 - INFO - 图斑 171674 没有找到邻居，跳过
# 2024-10-29 19:25:48,210 - INFO - 图斑 171751 没有找到邻居，跳过
# 2024-10-29 19:25:48,660 - INFO - 图斑 172009 没有找到邻居，跳过
# 2024-10-29 19:25:48,722 - INFO - 图斑 172082 没有找到邻居，跳过
# 2024-10-29 19:25:48,960 - INFO - 图斑 172162 没有找到邻居，跳过
# 2024-10-29 19:25:48,976 - INFO - 图斑 172163 没有找到邻居，跳过
# 2024-10-29 19:25:49,093 - INFO - 图斑 172213 没有找到邻居，跳过
# 2024-10-29 19:25:49,860 - INFO - 图斑 172762 没有找到邻居，跳过
# 2024-10-29 19:25:49,862 - INFO - 图斑 172763 没有找到邻居，跳过
# 2024-10-29 19:25:50,607 - INFO - 图斑 173563 没有找到邻居，跳过
# 2024-10-29 19:25:50,645 - INFO - 图斑 173618 没有找到邻居，跳过
# 2024-10-29 19:25:50,659 - INFO - 图斑 173626 没有找到邻居，跳过
# 2024-10-29 19:25:50,924 - INFO - 图斑 173865 没有找到邻居，跳过
# 2024-10-29 19:25:50,993 - INFO - 图斑 173952 没有找到邻居，跳过
# 2024-10-29 19:25:51,033 - INFO - 图斑 173986 没有找到邻居，跳过
# 2024-10-29 19:25:51,034 - INFO - 图斑 173987 没有找到邻居，跳过
# 2024-10-29 19:25:51,092 - INFO - 图斑 174065 没有找到邻居，跳过
# 2024-10-29 19:25:51,311 - INFO - 图斑 174218 没有找到邻居，跳过
# 2024-10-29 19:25:52,357 - INFO - 图斑 175272 没有找到邻居，跳过
# 2024-10-29 19:25:52,357 - INFO - 图斑 175273 没有找到邻居，跳过
# 2024-10-29 19:25:52,543 - INFO - 图斑 175493 没有找到邻居，跳过
# 2024-10-29 19:25:52,676 - INFO - 图斑 175609 没有找到邻居，跳过
# 2024-10-29 19:25:52,806 - INFO - 图斑 175671 没有找到邻居，跳过
# 2024-10-29 19:25:52,856 - INFO - 图斑 175738 没有找到邻居，跳过
# 2024-10-29 19:25:53,543 - INFO - 图斑 176306 没有找到邻居，跳过
# 2024-10-29 19:25:53,709 - INFO - 图斑 176475 没有找到邻居，跳过
# 2024-10-29 19:25:53,746 - INFO - 图斑 176501 没有找到邻居，跳过
# 2024-10-29 19:25:53,771 - INFO - 图斑 176527 没有找到邻居，跳过
# 2024-10-29 19:25:53,773 - INFO - 图斑 176529 没有找到邻居，跳过
# 2024-10-29 19:25:53,796 - INFO - 图斑 176547 没有找到邻居，跳过
# 2024-10-29 19:25:53,798 - INFO - 图斑 176548 没有找到邻居，跳过
# 2024-10-29 19:25:54,506 - INFO - 图斑 177496 没有找到邻居，跳过
# 2024-10-29 19:25:54,758 - INFO - 图斑 177719 没有找到邻居，跳过
# 2024-10-29 19:25:54,823 - INFO - 图斑 177802 没有找到邻居，跳过
# 2024-10-29 19:25:54,991 - INFO - 图斑 177964 没有找到邻居，跳过
# 2024-10-29 19:25:55,027 - INFO - 图斑 177996 没有找到邻居，跳过
# 2024-10-29 19:25:55,046 - INFO - 图斑 178007 没有找到邻居，跳过
# 2024-10-29 19:25:55,052 - INFO - 图斑 178012 没有找到邻居，跳过
# 2024-10-29 19:25:55,057 - INFO - 图斑 178013 没有找到邻居，跳过
# 2024-10-29 19:25:55,063 - INFO - 图斑 178016 没有找到邻居，跳过
# 2024-10-29 19:25:55,065 - INFO - 图斑 178017 没有找到邻居，跳过
# 2024-10-29 19:25:55,082 - INFO - 图斑 178042 没有找到邻居，跳过
# 2024-10-29 19:25:55,090 - INFO - 图斑 178059 没有找到邻居，跳过
# 2024-10-29 19:25:55,090 - INFO - 图斑 178060 没有找到邻居，跳过
# 2024-10-29 19:25:55,105 - INFO - 图斑 178065 没有找到邻居，跳过
# 2024-10-29 19:25:55,236 - INFO - 图斑 178303 没有找到邻居，跳过
# 2024-10-29 19:25:55,455 - INFO - 图斑 178553 没有找到邻居，跳过
# 2024-10-29 19:25:55,455 - INFO - 图斑 178554 没有找到邻居，跳过
# 2024-10-29 19:25:55,624 - INFO - 图斑 178746 没有找到邻居，跳过
# 2024-10-29 19:25:55,823 - INFO - 图斑 178963 没有找到邻居，跳过
# 2024-10-29 19:25:55,839 - INFO - 图斑 178981 没有找到邻居，跳过
# 2024-10-29 19:25:56,104 - INFO - 图斑 179330 没有找到邻居，跳过
# 2024-10-29 19:25:56,606 - INFO - 图斑 179830 没有找到邻居，跳过
# 2024-10-29 19:25:56,606 - INFO - 图斑 179831 没有找到邻居，跳过
# 2024-10-29 19:25:56,689 - INFO - 图斑 179896 没有找到邻居，跳过
# 2024-10-29 19:25:56,728 - INFO - 图斑 179947 没有找到邻居，跳过
# 2024-10-29 19:25:56,743 - INFO - 图斑 179962 没有找到邻居，跳过
# 2024-10-29 19:25:57,824 - INFO - 图斑 180924 没有找到邻居，跳过
# 2024-10-29 19:25:58,189 - INFO - 图斑 181250 没有找到邻居，跳过
# 2024-10-29 19:25:58,189 - INFO - 图斑 181251 没有找到邻居，跳过
# 2024-10-29 19:25:58,543 - INFO - 图斑 181470 没有找到邻居，跳过
# 2024-10-29 19:25:58,556 - INFO - 图斑 181487 没有找到邻居，跳过
# 2024-10-29 19:25:58,572 - INFO - 图斑 181488 没有找到邻居，跳过
# 2024-10-29 19:25:58,919 - INFO - 图斑 182013 没有找到邻居，跳过
# 2024-10-29 19:25:58,969 - INFO - 图斑 182073 没有找到邻居，跳过
# ...
# 2024-10-29 19:28:54,607 - INFO - 图斑 26734 没有找到邻居，跳过
# 2024-10-29 19:28:54,607 - INFO - 图斑 26753 没有找到邻居，跳过
# 2024-10-29 19:28:54,607 - INFO - 图斑 33237 没有找到邻居，跳过
# 2024-10-29 19:28:54,622 - INFO - 图斑 36238 没有找到邻居，跳过
# 2024-10-29 19:28:54,622 - INFO - 图斑 36239 没有找到邻居，跳过
# 2024-10-29 19:28:54,622 - INFO - 图斑 36240 没有找到邻居，跳过
# 2024-10-29 19:28:54,622 - INFO - 图斑 36256 没有找到邻居，跳过
# 2024-10-29 19:28:54,622 - INFO - 图斑 36257 没有找到邻居，跳过
# 2024-10-29 19:28:54,637 - INFO - 图斑 36315 没有找到邻居，跳过
# 2024-10-29 19:28:54,639 - INFO - 图斑 36316 没有找到邻居，跳过
# 2024-10-29 19:28:54,639 - INFO - 图斑 36317 没有找到邻居，跳过
# 2024-10-29 19:28:54,639 - INFO - 图斑 37049 没有找到邻居，跳过
# 2024-10-29 19:28:54,639 - INFO - 图斑 37209 没有找到邻居，跳过
# 2024-10-29 19:28:54,639 - INFO - 图斑 37222 没有找到邻居，跳过
# 2024-10-29 19:28:54,655 - INFO - 图斑 37383 没有找到邻居，跳过
# 2024-10-29 19:28:54,657 - INFO - 图斑 37515 没有找到邻居，跳过
# 2024-10-29 19:28:54,657 - INFO - 图斑 37516 没有找到邻居，跳过
# 2024-10-29 19:28:54,657 - INFO - 图斑 37870 没有找到邻居，跳过
# 2024-10-29 19:28:54,670 - INFO - 图斑 38060 没有找到邻居，跳过
# 2024-10-29 19:28:54,672 - INFO - 图斑 38482 没有找到邻居，跳过
# 2024-10-29 19:28:54,677 - INFO - 图斑 38658 没有找到邻居，跳过
# 2024-10-29 19:28:54,677 - INFO - 图斑 38659 没有找到邻居，跳过
# 2024-10-29 19:28:54,677 - INFO - 图斑 38660 没有找到邻居，跳过
# 2024-10-29 19:28:54,688 - INFO - 图斑 38669 没有找到邻居，跳过
# 2024-10-29 19:28:54,691 - INFO - 图斑 38791 没有找到邻居，跳过
# 2024-10-29 19:28:54,691 - INFO - 图斑 38916 没有找到邻居，跳过
# 2024-10-29 19:28:54,691 - INFO - 图斑 39134 没有找到邻居，跳过
# 2024-10-29 19:28:54,691 - INFO - 图斑 39577 没有找到邻居，跳过
# 2024-10-29 19:28:54,691 - INFO - 图斑 41156 没有找到邻居，跳过
# 2024-10-29 19:28:54,704 - INFO - 图斑 41157 没有找到邻居，跳过
# 2024-10-29 19:28:54,705 - INFO - 图斑 41158 没有找到邻居，跳过
# 2024-10-29 19:28:54,705 - INFO - 图斑 41159 没有找到邻居，跳过
# 2024-10-29 19:28:54,705 - INFO - 图斑 41160 没有找到邻居，跳过
# 2024-10-29 19:28:54,722 - INFO - 图斑 41161 没有找到邻居，跳过
# 2024-10-29 19:28:54,722 - INFO - 图斑 41162 没有找到邻居，跳过
# 2024-10-29 19:28:54,722 - INFO - 图斑 41943 没有找到邻居，跳过
# 2024-10-29 19:28:54,722 - INFO - 图斑 41944 没有找到邻居，跳过
# 2024-10-29 19:28:54,722 - INFO - 图斑 41945 没有找到邻居，跳过
# 2024-10-29 19:28:54,722 - INFO - 图斑 43560 没有找到邻居，跳过
# 2024-10-29 19:28:54,736 - INFO - 图斑 53601 没有找到邻居，跳过
# 2024-10-29 19:28:54,739 - INFO - 图斑 54178 没有找到邻居，跳过
# 2024-10-29 19:28:54,739 - INFO - 图斑 54179 没有找到邻居，跳过
# 2024-10-29 19:28:54,739 - INFO - 图斑 54180 没有找到邻居，跳过
# 2024-10-29 19:28:54,739 - INFO - 图斑 54182 没有找到邻居，跳过
# 2024-10-29 19:28:54,739 - INFO - 图斑 54183 没有找到邻居，跳过
# 2024-10-29 19:28:54,739 - INFO - 图斑 54184 没有找到邻居，跳过
# 2024-10-29 19:28:54,739 - INFO - 图斑 54185 没有找到邻居，跳过
# 2024-10-29 19:28:54,739 - INFO - 图斑 54507 没有找到邻居，跳过
# 2024-10-29 19:28:54,754 - INFO - 图斑 54663 没有找到邻居，跳过
# 2024-10-29 19:28:54,756 - INFO - 图斑 54666 没有找到邻居，跳过
# 2024-10-29 19:28:54,756 - INFO - 图斑 54768 没有找到邻居，跳过
# 2024-10-29 19:28:54,756 - INFO - 图斑 54942 没有找到邻居，跳过
# 2024-10-29 19:28:54,756 - INFO - 图斑 54943 没有找到邻居，跳过
# 2024-10-29 19:28:54,756 - INFO - 图斑 55059 没有找到邻居，跳过
# 2024-10-29 19:28:54,772 - INFO - 图斑 55066 没有找到邻居，跳过
# 2024-10-29 19:28:54,774 - INFO - 图斑 56051 没有找到邻居，跳过
# 2024-10-29 19:28:54,776 - INFO - 图斑 56052 没有找到邻居，跳过
# 2024-10-29 19:28:54,778 - INFO - 图斑 56324 没有找到邻居，跳过
# 2024-10-29 19:28:54,778 - INFO - 图斑 56325 没有找到邻居，跳过
# 2024-10-29 19:28:54,778 - INFO - 图斑 56326 没有找到邻居，跳过
# 2024-10-29 19:28:54,788 - INFO - 图斑 56327 没有找到邻居，跳过
# 2024-10-29 19:28:54,791 - INFO - 图斑 56366 没有找到邻居，跳过
# 2024-10-29 19:28:54,791 - INFO - 图斑 56377 没有找到邻居，跳过
# 2024-10-29 19:28:54,791 - INFO - 图斑 69042 没有找到邻居，跳过
# 2024-10-29 19:28:54,791 - INFO - 图斑 69043 没有找到邻居，跳过
# 2024-10-29 19:28:54,791 - INFO - 图斑 69901 没有找到邻居，跳过
# 2024-10-29 19:28:54,805 - INFO - 图斑 69981 没有找到邻居，跳过
# 2024-10-29 19:28:54,806 - INFO - 图斑 69982 没有找到邻居，跳过
# 2024-10-29 19:28:54,806 - INFO - 图斑 70377 没有找到邻居，跳过
# 2024-10-29 19:28:54,806 - INFO - 图斑 71315 没有找到邻居，跳过
# 2024-10-29 19:28:54,806 - INFO - 图斑 74036 没有找到邻居，跳过
# 2024-10-29 19:28:54,806 - INFO - 图斑 74037 没有找到邻居，跳过
# 2024-10-29 19:28:54,806 - INFO - 图斑 74109 没有找到邻居，跳过
# 2024-10-29 19:28:54,821 - INFO - 图斑 74871 没有找到邻居，跳过
# 2024-10-29 19:28:54,822 - INFO - 图斑 74872 没有找到邻居，跳过
# 2024-10-29 19:28:54,822 - INFO - 图斑 74987 没有找到邻居，跳过
# 2024-10-29 19:28:54,822 - INFO - 图斑 74988 没有找到邻居，跳过
# 2024-10-29 19:28:54,822 - INFO - 图斑 78850 没有找到邻居，跳过
# 2024-10-29 19:28:54,822 - INFO - 图斑 78851 没有找到邻居，跳过
# 2024-10-29 19:28:54,822 - INFO - 图斑 78852 没有找到邻居，跳过
# 2024-10-29 19:28:54,822 - INFO - 图斑 80720 没有找到邻居，跳过
# 2024-10-29 19:28:54,822 - INFO - 图斑 80721 没有找到邻居，跳过
# 2024-10-29 19:28:54,836 - INFO - 图斑 80999 没有找到邻居，跳过
# 2024-10-29 19:28:54,839 - INFO - 图斑 81321 没有找到邻居，跳过
# 2024-10-29 19:28:54,839 - INFO - 图斑 81868 没有找到邻居，跳过
# 2024-10-29 19:28:54,839 - INFO - 图斑 81869 没有找到邻居，跳过
# 2024-10-29 19:28:54,839 - INFO - 图斑 81870 没有找到邻居，跳过
# 2024-10-29 19:28:54,839 - INFO - 图斑 81966 没有找到邻居，跳过
# 2024-10-29 19:28:54,839 - INFO - 图斑 85058 没有找到邻居，跳过
# 2024-10-29 19:28:54,839 - INFO - 图斑 88039 没有找到邻居，跳过
# 2024-10-29 19:28:54,854 - INFO - 图斑 88040 没有找到邻居，跳过
# 2024-10-29 19:28:54,856 - INFO - 图斑 88564 没有找到邻居，跳过
# 2024-10-29 19:28:54,856 - INFO - 图斑 88565 没有找到邻居，跳过
# 2024-10-29 19:28:54,856 - INFO - 图斑 90199 没有找到邻居，跳过
# 2024-10-29 19:28:54,856 - INFO - 图斑 90200 没有找到邻居，跳过
# 2024-10-29 19:28:54,856 - INFO - 图斑 94448 没有找到邻居，跳过
# 2024-10-29 19:28:54,856 - INFO - 图斑 94449 没有找到邻居，跳过
# 2024-10-29 19:28:54,870 - INFO - 图斑 97212 没有找到邻居，跳过
# 2024-10-29 19:28:54,873 - INFO - 图斑 106610 没有找到邻居，跳过
# 2024-10-29 19:28:54,874 - INFO - 图斑 107374 没有找到邻居，跳过
# 2024-10-29 19:28:54,875 - INFO - 图斑 107375 没有找到邻居，跳过
# 2024-10-29 19:28:54,875 - INFO - 图斑 107376 没有找到邻居，跳过
# 2024-10-29 19:28:54,875 - INFO - 图斑 107377 没有找到邻居，跳过
# 2024-10-29 19:28:54,875 - INFO - 图斑 107378 没有找到邻居，跳过
# 2024-10-29 19:28:54,875 - INFO - 图斑 107379 没有找到邻居，跳过
# 2024-10-29 19:28:54,875 - INFO - 图斑 107389 没有找到邻居，跳过
# 2024-10-29 19:28:54,886 - INFO - 图斑 107390 没有找到邻居，跳过
# 2024-10-29 19:28:54,887 - INFO - 图斑 107391 没有找到邻居，跳过
# 2024-10-29 19:28:54,889 - INFO - 图斑 107503 没有找到邻居，跳过
# 2024-10-29 19:28:54,889 - INFO - 图斑 108087 没有找到邻居，跳过
# 2024-10-29 19:28:54,889 - INFO - 图斑 108252 没有找到邻居，跳过
# 2024-10-29 19:28:54,889 - INFO - 图斑 108253 没有找到邻居，跳过
# 2024-10-29 19:28:54,889 - INFO - 图斑 108426 没有找到邻居，跳过
# 2024-10-29 19:28:54,889 - INFO - 图斑 108427 没有找到邻居，跳过
# 2024-10-29 19:28:54,903 - INFO - 图斑 108615 没有找到邻居，跳过
# 2024-10-29 19:28:54,906 - INFO - 图斑 108616 没有找到邻居，跳过
# 2024-10-29 19:28:54,906 - INFO - 图斑 109155 没有找到邻居，跳过
# 2024-10-29 19:28:54,906 - INFO - 图斑 109156 没有找到邻居，跳过
# 2024-10-29 19:28:54,906 - INFO - 图斑 109157 没有找到邻居，跳过
# 2024-10-29 19:28:54,906 - INFO - 图斑 109158 没有找到邻居，跳过
# 2024-10-29 19:28:54,924 - INFO - 图斑 109405 没有找到邻居，跳过
# 2024-10-29 19:28:54,924 - INFO - 图斑 109478 没有找到邻居，跳过
# 2024-10-29 19:28:54,938 - INFO - 图斑 109513 没有找到邻居，跳过
# 2024-10-29 19:28:54,943 - INFO - 图斑 109514 没有找到邻居，跳过
# 2024-10-29 19:28:54,943 - INFO - 图斑 109530 没有找到邻居，跳过
# 2024-10-29 19:28:54,953 - INFO - 图斑 110434 没有找到邻居，跳过
# 2024-10-29 19:28:54,956 - INFO - 图斑 110829 没有找到邻居，跳过
# 2024-10-29 19:28:54,956 - INFO - 图斑 110830 没有找到邻居，跳过
# 2024-10-29 19:28:54,956 - INFO - 图斑 111845 没有找到邻居，跳过
# 2024-10-29 19:28:54,956 - INFO - 图斑 120652 没有找到邻居，跳过
# 2024-10-29 19:28:54,956 - INFO - 图斑 127181 没有找到邻居，跳过
# 2024-10-29 19:28:54,972 - INFO - 图斑 128873 没有找到邻居，跳过
# 2024-10-29 19:28:54,976 - INFO - 图斑 129676 没有找到邻居，跳过
# 2024-10-29 19:28:54,978 - INFO - 图斑 129677 没有找到邻居，跳过
# 2024-10-29 19:28:54,979 - INFO - 图斑 133250 没有找到邻居，跳过
# 2024-10-29 19:28:54,979 - INFO - 图斑 133288 没有找到邻居，跳过
# 2024-10-29 19:28:54,979 - INFO - 图斑 133289 没有找到邻居，跳过
# 2024-10-29 19:28:54,986 - INFO - 图斑 133610 没有找到邻居，跳过
# 2024-10-29 19:28:54,989 - INFO - 图斑 133653 没有找到邻居，跳过
# 2024-10-29 19:28:54,992 - INFO - 图斑 134544 没有找到邻居，跳过
# 2024-10-29 19:28:54,994 - INFO - 图斑 135301 没有找到邻居，跳过
# 2024-10-29 19:28:54,994 - INFO - 图斑 135302 没有找到邻居，跳过
# 2024-10-29 19:28:54,994 - INFO - 图斑 135433 没有找到邻居，跳过
# 2024-10-29 19:28:54,994 - INFO - 图斑 135644 没有找到邻居，跳过
# 2024-10-29 19:28:54,994 - INFO - 图斑 136040 没有找到邻居，跳过
# 2024-10-29 19:28:55,004 - INFO - 图斑 136041 没有找到邻居，跳过
# 2024-10-29 19:28:55,005 - INFO - 图斑 137448 没有找到邻居，跳过
# 2024-10-29 19:28:55,005 - INFO - 图斑 137804 没有找到邻居，跳过
# 2024-10-29 19:28:55,005 - INFO - 图斑 138723 没有找到邻居，跳过
# 2024-10-29 19:28:55,005 - INFO - 图斑 140935 没有找到邻居，跳过
# 2024-10-29 19:28:55,005 - INFO - 图斑 143742 没有找到邻居，跳过
# 2024-10-29 19:28:55,005 - INFO - 图斑 144042 没有找到邻居，跳过
# 2024-10-29 19:28:55,020 - INFO - 图斑 151631 没有找到邻居，跳过
# 2024-10-29 19:28:55,022 - INFO - 图斑 151799 没有找到邻居，跳过
# 2024-10-29 19:28:55,024 - INFO - 图斑 151800 没有找到邻居，跳过
# 2024-10-29 19:28:55,025 - INFO - 图斑 151801 没有找到邻居，跳过
# 2024-10-29 19:28:55,025 - INFO - 图斑 151802 没有找到邻居，跳过
# 2024-10-29 19:28:55,025 - INFO - 图斑 151831 没有找到邻居，跳过
# 2024-10-29 19:28:55,025 - INFO - 图斑 151832 没有找到邻居，跳过
# 2024-10-29 19:28:55,025 - INFO - 图斑 151833 没有找到邻居，跳过
# 2024-10-29 19:28:55,025 - INFO - 图斑 151834 没有找到邻居，跳过
# 2024-10-29 19:28:55,036 - INFO - 图斑 151835 没有找到邻居，跳过
# 2024-10-29 19:28:55,038 - INFO - 图斑 151836 没有找到邻居，跳过
# 2024-10-29 19:28:55,043 - INFO - 图斑 151876 没有找到邻居，跳过
# 2024-10-29 19:28:55,045 - INFO - 图斑 151904 没有找到邻居，跳过
# 2024-10-29 19:28:55,045 - INFO - 图斑 151943 没有找到邻居，跳过
# 2024-10-29 19:28:55,045 - INFO - 图斑 151944 没有找到邻居，跳过
# 2024-10-29 19:28:55,045 - INFO - 图斑 151945 没有找到邻居，跳过
# 2024-10-29 19:28:55,045 - INFO - 图斑 151946 没有找到邻居，跳过
# 2024-10-29 19:28:55,055 - INFO - 图斑 152331 没有找到邻居，跳过
# 2024-10-29 19:28:55,056 - INFO - 图斑 152332 没有找到邻居，跳过
# 2024-10-29 19:28:55,056 - INFO - 图斑 152639 没有找到邻居，跳过
# 2024-10-29 19:28:55,056 - INFO - 图斑 152640 没有找到邻居，跳过
# 2024-10-29 19:28:55,056 - INFO - 图斑 152641 没有找到邻居，跳过
# 2024-10-29 19:28:55,056 - INFO - 图斑 152642 没有找到邻居，跳过
# 2024-10-29 19:28:55,056 - INFO - 图斑 152827 没有找到邻居，跳过
# 2024-10-29 19:28:55,071 - INFO - 图斑 152999 没有找到邻居，跳过
# 2024-10-29 19:28:55,075 - INFO - 图斑 153000 没有找到邻居，跳过
# 2024-10-29 19:28:55,075 - INFO - 图斑 153625 没有找到邻居，跳过
# 2024-10-29 19:28:55,075 - INFO - 图斑 153954 没有找到邻居，跳过
# 2024-10-29 19:28:55,075 - INFO - 图斑 153955 没有找到邻居，跳过
# 2024-10-29 19:28:55,075 - INFO - 图斑 154126 没有找到邻居，跳过
# 2024-10-29 19:28:55,075 - INFO - 图斑 154156 没有找到邻居，跳过
# 2024-10-29 19:28:55,086 - INFO - 图斑 154408 没有找到邻居，跳过
# 2024-10-29 19:28:55,088 - INFO - 图斑 155768 没有找到邻居，跳过
# 2024-10-29 19:28:55,089 - INFO - 图斑 155815 没有找到邻居，跳过
# 2024-10-29 19:28:55,089 - INFO - 图斑 155816 没有找到邻居，跳过
# 2024-10-29 19:28:55,089 - INFO - 图斑 155921 没有找到邻居，跳过
# 2024-10-29 19:28:55,089 - INFO - 图斑 159460 没有找到邻居，跳过
# 2024-10-29 19:28:55,089 - INFO - 图斑 161086 没有找到邻居，跳过
# 2024-10-29 19:28:55,089 - INFO - 图斑 161087 没有找到邻居，跳过
# 2024-10-29 19:28:55,103 - INFO - 图斑 170897 没有找到邻居，跳过
# 2024-10-29 19:28:55,105 - INFO - 图斑 171332 没有找到邻居，跳过
# 2024-10-29 19:28:55,105 - INFO - 图斑 171333 没有找到邻居，跳过
# 2024-10-29 19:28:55,105 - INFO - 图斑 171674 没有找到邻居，跳过
# 2024-10-29 19:28:55,121 - INFO - 图斑 172162 没有找到邻居，跳过
# 2024-10-29 19:28:55,122 - INFO - 图斑 172163 没有找到邻居，跳过
# 2024-10-29 19:28:55,122 - INFO - 图斑 172762 没有找到邻居，跳过
# 2024-10-29 19:28:55,122 - INFO - 图斑 172763 没有找到邻居，跳过
# 2024-10-29 19:28:55,138 - INFO - 图斑 173563 没有找到邻居，跳过
# 2024-10-29 19:28:55,142 - INFO - 图斑 173618 没有找到邻居，跳过
# 2024-10-29 19:28:55,142 - INFO - 图斑 174218 没有找到邻居，跳过
# 2024-10-29 19:28:55,142 - INFO - 图斑 175272 没有找到邻居，跳过
# 2024-10-29 19:28:55,142 - INFO - 图斑 175273 没有找到邻居，跳过
# 2024-10-29 19:28:55,153 - INFO - 图斑 177719 没有找到邻居，跳过
# 2024-10-29 19:28:55,155 - INFO - 图斑 177802 没有找到邻居，跳过
# 2024-10-29 19:28:55,157 - INFO - 图斑 178042 没有找到邻居，跳过
# 2024-10-29 19:28:55,159 - INFO - 图斑 178059 没有找到邻居，跳过
# 2024-10-29 19:28:55,159 - INFO - 图斑 178060 没有找到邻居，跳过
# 2024-10-29 19:28:55,159 - INFO - 图斑 179947 没有找到邻居，跳过
# 2024-10-29 19:28:55,159 - INFO - 图斑 181470 没有找到邻居，跳过
# 2024-10-29 19:28:55,159 - INFO - 图斑 181487 没有找到邻居，跳过
# 2024-10-29 19:28:55,171 - INFO - 图斑 181488 没有找到邻居，跳过
# 2024-10-29 19:28:55,173 - INFO - 图斑 182249 没有找到邻居，跳过
# 2024-10-29 19:28:55,173 - INFO - 图斑 182546 没有找到邻居，跳过
# 2024-10-29 19:28:55,173 - INFO - 图斑 185127 没有找到邻居，跳过
# 2024-10-29 19:28:55,173 - INFO - 图斑 188318 没有找到邻居，跳过
# 2024-10-29 19:28:55,173 - INFO - 图斑 189524 没有找到邻居，跳过
# 2024-10-29 19:28:55,187 - INFO - 图斑 204910 没有找到邻居，跳过
# 2024-10-29 19:28:55,187 - INFO - 图斑 204911 没有找到邻居，跳过
# 2024-10-29 19:28:55,187 - INFO - 图斑 204912 没有找到邻居，跳过
# 2024-10-29 19:28:55,187 - INFO - 图斑 204913 没有找到邻居，跳过
# 2024-10-29 19:28:55,187 - INFO - 图斑 204969 没有找到邻居，跳过
# 2024-10-29 19:28:55,187 - INFO - 图斑 204970 没有找到邻居，跳过
# 2024-10-29 19:28:55,187 - INFO - 图斑 205789 没有找到邻居，跳过
# 2024-10-29 19:28:55,187 - INFO - 图斑 207034 没有找到邻居，跳过
# 2024-10-29 19:28:55,187 - INFO - 图斑 207610 没有找到邻居，跳过
# 2024-10-29 19:28:55,206 - INFO - 图斑 207779 没有找到邻居，跳过
# 2024-10-29 19:28:55,208 - INFO - 图斑 207895 没有找到邻居，跳过
# 2024-10-29 19:28:55,208 - INFO - 图斑 208038 没有找到邻居，跳过
# 2024-10-29 19:28:55,208 - INFO - 图斑 208039 没有找到邻居，跳过
# 2024-10-29 19:28:55,223 - INFO - 图斑 208143 没有找到邻居，跳过
# 2024-10-29 19:28:55,223 - INFO - 图斑 208263 没有找到邻居，跳过
# 2024-10-29 19:28:55,223 - INFO - 图斑 208264 没有找到邻居，跳过
# 2024-10-29 19:28:55,223 - INFO - 图斑 208337 没有找到邻居，跳过
# 2024-10-29 19:28:55,223 - INFO - 图斑 210382 没有找到邻居，跳过
# 2024-10-29 19:28:55,236 - INFO - 图斑 210511 没有找到邻居，跳过
# 2024-10-29 19:28:55,238 - INFO - 图斑 232448 没有找到邻居，跳过
# 2024-10-29 19:28:55,239 - INFO - 图斑 234512 没有找到邻居，跳过
# 2024-10-29 19:28:55,239 - INFO - 图斑 234513 没有找到邻居，跳过
# 2024-10-29 19:28:55,239 - INFO - 图斑 235315 没有找到邻居，跳过
# 2024-10-29 19:28:55,239 - INFO - 图斑 236243 没有找到邻居，跳过
# 2024-10-29 19:28:55,239 - INFO - 图斑 236816 没有找到邻居，跳过
# 2024-10-29 19:28:55,239 - INFO - 图斑 238988 没有找到邻居，跳过
# 2024-10-29 19:28:55,239 - INFO - 图斑 238989 没有找到邻居，跳过
# 2024-10-29 19:28:55,239 - INFO - 图斑 239046 没有找到邻居，跳过
# 2024-10-29 19:28:55,253 - INFO - 图斑 239047 没有找到邻居，跳过
# 2024-10-29 19:28:55,255 - INFO - 图斑 239104 没有找到邻居，跳过
# 2024-10-29 19:28:55,255 - INFO - 图斑 239559 没有找到邻居，跳过
# 2024-10-29 19:28:55,255 - INFO - 图斑 239938 没有找到邻居，跳过
# 2024-10-29 19:28:55,255 - INFO - 图斑 240013 没有找到邻居，跳过
# 2024-10-29 19:28:55,255 - INFO - 图斑 240074 没有找到邻居，跳过
# 2024-10-29 19:28:55,255 - INFO - 图斑 240075 没有找到邻居，跳过
# 2024-10-29 19:28:55,255 - INFO - 图斑 241106 没有找到邻居，跳过
# 2024-10-29 19:28:55,255 - INFO - 图斑 242036 没有找到邻居，跳过
# 2024-10-29 19:28:55,271 - INFO - 图斑 242610 没有找到邻居，跳过
# 2024-10-29 19:28:55,274 - INFO - 图斑 243476 没有找到邻居，跳过
# 2024-10-29 19:28:55,276 - INFO - 图斑 243606 没有找到邻居，跳过
# 2024-10-29 19:28:55,276 - INFO - 图斑 243607 没有找到邻居，跳过
# 2024-10-29 19:28:55,276 - INFO - 图斑 243611 没有找到邻居，跳过
# 2024-10-29 19:28:55,276 - INFO - 图斑 243612 没有找到邻居，跳过
# 2024-10-29 19:28:55,287 - INFO - 图斑 243666 没有找到邻居，跳过
# 2024-10-29 19:28:55,288 - INFO - 图斑 243667 没有找到邻居，跳过
# 2024-10-29 19:28:55,288 - INFO - 图斑 244140 没有找到邻居，跳过
# 2024-10-29 19:28:55,288 - INFO - 图斑 244332 没有找到邻居，跳过
# 2024-10-29 19:28:55,288 - INFO - 图斑 244333 没有找到邻居，跳过
# 2024-10-29 19:28:55,288 - INFO - 图斑 250258 没有找到邻居，跳过
# 2024-10-29 19:28:55,303 - INFO - 图斑 250300 没有找到邻居，跳过
# 2024-10-29 19:28:55,305 - INFO - 图斑 250327 没有找到邻居，跳过
# 2024-10-29 19:28:55,307 - INFO - 图斑 250328 没有找到邻居，跳过
# 2024-10-29 19:28:55,307 - INFO - 图斑 250471 没有找到邻居，跳过
# 2024-10-29 19:28:55,307 - INFO - 图斑 250664 没有找到邻居，跳过
# 2024-10-29 19:28:55,307 - INFO - 图斑 250670 没有找到邻居，跳过
# 2024-10-29 19:28:55,307 - INFO - 图斑 250671 没有找到邻居，跳过
# 2024-10-29 19:28:55,307 - INFO - 图斑 251073 没有找到邻居，跳过
# 2024-10-29 19:28:55,320 - INFO - 图斑 251074 没有找到邻居，跳过
# 2024-10-29 19:28:55,322 - INFO - 图斑 251561 没有找到邻居，跳过
# 2024-10-29 19:28:55,325 - INFO - 图斑 251747 没有找到邻居，跳过
# 2024-10-29 19:28:55,325 - INFO - 图斑 252134 没有找到邻居，跳过
# 2024-10-29 19:28:55,325 - INFO - 图斑 252135 没有找到邻居，跳过
# 2024-10-29 19:28:55,325 - INFO - 图斑 252136 没有找到邻居，跳过
# 2024-10-29 19:28:55,325 - INFO - 图斑 252137 没有找到邻居，跳过
# 2024-10-29 19:28:55,325 - INFO - 图斑 252415 没有找到邻居，跳过
# 2024-10-29 19:28:55,325 - INFO - 图斑 252878 没有找到邻居，跳过
# 2024-10-29 19:28:55,337 - INFO - 图斑 252959 没有找到邻居，跳过
# 2024-10-29 19:28:55,339 - INFO - 图斑 252960 没有找到邻居，跳过
# 2024-10-29 19:28:55,339 - INFO - 图斑 253011 没有找到邻居，跳过
# 2024-10-29 19:28:55,339 - INFO - 图斑 253023 没有找到邻居，跳过
# 2024-10-29 19:28:55,339 - INFO - 图斑 253024 没有找到邻居，跳过
# 2024-10-29 19:28:55,339 - INFO - 图斑 253032 没有找到邻居，跳过
# 2024-10-29 19:28:55,339 - INFO - 图斑 253033 没有找到邻居，跳过
# 2024-10-29 19:28:55,339 - INFO - 图斑 261403 没有找到邻居，跳过
# 2024-10-29 19:28:55,339 - INFO - 图斑 261404 没有找到邻居，跳过
# 2024-10-29 19:28:55,353 - INFO - 图斑 261405 没有找到邻居，跳过
# 2024-10-29 19:28:55,354 - INFO - 没有可以合并的图斑，处理结束。
# 2024-10-29 19:28:55,354 - INFO - 处理完成。总共合并 94489 个图斑。
# 2024-10-29 19:28:55,437 - INFO - 最终总面积: 1462965997.4097586
# 2024-10-29 19:28:55,437 - INFO - 总面积变化: -4.76837158203125e-07
# 2024-10-29 19:29:26,752 - INFO - 结果保存为SHP（字段名已截断）: C:\Users\Runker\Desktop\ele_sb\sb_merge_data_single_moudle2.shp
# 2024-10-29 19:29:26,753 - INFO - 总处理时间: 6.63 分钟
# 2024-10-29 19:29:26,753 - INFO - 最终图斑数量: 167492
# 2024-10-29 19:29:26,753 - INFO - 减少的图斑数量: 94489

# %% [markdown]
# # 稳定快速

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
from shapely.ops import unary_union
from shapely.validation import make_valid
from tqdm import tqdm
import time
import logging

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def safe_union(geom1, geom2):
    try:
        union = unary_union([geom1, geom2])
        if not union.is_valid:
            union = make_valid(union)
        return union
    except Exception as e:
        logging.error(f"合并几何形状时出错: {str(e)}")
        return None

def find_neighbors(parcel, gdf):
    try:
        possible_matches_index = list(gdf.sindex.intersection(parcel.geometry.bounds))
        possible_matches = gdf.iloc[possible_matches_index]
        return possible_matches[possible_matches.geometry.touches(parcel.geometry)]
    except Exception as e:
        logging.error(f"在查找邻居时出错: {str(e)}")
        return gpd.GeoDataFrame()

def mark_small_parcels_for_merging(gdf, small_parcels, large_parcels, dldm_field, dlmc_field):
    merge_operations = []
    for index, small_parcel in small_parcels.iterrows():
        neighbors = find_neighbors(small_parcel, large_parcels)
        if neighbors.empty:
            # logging.info(f"图斑 {index} 没有找到邻居，跳过")
            continue
        
        same_dlmc_neighbors = neighbors[neighbors[dlmc_field] == small_parcel[dlmc_field]]
        if not same_dlmc_neighbors.empty:
            target = same_dlmc_neighbors.loc[same_dlmc_neighbors['area'].idxmax()]
        else:
            continue  # 只合并相同 DLMC 的图斑
        
        merge_operations.append((index, target.name))
    
    return merge_operations

def execute_merges(gdf, merge_operations):
    merged_count = 0
    skipped_count = 0
    
    gdf['to_delete'] = False
    
    for small_index, large_index in tqdm(merge_operations, desc="执行合并操作"):
        if small_index not in gdf.index or large_index not in gdf.index:
            skipped_count += 1
            logging.info(f"跳过合并操作：小图斑 {small_index} 或大图斑 {large_index} 不在索引中")
            continue
        
        small_geom = gdf.loc[small_index, 'geometry']
        large_geom = gdf.loc[large_index, 'geometry']
        
        new_geometry = safe_union(small_geom, large_geom)
        
        if new_geometry is None:
            skipped_count += 1
            logging.info(f"跳过合并操作：无法合并图斑 {small_index} 和 {large_index}")
            continue
        
        gdf.loc[large_index, 'geometry'] = new_geometry
        gdf.loc[large_index, 'area'] = new_geometry.area
        gdf.loc[small_index, 'to_delete'] = True
        
        merged_count += 1
    
    gdf = gdf[~gdf['to_delete']]
    gdf = gdf.drop(columns=['to_delete'])
    
    logging.info(f"合并了 {merged_count} 个图斑，跳过了 {skipped_count} 个图斑")
    
    return gdf, merged_count

def merge_small_parcels(input_shp, output_base, dldm_field, dlmc_field, thresholds, default_threshold=50, max_iterations=10):
    start_time = time.time()
    logging.info(f"开始处理。输入Shapefile: {input_shp}")
    
    try:
        gdf = gpd.read_file(input_shp)
    except Exception as e:
        logging.error(f"读取shapefile时出错: {str(e)}")
        return
    
    original_crs = gdf.crs
    original_count = len(gdf)
    original_area = gdf.geometry.area.sum()
    logging.info(f"读取了 {original_count} 个图斑，总面积: {original_area}")
    logging.info(f"原始坐标系统: {original_crs}")
    
    logging.info("正在将多部件要素转换为单部件...")
    gdf = gdf.explode(index_parts=True).reset_index(drop=True)
    logging.info(f"转换后共有 {len(gdf)} 个图斑")
    
    iteration = 0
    total_merged = 0
    
    while iteration < max_iterations:
        iteration += 1
        logging.info(f"开始第 {iteration} 轮处理")
        
        gdf['area'] = gdf.geometry.area
        
        def get_threshold(row):
            dldm = row[dldm_field]
            return thresholds.get(dldm, default_threshold)
        
        gdf['threshold'] = gdf.apply(get_threshold, axis=1)
        small_parcels = gdf[gdf['area'] < gdf['threshold']]
        large_parcels = gdf[gdf['area'] >= gdf['threshold']]
        
        logging.info(f"小面积图斑数量: {len(small_parcels)}, 大面积图斑数量: {len(large_parcels)}")
        logging.info(f"小面积图斑DLDM分布: {small_parcels[dldm_field].value_counts().to_dict()}")
        
        if len(small_parcels) == 0:
            logging.info("没有找到小面积图斑，处理结束。")
            break
        
        merge_operations = mark_small_parcels_for_merging(gdf, small_parcels, large_parcels, dldm_field, dlmc_field)
        
        if not merge_operations:
            logging.info("没有可以合并的图斑，处理结束。")
            break
        
        gdf, merged_count = execute_merges(gdf, merge_operations)
        
        total_merged += merged_count
        
        current_area = gdf.geometry.area.sum()
        logging.info(f"第 {iteration} 轮处理完成。本轮合并 {merged_count} 个图斑。当前总面积: {current_area}")
        
        if merged_count == 0:
            logging.info("没有更多图斑可以合并，处理结束。")
            break
    
    logging.info(f"处理完成。总共合并 {total_merged} 个图斑。")
    
    final_area = gdf.geometry.area.sum()
    logging.info(f"最终总面积: {final_area}")
    logging.info(f"总面积变化: {final_area - original_area}")
    
    # 确保坐标系统不变
    gdf = gdf.set_crs(original_crs, allow_override=True)
    
    # 保存结果到SHP（截断字段名）
    output_shp = f"{output_base}.shp"
    result_truncated = gdf.rename(columns={col: col[:10] for col in gdf.columns if len(col) > 10})
    result_truncated.to_file(output_shp, encoding='utf-8')
    logging.info(f"结果保存为SHP（字段名已截断）: {output_shp}")
    
    end_time = time.time()
    logging.info(f"总处理时间: {(end_time - start_time) / 60:.2f} 分钟")
    logging.info(f"最终图斑数量: {len(gdf)}")
    logging.info(f"减少的图斑数量: {original_count - len(gdf)}")

# 使用示例
input_shp = r"C:\Users\Runker\Desktop\ele_sb\sb_merge_data_single_result.shp"
output_base = r"C:\Users\Runker\Desktop\ele_sb\sb_merge_data_single_result_2"
dldm_field = "DLDM"
dlmc_field = "DLMC"
thresholds = {"01": 50, "02": 50, "03": 50, "04": 50}
default_threshold = 50  # 为未指定的DLDM类型设置默认阈值

merge_small_parcels(input_shp, output_base, dldm_field, dlmc_field, thresholds, default_threshold)
# Out:
# 2024-10-29 19:19:18,966 - INFO - 开始处理。输入Shapefile: C:\Users\Runker\Desktop\ele_sb\sb_merge_data_single_result.shp
# 2024-10-29 19:19:50,962 - INFO - 读取了 191827 个图斑，总面积: 1462965997.4097588
# 2024-10-29 19:19:50,962 - INFO - 原始坐标系统: EPSG:4545
# 2024-10-29 19:19:50,962 - INFO - 正在将多部件要素转换为单部件...
# 2024-10-29 19:19:51,924 - INFO - 转换后共有 193172 个图斑
# 2024-10-29 19:19:51,924 - INFO - 开始第 1 轮处理
# 2024-10-29 19:19:52,597 - INFO - 小面积图斑数量: 1075, 大面积图斑数量: 192097
# 2024-10-29 19:19:52,597 - INFO - 小面积图斑DLDM分布: {'01': 560, '03': 480, '02': 19, '04': 9, '12': 7}
# 执行合并操作: 100%|██████████| 1065/1065 [00:00<00:00, 1479.76it/s]
# 2024-10-29 19:19:55,999 - INFO - 合并了 1065 个图斑，跳过了 0 个图斑
# 2024-10-29 19:19:56,079 - INFO - 第 1 轮处理完成。本轮合并 1065 个图斑。当前总面积: 1462965997.4097586
# 2024-10-29 19:19:56,079 - INFO - 开始第 2 轮处理
# 2024-10-29 19:19:56,748 - INFO - 小面积图斑数量: 10, 大面积图斑数量: 192097
# 2024-10-29 19:19:56,748 - INFO - 小面积图斑DLDM分布: {'01': 5, '12': 4, '03': 1}
# 执行合并操作: 100%|██████████| 1/1 [00:00<00:00, 346.49it/s]
# 2024-10-29 19:19:56,880 - INFO - 合并了 1 个图斑，跳过了 0 个图斑
# 2024-10-29 19:19:56,964 - INFO - 第 2 轮处理完成。本轮合并 1 个图斑。当前总面积: 1462965997.4097583
# 2024-10-29 19:19:56,964 - INFO - 开始第 3 轮处理
# 2024-10-29 19:19:57,629 - INFO - 小面积图斑数量: 9, 大面积图斑数量: 192097
# 2024-10-29 19:19:57,629 - INFO - 小面积图斑DLDM分布: {'01': 5, '12': 4}
# 2024-10-29 19:19:57,698 - INFO - 没有可以合并的图斑，处理结束。
# 2024-10-29 19:19:57,698 - INFO - 处理完成。总共合并 1066 个图斑。
# 2024-10-29 19:19:57,778 - INFO - 最终总面积: 1462965997.4097583
# 2024-10-29 19:19:57,778 - INFO - 总面积变化: -4.76837158203125e-07
# 2024-10-29 19:20:23,078 - INFO - 结果保存为SHP（字段名已截断）: C:\Users\Runker\Desktop\ele_sb\sb_merge_data_single_result_2.shp
# 2024-10-29 19:20:23,078 - INFO - 总处理时间: 1.07 分钟
# 2024-10-29 19:20:23,078 - INFO - 最终图斑数量: 192106
# 2024-10-29 19:20:23,078 - INFO - 减少的图斑数量: -279
