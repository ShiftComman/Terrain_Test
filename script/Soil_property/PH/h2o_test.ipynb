# %%
import h2o
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csv_path = r'D:\ArcgisData\pred_ph\feature_table_result\feature_table_result_all1.csv'

# %%
# 读取数据
data = pd.read_csv(r'D:\ArcgisData\pred_ph\feature_table_result\feature_table_result_all1.csv')
print(len(data))
# 删除有缺失值的行
data.dropna(inplace=True)
len(data),data.columns
# Out:
# 7493
# (7489,
#  Index(['PH', 'LON', 'LAT', 'TWI5', 'TPI201', 'TPI101', 'TPI11', 'TPI3', 'TMP',
#         'SOILQS', 'SLOP', 'PRE', 'NIGTH', 'NDVI', 'DEM', 'CUR', 'ASP', 'PLCUR',
#         'POCUR', 'PH.1', 'DL', 'SC2', 'OSJL', 'SOM', 'DZ'],
#        dtype='object'))

# %%
# features = ['TWI5', 'TPI201', 'TPI101', 'TPI11', 'TPI3', 'TMP', 'SOILQS','SLOP', 'PRE', 'NIGTH', 'NDVI', 'DEM', 'CUR', 'ASP', 'PLCUR', 'POCUR','LON', 'LAT',  'DL', 'SC2', 'OSJL', 'DZ','PH']
features = ['TWI5', 'TPI201', 'TPI101', 'TPI11', 'TPI3', 'TMP','SLOP', 'PRE', 'NIGTH', 'NDVI', 'DEM', 'CUR', 'ASP', 'PLCUR', 'POCUR','LON', 'LAT', 'OSJL','DZ', 'PH']

# %%
data = data[features]
data
# Out:
#           TWI5     TPI201     TPI101     TPI11      TPI3        TMP  \
# 0     6.863755  -5.770264   3.639526 -0.528686 -0.033447  142.08333
# 1     5.269061 -29.284790 -11.368164 -0.298706 -0.006470  137.25000
# 2     7.422158 -24.041382 -44.247437 -0.945496 -0.034363  155.08333
# 3     6.672807 -28.773560  -6.647278 -0.071838 -0.004578  157.41667
# 4     6.186606 -11.460632 -18.309082 -0.400146 -0.032593  151.16667
# ...        ...        ...        ...       ...       ...        ...
# 7488  5.343458  17.034668   2.106323 -0.224121 -0.005371  144.66667
# 7489  6.946837 -52.834167 -32.650635 -3.176880 -0.284668  149.41667
# 7490  4.052505 -71.056460 -47.384644 -1.769226 -0.180542  151.33333
# 7491  8.194191 -50.687256 -27.609863 -0.879150 -0.066467  147.91667
# 7492  7.020891 -63.315796 -41.342530 -0.308472 -0.025452  153.33333
#
#            SLOP       PRE  NIGTH    NDVI     DEM        CUR         ASP  \
# 0      6.067848  873.1667   0.21  1772.0  1222.4  -0.399414  311.184540
# 1     11.214284  837.5000   0.36    94.0  1240.6  -2.400391   41.932870
# 2      6.959332  852.2500   0.34   349.0   992.1  -1.200440  325.007700
# 3      3.237762  807.6667   0.63  5088.0   908.1  -1.600586  315.000000
# 4     17.349290  820.4167   0.31  5231.0   992.8  -0.400146  309.806030
# ...         ...       ...    ...     ...     ...        ...         ...
# 7488   5.419226  849.5000   0.25  4974.0  1078.6  -2.000488  341.567380
# 7489   9.301414  845.5833   0.24  6388.0   911.6 -10.400391  121.263115
# 7490  21.019365  845.5833   0.22  6017.0   825.7  -8.799805  122.242320
# 7491   5.544981  851.0833   0.27  5952.0   877.0   0.799805  101.886760
# 7492   8.467508  840.0000   0.25  6669.0   790.7   0.000244  310.913730
#
#          PLCUR     POCUR       LON        LAT        OSJL  DZ    PH
# 0    -0.120092  0.279322  415805.0  3149160.0   80.156100   6  4.78
# 1    -1.300171  1.100220  402330.0  3124690.0  101.242290   6  4.34
# 2    -0.719673  0.480766  443815.0  3123235.0  134.629120   6  5.83
# 3    -0.800354  0.800232  407765.0  3082835.0   82.764725   7  7.30
# 4    -1.002323 -0.602177  401890.0  3119625.0   53.150730   7  4.12
# ...        ...       ...       ...        ...         ...  ..   ...
# 7488 -2.283018 -0.282530  445835.0  3099670.0   10.000000   4  6.30
# 7489 -3.087831  7.312560  446180.0  3104585.0    7.071068   7  6.90
# 7490 -2.345092  6.454713  446220.0  3106340.0    7.071068   7  7.03
# 7491  0.030771 -0.769034  446335.0  3108340.0   15.811388   7  7.25
# 7492  0.150935  0.150690  444900.0  3105215.0   18.027756   7  6.73
#
# [7489 rows x 20 columns]
